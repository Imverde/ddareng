# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '서울특별시 공공자전거 대여이력 정보_2023'
df_2023 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 124.19851899147034

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '서울특별시 공공자전거 대여이력 정보_2022'
df_2022 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 58.05129551887512

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '서울특별시 공공자전거 대여이력 정보_2021'
df_2021 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 95.74791717529297

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '서울특별시 공공자전거 대여이력 정보_2024'
df_2024 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 21.345508337020874

# %%
df_2021
# Out:
#               자전거번호 대여대여소번호   대여대여소명 대여거치대 반납대여소번호           반납대여소명  반납거치대  \
# 0         SPB-53145   00003     중랑센터     0   00668     서울축산농협(장안지점)      0
# 1         SPB-53074   00003     중랑센터     0   00668     서울축산농협(장안지점)      0
# 2         SPB-50952   00003     중랑센터     0   00668     서울축산농협(장안지점)      0
# 3         SPB-52380   00003     중랑센터     0   00668     서울축산농협(장안지점)      0
# 4         SPB-52380   00003     중랑센터     0   00540  군자역 7번출구 베스트샵 앞      0
# ...             ...     ...      ...   ...     ...              ...    ...
# 30788783  SPB-51882   09999     상담센터     0   00346           맥스타일 앞      0
# 30788784  SPB-51134   09999     상담센터     0   01986          태평양물산빌딩      0
# 30788785  SPB-37732   09999     상담센터     0   00188      홍은동 정원여중 입구      0
# 30788786  SPB-51854   88888     영남배송     0   00236       문래동자이아파트 앞      0
# 30788787  SPB-53564   99999  영남단말기정비     0   09998       영남주차장 정비센터      0
#
#           이용시간(분)  이용거리(M)        대여일자      대여시간        반납일자      반납시간
# 0            25.0     0.00  2021-01-02  20:50:36  2021-01-02  21:15:41
# 1            14.0     0.00  2021-01-04  16:02:12  2021-01-04  16:17:06
# 2            11.0  1853.99  2021-01-13  21:02:05  2021-01-13  21:14:04
# 3            10.0     0.00  2021-01-14  21:02:55  2021-01-14  21:13:41
# 4            13.0  2291.05  2021-01-18  18:02:08  2021-01-18  18:15:22
# ...           ...      ...         ...       ...         ...       ...
# 30788783     12.0     0.00  2021-12-30  09:39:45  2021-12-30  09:52:44
# 30788784      3.0     0.00  2021-12-30  18:55:31  2021-12-30  18:59:04
# 30788785      3.0   345.45  2021-12-30  21:12:40  2021-12-30  21:15:54
# 30788786     17.0     0.00  2021-12-22  09:46:16  2021-12-22  10:03:24
# 30788787      1.0     0.00  2021-12-22  14:38:04  2021-12-22  14:39:29
#
# [30788788 rows x 13 columns]

# %%
df_2021['자전거번호'].unique
# Out:
# <bound method Series.unique of 0           SPB-53145
# 1           SPB-53074
# 2           SPB-50952
# 3           SPB-52380
# 4           SPB-52380
#               ...
# 30788783    SPB-51882
# 30788784    SPB-51134
# 30788785    SPB-37732
# 30788786    SPB-51854
# 30788787    SPB-53564
# Name: 자전거번호, Length: 30788788, dtype: object>

# %%
df_2021['자전거번호'].max()
# Out:
# 'SPB-84252'

# %%
df_2021['자전거번호'].min()
# Out:
# 'SPB-00025'

# %%
df_2022
# Out:
#               자전거번호 대여대여소번호               대여대여소명  대여거치대 반납대여소번호  \
# 0         SPB-33633   00003                 중랑센터      0   00540
# 1         SPB-49457   00003                 중랑센터      0   00003
# 2         SPB-32344   00003                 중랑센터      0   00529
# 3         SPB-50724   00003                 중랑센터      0   00529
# 4         SPB-34117   00003                 중랑센터      0   00529
# ...             ...     ...                  ...    ...     ...
# 41591727  SPB-30272   01906         신도림역 1번 출구 앞      0   01906
# 41591728  SPB-65828   05858             영등포역5번출구      0    None
# 41591729  SPB-33852   02635           잠실새내역 1번출구      0    None
# 41591730  SPB-55558   02325        대치삼성아파트 앞 교차로      0    None
# 41591731  SPB-42935   02423  영희초교 사거리(래미안개포루체하임)      0    None
#
#                    반납대여소명 반납거치대  이용시간(분)   이용거리(M)        대여일자      대여시간  \
# 0         군자역 7번출구 베스트샵 앞     0       11   2419.63  2022-01-02  16:02:42
# 1                    중랑센터     0       10      0.00  2022-01-06  08:09:11
# 2            장한평역 8번 출구 앞     0       11   1081.14  2022-01-11  17:53:40
# 3            장한평역 8번 출구 앞     0        5      0.00  2022-01-17  16:02:21
# 4            장한평역 8번 출구 앞     0        8   1121.03  2022-01-17  17:57:28
# ...                   ...   ...      ...       ...         ...       ...
# 41591727     신도림역 1번 출구 앞     0     2210  25001.78  2022-12-31  19:48:21
# 41591728             None  None      810      0.00  2022-12-31  11:59:43
# 41591729             None  None      810      0.00  2022-12-31  21:56:32
# 41591730             None  None      810      0.00  2022-12-31  22:30:52
# 41591731             None  None      810      0.00  2022-12-31  23:33:22
#
#                 반납일자      반납시간
# 0         2022-01-02  16:14:14
# 1         2022-01-06  08:19:43
# 2         2022-01-11  18:05:07
# 3         2022-01-17  16:07:28
# 4         2022-01-17  18:06:03
# ...              ...       ...
# 41591727  2023-01-02  08:38:53
# 41591728  2023-01-03  12:57:29
# 41591729  2023-01-03  12:58:19
# 41591730  2023-01-03  12:59:26
# 41591731  2023-01-03  12:59:40
#
# [41591732 rows x 13 columns]

# %%
df_2022['자전거번호'].unique
# Out:
# <bound method Series.unique of 0           SPB-33633
# 1           SPB-49457
# 2           SPB-32344
# 3           SPB-50724
# 4           SPB-34117
#               ...
# 41591727    SPB-30272
# 41591728    SPB-65828
# 41591729    SPB-33852
# 41591730    SPB-55558
# 41591731    SPB-42935
# Name: 자전거번호, Length: 41591732, dtype: object>

# %%
df_2022['자전거번호'].min()
# Out:
# 'SPB-30001'

# %%
df_2022['자전거번호'].max()
# Out:
# 'SPB-85000'

# %%
df_2023
# Out:
#               자전거번호 대여대여소번호              대여대여소명  대여거치대 반납대여소번호  \
# 0         SPB-39194   01554               번동사거리      0   01554
# 1         SPB-43457   01653             노원역1번출구      0   04003
# 2         SPB-44383   02601           석촌호수 아뜰리에      0   02601
# 3         SPB-37186   01080                 엘웨딩      0   03668
# 4         SPB-59440   01351              안암2교 옆      0   01308
# ...             ...     ...                 ...    ...     ...
# 46388218  SPB-38867   02539  대한무역투자진흥공사 KOTRA 앞      0    None
# 46388219  SPB-46265   00130     신촌역(2호선) 7번출구 앞      0   03116
# 46388220  SPB-53462   05768               방이삼거리      0    None
# 46388221  SPB-80495   00451               청와대앞길     99    None
# 46388222  SPB-67494   02704           홈플러스(강서점)      0    None
#
#                       반납대여소명 반납거치대  이용시간(분)  이용거리(M)        대여일자      대여시간  \
# 0                      번동사거리     0        0      0.0  2023-01-01  00:02:13
# 1         상계초교 입구 교차로 명주빌딩 앞     0        2      0.0  2023-01-01  00:01:20
# 2                  석촌호수 아뜰리에     0        0      0.0  2023-01-01  00:04:01
# 3                    성내삼성아파트     0        2      0.0  2023-01-01  00:02:09
# 4              안암로터리 버스정류장 앞     0        2    780.0  2023-01-01  00:02:24
# ...                      ...   ...      ...      ...         ...       ...
# 46388218                None  None      870  27141.0  2023-12-31  02:37:11
# 46388219            신촌역 4번출구     0     1467    610.0  2023-12-31  18:58:56
# 46388220                None  None      810  14330.0  2023-12-31  15:42:28
# 46388221                None  None       60    444.0  2023-12-31  16:55:41
# 46388222                None  None      810  11621.0  2023-12-31  21:40:32
#
#                 반납일자      반납시간
# 0         2023-01-01  00:02:43
# 1         2023-01-01  00:03:28
# 2         2023-01-01  00:04:21
# 3         2023-01-01  00:04:59
# 4         2023-01-01  00:05:02
# ...              ...       ...
# 46388218  2024-01-01  14:50:58
# 46388219  2024-01-01  19:26:40
# 46388220  2024-01-02  13:02:35
# 46388221  2024-01-02  13:03:23
# 46388222  2024-01-02  13:04:14
#
# [46388223 rows x 13 columns]

# %%
df_2023['자전거번호'].unique
# Out:
# <bound method Series.unique of 0           SPB-39194
# 1           SPB-43457
# 2           SPB-44383
# 3           SPB-37186
# 4           SPB-59440
#               ...
# 46388218    SPB-38867
# 46388219    SPB-46265
# 46388220    SPB-53462
# 46388221    SPB-80495
# 46388222    SPB-67494
# Name: 자전거번호, Length: 46388223, dtype: object>

# %%
df_2023['자전거번호'].min()
# Out:
# 'SPB-30001'

# %%
df_2023['자전거번호'].max()
# Out:
# 'SPB-85000'

# %%
df_2024
# Out:
#               자전거번호 대여대여소번호           대여대여소명  대여거치대 반납대여소번호         반납대여소명  \
# 0         SPB-46712   04804          동서울농협 앞      0   01416       상봉역 3번출구
# 1         SPB-35089   04169           신대방삼거리      0   00251  서울지방병무청 버스정류장
# 2         SPB-36386   00540  군자역 7번출구 베스트샵 앞      0   03509       세종사이버대학교
# 3         SPB-61278   01139        용문사 버스정류장      0   00701       목동사거리 부근
# 4         SPB-36848   03416        동묘앞역 6번출구      0   00346         맥스타일 앞
# ...             ...     ...              ...    ...     ...            ...
# 22107536  SPB-52120   00334     종로3가역 2번출구 뒤      0    None           None
# 22107537  SPB-57512   04217       한강공원 망원나들목      0    None           None
# 22107538  SPB-50402   03569           건대병원후문      0    None           None
# 22107539  SPB-56869   02547       반포래미안 리오센트      0    None           None
# 22107540  SPB-45157   02255     양재시민의숲역 1번출구      0    None           None
#
#          반납거치대  이용시간(분)   이용거리(M)        대여일자      대여시간        반납일자      반납시간
# 0            0        1      0.00  2024-01-01  00:04:10  2024-01-01  00:05:13
# 1            0        6   1147.58  2024-01-01  00:00:10  2024-01-01  00:06:23
# 2            0        3    642.13  2024-01-01  00:03:13  2024-01-01  00:06:33
# 3            0        4    830.00  2024-01-01  00:02:42  2024-01-01  00:07:24
# 4            0        4    791.08  2024-01-01  00:03:02  2024-01-01  00:07:33
# ...        ...      ...       ...         ...       ...         ...       ...
# 22107536  None       60   4348.00  2024-06-30  22:42:25  2024-07-02  11:24:51
# 22107537  None       60  32253.00  2024-06-30  21:46:13  2024-07-02  11:25:54
# 22107538  None      870    848.00  2024-06-30  23:57:41  2024-07-02  13:00:21
# 22107539  None      870   2119.00  2024-06-30  18:35:04  2024-07-02  13:00:59
# 22107540  None      870      0.00  2024-06-30  08:03:43  2024-07-02  13:01:37
#
# [22107541 rows x 13 columns]

# %%
df_2024['자전거번호'].unique
# Out:
# <bound method Series.unique of 0           SPB-46712
# 1           SPB-35089
# 2           SPB-36386
# 3           SPB-61278
# 4           SPB-36848
#               ...
# 22107536    SPB-52120
# 22107537    SPB-57512
# 22107538    SPB-50402
# 22107539    SPB-56869
# 22107540    SPB-45157
# Name: 자전거번호, Length: 22107541, dtype: object>

# %%
df_2024['자전거번호'].min()
# Out:
# 'SPB-30001'

# %%
df_2024['자전거번호'].max()
# Out:
# 'SPB-85000'
