# %%
_year='2023'

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'
filename = '서울특별시 공공자전거 대여소별 이용정보(시간대별)_' + _year + '.parquet'
start_time = time.time()
df_2024 = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df_2024.head(5)
# Out:
# read_parquet time : 10.880874156951904
#          대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0  2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1  2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2  2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3  2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4  2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#       운동량   탄소량  이동거리(M)  이용시간(분)
# 0   44.24  0.42  1831.45      8.0
# 1    7.11  0.06   276.06      4.0
# 2   25.05  0.24  1020.46      7.0
# 3   34.05  0.20   859.74      4.0
# 4  141.49  1.31  5675.10     78.0

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2024)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  39993697             0          0.000000
# 1      대여시간  39993697             0          0.000000
# 2     대여소번호  39993697             0          0.000000
# 3      대여소명  39993697             0          0.000000
# 4    대여구분코드  39993697             0          0.000000
# 5        성별  27853187      12140510         30.356058
# 6     연령대코드  39993697             0          0.000000
# 7      이용건수  39993697             0          0.000000
# 8       운동량  39848716        144981          0.362510
# 9       탄소량  39848716        144981          0.362510
# 10  이동거리(M)  39993697             0          0.000000
# 11  이용시간(분)  39993697             0          0.000000

# %%
df_2024.head()
# Out:
#          대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0  2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1  2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2  2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3  2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4  2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#       운동량   탄소량  이동거리(M)  이용시간(분)
# 0   44.24  0.42  1831.45      8.0
# 1    7.11  0.06   276.06      4.0
# 2   25.05  0.24  1020.46      7.0
# 3   34.05  0.20   859.74      4.0
# 4  141.49  1.31  5675.10     78.0

# %%
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39993697 entries, 0 to 39993696
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 3.6+ GB

# %%
pd.options.display.float_format = '{:3}'.format

# %%
df_2024.shape
# Out:
# (39993697, 12)

# %%
df_2024.isnull().sum()
# Out:
# 대여일자              0
# 대여시간              0
# 대여소번호             0
# 대여소명              0
# 대여구분코드            0
# 성별         12140510
# 연령대코드             0
# 이용건수              0
# 운동량          144981
# 탄소량          144981
# 이동거리(M)           0
# 이용시간(분)           0
# dtype: int64

# %%
df_2024['대여시간'].value_counts()
# Out:
# 대여시간
# 18    3682252
# 17    3127036
# 8     2727067
# 19    2720692
# 16    2464183
# 20    2332242
# 21    2124363
# 15    2032202
# 7     1924402
# 14    1820087
# 22    1798498
# 13    1783497
# 12    1774547
# 9     1734464
# 11    1606910
# 10    1408992
# 23    1195675
# 0      905703
# 6      864106
# 1      624178
# 5      415190
# 2      412158
# 3      283384
# 4      231869
# Name: count, dtype: int64

# %% [markdown]
# ## 1. 가설 1) 따릉이 최다 사용량이 출퇴근 시간이고

# %% [markdown]
# ### - 최다 사용량이 출퇴근 시간인 것을 확인한다.

# %% [markdown]
# - 대여일자 컬럼을 datetime 형식으로 변환

# %%
df_2024['대여일자'] = pd.to_datetime(df_2024['대여일자'], format='%Y-%m-%d')
# df_2020['대여시간'].astype('datetime64[ns]')

# %%
print(df_2024['대여일자'].dtype)
# Out:
# datetime64[ns]

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)
# 0  44.24 0.42  1831.45      8.0
# 1   7.11 0.06   276.06      4.0
# 2  25.05 0.24  1020.46      7.0
# 3  34.05  0.2   859.74      4.0
# 4 141.49 1.31   5675.1     78.0

# %% [markdown]
# - datetime 형식으로 변경된 '대여일자' 컬럼에서 요일을 추출하여 새로운 컬럼으로 저장

# %%
# dt.weekday : 요일 정보를 숫자로 추출 
# 0 : 월요일, 1 : 화요일, .... 6 : 일요일
df_2024['요일_인덱스'] = df_2024['대여일자'].dt.weekday

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스
# 0  44.24 0.42  1831.45      8.0       6
# 1   7.11 0.06   276.06      4.0       6
# 2  25.05 0.24  1020.46      7.0       6
# 3  34.05  0.2   859.74      4.0       6
# 4 141.49 1.31   5675.1     78.0       6

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df_2024['요일'] = df_2024.apply(lambda x : weekday_list[x['요일_인덱스']], axis=1)

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0  44.24 0.42  1831.45      8.0       6  일
# 1   7.11 0.06   276.06      4.0       6  일
# 2  25.05 0.24  1020.46      7.0       6  일
# 3  34.05  0.2   859.74      4.0       6  일
# 4 141.49 1.31   5675.1     78.0       6  일

# %%
df_2024[['요일', '대여시간']].value_counts(ascending=False)
# Out:
# 요일  대여시간
# 월   18      618107
# 수   18      601533
# 금   18      601238
# 화   18      592667
# 목   18      578621
#              ...
# 금   4        33380
# 화   4        32805
# 수   4        31363
# 월   3        29581
#     4        27754
# Name: count, Length: 168, dtype: int64

# %%
grounded = df_2024.groupby(['요일', '대여시간'])['이용건수'].sum().unstack()
grounded
# Out:
# 대여시간       0        1       2       3       4       5        6        7   \
# 요일
# 금    133759.0  91370.0 58584.0 40473.0 34142.0 65184.0 149673.0 383018.0
# 목    138914.0  95226.0 61324.0 40483.0 34610.0 71762.0 167307.0 415710.0
# 수    125810.0  85411.0 54714.0 37436.0 32025.0 68881.0 159854.0 416491.0
# 월    113619.0  68251.0 43538.0 30628.0 28378.0 65437.0 147722.0 368782.0
# 일    164416.0 108103.0 74820.0 50532.0 34771.0 34601.0  50854.0  78422.0
# 토    168175.0 125231.0 84219.0 56174.0 40393.0 47108.0  72342.0 113097.0
# 화    129960.0  86778.0 54493.0 38032.0 33570.0 73350.0 167320.0 416929.0
#
# 대여시간       8        9   ...       14       15       16       17       18  \
# 요일                      ...
# 금    576630.0 299526.0  ... 281298.0 335632.0 416171.0 586130.0 725387.0
# 목    595936.0 291979.0  ... 242821.0 277273.0 384196.0 539849.0 707951.0
# 수    628777.0 313675.0  ... 256092.0 294530.0 374328.0 546919.0 738234.0
# 월    531899.0 281485.0  ... 274536.0 319727.0 409248.0 577403.0 761672.0
# 일    128723.0 171201.0  ... 341366.0 381037.0 411223.0 425629.0 393399.0
# 토    190351.0 230198.0  ... 335232.0 358759.0 391964.0 408463.0 386847.0
# 화    599403.0 301112.0  ... 247679.0 277433.0 389282.0 550542.0 726578.0
#
# 대여시간       19       20       21       22       23
# 요일
# 금    473031.0 381962.0 352154.0 318463.0 212500.0
# 목    470653.0 390103.0 360875.0 311691.0 190628.0
# 수    486130.0 406863.0 375600.0 317952.0 196196.0
# 월    511342.0 424148.0 372342.0 305594.0 184183.0
# 일    338286.0 306296.0 276997.0 222208.0 155586.0
# 토    339279.0 316457.0 302855.0 258765.0 193191.0
# 화    487007.0 407889.0 361114.0 299060.0 179339.0
#
# [7 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 요일 순서 정의
day_order = ['일', '토', '금', '목', '수', '화', '월']

# 데이터프레임 재정렬
grounded_sorted = grounded.reindex(day_order)

# 히트맵 그리기
plt.figure(figsize=(10, 6))
sns.heatmap(grounded_sorted, annot=False, cmap='Greens', cbar_kws={'label': '이용건수'}, linewidths=1)

# 제목 및 축 레이블 설정
plt.title('요일 및 대여시간별 이용건수', fontsize=16)
plt.xlabel('대여시간', fontsize=12)
plt.ylabel('요일', fontsize=12)

# 그래프 표시
plt.tight_layout()
plt.show()

# %%
# 요일 순서 정의
weekday_order = ['월', '화', '수', '목', '금', '토', '일']

plt.figure(figsize=(10,6))
sns.lineplot(x='대여시간', y='이용건수', hue='요일', data=df_2024, marker='o', hue_order=weekday_order)
plt.title(_year + '년 대여시간에 따른 요일별 이용건수')
plt.xticks(range(0,24))
plt.xlabel('대여시간')
plt.ylabel('이용건수')
plt.show()

# %% [markdown]
# ## 2. 가설 2) 출퇴근 시간에 따릉이 대여량이 최다인 대여소는 지하철역 인근 대여소일 것이다.

# %% [markdown]
# ### - 출퇴근 시간 대여소별 사용량 확인

# %% [markdown]
# - 요일 : 월~금요일 추출한다.

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0  44.24 0.42  1831.45      8.0       6  일
# 1   7.11 0.06   276.06      4.0       6  일
# 2  25.05 0.24  1020.46      7.0       6  일
# 3  34.05  0.2   859.74      4.0       6  일
# 4 141.49 1.31   5675.1     78.0       6  일

# %%
df_2024.count()
# Out:
# 대여일자       39993697
# 대여시간       39993697
# 대여소번호      39993697
# 대여소명       39993697
# 대여구분코드     39993697
# 성별         27853187
# 연령대코드      39993697
# 이용건수       39993697
# 운동량        39848716
# 탄소량        39848716
# 이동거리(M)    39993697
# 이용시간(분)    39993697
# 요일_인덱스     39993697
# 요일         39993697
# dtype: int64

# %%
df_2024_day = df_2024[~(df_2024['요일'].isin(['토', '일']))]
df_2024_day
# Out:
#                대여일자  대여시간  대여소번호                   대여소명 대여구분코드    성별 연령대코드  \
# 36119    2023-01-02     0    954       954. 은평뉴타운구파발9단지    정기권  None  ~10대
# 36120    2023-01-02     0   1743  1743.창동19단지아파트 관리사무소앞    정기권  None  ~10대
# 36121    2023-01-02     0   3558     3558.마장동 금호어울림APT앞    정기권  None  ~10대
# 36122    2023-01-02     0   3904          3904. 테크노마트 앞    정기권  None  ~10대
# 36123    2023-01-02     0   3798     3798. 그랜드아이파크아파트 앞    정기권  None  ~10대
# ...             ...   ...    ...                    ...    ...   ...   ...
# 39950727 2023-12-29    23   1637   1637. KT 전화국 버스정류장 옆    정기권     M    기타
# 39950728 2023-12-29    23   1908      1908. 해원리바파크 육교 밑    정기권     M    기타
# 39950729 2023-12-29    23   1103        1103. 방화역 4번출구앞    정기권     M    기타
# 39950730 2023-12-29    23   1941        1941. 오류동역 2번출구    정기권     M    기타
# 39950731 2023-12-29    23    107        107. 신한은행 서교동지점    정기권     M    기타
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 36119      1.0  28.0 0.23   1010.0      5.0       0  월
# 36120      1.0   4.1 0.03    150.0      2.0       0  월
# 36121      1.0 10.28 0.12   518.95      2.0       0  월
# 36122      1.0 57.98 0.52   2252.6     14.0       0  월
# 36123      1.0 82.08 0.76   3290.0     20.0       0  월
# ...        ...   ...  ...      ...      ...     ... ..
# 39950727   1.0 21.66 0.19   804.37     10.0       4  금
# 39950728   1.0   0.0  0.0      0.0      2.0       4  금
# 39950729   1.0 43.97 0.32  1388.06      7.0       4  금
# 39950730   1.0 44.93 0.24   1050.6      8.0       4  금
# 39950731   1.0 41.06 0.33   1440.0     15.0       4  금
#
# [30240905 rows x 14 columns]

# %% [markdown]
# - '출퇴근' 컬럼을 새로 만들어서 출근, 퇴근을 넣어준다. (월~금요일, 출퇴근)

# %%
df_2024_day.loc[df_2024_day['대여시간'].isin([7,8]),'출퇴근'] = '출근'
df_2024_day.loc[df_2024_day['대여시간'].isin([17,18]),'출퇴근'] = '퇴근'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7444\2796379095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_day.loc[df_2024_day['대여시간'].isin([7,8]),'출퇴근'] = '출근'

# %%
df_2024_day
# Out:
#                대여일자  대여시간  대여소번호                   대여소명 대여구분코드    성별 연령대코드  \
# 36119    2023-01-02     0    954       954. 은평뉴타운구파발9단지    정기권  None  ~10대
# 36120    2023-01-02     0   1743  1743.창동19단지아파트 관리사무소앞    정기권  None  ~10대
# 36121    2023-01-02     0   3558     3558.마장동 금호어울림APT앞    정기권  None  ~10대
# 36122    2023-01-02     0   3904          3904. 테크노마트 앞    정기권  None  ~10대
# 36123    2023-01-02     0   3798     3798. 그랜드아이파크아파트 앞    정기권  None  ~10대
# ...             ...   ...    ...                    ...    ...   ...   ...
# 39950727 2023-12-29    23   1637   1637. KT 전화국 버스정류장 옆    정기권     M    기타
# 39950728 2023-12-29    23   1908      1908. 해원리바파크 육교 밑    정기권     M    기타
# 39950729 2023-12-29    23   1103        1103. 방화역 4번출구앞    정기권     M    기타
# 39950730 2023-12-29    23   1941        1941. 오류동역 2번출구    정기권     M    기타
# 39950731 2023-12-29    23    107        107. 신한은행 서교동지점    정기권     M    기타
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일  출퇴근
# 36119      1.0  28.0 0.23   1010.0      5.0       0  월  NaN
# 36120      1.0   4.1 0.03    150.0      2.0       0  월  NaN
# 36121      1.0 10.28 0.12   518.95      2.0       0  월  NaN
# 36122      1.0 57.98 0.52   2252.6     14.0       0  월  NaN
# 36123      1.0 82.08 0.76   3290.0     20.0       0  월  NaN
# ...        ...   ...  ...      ...      ...     ... ..  ...
# 39950727   1.0 21.66 0.19   804.37     10.0       4  금  NaN
# 39950728   1.0   0.0  0.0      0.0      2.0       4  금  NaN
# 39950729   1.0 43.97 0.32  1388.06      7.0       4  금  NaN
# 39950730   1.0 44.93 0.24   1050.6      8.0       4  금  NaN
# 39950731   1.0 41.06 0.33   1440.0     15.0       4  금  NaN
#
# [30240905 rows x 15 columns]

# %%
df_2024_day[df_2024_day['출퇴근'] == '출근'] # df_parquet[df_parquet['이용건수'] == '\\N']
# Out:
#                대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 40208    2023-01-02     7   1168   1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 40209    2023-01-02     7   1088      1088.풍납사거리(강동)    정기권  None  ~10대   1.0
# 40210    2023-01-02     7    726  726. 목동3단지 시내버스정류장    정기권  None  ~10대   1.0
# 40211    2023-01-02     7    748          748. 목동운동장    정기권  None   20대   1.0
# 40212    2023-01-02     7   1150      1150. 송정역 1번출구    정기권  None   20대   1.0
# ...             ...   ...    ...                 ...    ...   ...   ...   ...
# 39889961 2023-12-29     8    196       196. 연희교차로 인근    정기권     M    기타   1.0
# 39889962 2023-12-29     8    262     262. 영문초등학교 사거리    정기권     M    기타   1.0
# 39889963 2023-12-29     8    584       584. 광진광장 교통섬    정기권     M    기타   1.0
# 39889964 2023-12-29     8   2002      2002. 노들역 1번출구    정기권     M    기타   1.0
# 39889965 2023-12-29     8    226     226. 샛강역 1번출구 앞    정기권     M    기타   1.0
#
#            운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208    24.63 0.24  1036.67      5.0       0  월  출근
# 40209    39.05 0.39   1700.0      3.0       0  월  출근
# 40210    25.19 0.28   1200.0      8.0       0  월  출근
# 40211    18.18  0.2    850.0      5.0       0  월  출근
# 40212    31.66 0.29   1230.0      6.0       0  월  출근
# ...        ...  ...      ...      ...     ... ..  ..
# 39889961 35.64 0.28   1200.0      9.0       4  금  출근
# 39889962 30.92 0.28  1201.17      8.0       4  금  출근
# 39889963 18.02 0.16    700.0      6.0       4  금  출근
# 39889964 72.92 0.69   2970.0     16.0       4  금  출근
# 39889965 28.87 0.19    810.0      4.0       4  금  출근
#
# [4162143 rows x 15 columns]

# %%
df_2024_day[df_2024_day['출퇴근'] == '퇴근']
# Out:
#                대여일자  대여시간  대여소번호                         대여소명 대여구분코드    성별  \
# 67029    2023-01-02    17    746                746. 목동2단지 상가    정기권  None
# 67030    2023-01-02    17   1450              1450. 화랑대역 7번출구    정기권  None
# 67031    2023-01-02    17   1180  1180. 마곡엠밸리 15단지(1502동) 건너편    정기권  None
# 67032    2023-01-02    17   1184                 1184. 마곡13단지    정기권  None
# 67033    2023-01-02    17   1197            1197. 엠펠리체 호텔 건너편    정기권  None
# ...             ...   ...    ...                          ...    ...   ...
# 39935551 2023-12-29    18   2310         2310. 청담동 맥도날드 옆(위치)    정기권     M
# 39935552 2023-12-29    18    421                  421. 마포구청 앞    정기권     M
# 39935553 2023-12-29    18   1952            1952. 천왕연지타운2단지 앞    정기권     M
# 39935554 2023-12-29    18   1625               1625. 상계역 3번출구    정기권     M
# 39935555 2023-12-29    18   1914                1914. 대림역4번출구    정기권     M
#
#          연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 67029     ~10대   1.0 21.81 0.24  1019.99      6.0       0  월  퇴근
# 67030     ~10대   1.0 27.26 0.25  1059.13      7.0       0  월  퇴근
# 67031     ~10대   1.0 29.95 0.29  1260.48      7.0       0  월  퇴근
# 67032     ~10대   1.0 46.57 0.45   1960.0     13.0       0  월  퇴근
# 67033     ~10대   1.0 39.16 0.48   2060.0     15.0       0  월  퇴근
# ...        ...   ...   ...  ...      ...      ...     ... ..  ..
# 39935551    기타   1.0 66.43 0.56  2396.64     22.0       4  금  퇴근
# 39935552    기타   1.0 85.99 0.78  3340.56     46.0       4  금  퇴근
# 39935553    기타   1.0  51.2 0.37  1616.21      9.0       4  금  퇴근
# 39935554    기타   1.0 22.95 0.16    690.0      8.0       4  금  퇴근
# 39935555    기타   1.0 28.99  0.2   861.18      4.0       4  금  퇴근
#
# [5381387 rows x 15 columns]

# %%
df_2024_day['출퇴근'].unique()
# Out:
# array([nan, '출근', '퇴근'], dtype=object)

# %%
df_2024_day['출퇴근'].value_counts()
# Out:
# 출퇴근
# 퇴근    5381387
# 출근    4162143
# Name: count, dtype: int64

# %%
df_2024_day.count()
# Out:
# 대여일자       30240905
# 대여시간       30240905
# 대여소번호      30240905
# 대여소명       30240905
# 대여구분코드     30240905
# 성별         21098207
# 연령대코드      30240905
# 이용건수       30240905
# 운동량        30127257
# 탄소량        30127257
# 이동거리(M)    30240905
# 이용시간(분)    30240905
# 요일_인덱스     30240905
# 요일         30240905
# 출퇴근         9543530
# dtype: int64

# %%
df_2024_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30240905 entries, 36119 to 39950731
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(6)
# memory usage: 3.5+ GB

# %%
df_2024_day.loc[:, '이용건수'] = df_2024_day['이용건수'].astype(int)

# %%
df_2024_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30240905 entries, 36119 to 39950731
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(6)
# memory usage: 3.5+ GB

# %%
df_2024_time = df_2024_day[~df_2024_day['출퇴근'].isnull()] # df_2020_day.dropna(subset=['출퇴근'])

# %%
df_2024_time
# Out:
#                대여일자  대여시간  대여소번호                  대여소명 대여구분코드    성별 연령대코드  \
# 40208    2023-01-02     7   1168     1168. 마곡엠밸리10단지 앞    정기권  None  ~10대
# 40209    2023-01-02     7   1088        1088.풍납사거리(강동)    정기권  None  ~10대
# 40210    2023-01-02     7    726    726. 목동3단지 시내버스정류장    정기권  None  ~10대
# 40211    2023-01-02     7    748            748. 목동운동장    정기권  None   20대
# 40212    2023-01-02     7   1150        1150. 송정역 1번출구    정기권  None   20대
# ...             ...   ...    ...                   ...    ...   ...   ...
# 39935551 2023-12-29    18   2310  2310. 청담동 맥도날드 옆(위치)    정기권     M    기타
# 39935552 2023-12-29    18    421           421. 마포구청 앞    정기권     M    기타
# 39935553 2023-12-29    18   1952     1952. 천왕연지타운2단지 앞    정기권     M    기타
# 39935554 2023-12-29    18   1625        1625. 상계역 3번출구    정기권     M    기타
# 39935555 2023-12-29    18   1914         1914. 대림역4번출구    정기권     M    기타
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208      1.0 24.63 0.24  1036.67      5.0       0  월  출근
# 40209      1.0 39.05 0.39   1700.0      3.0       0  월  출근
# 40210      1.0 25.19 0.28   1200.0      8.0       0  월  출근
# 40211      1.0 18.18  0.2    850.0      5.0       0  월  출근
# 40212      1.0 31.66 0.29   1230.0      6.0       0  월  출근
# ...        ...   ...  ...      ...      ...     ... ..  ..
# 39935551   1.0 66.43 0.56  2396.64     22.0       4  금  퇴근
# 39935552   1.0 85.99 0.78  3340.56     46.0       4  금  퇴근
# 39935553   1.0  51.2 0.37  1616.21      9.0       4  금  퇴근
# 39935554   1.0 22.95 0.16    690.0      8.0       4  금  퇴근
# 39935555   1.0 28.99  0.2   861.18      4.0       4  금  퇴근
#
# [9543530 rows x 15 columns]

# %%
df_2024_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9543530 entries, 40208 to 39935555
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(6)
# memory usage: 1.1+ GB

# %%
df_2024_time.count()
# Out:
# 대여일자       9543530
# 대여시간       9543530
# 대여소번호      9543530
# 대여소명       9543530
# 대여구분코드     9543530
# 성별         6669880
# 연령대코드      9543530
# 이용건수       9543530
# 운동량        9501596
# 탄소량        9501596
# 이동거리(M)    9543530
# 이용시간(분)    9543530
# 요일_인덱스     9543530
# 요일         9543530
# 출퇴근        9543530
# dtype: int64

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본_최종.parquet'
start_time = time.time()
df_st = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df_st.head(5)
# Out:
# read_parquet time : 0.09870457649230957
#    대여소번호          대여소명  자치구                         상세주소          위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 126.8210602  2024-03-18  NaN 10.0   QR  2024-06  ST-3284   NaN
# 1 127.0669098  2020-03-24  NaN 12.0   QR  2024-06  ST-2068   NaN
# 2 127.0732651  2020-03-23  NaN 20.0   QR  2024-06  ST-2078   NaN
# 3 127.0719147  2020-03-23  NaN  7.0   QR  2024-06  ST-2077   NaN
# 4 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN

# %%
df_st.head()
# Out:
#    대여소번호          대여소명  자치구                         상세주소          위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 126.8210602  2024-03-18  NaN 10.0   QR  2024-06  ST-3284   NaN
# 1 127.0669098  2020-03-24  NaN 12.0   QR  2024-06  ST-2068   NaN
# 2 127.0732651  2020-03-23  NaN 20.0   QR  2024-06  ST-2078   NaN
# 3 127.0719147  2020-03-23  NaN  7.0   QR  2024-06  ST-2077   NaN
# 4 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN

# %%
df_st.info() # 대여소번호 int / object 다름.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2960 entries, 0 to 2959
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   2960 non-null   object
#  1   대여소명    2960 non-null   object
#  2   자치구     2960 non-null   object
#  3   상세주소    2960 non-null   object
#  4   위도      2959 non-null   float64
#  5   경도      2959 non-null   float64
#  6   설치시기    2921 non-null   object
#  7   LCD     1517 non-null   float64
#  8   QR      1752 non-null   float64
#  9   운영방식    2921 non-null   object
#  10  데이터등록월  2921 non-null   object
#  11  대여소ID   2701 non-null   object
#  12  거치대수    39 non-null     float64
# dtypes: float64(5), object(8)
# memory usage: 300.8+ KB

# %%
df_st.shape
# Out:
# (2960, 13)

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

import ExcelFile_EDA as ee
ee.ss_isnull(df_st)
# Out:
#      [컬럼명]  [sum]  [sum_isnull]     [mean_isnull(%)]
# 0    대여소번호   2960             0                  0.0
# 1     대여소명   2960             0                  0.0
# 2      자치구   2960             0                  0.0
# 3     상세주소   2960             0                  0.0
# 4       위도   2959             1 0.033783783783783786
# 5       경도   2959             1 0.033783783783783786
# 6     설치시기   2921            39   1.3175675675675675
# 7      LCD   1517          1443                48.75
# 8       QR   1752          1208    40.81081081081081
# 9     운영방식   2921            39   1.3175675675675675
# 10  데이터등록월   2921            39   1.3175675675675675
# 11   대여소ID   2701           259                 8.75
# 12    거치대수     39          2921    98.68243243243244

# %%
df_st_1 = df_st[['대여소번호', '대여소명', '자치구', '설치시기', '데이터등록월']]
df_st_1
# Out:
#       대여소번호            대여소명   자치구        설치시기   데이터등록월
# 0     06173     서울자동차운전전문학원   강서구  2024-03-18  2024-06
# 1     02902    공릉풍림아파트 108동   노원구  2020-03-24  2024-06
# 2     02912          대진고등학교   노원구  2020-03-23  2024-06
# 3     02911         상계역중앙시장   노원구  2020-03-23  2024-06
# 4     02910           도깨비시장   노원구  2020-03-25  2024-06
# ...     ...             ...   ...         ...      ...
# 2955  05884          GS강서타워  영등포구        None     None
# 2956  05885  신정교하부(도림천역 방면)  영등포구        None     None
# 2957  06060         신한은행 본점    중구        None     None
# 2958  06176      유광사 여성병원 앞   강서구        None     None
# 2959  06177      마곡롯데캐슬르웨스트   강서구        None     None
#
# [2960 rows x 5 columns]

# %% [markdown]
# - 시간대별 데이터, 대여소정보 데이터 에서 '대여소번호' 컬럼의 숫자 표현방식, 데이터 타입이 다르다.

# %% [markdown]
# - 따라서, 1. 시간대별 데이터(월~금 / 출퇴근 시간대 추출함)의 '대여소번호' 컬럼의 숫자를 object로 바꾸어준다.
#      ##### 2. 시간대별 데이터의 '대여소번호' 컬럼의 숫자를 00000 자리로 바꾸어준다.

# %%
df_2024_time.head()
# Out:
#             대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 40208 2023-01-02     7   1168   1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 40209 2023-01-02     7   1088      1088.풍납사거리(강동)    정기권  None  ~10대   1.0
# 40210 2023-01-02     7    726  726. 목동3단지 시내버스정류장    정기권  None  ~10대   1.0
# 40211 2023-01-02     7    748          748. 목동운동장    정기권  None   20대   1.0
# 40212 2023-01-02     7   1150      1150. 송정역 1번출구    정기권  None   20대   1.0
#
#         운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208 24.63 0.24  1036.67      5.0       0  월  출근
# 40209 39.05 0.39   1700.0      3.0       0  월  출근
# 40210 25.19 0.28   1200.0      8.0       0  월  출근
# 40211 18.18  0.2    850.0      5.0       0  월  출근
# 40212 31.66 0.29   1230.0      6.0       0  월  출근

# %%
df_2024_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9543530 entries, 40208 to 39935555
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(6)
# memory usage: 1.1+ GB

# %%
df_2024_time.loc[:, '대여소번호'] = df_2024_time['대여소번호'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7444\1832997655.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['1168' '1088' '726' ... '1952' '1625' '1914']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_2024_time.loc[:, '대여소번호'] = df_2024_time['대여소번호'].astype(str)

# %%
df_2024_time.dtypes
# Out:
# 대여일자       datetime64[ns]
# 대여시간                int64
# 대여소번호              object
# 대여소명               object
# 대여구분코드             object
# 성별                 object
# 연령대코드              object
# 이용건수              float64
# 운동량               float64
# 탄소량               float64
# 이동거리(M)           float64
# 이용시간(분)           float64
# 요일_인덱스              int32
# 요일                 object
# 출퇴근                object
# dtype: object

# %%
df_2024_time.loc[:,'대여소번호'] = df_2024_time['대여소번호'].str.zfill(5)

# %%
df_2024_time.head()
# Out:
#             대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 40208 2023-01-02     7  01168   1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 40209 2023-01-02     7  01088      1088.풍납사거리(강동)    정기권  None  ~10대   1.0
# 40210 2023-01-02     7  00726  726. 목동3단지 시내버스정류장    정기권  None  ~10대   1.0
# 40211 2023-01-02     7  00748          748. 목동운동장    정기권  None   20대   1.0
# 40212 2023-01-02     7  01150      1150. 송정역 1번출구    정기권  None   20대   1.0
#
#         운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208 24.63 0.24  1036.67      5.0       0  월  출근
# 40209 39.05 0.39   1700.0      3.0       0  월  출근
# 40210 25.19 0.28   1200.0      8.0       0  월  출근
# 40211 18.18  0.2    850.0      5.0       0  월  출근
# 40212 31.66 0.29   1230.0      6.0       0  월  출근

# %%
df_sum = pd.merge(df_2024_time, df_st_1, on='대여소번호', how='left')
df_sum
# Out:
#               대여일자  대여시간  대여소번호                대여소명_x 대여구분코드    성별 연령대코드  \
# 0       2023-01-02     7  01168     1168. 마곡엠밸리10단지 앞    정기권  None  ~10대
# 1       2023-01-02     7  01088        1088.풍납사거리(강동)    정기권  None  ~10대
# 2       2023-01-02     7  00726    726. 목동3단지 시내버스정류장    정기권  None  ~10대
# 3       2023-01-02     7  00748            748. 목동운동장    정기권  None   20대
# 4       2023-01-02     7  01150        1150. 송정역 1번출구    정기권  None   20대
# ...            ...   ...    ...                   ...    ...   ...   ...
# 9543525 2023-12-29    18  02310  2310. 청담동 맥도날드 옆(위치)    정기권     M    기타
# 9543526 2023-12-29    18  00421           421. 마포구청 앞    정기권     M    기타
# 9543527 2023-12-29    18  01952     1952. 천왕연지타운2단지 앞    정기권     M    기타
# 9543528 2023-12-29    18  01625        1625. 상계역 3번출구    정기권     M    기타
# 9543529 2023-12-29    18  01914         1914. 대림역4번출구    정기권     M    기타
#
#          이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근          대여소명_y  \
# 0         1.0 24.63 0.24  1036.67      5.0       0  월  출근     마곡엠밸리10단지 앞
# 1         1.0 39.05 0.39   1700.0      3.0       0  월  출근       풍납사거리(강동)
# 2         1.0 25.19 0.28   1200.0      8.0       0  월  출근   목동3단지 시내버스정류장
# 3         1.0 18.18  0.2    850.0      5.0       0  월  출근           목동운동장
# 4         1.0 31.66 0.29   1230.0      6.0       0  월  출근        송정역 1번출구
# ...       ...   ...  ...      ...      ...     ... ..  ..             ...
# 9543525   1.0 66.43 0.56  2396.64     22.0       4  금  퇴근  청담동 맥도날드 옆(위치)
# 9543526   1.0 85.99 0.78  3340.56     46.0       4  금  퇴근          마포구청 앞
# 9543527   1.0  51.2 0.37  1616.21      9.0       4  금  퇴근     천왕연지타운2단지 앞
# 9543528   1.0 22.95 0.16    690.0      8.0       4  금  퇴근        상계역 3번출구
# 9543529   1.0 28.99  0.2   861.18      4.0       4  금  퇴근         대림역4번출구
#
#          자치구        설치시기   데이터등록월
# 0        강서구  2018-02-26  2024-06
# 1        강동구  2020-01-14  2024-06
# 2        양천구  2017-11-01  2024-06
# 3        양천구  2017-11-01  2024-06
# 4        강서구  2017-11-01  2024-06
# ...      ...         ...      ...
# 9543525  강남구  2017-06-13  2024-06
# 9543526  마포구  2015-10-07  2024-06
# 9543527  구로구  2017-06-22  2024-06
# 9543528  노원구  2017-06-27  2024-06
# 9543529  구로구  2017-06-27  2024-06
#
# [9543530 rows x 19 columns]

# %%
group1 = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().reset_index()
group1
# Out:
#               대여소명_y 출퇴근   이용건수
# 0        (시립)고덕평생학습관  출근  648.0
# 1        (시립)고덕평생학습관  퇴근  856.0
# 2       (재)FITI시험연구원  출근 5427.0
# 3       (재)FITI시험연구원  퇴근 4319.0
# 4      3호선 매봉역 3번출구앞  출근 3179.0
# ...              ...  ..    ...
# 5561         힐스테이트에코  퇴근 7084.0
# 5562  힐스테이트창경궁 아파트 앞  출근 1451.0
# 5563  힐스테이트창경궁 아파트 앞  퇴근 1679.0
# 5564    힐스테이트클래시안아파트  출근 3049.0
# 5565    힐스테이트클래시안아파트  퇴근 1105.0
#
# [5566 rows x 3 columns]

# %% [markdown]
# - 출근 시간대 대여소별 이용건수

# %%
commute_data = group1[group1['출퇴근'] == '출근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data = commute_data.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data = top_20_commute_data.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
bars = plt.barh(top_20_commute_data['대여소명_y'], top_20_commute_data['이용건수'])
plt.title(_year + '년 출근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')

# 각 막대 끝에 이용건수 표시
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:,.0f}', 
             ha='left', va='center', fontweight='bold')
    
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %%
top_20_m = top_20_commute_data.sort_values(by='이용건수', ascending=False)

# %%
top_20_m
# Out:
#                  대여소명_y 출퇴근    이용건수
# 1757      마곡나루역 5번출구 뒤편  출근 38269.0
# 1753        마곡나루역 2번 출구  출근 26289.0
# 1755        마곡나루역 3번 출구  출근 15899.0
# 891        그랜드아이파크아파트 앞  출근 12862.0
# 3966        영등포구청역 1번출구  출근 12641.0
# 1587       등촌1-10단지 교차로  출근 11694.0
# 2049         문래동롯데캐슬아파트  출근 11668.0
# 1255            대방역6번출구  출근 11509.0
# 1739             마곡13단지  출근 11276.0
# 3436       신도림역 1번 출구 앞  출근 11075.0
# 2938       서울축산농협(장안지점)  출근 10675.0
# 1685  롯데월드타워(잠실역2번출구 쪽)  출근 10609.0
# 3778           양천아파트 입구  출근 10257.0
# 747          구로디지털단지역 앞  출근 10102.0
# 3658   아크로타워 스퀘어(영등포시장)  출근  9856.0
# 5022             충북 미래관  출근  9719.0
# 3136         성수역 2번출구 앞  출근  9658.0
# 3562          신정보도육교 아래  출근  9652.0
# 3280        수명산파크1단지교차로  출근  9577.0
# 3798           양평역 1번출구  출근  9562.0

# %% [markdown]
# ## 출근 시간대 top20 대여소 지도에 나타내기

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일/서울시 공공자전거 대여소 정보/공공자전거 대여소 정보_통합본_최종.parquet')
rental = rental.iloc[4:]
rental.reset_index(drop = True, inplace = True)

# %%
rental.head()
# Out:
#    대여소번호         대여소명  자치구                          상세주소          위도  \
# 0  02910        도깨비시장  노원구      서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1  02909    석계역 3번 출구  노원구  서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2  02908  광운대학교 중앙도서관  노원구        서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3  02907        월계중학교  노원구      서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4  02904    중계3차청구아파트  노원구     서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN
# 1 127.0674515  2020-03-25  NaN 13.0   QR  2024-06  ST-2075   NaN
# 2 127.0585632  2020-03-24  NaN 20.0   QR  2024-06  ST-2074   NaN
# 3 127.0531082  2020-03-24  NaN 15.0   QR  2024-06  ST-2073   NaN
# 4 127.0739822  2020-03-24  NaN  8.0   QR  2024-06  ST-2070   NaN

# %%
have_bikes = rental.groupby('자치구').size()

# %%
rental = rental.rename(columns={'대여소명':'대여소명_y'})
rental
# Out:
#       대여소번호          대여소명_y   자치구  \
# 0     02910           도깨비시장   노원구
# 1     02909       석계역 3번 출구   노원구
# 2     02908     광운대학교 중앙도서관   노원구
# 3     02907           월계중학교   노원구
# 4     02904       중계3차청구아파트   노원구
# ...     ...             ...   ...
# 2951  05884          GS강서타워  영등포구
# 2952  05885  신정교하부(도림천역 방면)  영등포구
# 2953  06060         신한은행 본점    중구
# 2954  06176      유광사 여성병원 앞   강서구
# 2955  06177      마곡롯데캐슬르웨스트   강서구
#
#                                                    상세주소          위도  \
# 0                              서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1                          서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2                                서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3                              서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4                             서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
# ...                                                 ...         ...
# 2951  GS 홈쇼핑본사(GS강서빌딩), 75, 선유로, 문래동4가, 문래동, 영등포구, 서... 37.52098083
# 2952         도림천로, 문래동5가, 문래동, 영등포구, 서울특별시, 07285, 대한민국 37.51594543
# 2953          세종대로9길, 서소문동, 소공동, 중구, 서울특별시, 04512, 대한민국 37.56077576
# 2954   유광사여성병원, 194, 강서로, 우장산동, 강서구, 서울특별시, 07698, 대한민국  37.5434494
# 2955          마곡중앙로, 마곡동, 방화1동, 강서구, 서울특별시, 07800, 대한민국 37.56356049
#
#                경도        설치시기  LCD   QR  운영방식   데이터등록월    대여소ID  거치대수
# 0     127.0740509  2020-03-25  NaN 10.0    QR  2024-06     None   NaN
# 1     127.0674515  2020-03-25  NaN 13.0    QR  2024-06  ST-2075   NaN
# 2     127.0585632  2020-03-24  NaN 20.0    QR  2024-06  ST-2074   NaN
# 3     127.0531082  2020-03-24  NaN 15.0    QR  2024-06  ST-2073   NaN
# 4     127.0739822  2020-03-24  NaN  8.0    QR  2024-06  ST-2070   NaN
# ...           ...         ...  ...  ...   ...      ...      ...   ...
# 2951 126.88929749        None  NaN  NaN  None     None  ST-3331   8.0
# 2952 126.88288879        None  NaN  NaN  None     None  ST-3341  10.0
# 2953 126.97480774        None  NaN  NaN  None     None  ST-3342   8.0
# 2954 126.83891296        None  NaN  NaN  None     None  ST-3327   7.0
# 2955 126.82462311        None  NaN  NaN  None     None  ST-3324  10.0
#
# [2956 rows x 13 columns]

# %%
top_20_m = pd.merge(top_20_m, rental, on='대여소명_y', how='left')
top_20_m
# Out:
#                대여소명_y 출퇴근    이용건수  대여소번호   자치구                           상세주소  \
# 0       마곡나루역 5번출구 뒤편  출근 38269.0  02701   강서구                  강서구 마곡동 761-5
# 1         마곡나루역 2번 출구  출근 26289.0  02715   강서구                   강서구 마곡중앙5로 6
# 2         마곡나루역 3번 출구  출근 15899.0  02728   강서구                 강서구 마곡동 372-23
# 3        그랜드아이파크아파트 앞  출근 12862.0  03798   강서구
# 4         영등포구청역 1번출구  출근 12641.0  00230  영등포구           서울특별시 영등포구 당산로 111-2
# 5        등촌1-10단지 교차로  출근 11694.0  02721   강서구                    강서구 강서로 419
# 6          문래동롯데캐슬아파트  출근 11668.0  04571  영등포구                  영등포구 선유로9길 30
# 7             대방역6번출구  출근 11509.0  00259  영등포구             서울특별시 영등포구 신길동1368
# 8              마곡13단지  출근 11276.0  01184   강서구                   강서구 공항동 1343
# 9        신도림역 1번 출구 앞  출근 11075.0  01906   구로구              서울특별시 구로구 경인로 688
# 10       서울축산농협(장안지점)  출근 10675.0  00668  동대문구              서울특별시 동대문구 장한로 79
# 11  롯데월드타워(잠실역2번출구 쪽)  출근 10609.0  01210   송파구          서울특별시 송파구 올림픽로 293-19
# 12           양천아파트 입구  출근 10257.0  00787   양천구                   양천구 목동로3길 41
# 13         구로디지털단지역 앞  출근 10102.0  01911   구로구           서울특별시 구로구 시흥대로 577-2
# 14   아크로타워 스퀘어(영등포시장)  출근  9856.0  00283  영등포구                영등포구 영등포동7가 3-2
# 15             충북 미래관  출근  9719.0  00293  영등포구               영등포구 당산동 121-258
# 16         성수역 2번출구 앞  출근  9658.0  00567   성동구  서울특별시 성동구 아차산로 113 성수역 2번출구 앞
# 17          신정보도육교 아래  출근  9652.0  00781   양천구                     양천구 신목로 10
# 18        수명산파크1단지교차로  출근  9577.0  02739   강서구                     강서로47길 142
# 19           양평역 1번출구  출근  9562.0  04561  영등포구                영등포구 양평동3가 22-1
#
#             위도          경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  37.56520081 126.8273163  2018-11-14 26.0  NaN  LCD  2024-06  ST-1718   NaN
# 1  37.56692505 126.8274384  2020-05-27  NaN 25.0   QR  2024-06  ST-2031   NaN
# 2  37.56580353 126.8280792  2020-03-12  NaN 55.0   QR  2024-06  ST-2045   NaN
# 3  37.55510712 126.8515472  2020-12-21  NaN 11.0   QR  2024-06  ST-2557   NaN
# 4  37.52463531 126.8962174  2016-07-06 13.0 13.0   QR  2024-06   ST-413   NaN
# 5  37.56320572 126.8393631  2020-03-15  NaN 12.0   QR  2024-06  ST-2037   NaN
# 6  37.51800156 126.8845978  2021-05-17  NaN 10.0   QR  2024-06  ST-2820   NaN
# 7  37.51359177 126.9259338  2016-06-29 17.0 17.0   QR  2024-06   ST-307   NaN
# 8  37.55644989  126.815979  2018-10-10 26.0  NaN  LCD  2024-06  ST-1645   NaN
# 9  37.50971985 126.8900986  2017-05-11 20.0  NaN  LCD  2024-06   ST-664   NaN
# 10 37.56787109  127.068718  2020-04-22  NaN 10.0   QR  2024-06  ST-2268   NaN
# 11 37.51312637 127.1009598  2017-06-27 30.0  NaN  LCD  2024-06   ST-891   NaN
# 12 37.50790405  126.862648  2020-03-09  NaN 14.0   QR  2024-06  ST-2013   NaN
# 13 37.48493958 126.9013214  2017-05-11 18.0  NaN  LCD  2024-06   ST-668   NaN
# 14 37.52251816 126.9072189  2018-09-28 15.0  NaN  LCD  2024-06  ST-1649   NaN
# 15 37.52917099 126.9075775  2018-12-04 15.0  NaN  LCD  2024-06  ST-1701   NaN
# 16    37.54459 127.0570831  2016-07-06 15.0 15.0   QR  2024-06   ST-368   NaN
# 17 37.51759338 126.8765564  2020-03-11  NaN 15.0   QR  2024-06  ST-2007   NaN
# 18 37.55363083 126.8286133  2020-03-17  NaN 20.0   QR  2024-06  ST-2056   NaN
# 19 37.52572632 126.8860016  2021-05-17  NaN 10.0   QR  2024-06  ST-2812   NaN

# %% [markdown]
# ### 자전거 도로 정보

# %%
geo_path = path_dateset + '_최종 병합 파일\\서울시 자전거 도로 데이터\\' + 'ddareng_road.geojson'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str = json.load(f)
# # ============================

# %% [markdown]
# ### 자치구 정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %% [markdown]
# ### 지하철역통합

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#     연번   역번호  호선    역명         역전화번호                      도로명주소  \
# 0  NaN  None NaN  <NA>          <NA>                       <NA>
# 1  NaN  None NaN  <NA>          <NA>                       <NA>
# 2 92.0   340 3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3  NaN  None NaN  <NA>          <NA>                       <NA>
# 4  NaN  None NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat        lng
# 0            943            419민주묘지 37.6482352 127.008614
# 1            109                 가능  37.748577 127.044213
# 2            350               가락시장  37.492522 127.118234
# 3           P142            가산디지털단지  37.481072 126.882343
# 4            907                 가양  37.561391 126.854456

# %%
b_출퇴근 = '출근'

if b_출퇴근 == '출근':
    df_출퇴근 = top_20_m
else:
    df_출퇴근 = top_20_e

# %%
# 지도 생성
center = [37.541, 126.986]
# center on Liberty Bell, add marker
bike_map = folium.Map(location=center, zoom_start=13)
# 스타일 지정 예시 (선의 색상, 두께 등)
style = {
    'color': 'red',
    'weight': 3,
    'opacity': 0.7,
}

fg0 = folium.FeatureGroup(name="bike_road", show=False).add_to(bike_map)
# 자전거 도로 표시
# GeoJSON 파일을 불러와 스타일 적용
folium.GeoJson(
    geo_str,
    name='bike_road',
    style_function=lambda x: style
).add_to(fg0)

fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)
# 자전거 대여소 표시
for i, row in top_20_m.iterrows():
  # folium.Marker(
    #folium.CircleMarker(
    folium.Circle(
      location = [row['위도'], row['경도']],
      radius = 100,
      color='black',                  # 외곽선 색상
      fill=False,                     # 채우기 여부
      fill_color='blue',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      #popup=row['대여소번호'],             # 클릭 시 표시되는 팝업
      tooltip=row['대여소명_y'],                 # 마우스 오버 시 표시되는 툴팁
      #icon=folium.Icon(icon = 'bookmark', color = 'blue')
  ).add_to(fg1)

fg2 = folium.FeatureGroup(name="train_station", show=False).add_to(bike_map)
# 지하철역 표시
for i, row in df_train_station.iterrows():
  folium.CircleMarker(
      location = [row['lat'], row['lng']],
      radius=2,                     # 반지름 (픽셀 단위)
      color='yellow',                  # 외곽선 색상
      fill=True,                     # 채우기 여부
      fill_color='yellow',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      popup=row[' seoulmetro_code'],             # 클릭 시 표시되는 팝업
      tooltip=row[' station_name(kor)']                 # 마우스 오버 시 표시되는 툴팁      
  ).add_to(fg2)

# 자치구 구분 표
geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))
choropleth = folium.Choropleth(geo_data = geo_str2,
                  data = have_bikes,
                  name = 'gu',
                  key_on = 'feature.properties.SIG_KOR_NM',
                  fill_color = 'Blues')
# 1. GeoJsonTooltip을 사용하는 방법:
# folium.GeoJsonTooltip(fields=['SIG_ENG_NM'],
#                       aliases=['지역:'],
#                       style=('background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;')
# ).add_to(choropleth.geojson)
# 2. GeoJsonPopup을 사용하는 방법:
folium.GeoJsonPopup(fields=['SIG_KOR_NM'],
                    aliases=['지역:'],
                    style='font-weight: bold;'
).add_to(choropleth.geojson)
choropleth.add_to(bike_map)

folium.LayerControl().add_to(bike_map)

# jupyter 에서 곧장 지도 표시하기
#bike_map

# web에서 표시하기
# 지도 저장
bike_map.save("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
import webbrowser
webbrowser.open("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
# Out:
# True

# %% [markdown]
# - 퇴근 시간대 대여소별 이용건수

# %%
commute_data_2 = group1[group1['출퇴근'] == '퇴근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data_2 = commute_data_2.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data_2 = top_20_commute_data_2.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
bars = plt.barh(top_20_commute_data_2['대여소명_y'], top_20_commute_data_2['이용건수'])
plt.title(_year + '년 퇴근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')

# 각 막대 끝에 이용건수 표시
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:,.0f}', 
             ha='left', va='center', fontweight='bold')

plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %%
top_20_e = top_20_commute_data_2.sort_values(by='이용건수', ascending=False)
top_20_e
# Out:
#                  대여소명_y 출퇴근    이용건수
# 1754        마곡나루역 2번 출구  퇴근 34384.0
# 139         LG유플러스 마곡사옥  퇴근 24414.0
# 1758      마곡나루역 5번출구 뒤편  퇴근 23810.0
# 1686  롯데월드타워(잠실역2번출구 쪽)  퇴근 23446.0
# 748          구로디지털단지역 앞  퇴근 20763.0
# 1756        마곡나루역 3번 출구  퇴근 19540.0
# 1214        대륭포스트타워6차 앞  퇴근 18191.0
# 3439         신도림테크노근린공원  퇴근 17723.0
# 3839       여의나루역 1번출구 앞  퇴근 17578.0
# 844              국민일보 앞  퇴근 17345.0
# 5071            태평양물산빌딩  퇴근 17269.0
# 3609           신한금융투자 앞  퇴근 16968.0
# 1764             마곡문화공원  퇴근 16042.0
# 3229               송파구청  퇴근 15826.0
# 1630      뚝섬유원지역 1번출구 앞  퇴근 15816.0
# 2164  발산역 1번, 9번 인근 대여소  퇴근 15520.0
# 5041      코오롱One&Only타워  퇴근 15503.0
# 3437       신도림역 1번 출구 앞  퇴근 14999.0
# 3967        영등포구청역 1번출구  퇴근 14905.0
# 3771      양천구청, 보건소 사잇길  퇴근 14243.0

# %% [markdown]
# ## 퇴근 시간대 top20 대여소 지도에 나타내기

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일/서울시 공공자전거 대여소 정보/공공자전거 대여소 정보_통합본_최종.parquet')
rental = rental.iloc[4:]
rental.reset_index(drop = True, inplace = True)

# %%
rental.head()
# Out:
#    대여소번호         대여소명  자치구                          상세주소          위도  \
# 0  02910        도깨비시장  노원구      서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1  02909    석계역 3번 출구  노원구  서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2  02908  광운대학교 중앙도서관  노원구        서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3  02907        월계중학교  노원구      서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4  02904    중계3차청구아파트  노원구     서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN
# 1 127.0674515  2020-03-25  NaN 13.0   QR  2024-06  ST-2075   NaN
# 2 127.0585632  2020-03-24  NaN 20.0   QR  2024-06  ST-2074   NaN
# 3 127.0531082  2020-03-24  NaN 15.0   QR  2024-06  ST-2073   NaN
# 4 127.0739822  2020-03-24  NaN  8.0   QR  2024-06  ST-2070   NaN

# %%
have_bikes = rental.groupby('자치구').size()

# %%
rental = rental.rename(columns={'대여소명':'대여소명_y'})
rental
# Out:
#       대여소번호          대여소명_y   자치구  \
# 0     02910           도깨비시장   노원구
# 1     02909       석계역 3번 출구   노원구
# 2     02908     광운대학교 중앙도서관   노원구
# 3     02907           월계중학교   노원구
# 4     02904       중계3차청구아파트   노원구
# ...     ...             ...   ...
# 2951  05884          GS강서타워  영등포구
# 2952  05885  신정교하부(도림천역 방면)  영등포구
# 2953  06060         신한은행 본점    중구
# 2954  06176      유광사 여성병원 앞   강서구
# 2955  06177      마곡롯데캐슬르웨스트   강서구
#
#                                                    상세주소          위도  \
# 0                              서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1                          서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2                                서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3                              서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4                             서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
# ...                                                 ...         ...
# 2951  GS 홈쇼핑본사(GS강서빌딩), 75, 선유로, 문래동4가, 문래동, 영등포구, 서... 37.52098083
# 2952         도림천로, 문래동5가, 문래동, 영등포구, 서울특별시, 07285, 대한민국 37.51594543
# 2953          세종대로9길, 서소문동, 소공동, 중구, 서울특별시, 04512, 대한민국 37.56077576
# 2954   유광사여성병원, 194, 강서로, 우장산동, 강서구, 서울특별시, 07698, 대한민국  37.5434494
# 2955          마곡중앙로, 마곡동, 방화1동, 강서구, 서울특별시, 07800, 대한민국 37.56356049
#
#                경도        설치시기  LCD   QR  운영방식   데이터등록월    대여소ID  거치대수
# 0     127.0740509  2020-03-25  NaN 10.0    QR  2024-06     None   NaN
# 1     127.0674515  2020-03-25  NaN 13.0    QR  2024-06  ST-2075   NaN
# 2     127.0585632  2020-03-24  NaN 20.0    QR  2024-06  ST-2074   NaN
# 3     127.0531082  2020-03-24  NaN 15.0    QR  2024-06  ST-2073   NaN
# 4     127.0739822  2020-03-24  NaN  8.0    QR  2024-06  ST-2070   NaN
# ...           ...         ...  ...  ...   ...      ...      ...   ...
# 2951 126.88929749        None  NaN  NaN  None     None  ST-3331   8.0
# 2952 126.88288879        None  NaN  NaN  None     None  ST-3341  10.0
# 2953 126.97480774        None  NaN  NaN  None     None  ST-3342   8.0
# 2954 126.83891296        None  NaN  NaN  None     None  ST-3327   7.0
# 2955 126.82462311        None  NaN  NaN  None     None  ST-3324  10.0
#
# [2956 rows x 13 columns]

# %%
top_20_e = pd.merge(top_20_e, rental, on='대여소명_y', how='left')
top_20_e
# Out:
#                대여소명_y 출퇴근    이용건수  대여소번호   자치구  \
# 0         마곡나루역 2번 출구  퇴근 34384.0  02715   강서구
# 1         LG유플러스 마곡사옥  퇴근 24414.0  02717   강서구
# 2       마곡나루역 5번출구 뒤편  퇴근 23810.0  02701   강서구
# 3   롯데월드타워(잠실역2번출구 쪽)  퇴근 23446.0  01210   송파구
# 4          구로디지털단지역 앞  퇴근 20763.0  01911   구로구
# 5         마곡나루역 3번 출구  퇴근 19540.0  02728   강서구
# 6         대륭포스트타워6차 앞  퇴근 18191.0  01867   금천구
# 7          신도림테크노근린공원  퇴근 17723.0  01961   구로구
# 8        여의나루역 1번출구 앞  퇴근 17578.0  00207  영등포구
# 9              국민일보 앞  퇴근 17345.0  00202  영등포구
# 10            태평양물산빌딩  퇴근 17269.0  01986   구로구
# 11           신한금융투자 앞  퇴근 16968.0  05854  영등포구
# 12             마곡문화공원  퇴근 16042.0  02719   강서구
# 13               송파구청  퇴근 15826.0  02608   송파구
# 14      뚝섬유원지역 1번출구 앞  퇴근 15816.0  00502   광진구
# 15  발산역 1번, 9번 인근 대여소  퇴근 15520.0  01153   강서구
# 16      코오롱One&Only타워  퇴근 15503.0  01195   강서구
# 17       신도림역 1번 출구 앞  퇴근 14999.0  01906   구로구
# 18        영등포구청역 1번출구  퇴근 14905.0  00230  영등포구
# 19      양천구청, 보건소 사잇길  퇴근 14243.0  00785   양천구
#
#                               상세주소          위도          경도        설치시기  LCD  \
# 0                     강서구 마곡중앙5로 6 37.56692505 126.8274384  2020-05-27  NaN
# 1                    강서구 마곡중앙8로 71 37.56133652 126.8339005  2020-03-15  NaN
# 2                    강서구 마곡동 761-5 37.56520081 126.8273163  2018-11-14 26.0
# 3            서울특별시 송파구 올림픽로 293-19 37.51312637 127.1009598  2017-06-27 30.0
# 4             서울특별시 구로구 시흥대로 577-2 37.48493958 126.9013214  2017-05-11 18.0
# 5                   강서구 마곡동 372-23 37.56580353 126.8280792  2020-03-12  NaN
# 6                          벚꽃로 298 37.48088837 126.8838043  2020-02-26  NaN
# 7             서울특별시 구로구 새말로 121-15 37.50818253 126.8913345  2017-11-13 15.0
# 8            서울특별시 영등포구 여의동로 지하343 37.52715683    126.9319  2015-09-17 46.0
# 9             서울특별시 영등포구 여의공원로 101 37.52881622   126.92453  2015-09-11 30.0
# 10                  구로구 구로동 197-21 37.48485947 126.8951874  2018-09-28 15.0
# 11                         여의대로 70 37.52508926 126.9240799  2022-06-09  NaN
# 12                   강서구 마곡중앙8로 20 37.56121063 126.8303452  2020-03-16  NaN
# 13                    송파구 올림픽로 326  37.5150528 127.1062698  2018-11-12 15.0
# 14  서울특별시 광진구 능동로 10 뚝섬유원지역 1번출구 앞 37.53186035 127.0671921  2015-10-07 17.0
# 15              서울특별시 강서구 공항대로 281 37.55894852 126.8371735  2017-11-01 17.0
# 16                 강서구 마곡동 727-525 37.56412888 126.8343124  2018-11-20 24.0
# 17               서울특별시 구로구 경인로 688 37.50971985 126.8900986  2017-05-11 20.0
# 18            서울특별시 영등포구 당산로 111-2 37.52463531 126.8962174  2016-07-06 13.0
# 19                   양천구 신정동 321-8 37.51747513 126.8663254  2020-03-15  NaN
#
#      QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  25.0   QR  2024-06  ST-2031   NaN
# 1  62.0   QR  2024-06  ST-2033   NaN
# 2   NaN  LCD  2024-06  ST-1718   NaN
# 3   NaN  LCD  2024-06   ST-891   NaN
# 4   NaN  LCD  2024-06   ST-668   NaN
# 5  55.0   QR  2024-06  ST-2045   NaN
# 6  30.0   QR  2024-06  ST-1938   NaN
# 7   NaN  LCD  2024-06  ST-1223   NaN
# 8  46.0   QR  2024-06    ST-73   NaN
# 9  30.0   QR  2024-06    ST-47   NaN
# 10  NaN  LCD  2024-06  ST-1521   NaN
# 11 26.0   QR  2024-06     None   NaN
# 12 40.0   QR  2024-06  ST-2035   NaN
# 13 10.0   QR  2024-06  ST-1681   NaN
# 14 33.0   QR  2024-06     None   NaN
# 15 15.0  LCD  2024-06  ST-1065   NaN
# 16  NaN  LCD  2024-06  ST-1712   NaN
# 17  NaN  LCD  2024-06   ST-664   NaN
# 18 13.0   QR  2024-06   ST-413   NaN
# 19 24.0   QR  2024-06  ST-2011   NaN

# %% [markdown]
# ### 자전거도로정보

# %%
geo_path = path_dateset + '_최종 병합 파일\\서울시 자전거 도로 데이터\\' + 'ddareng_road.geojson'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str = json.load(f)
# # ============================

# %% [markdown]
# ### 자치구정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %% [markdown]
# ### 지하철역통합

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#     연번   역번호  호선    역명         역전화번호                      도로명주소  \
# 0  NaN  None NaN  <NA>          <NA>                       <NA>
# 1  NaN  None NaN  <NA>          <NA>                       <NA>
# 2 92.0   340 3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3  NaN  None NaN  <NA>          <NA>                       <NA>
# 4  NaN  None NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat        lng
# 0            943            419민주묘지 37.6482352 127.008614
# 1            109                 가능  37.748577 127.044213
# 2            350               가락시장  37.492522 127.118234
# 3           P142            가산디지털단지  37.481072 126.882343
# 4            907                 가양  37.561391 126.854456

# %%
b_출퇴근 = '퇴근'

if b_출퇴근 == '출근':
    df_출퇴근 = top_20_m
else:
    df_출퇴근 = top_20_e

# %%
# 지도 생성
center = [37.541, 126.986]
# center on Liberty Bell, add marker
bike_map = folium.Map(location=center, zoom_start=13)
# 스타일 지정 예시 (선의 색상, 두께 등)
style = {
    'color': 'red',
    'weight': 3,
    'opacity': 0.7,
}

fg0 = folium.FeatureGroup(name="bike_road", show=False).add_to(bike_map)
# 자전거 도로 표시
# GeoJSON 파일을 불러와 스타일 적용
folium.GeoJson(
    geo_str,
    name='bike_road',
    style_function=lambda x: style
).add_to(fg0)

fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)
# 자전거 대여소 표시
for i, row in df_출퇴근.iterrows():
  # folium.Marker(
    #folium.CircleMarker(
    folium.Circle(
      location = [row['위도'], row['경도']],
      radius = 100,
      color='black',                  # 외곽선 색상
      fill=False,                     # 채우기 여부
      fill_color='blue',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      #popup=row['대여소번호'],             # 클릭 시 표시되는 팝업
      tooltip=row['대여소명_y'],                 # 마우스 오버 시 표시되는 툴팁
      #icon=folium.Icon(icon = 'bookmark', color = 'blue')
  ).add_to(fg1)

fg2 = folium.FeatureGroup(name="train_station", show=False).add_to(bike_map)
# 지하철역 표시
for i, row in df_train_station.iterrows():
  folium.CircleMarker(
      location = [row['lat'], row['lng']],
      radius=2,                     # 반지름 (픽셀 단위)
      color='yellow',                  # 외곽선 색상
      fill=True,                     # 채우기 여부
      fill_color='yellow',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      popup=row[' seoulmetro_code'],             # 클릭 시 표시되는 팝업
      tooltip=row[' station_name(kor)']                 # 마우스 오버 시 표시되는 툴팁      
  ).add_to(fg2)

# 자치구 구분 표
geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))
choropleth = folium.Choropleth(geo_data = geo_str2,
                  data = have_bikes,
                  name = 'gu',
                  key_on = 'feature.properties.SIG_KOR_NM',
                  fill_color = 'Blues')
# 1. GeoJsonTooltip을 사용하는 방법:
# folium.GeoJsonTooltip(fields=['SIG_ENG_NM'],
#                       aliases=['지역:'],
#                       style=('background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;')
# ).add_to(choropleth.geojson)
# 2. GeoJsonPopup을 사용하는 방법:
folium.GeoJsonPopup(fields=['SIG_KOR_NM'],
                    aliases=['지역:'],
                    style='font-weight: bold;'
).add_to(choropleth.geojson)
choropleth.add_to(bike_map)

folium.LayerControl().add_to(bike_map)

# jupyter 에서 곧장 지도 표시하기
#bike_map

# web에서 표시하기
# 지도 저장

bike_map.save("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
import webbrowser
webbrowser.open("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
# Out:
# True

# %% [markdown]
# -------------------------------------------------
