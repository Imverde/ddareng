# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'
filename = '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2020.parquet'
start_time = time.time()
df_2020 = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df_2020.head(5)
# Out:
# read_parquet time : 5.443434476852417
#          대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0  2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1
# 1  2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1
# 2  2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1
# 3  2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1
# 4  2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1
#
#      운동량   탄소량  이동거리(M)  이용시간(분)
# 0  53.86  0.32   1360.0        6
# 1  10.04  0.09    390.0        3
# 2  75.14  0.64   2750.0       24
# 3  28.42  0.18    780.0        3
# 4  52.97  0.41   1760.0       11

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2020)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  19026024             0          0.000000
# 1      대여시간  19026024             0          0.000000
# 2     대여소번호  19026024             0          0.000000
# 3      대여소명  19026024             0          0.000000
# 4    대여구분코드  19026024             0          0.000000
# 5        성별   9530047       9495977         49.910465
# 6     연령대코드  19026024             0          0.000000
# 7      이용건수  19026024             0          0.000000
# 8       운동량  18906625        119399          0.627556
# 9       탄소량  18906625        119399          0.627556
# 10  이동거리(M)  19026024             0          0.000000
# 11  이용시간(분)  19026024             0          0.000000

# %%
sorted(dict(df_2020['대여소명'].value_counts()).items(), key=lambda x:x[1])
# Out:
# [('2726.서울식물원 주제원입구', 1),
#  ('3108.서울홍성교회', 1),
#  ('3562.행당중학교 후문', 1),
#  ('3703. 신성교회 앞', 1),
#  ('1766.소피아 관광호텔 앞', 1),
#  ('1476.중목초등학교 앞 육교', 1),
#  ('496.마포아트센터 앞', 1),
#  ('1769.신동아아파트 교차로', 1),
#  ('3601.용답역 2번출구 앞', 1),
#  ('2073.동작상떼빌 103동 앞', 2),
#  ('3576.강변SK뷰 APT앞', 2),
#  ('3776. 김포공항교차로', 2),
#  ('2705.홈플러스(가양점)', 2),
#  ('1687. 서울월드컵경기장 테스트', 2),
#  ('도봉센터', 2),
#  ('3765. 문소빌딩', 3),
#  ('종묘센터', 3),
#  ('3118.연대 정문앞', 3),
#  ('훈련원센터', 3),
#  ('2546.한신18차아파트', 3),
#  ('861.삼익상가 앞', 3),
#  ('4617. 동원베네스트 건너편', 3),
#  ('3572.중곡동 성당', 4),
#  ('4604. 원효로다목적체육관 앞', 4),
#  ('3761. 나이아가라관광호텔', 4),
#  ('3753. 공항중학교 버스정류장', 4),
#  ('4776. 신세계면세점', 4),
#  ('4618. 풍전아파트 건너편', 5),
#  ('4627. 효창공원앞역 5번출구 옆', 5),
#  ('1475.보도 육교(타이어뱅크앞)', 5),
#  ('3788. 정곡나들목', 5),
#  ('4785. 롯데시티호텔', 6),
#  ('4775. 을지로지하쇼핑센터', 6),
#  ('9990_도봉센터', 6),
#  ('4772. 중앙일보', 7),
#  ('4774. 을지로입구역 8번출구', 7),
#  ('99998. 상암단말정비', 7),
#  ('4116. 이문e편한세상아파트 앞', 7),
#  ('4616. 신용산지하차도 앞', 8),
#  ('3714. 송천센트레빌', 8),
#  ('4762. 국제빌딩', 8),
#  ('3782. 겸재정선미술관', 9),
#  ('천왕센터', 9),
#  ('3778. 김포공항입구 교차로', 9),
#  ('4107. 장안동근린공원 입구', 9),
#  ('2394. 래미안강남포레스트 입구 (보도육교)', 9),
#  ('4112. 신이문빗물펌프장 옆', 9),
#  ('4103. 휘경sk뷰아파트 앞', 9),
#  ('1623. 노원 구민회관', 9),
#  ('4123. 배봉초교 교차로', 10),
#  ('4602. 숙명여대앞 버스정류소 주변', 10),
#  ('3301.도림천 신림2교 ', 10),
#  ('천호센터', 10),
#  ('4362. 행당중학교 후문', 11),
#  ('3763. 등촌태영아파트', 12),
#  ('3787. 가양나들목', 13),
#  ('3767. 대원빌딩', 13),
#  ('3655. 둔촌신성미소지움아파트', 13),
#  ('9980. 에이텍', 14),
#  ('4761. 탐앤탐스 을지로3가점', 14),
#  ('4110. 용두롯데캐슬리치아파트 앞', 14),
#  ('4654. OK부동산 앞', 14),
#  ('4117. 휘경119안전센터 앞', 15),
#  ('4360. 르노삼성자동차 성수사업소 앞', 15),
#  ('4778. 대신파이낸스센터', 16),
#  ('사대문센터', 16),
#  ('3775. 가양오토갤러리', 16),
#  ('3522. 사근삼거리', 17),
#  ('4784. 중부경찰서앞 사거리', 17),
#  ('4102. 휘경1동주민센터 앞', 18),
#  ('9998. 영남주차장 정비센터', 18),
#  ('4105. 하나은행 장안동지점앞', 19),
#  ('3707. 드래곤타워 앞', 19),
#  ('4605. 노들섬 다목적홀(동쪽) 숲, 앞', 19),
#  ('3784. 벽산아파트', 20),
#  ('4791. 명동역9번 출구', 21),
#  ('4403. 하월곡동 광명비전교회 앞', 21),
#  ('3711. 월계2교 교차로', 21),
#  ('3780. 등촌서광아파트', 23),
#  ('3756. 마곡힐스테이트 정문', 23),
#  ('4121. 서울문화재단 앞', 25),
#  ('4653. LG 베스트샵 앞', 27),
#  ('4122. 청계9가교차로 앞', 27),
#  ('3772. 길성그랑프리텔아파트', 27),
#  ('4113. 한국국방연구원 앞', 29),
#  ('9993. 개화정비', 33),
#  ('2543.경문고교 사거리', 34),
#  ('4353. 코오롱디지털타워 3차앞', 34),
#  ('3789. 염창나들목', 37),
#  ('4104. 외대앞역 교차로', 37),
#  ('2194.봉림교 남측', 40),
#  ('3769. 가양동 이마트 앞', 64),
#  ('4710. 자교교회 앞', 100),
#  ('2417.선정릉 일등 추어탕 앞', 119),
#  ('99999. 영남단말기정비', 126),
#  ('4076. 진영상운 앞 중랑천 변', 130),
#  ('2394. 개포래미안포레스트아파트 107동 앞', 130),
#  ('3902. 항동지구5단지 501동 앞', 142),
#  ('580. 신금호역 3번출구 뒤', 150),
#  ('상암센터 정비실', 156),
#  ('859.남산공원 야외식물원 앞', 160),
#  ('1087.레미안 솔베뉴(양재대로)', 171),
#  ('2534.신흥교(애견훈련소)', 174),
#  ('3903. 현대아파트 앞', 179),
#  ('2536.서초종합체육관 입구', 180),
#  ('중랑센터', 189),
#  ('3802. 관악구민체육센터', 196),
#  ('9997.강남센터', 200),
#  ('1550.삼각산아이원아파트(105동 옆)', 204),
#  ('669.청계신한신휴플러스앞 삼거리', 213),
#  ('1397.래미안월곡아파트 (창문여고 건터편)', 213),
#  ('2547.포드서초서비스센터앞', 224),
#  ('2391. 구룡터널 입구(개포1단지아파트)', 231),
#  ('3652. 한영외국어고등학교', 258),
#  ('2287. 능안마을입구', 263),
#  ('2539.대한무역투자진흥공사 KOTRA 앞', 268),
#  ('1114. 서남물재생센터 버스정류장', 268),
#  ('1392.돈암삼성풍림아파트', 277),
#  ('865.하얏트호텔 앞', 298),
#  ('2395. 개포1단지아파트 입구 (보도육교)', 299),
#  ('4108. 답십리파크자이아파트 앞', 301),
#  ('3906. 천왕차량사업소 입구', 336),
#  ('2736.마곡엠벨리7단지 M타워', 338),
#  ('2288. 안골마을입구', 345),
#  ('1082.중앙보훈병원역3번출구', 378),
#  ('330. 청계천 한빛광장', 387),
#  ('3527. 왕십리 자이아파트', 389),
#  ('2096.서울특별시 동작관악교육지원청', 389),
#  ('447. 신영동삼거리', 400),
#  ('3404.서울특별시 중부교육지원청', 402),
#  ('2659.서울친환경유통센터', 414),
#  ('3003.래미안신공덕3차아파트', 436),
#  ('484.도동삼거리', 440),
#  ('1572.우이산 입구', 442),
#  ('3564.나루마당', 459),
#  ('1566.삼각산 아이언APT앞', 463),
#  ('3401.창신두산아파트', 473),
#  ('2200.관악문화원 건너편', 479),
#  ('2541.옛골 입구', 491),
#  ('위트콤', 499),
#  ('1680. 삼육대 제3과학관', 504),
#  ('4702. 평창동 꽃여울(꽃집),스타벅스 앞', 504),
#  ('3013.서울지방고용노동청 앞', 507),
#  ('1383.성북동 주민센터 건너편', 508),
#  ('3556.신금호파크자이APT앞', 518),
#  ('1393.돈암육교 하단', 520),
#  ('3306.서울신우초등학교', 540),
#  ('1770.강북성복교회 주변', 552),
#  ('1467.sk신내 주유소앞(용마산로)', 553),
#  ('3905. 희훈타워빌 앞', 553),
#  ('2532.국립국악원 앞', 557),
#  ('3112.독립문역 5번 출구', 561),
#  ('974.연신초등학교옆 마을마당', 562),
#  ('855.이촌역5번출구 앞', 587),
#  ('991.흥국사 정류장', 590),
#  ('2286. 탑성마을입구', 612),
#  ('3430.구기치안센터 앞', 622),
#  ('1564.4.19민주묘지역 1번출구', 634),
#  ('2093.상도SH빌아파트 입구', 641),
#  ('2545.국립중앙도서관(국제회의장옆)', 645),
#  ('494.신수동주민센터', 653),
#  ('482.예수소망교회', 665),
#  ('상담센터', 666),
#  ('2079.중앙대학교 정문', 682),
#  ('1066.생태공원앞 교차로(조명탑)', 692),
#  ('3563.구의7단지현대아파트', 699),
#  ('2425.세곡동 사거리(대왕초등학교 정류장)', 700),
#  ('1379.길음뉴타운푸르지오아파트 3단지', 702),
#  ('3904. 테크노마트 앞', 706),
#  ('3561.행당동 삼부APT후문', 727),
#  ('3418.창신역2번 출구', 730),
#  ('2392. 구룡산 입구 (구룡산 서울둘레길 입구)', 739),
#  ('462. 신영동삼거리(북악터널방향)', 743),
#  ('2722.마곡 문영비지윅스', 759),
#  ('1910. 낙원교회 맞은편', 769),
#  ('315. 신한은행 안국역지점 옆', 780),
#  ('2180. 신림동주민센터', 786),
#  ('2094.숭실대학교(중문) ', 787),
#  ('977.신도중학교앞', 796),
#  ('1463.중랑구민회관', 798),
#  ('1836. 금천구립 독산도서관', 812),
#  ('2393. 구룡사 앞 교차로 (보도육교)', 815),
#  ('2517.서초3교(효령로69길 방면)', 822),
#  ('2386. 논현동 279-165', 823),
#  ('2612. 문정·가락 대여소 앞', 833),
#  ('2275. 염곡치안센터 건너편', 839),
#  ('681.서울특별시 동부교육지원청(육교)', 840),
#  ('2914.서울과학기술대학교(미래관)', 844),
#  ('3133.핀란드 타워앞', 856),
#  ('3555.양지사거리(센트라스APT 115동앞)', 869),
#  ('2514.사평역 2번출구', 876),
#  ('2816.항동지구 8단지 803동옆(주차장입구)', 895),
#  ('1675. 월계문화체육센터', 905),
#  ('2533.한가람미술관 앞', 917),
#  ('3431.로제우스 레포츠센터', 947),
#  ('2417.선정릉 디캠프(D.CAMP)앞', 949),
#  ('710. 금옥여고보도육교', 958),
#  ('3429.AW컨벤션앞', 961),
#  ('2199.신봉천주유소', 969),
#  ('2548.반포1동 자율방범초소 옆', 972),
#  ('2519.서초2교(사임당로 방면)', 976),
#  ('858.녹사평역3번 출구', 987),
#  ('2092.흑석한강푸르지오(110동)', 989),
#  ('995.은평다목적체육관', 1000),
#  ('2805.구로자원순환센터 ', 1002),
#  ('973.제각말푸르지오 5-1단지 아파트', 1011),
#  ('523. 옥수동성당 옆', 1018),
#  ('2650.위례22단지 2208동 다리앞', 1021),
#  ('992.북한산입구 정류장', 1024),
#  ('1089.고덕 래미안힐스테이트(201동)', 1026),
#  ('3547.상왕십리역 6번 출입구', 1031),
#  ('3428.서울미술관', 1048),
#  ('1861.IBK기업은행 석수역 지점 앞', 1051),
#  ('2427.개포고등학교 정문앞', 1073),
#  ('1072.고덕역 5번출구', 1085),
#  ('827. 국군복지단', 1090),
#  ('854.HID 유족동지회 앞', 1093),
#  ('3117.이화여대 인문관 인근', 1135),
#  ('3305.낙성대역 8번 출구', 1149),
#  ('3111.무악재역 4번 출구', 1159),
#  ('2428.롯데리아 개포점앞', 1167),
#  ('710. 서부화물트럭터미널 사거리', 1176),
#  ('3126.남가좌동 제2공영주차장', 1190),
#  ('3532. 왕십리KCC스위첸아파트', 1193),
#  ('3531. 논골사거리(금호도서관 입구)', 1201),
#  ('3109.북한산더샾 106동 앞', 1214),
#  ('1558.강북문화정보도서관', 1214),
#  ('2416.한티역 6번 출구', 1217),
#  ('2806.항동지구 4단지 입구', 1230),
#  ('298.KBS 연구동 건너편', 1252),
#  ('2809.항동지구 11단지 1103동 앞', 1291),
#  ('994.북한산생태공원입구(교통섬)', 1292),
#  ('1406. 망우청소년수련관', 1300),
#  ('564. 금호역 3번출구', 1303),
#  ('2810.항동지구 3단지 311동 앞', 1305),
#  ('2343. 세곡사거리 대왕파출소 앞', 1305),
#  ('1573.현대성우아파트 옆', 1310),
#  ('3426.독립문역 2번출구 뒤', 1319),
#  ('1064.중앙보훈병원역 1번출구', 1351),
#  ('477.앰배서더 호텔 주변', 1362),
#  ('2403. 공무원연금매점 교차로 (개포주공9단지 입구)', 1379),
#  ('975.백련산 힐스테이트상가앞', 1383),
#  ('3524. 세종대학교', 1390),
#  ('2516.본마을 노인복지센터 앞', 1398),
#  ('465. 삼청공원 앞', 1412),
#  ('3006. 상암월드컵파크5단지(상암중학교)', 1415),
#  ('1242. 문정 법조단지6', 1418),
#  ('2078.흑석 아크로리버하임(103동)', 1418),
#  ('2813.항동지구 3단지 302동 앞', 1419),
#  ('1071.명일근린공원공동체텃밭', 1427),
#  ('2207. 내곡파출소 뒤 정자', 1430),
#  ('469.회현역 1번출구', 1431),
#  ('444.서울역3번 출구', 1432),
#  ('937. 상림마을 롯데캐슬2단지 옆', 1432),
#  ('483.남산타운아파트 버스정류장', 1436),
#  ('3403.서울특별시 교육청', 1442),
#  ('867.서빙고역 광장(1번출구)', 1446),
#  ('3551.성동도로사업소', 1458),
#  ('2289. 남태령역 2번출구', 1475),
#  ('767.신정숲속마을아파트', 1484),
#  ('297.국회3문', 1495),
#  ('479.동대입구역 3번 출구', 1496),
#  ('1477.면목삼익아파트 앞', 1497),
#  ('2068. 총신대 앞(육교)', 1505),
#  ('2822.제니스스포츠 앞', 1507),
#  ('2812.항동프라자', 1510),
#  ('851.효창 푸르지오 앞', 1511),
#  ('1855. 성지아파트 옆 도로변', 1530),
#  ('1424. 양원역 2번출구', 1548),
#  ('2225.백석예술대학교 제3캠퍼스 앞', 1553),
#  ('3427.인왕산 아이파크 정문', 1555),
#  ('3304.낙성대역 5번 출구', 1563),
#  ('3221.서울특별시 남부교육지원청', 1564),
#  ('847. 국방부민원실옆', 1579),
#  ('3132.홍제교', 1580),
#  ('480.약수역 6번 출구', 1598),
#  ('1756.서울북부광역등기국', 1651),
#  ('1866.서울안천초등학교 옆', 1676),
#  ('2334. 삼호아파트 2동 ( 간선도로)', 1690),
#  ('1864.산호시티빌 옆', 1694),
#  ('1007.암사동 선사유적지', 1696),
#  ('295.영등포공원 분수대 앞', 1700),
#  ('2649.오금공원사거리2', 1705),
#  ('1039. 고덕초등학교', 1712),
#  ('2518.서초3교(효령로70길 방면)', 1715),
#  ('2201. 본마을 정류소 앞', 1721),
#  ('3588.세종대학교(영실관)', 1722),
#  ('1069.강동경희대학교병원 입구', 1726),
#  ('3503. 광진유진스웰', 1726),
#  ('429. 송도병원', 1729),
#  ('1713. 쌍문동 이안아파트 앞', 1745),
#  ('373. 청구 어린이공원', 1758),
#  ('489.구룡근린공원', 1760),
#  ('968. 은평뉴타운 상림마을 13단지', 1765),
#  ('2535.신반포역 3번출구 뒤', 1766),
#  ('2376. 수서역 6번출구 앞', 1768),
#  ('1067.한영중고앞사거리', 1780),
#  ('1466.두산대림아파트 삼거리', 1782),
#  ('2527.반포중학교 앞(세화여고 맞은편)', 1787),
#  ('2817.천왕이펜하우스5단지 앞', 1788),
#  ('3310.영락고등학교', 1795),
#  ('2088.상도중앙하이츠빌 입구', 1800),
#  ('671.대광빌딩', 1807),
#  ('3114.충정로역 3번 출구', 1811),
#  ('2716.롯데 R&D 센터', 1813),
#  ('863.이촌역2번 출구', 1813),
#  ('2083.흑석롯데캐슬에듀포레(107동)', 1818),
#  ('2826.가마산지하보도 옆', 1819),
#  ('486. 평창동주민센터 앞', 1822),
#  ('2609. 보성중고등학교 후문 앞', 1832),
#  ('556. 달맞이공원', 1841),
#  ('1865.금천구청앞(M빌딩)', 1843),
#  ('381. 장충체육관', 1846),
#  ('2426.강남한신휴플러스 6단지', 1863),
#  ('2815.항동지구 7단지 정문', 1874),
#  ('2521.서초 크로바타워 앞', 1883),
#  ('2226. 신동아럭스빌아파트 앞', 1889),
#  ('1863.위너스 스포츠클럽 골프연습장옆', 1896),
#  ('1969. 궁동생태공원', 1913),
#  ('2190.도원맨션', 1926),
#  ('3005.마포구청 청사내', 1928),
#  ('3134.SK리쳄블(상수도사업본부)', 1928),
#  ('2818.천왕이펜하우스3단지 앞', 1931),
#  ('2061. 한강 현대아파트 건너편', 1937),
#  ('2141. 미림여고입구 교차로', 1945),
#  ('2520.서초1교 (진흥아파트 방면)', 1946),
#  ('2430.강남파이낸스센터앞(역삼역2번출구)', 1951),
#  ('1070.(시립)고덕평생학습관', 1952),
#  ('3539. 서원마을', 1954),
#  ('978.녹번 힐스테이트상가앞', 1955),
#  ('1079.강일동입구교차로', 1973),
#  ('3419.국립어린이과학관', 1976),
#  ('491.월드컵파크 4단지', 1976),
#  ('2549.LH 서초 4단지 403동', 1986),
#  ('434. 신당 래미안 버스정류장', 1988),
#  ('3127.홍은2파출소 옆', 1998),
#  ('3307.봉천고개 육교', 2004),
#  ('1376. 한국과학기술연구원 중문', 2008),
#  ('1679. 삼육대 도서관', 2015),
#  ('3553.마장역3번출구', 2025),
#  ('2319. 포스코사거리 서측(수협 삼성동 지점)', 2026),
#  ('848. 삼각지12번 출구', 2046),
#  ('485.서울역4번출구', 2071),
#  ('1979. 구로1동우체국 앞', 2072),
#  ('1018. 둔촌 주공 GS 맞은편', 2073),
#  ('468.웨스틴 조선호텔', 2080),
#  ('3557.서울숲리버뷰자이APT105동 앞', 2090),
#  ('667.청량차도 육교 밑', 2100),
#  ('467.한국은행', 2103),
#  ('976.진관고등학교앞', 2110),
#  ('3203.도림동배드민턴체육관', 2114),
#  ('2283. 그룹한빌딩옆', 2127),
#  ('3425.광화문 풍림스페이스본 1단지앞', 2127),
#  ('2257. 하나로클럽 양재점 맞은편', 2128),
#  ('442.서울역 서부', 2128),
#  ('1868.우리은행 시흥남자동화점 앞', 2132),
#  ('2808.항동지구 2단지 202동 앞', 2139),
#  ('2038. 동작역 7번출구', 2141),
#  ('1774.반석교회(쌍문동)', 2145),
#  ('2804.항동지구 6단지 602동 앞', 2148),
#  ('2351. 청소년수련관(수영장)앞', 2152),
#  ('3008.DMC역7번출구', 2153),
#  ('1083.광문고교사거리(아이파크)', 2155),
#  ('1391.성북청소년센터', 2156),
#  ('1031. 암사동 CBIS', 2162),
#  ('441.염천교사거리', 2171),
#  ('2627.문정시영아파트 5동 앞 공원', 2171),
#  ('449. 일성아파트', 2178),
#  ('2712.화곡터널입구교차로', 2194),
#  ('2419.봉은사역 1,2번 출구 ', 2197),
#  ('1422. 신내우디안아파트 1단지', 2209),
#  ('4711. 올림픽기념 국민생활관 로터리', 2230),
#  ('2526.반포경남쇼핑 앞', 2240),
#  ('2657.송파 파인타운 11단지 ', 2241),
#  ('2510. JW타워', 2245),
#  ('1746. 다이소방학점 앞', 2248),
#  ('1065.보훈병원 정문옆(중앙대영약국)', 2256),
#  ('776.목마공원', 2258),
#  ('2383. 보금자리정원', 2264),
#  ('3577.신자초교 입구 교차로(SC제일은행)', 2267),
#  ('1386.동선고가차도 초입', 2267),
#  ('2284. CJ오쇼핑앞', 2276),
#  ('938. 금암 문화공원', 2298),
#  ('2282. 방배래미안아트힐 101동앞', 2306),
#  ('679.전농SK아파트 앞', 2315),
#  ('1545. 솔샘역 2번 출구', 2320),
#  ('1751. 창원초등학교 교차로', 2328),
#  ('1757.솔밭공원역 1번출구 앞', 2329),
#  ('1101. 개화동상사마을종점 버스정류장', 2332),
#  ('1377. 한국과학기술연구원 북문', 2336),
#  ('857. 현대 안성타워', 2341),
#  ('2825.초롱타운 앞', 2343),
#  ('969. 은평 지웰테라스', 2351),
#  ('2184. 구암초등학교 버스정류장', 2353),
#  ('1553.예수그리스도후기성도교회 앞', 2365),
#  ('1571.북서울 꿈의 숲 입구', 2367),
#  ('1342. 성북쉼터 앞', 2372),
#  ('1714. 도봉문화정보도서관 삼거리', 2378),
#  ('993.은평뉴타운 온뜨락아파트앞', 2380),
#  ('672.대광고등학교', 2400),
#  ('2422.수서동 성당 맞은편', 2419),
#  ('2368. 도곡동 경남아파트 건너편', 2427),
#  ('2421. 신논현역 4번출구', 2432),
#  ('812. 용산전쟁기념관', 2434),
#  ('868.롯데하이마트 용산점 앞', 2462),
#  ('2319. 포스코4거리 서측(수협 삼성동 지점)', 2470),
#  ('476.광희문', 2487),
#  ('2907. 월계중학교', 2488),
#  ('1421. 신내역 4번출구', 2503),
#  ('924. 메뚜기다리', 2508),
#  ('1263. 장지공영차고지', 2508),
#  ('422. 문화비축기지', 2509),
#  ('3311.서울대입구역 4번 출구', 2520),
#  ('608. 전농삼성아파트', 2520),
#  ('1453. 중랑캠핑숲', 2521),
#  ('2160. 관악구 보건소', 2525),
#  ('724. 계남공원 입구 주출입구 좌측', 2527),
#  ('1511. 번동 금호어울림아파트102동앞', 2531),
#  ('1574.송중초등학교 옆', 2546),
#  ('1541. 삼양역', 2555),
#  ('1445. 용마지구대', 2556),
#  ('2814.항동지구 10단지 1001동 앞', 2557),
#  ('1037. 강일리버파크 6단지', 2559),
#  ('2401. 밀알학교 입구 (삼성서울병원 입구)', 2564),
#  ('591. 건국대학교 (행정관)', 2577),
#  ('3113.독립문역사거리', 2584),
#  ('2352. 서울본부세관(건설회관 앞)', 2592),
#  ('1770.도봉한신아파트 주변', 2592),
#  ('616. 서울시립대 앞', 2594),
#  ('3414.종로5가역 4번출구', 2617),
#  ('4652. 신사두산위브2차아파트 앞', 2619),
#  ('2807.항동지구 1단지 105동 앞', 2623),
#  ('1992. 구로구배드민턴실내체육관 앞', 2625),
#  ('1816. 금천폭포공원 앞', 2628),
#  ('2269. 주홍교 하부', 2650),
#  ('2550.양재동 꽃시장 건너편', 2653),
#  ('451. 청와대앞길', 2657),
#  ('823. 효창동주민센터 앞', 2659),
#  ('2390. 구룡마을 입구 (래미안블레스티지 아파트)', 2660),
#  ('1200. 개화광역환승센터', 2662),
#  ('2186.우리은행 낙성대역지점', 2674),
#  ('2196.삼화페인트 봉천점', 2680),
#  ('3122.북가좌삼거리2', 2681),
#  ('948. 디지털미디어 시티역 4번출구', 2688),
#  ('3129.DMC래미안e편한세상203동옆', 2692),
#  ('1435. 능산삼거리', 2702),
#  ('2515.서초초등학교 후문', 2707),
#  ('1678. 성서대학교 밀알관', 2710),
#  ('2406. 논현동 광명빌딩 앞', 2712),
#  ('2086.삼일수영장 앞', 2713),
#  ('1365. 선잠단지 앞', 2716),
#  ('1759.서울북부지방법원 앞', 2720),
#  ('1388.커핀그루나루', 2722),
#  ('3402.이화공영주차장', 2724),
#  ('2634.위례포레샤인아파트 2318동', 2724),
#  ('481.신당역 10번 출구', 2725),
#  ('600. 휘경2동 주민센터', 2732),
#  ('1063.강동롯데캐슬퍼스트 아파트(관리동)', 2734),
#  ('2095.경문고등학교 앞', 2753),
#  ('1857. 주공14단지', 2778),
#  ('3123.DMC파크뷰자이1단지 110동 앞', 2778),
#  ('2654.올림픽선수촌아파트 136동 앞', 2786),
#  ('1352. e 편한세상 보문아파트 내', 2788),
#  ('1054. 말우물 어린이 공원', 2790),
#  ('966. 서울혁신파크1', 2792),
#  ('2382. 역삼동 sk뷰 501동앞', 2792),
#  ('2082.7호선 이수역7번출구', 2793),
#  ('470.회현역 7번출구', 2793),
#  ('2329. 르네상스호텔사거리 역삼지하보도 2번출구', 2796),
#  ('1283. 오금공원 사거리', 2799),
#  ('569. 응봉현대아파트 정류소', 2805),
#  ('1870.독산3동주민센터 앞', 2806),
#  ('1085.래미안 솔베뉴(고덕로)', 2820),
#  ('3125.연희파크푸르지오아파트 앞', 2824),
#  ('3116.신촌역 4번출구', 2825),
#  ('1761.방학중학교 앞', 2832),
#  ('1748. 피자헛 앞(도봉병원 옆)', 2834),
#  ('866.브라운스톤 남산아파트', 2845),
#  ('2371. 한국우편사업진흥원', 2849),
#  ('2626.경찰병원역 1,2번 출구 사이', 2854),
#  ('3100. 북성초교', 2863),
#  ('2354. 청담역 2번출구', 2870),
#  ('2336. 강남세브란스교차로  래미안그레이튼 104동 앞', 2882),
#  ('1038. 강일 다솜 어린이 공원', 2885),
#  ('1510. 번동주공5단지 관리사무소 앞', 2899),
#  ('1472.영성빌딩(PAT)', 2900),
#  ('2358. 구룡초사거리 (현대아파트10동 앞 )', 2909),
#  ('2258.구룡사 삼거리', 2913),
#  ('2198.사랑의병원', 2915),
#  ('1730. 도봉산역 교차로 앞', 2915),
#  ('1772.시립도봉노인복지관 버스정류소', 2918),
#  ('2272. 교대입구 교차로', 2927),
#  ('2537.양재역 8번출구 앞', 2946),
#  ('1847. 독산주공 14단지 버스정류소', 2946),
#  ('2071. 대림아파트 후문 상가 옆', 2946),
#  ('3521. 현대홈타운 뒷길', 2947),
#  ('2905.중계주공6단지', 2950),
#  ('1513. 강북구청 뒷편', 2962),
#  ('1410. 면목 대원칸타빌아파트', 2966),
#  ('1551.4.19탑 앞', 2975),
#  ('1696.수락리버시티4단지', 2979),
#  ('2524.반포쇼핑타운 8동 앞', 2984),
#  ('1427. 용마산역 1번출구', 2985),
#  ('1731. 도봉고등학교 맞은편', 2997),
#  ('1304. 만해공원', 2998),
#  ('2064. 흑석한강푸르지오 106동앞', 3003),
#  ('2304. 신영 ROYAL PALACE 앞', 3030),
#  ('2040. 비계 버스정류소', 3032),
#  ('1853. 서울디자인직업전문학교 앞', 3037),
#  ('2350. 래미안그레이튼102동앞', 3046),
#  ('3530. 왕십리자이아파트 후문(삼거리)', 3056),
#  ('159. 이대역 4번 출구', 3057),
#  ('2819.하늘숲초등학교 앞', 3064),
#  ('2249. 우솔초등학교 맞은편', 3071),
#  ('475.DDP 패션몰', 3072),
#  ('2415.한티역 롯데백화점 앞', 3075),
#  ('1395.래미안장위포레카운티(102동)', 3076),
#  ('1951. 천왕이펜하우스 4단지 상가 앞', 3088),
#  ('1479.면목 홈플러스 2 ', 3093),
#  ('1052. 리싸이클시티', 3100),
#  ('1465.중랑공영차고지 옆', 3100),
#  ('1967. 참새공원(백곡경노당)', 3102),
#  ('3558.마장동 금호어울림APT앞', 3108),
#  ('1086.래미안 솔베뉴(구천면로)', 3110),
#  ('2744.강서세무서 앞', 3112),
#  ('2203. 청계산입구역 2번출구', 3126),
#  ('3204.도림고가도로 밑', 3134),
#  ('522. 금호역 1번출구 앞', 3143),
#  ('3115.북아현 치안센터 인근', 3151),
#  ('902. 진관동 은빛초등학교', 3152),
#  ('136. 대흥동 주민센터', 3163),
#  ('621. 동대문중학교 옆', 3165),
#  ('443.호암아트홀', 3168),
#  ('1752. 창동 주공 4단지 입구 옆', 3170),
#  ('1758.북서울교회 버스정류소 앞', 3171),
#  ('651. 우리은행청량리지점앞', 3171),
#  ('352. 중앙고입구 삼거리', 3172),
#  ('971. 역촌 센트레빌 아파트', 3174),
#  ('2418.봉은사역 7번 출구 ', 3175),
#  ('1842. 한울중학교', 3179),
#  ('2292. 무지개아파트 앞', 3187),
#  ('2745.수명초등학교', 3189),
#  ('534. 금호사거리', 3194),
#  ('2506. LG유플러스 (방배사옥)', 3198),
#  ('928. 은평역사한옥박물관', 3206),
#  ('666.이문대성유니드아파트 앞', 3209),
#  ('1426. 면목도시개발아파트 1동 앞', 3220),
#  ('2740.마곡레포츠센터', 3225),
#  ('3110.홍은 현대아이파크 아파트 202동 앞', 3231),
#  ('782.서남병원 후문', 3233),
#  ('2311. 학동로 래미안 아파트 앞', 3233),
#  ('2349. 역삼빌딩 앞(하나은행 옆)', 3245),
#  ('2357. 르네상스호텔사거리 역삼지하보도 3번출구 앞 (더 오번 빌딩 명동칼국수 앞)', 3252),
#  ('2542.신논현타워 앞', 3256),
#  ('3207.양남사거리 교통섬', 3265),
#  ('3543. 세종대학교(학술정보원)', 3267),
#  ('790.화곡고가 사거리', 3278),
#  ('1554.번동사거리', 3313),
#  ('1474.서울중랑우체국', 3329),
#  ('1181. 농수산식품공사 (강서지사)', 3336),
#  ('3410.종로3가역 8번출구', 3338),
#  ('803. 한남초교 앞 보도육교', 3344),
#  ('831. 이태원관광특구입구', 3362),
#  ('3412.세운상가', 3371),
#  ('1869.롯데캐슬골드파크3차 301동 앞', 3380),
#  ('3131.연가교 교차로', 3390),
#  ('1062. 고덕숲 아이파크 2', 3391),
#  ('1397.래미안월곡아파트 (창문여고 건너편)', 3400),
#  ('2823.중앙유통단지 앞', 3400),
#  ('852.청암자이APT(103동)', 3413),
#  ('664. 서울시립대 대학본부', 3417),
#  ('1080.엘웨딩', 3425),
#  ('2528.함지박 사거리', 3440),
#  ('948. 디지털미디어 시티역 4번출구(DMC역)', 3446),
#  ('2229.로고스교회 맞은 편', 3456),
#  ('2084.e편한세상 상도노빌리티 앞', 3483),
#  ('3581.광진광장', 3489),
#  ('2413.도곡역 1번 출구', 3492),
#  ('869.노들섬 동측 앞', 3493),
#  ('3416.동묘앞역 6번출구', 3496),
#  ('985.은평온누리약국앞', 3498),
#  ('1820. 신한은행 시흥대로금융센터지점', 3512),
#  ('1053. 동명근린공원 진입로 (아리수로)', 3513),
#  ('2347. 두산건설 본사', 3515),
#  ('1775.신원리베르텔 앞', 3517),
#  ('2746.수명산파크 4단지 411동 앞', 3525),
#  ('3415.동대문역6번출구', 3539),
#  ('2248. 서초리슈빌S 글로벌 앞', 3544),
#  ('2420.학여울역 사거리(LG베스트샵 앞)', 3546),
#  ('3105. 홍은센트레빌 아파트 앞', 3551),
#  ('1081.트레빌빌딩', 3557),
#  ('2363. 강남 을지병원 교차로', 3561),
#  ('850. KCC용산월츠타워 ', 3572),
#  ('1183. KC 대학교', 3577),
#  ('741. 화곡로 입구 교차로', 3592),
#  ('2241.양재전화국 사거리', 3593),
#  ('1809. LG전자 별관동(호서대 벤처타워 맞은편)', 3623),
#  ('1768.신동아타워 버스정류소', 3623),
#  ('2143. 서울산업정보학교', 3624),
#  ('3406.세종로공원', 3625),
#  ('2388. 강남구 도시관리공단', 3630),
#  ('1188. 롯데중앙연구소', 3643),
#  ('2326. 대치동 삼성로', 3653),
#  ('3206.문래동 주민센터', 3656),
#  ('1717. 시립창동운동장 입구', 3663),
#  ('1316. 고려사대부속중고 건너편 ', 3664),
#  ('952. 서울연신중학교', 3665),
#  ('435. SK 남산빌딩', 3673),
#  ('3128.동신병원 맞은편', 3676),
#  ('1695.월계미륭아파트 정문', 3676),
#  ('1031. 올림픽로 836(아리수로)', 3678),
#  ('979.원풍빌라앞', 3687),
#  ('1480. 용마지구대 옆', 3688),
#  ('1568.4.19민주묘지 입구사거리', 3689),
#  ('299.여의도 순복음교회', 3692),
#  ('1849. 대륭포스트타워5차', 3694),
#  ('1353. 금호어울림센터힐 내', 3709),
#  ('942. 상림마을 생태공원', 3712),
#  ('748. 목동운동장', 3715),
#  ('2165. JK장평타워', 3715),
#  ('2305. MCM 본사 직영점 앞', 3729),
#  ('2085.강남중학교 앞', 3742),
#  ('2130. 영어마을 관악캠프', 3743),
#  ('410. 상암중학교 옆', 3749),
#  ('3587.우성식품 앞', 3759),
#  ('3417.창신3동주민센터', 3762),
#  ('1850. 코오롱테크노밸리', 3764),
#  ('2195.은천교회', 3767),
#  ('2341. 일원역 4~5번 출구 사이', 3775),
#  ('1635. 상계3.4동 주민센터 대여소', 3791),
#  ('2633.송파학사 옆', 3794),
#  ('2041. 사당중학교 버스정류소', 3795),
#  ('137. NH농협 신촌지점 앞', 3800),
#  ('2652.송파 레미니스1단지 102동 앞', 3802),
#  ('2281. 연세사랑병원신관앞', 3816),
#  ('909. 백련산 힐스테이트 3차', 3819),
#  ('3420.성균관대입구사거리(맥도날드)', 3819),
#  ('139. 연세대 정문 건너편', 3821),
#  ('959. 구파발10단지 인근', 3824),
#  ('982.유니클로 은평점앞', 3833),
#  ('1728. 서울북부지방법원', 3836),
#  ('2091.이수역9번출구(맥도날드)', 3841),
#  ('2090.기아자동차 사당점 앞', 3843),
#  ('163. 명지전문대학교 정문 앞', 3852),
#  ('196. 연희교차로 인근', 3853),
#  ('394. 경희궁 자이 3단지', 3858),
#  ('1976. 남구로역 5번 출입구 앞', 3863),
#  ('127. 현대벤처빌 앞', 3865),
#  ('3582.화양동 우체국', 3867),
#  ('2903.월계초안아파트 1단지', 3872),
#  ('3130.가재울사거리', 3874),
#  ('3578.중곡동 파크웨이빌딩', 3875),
#  ('1999. 수궁동 성당 주변', 3880),
#  ('1241. 문정 법조단지5', 3890),
#  ('1366. 일신초등학교 옆', 3895),
#  ('2655.송이공원', 3898),
#  ('774.등촌역 4번 출구 ', 3904),
#  ('1469.먹골역 4번출구', 3910),
#  ('1547. 꿈의숲 롯데캐슬', 3910),
#  ('3423.현대그룹(본사)', 3920),
#  ('1056. 강일리버파크 7~11단지', 3932),
#  ('1968. 동인오피스텔 건너편 소공원', 3939),
#  ('575. 중앙농협 중곡지점', 3945),
#  ('808. 서빙고동 금호맨션 앞', 3953),
#  ('1693. 원자력 병원', 3967),
#  ('2223. 방배래미안 정문 앞', 3975),
#  ('965. 서울특별시 은평병원', 3980),
#  ('921. 신도고등학교', 3981),
#  ('2062. 사당새마을금고', 3984),
#  ('3211.신길 래미안 프레비뉴', 3987),
#  ('1852. 혜명양로원 담장 옆', 3994),
#  ('638. 서울시립대 정보기술관', 3997),
#  ('1367. 길음문화복합미디어센터', 4013),
#  ('2189.삼성서비스센터(관악점) ', 4016),
#  ('2323. 주식회사 오뚜기 정문 앞', 4021),
#  ('676.FITI시험연구원 앞', 4024),
#  ('2089.사당역10번출구(금강빌딩)', 4030),
#  ('2920.상계중학교(당현2교사거리)', 4034),
#  ('2658.가락몰 업무동', 4034),
#  ('967. 서울혁신파크2', 4037),
#  ('822. 이촌1동 마을공원', 4051),
#  ('436. 이대역 5번출구', 4064),
#  ('775.세종그랑시아 앞(102동)', 4068),
#  ('3121.가좌삼거리', 4073),
#  ('337. 창경궁 입구', 4077),
#  ('1971. 오정초교 앞 보도육교', 4086),
#  ('2309. 청담역(우리들병원 앞)', 4092),
#  ('2742.강서구민올림픽체육센터', 4094),
#  ('1754. 창동시장입구 사거리', 4097),
#  ('3120.DMC엘가아파트 앞', 4099),
#  ('1468.먹골역 7번 출구', 4104),
#  ('1385.성신여대입구역 3번출구 앞', 4104),
#  ('2703.서울도시가스 앞 ', 4107),
#  ('1713. 쌍문동 청소년 랜드', 4108),
#  ('1459. 용마한신아파트사거리', 4116),
#  ('945. 기자촌 사거리', 4122),
#  ('115. 마스타 빌딩 앞', 4140),
#  ('2212.서초현대4차아파트 201동 맞은편', 4145),
#  ('2081.대방1차 e편한세상 앞', 4151),
#  ('466.롯데호텔', 4153),
#  ('594. 중랑물재생센터(서울새활용플라자)', 4164),
#  ('2270. 서초포레스타 7단지', 4164),
#  ('2631.배명고등학교', 4168),
#  ('2191.대학동주민센터 ', 4182),
#  ('2398. 더라움', 4187),
#  ('1823. 상신정비공업 앞', 4187),
#  ('1443. 구립망우청소년독서실', 4196),
#  ('2605. 복정역 1번 출구 앞', 4197),
#  ('964. 북한산힐스테이트 7차아파트', 4202),
#  ('2820.신세기아파트 앞', 4203),
#  ('1471.동양쇼핑 정류소 앞', 4205),
#  ('2339. 현대아파트 정문 앞', 4211),
#  ('2616. 거여동 사거리', 4221),
#  ('2643.풍납중학교 측면', 4224),
#  ('1382.래미안월곡아파트 입구', 4224),
#  ('2625.가락1동 주민센터', 4226),
#  ('1727. 서울도봉초등학교인근', 4236),
#  ('2731.명덕고교', 4242),
#  ('1314. 정릉꿈에그린1단지 201동 앞', 4254),
#  ('1743.창동19단지아파트 관리사무소앞', 4275),
#  ('2298. 래미안서초스위트앞', 4288),
#  ('2008. 노량진근린공원 대방공원', 4290),
#  ('3545.한양대역 1번출구', 4290),
#  ('1370. 복자사랑 피정의 집', 4293),
#  ('2540.반포천 앞', 4296),
#  ('161. 무악재역1번 출구', 4301),
#  ('2210. 반포1동 주민센터 앞', 4302),
#  ('2414. 도곡역 아카데미스위트 앞', 4310),
#  ('1161. 강서면허시험장앞', 4316),
#  ('1973. 오리로와 서해안도로 교차로 앞', 4329),
#  ('1664. 노해근린공원내', 4331),
#  ('1239. 문정 법조단지3', 4334),
#  ('1105. 방화근린공원', 4335),
#  ('424. 롯데하이마트 (상암월드컵점) ', 4338),
#  ('1542. 삼양사거리역', 4349),
#  ('386. 올림픽기념 국민생활관 앞', 4352),
#  ('1068.명일파출소', 4360),
#  ('2713.우장초등학교 앞', 4369),
#  ('1522. 월드전기조명인테리어(우이동)', 4372),
#  ('2743.동신아파트 104동 앞', 4372),
#  ('1862.스타즈호텔독산 빌딩 앞', 4379),
#  ('1258. 가락미륭아파트 앞', 4386),
#  ('2328. 르네상스 호텔 사거리 역삼지하보도 7번출구 앞', 4387),
#  ('1315. 고려사대부속중고 정문', 4392),
#  ('524. 래미안금호하이리버 아파트 102동 옆', 4394),
#  ('1916. 구로중학교앞', 4395),
#  ('2423.영희초교 사거리(래미안개포루체하임)', 4396),
#  ('1464.중화역 4번출구', 4402),
#  ('2159. 인헌초교', 4404),
#  ('233. YP 센터 앞', 4405),
#  ('2529.우리은행 방배동지점 앞', 4408),
#  ('506. 금호 어울림 아파트 앞', 4419),
#  ('1943. 온수역 북측', 4422),
#  ('2718.마곡수명산파크1단지', 4427),
#  ('471.회현사거리 남측', 4448),
#  ('1034. 고덕동 래미안 힐스테이트', 4457),
#  ('941. 은평뉴타운 도서관', 4463),
#  ('1088.풍납사거리(강동)', 4487),
#  ('3573.광나루안전체험관', 4488),
#  ('1396.래미안장위퍼스트하이(513동)', 4506),
#  ('2337. 대모산입구역 2번출구 앞', 4520),
#  ('3007.MBC 앞', 4523),
#  ('343. 예일빌딩(율곡로) 앞', 4527),
#  ('1843. 독산고등학교', 4530),
#  ('1347. 길음래미안아파트817동 상가 앞', 4532),
#  ('2110. 조원동 미성아파트', 4535),
#  ('1765.쌍문역 1번 출구(양산부인과 빌딩)', 4536),
#  ('989.응암 꼬꼬닭치킨호프 앞', 4572),
#  ('2380. 삼성동베이직하우스앞', 4572),
#  ('2312. 청담역 13번 출구 앞', 4589),
#  ('445.대한상공회의소', 4604),
#  ('3201.당산skv1센터', 4605),
#  ('1461.동양엔파트 앞', 4606),
#  ('1418. 새솔초등학교', 4630),
#  ('2077.노들역 3번출구', 4634),
#  ('2509. KT반포지사', 4634),
#  ('2172. 나들목공원', 4645),
#  ('181. 망원초록길 입구', 4657),
#  ('2431.대치역 7번출구', 4662),
#  ('2381. 언주역 6번출구앞', 4666),
#  ('1240. 문정 법조단지4', 4671),
#  ('472.삼일교(시그니쳐 타워)', 4673),
#  ('1744.KT방학지사 앞', 4688),
#  ('2523.뉴코아 킴스클럽 앞', 4704),
#  ('572. 국립정신 건강센터 앞', 4721),
#  ('3215.강변삼성래미안', 4729),
#  ('1831. 메이퀸웨딩컨벤션 앞', 4747),
#  ('2908. 광운대학교 중앙도서관', 4764),
#  ('3552.서울숲 공영주차장앞', 4775),
#  ('1725. 창1동주민센터', 4780),
#  ('1525. 미아동 복합청사', 4781),
#  ('2187.현대시장사거리(신한은행)', 4784),
#  ('2531.멤피스아파트 앞', 4793),
#  ('1266. 문정동 글샘 공원', 4815),
#  ('1560. 도봉세무서 앞', 4821),
#  ('1528. 삼각산동 주민센터', 4825),
#  ('1137. 등촌2동주민센터', 4846),
#  ('1750. 창포원 남쪽 입구', 4848),
#  ('533. 우리은행 금호동 지점 앞', 4853),
#  ('3107. 연희초등학교 앞', 4866),
#  ('1287. 위례아이파크 101동 맞은편', 4868),
#  ('1660. 서울시립과학관', 4885),
#  ('1073.SSTS 몰 앞', 4886),
#  ('927. 연신내역 3번출구 인근', 4890),
#  ('3411.종묘', 4892),
#  ('760. 잣절보도육교 아래', 4911),
#  ('1473.중랑역 1번 출구(중화문화복지센터)', 4913),
#  ('1504. 다이소 삼양시장점', 4923),
#  ('922. 연신내역 4번출구', 4937),
#  ('2502. 서초역1번출구 앞', 4940),
#  ('3212.신풍역 6번출구', 4945),
#  ('2635.잠실새내역 1번출구', 4946),
#  ('2364. 도산대로 렉서스 앞', 4958),
#  ('665.이문동 쌍용아파트 정문', 4960),
#  ('720. 서울강월초등학교 앞', 4964),
#  ('953. 서울연신초등학교', 4969),
#  ('1075.천동초교 삼거리', 4976),
#  ('3550.금호나들목', 4978),
#  ('2647.잠실 자전거 수리센터 앞', 4989),
#  ('1275. 거여초등학교 옆', 4996),
#  ('1700.상계보람아파트 202동 ', 4996),
#  ('2642.마천동 성내천 쉼터', 4999),
#  ('3124.DMC센트럴아이파크아파트', 5001),
#  ('1565.대한병원앞', 5007),
#  ('2256.양재동 꽃시장 입구', 5010),
#  ('2538.사평리 공원', 5015),
#  ('849. 삼각지 자이아파트', 5018),
#  ('673.안암골벽산아파트(후문)', 5020),
#  ('2360. 도곡1동 주민센터 교차로', 5023),
#  ('432. 마포중앙도서관', 5024),
#  ('2057. 상도 아이파크 아파트', 5028),
#  ('1736. 버스정류장 앞', 5038),
#  ('2127. 보성운수차고지 맞은편', 5043),
#  ('110. 사천교', 5049),
#  ('1859. 대륭테크노타운 18차', 5054),
#  ('2651.경찰병원역 3번출구 앞', 5066),
#  ('3548.뚝섬역 6번출구', 5068),
#  ('167. 연가초등학교 옆', 5070),
#  ('141. 연대 대운동장 옆', 5073),
#  ('2917.신창중학교 후문 맞은편 버스정류장', 5079),
#  ('1771.성원APT버스정류소', 5080),
#  ('2389. 경기여자고등학교 후문 (삼성로3길 입구)', 5085),
#  ('282. 신한은행', 5098),
#  ('200. 국회의원회관', 5100),
#  ('3549.건영아파트 앞', 5108),
#  ('2644.성내5교 (GS주유소)', 5110),
#  ('840. 용산 파크타워 앞', 5115),
#  ('1394.길음뉴타운 래미안9단지', 5117),
#  ('425. DMC첨단산업센터', 5118),
#  ('490.가온문화공원', 5127),
#  ('2709.강변아파트 310동 앞', 5130),
#  ('1035. 고덕역 4번출구', 5136),
#  ('3523. 건국대학교 과학관(이과대) 앞', 5140),
#  ('757. 신정이펜하우스 1단지아파트 입구 사거리', 5143),
#  ('2727.서울식물원 잔디마당 앞', 5156),
#  ('120. 신수동 사거리', 5165),
#  ('3220.래미안에스티움 앞 (신풍로)', 5170),
#  ('2318. 삼성중앙역4번출구(문화센터더 리빌)', 5176),
#  ('2429.압구정로데오역 6번출구', 5180),
#  ('1652. 파르코 앞', 5188),
#  ('2239.교대역 6번출구', 5200),
#  ('802. 한강진역 2번 출구 앞', 5203),
#  ('830. 청암자이아파트앞', 5203),
#  ('1762.북한산 한신휴플러스APT앞', 5205),
#  ('2331. 동영문화센터앞', 5206),
#  ('1538. 솔밭공원역', 5209),
#  ('1074.대명초교입구 사거리', 5222),
#  ('1299. 송파소방서 (방이119안전센터)', 5241),
#  ('2245.양재초등학교 맞은편', 5242),
#  ('391. 정동길입구', 5245),
#  ('984.상신초등학교앞 버스정류장', 5258),
#  ('1250.문정2동 주민센터', 5273),
#  ('2821.청구아파트 앞', 5276),
#  ('1557.신창교', 5282),
#  ('2723.마곡 필네이처', 5285),
#  ('777.신월6차보람아파트 앞', 5296),
#  ('495.염리초등학교 앞', 5298),
#  ('1357. 북한산보국문역', 5304),
#  ('255. 도림4거리', 5324),
#  ('2137. KT&G 관악지점', 5327),
#  ('725. 양강중학교앞 교차로', 5329),
#  ('2725.서울식물원 식물문화센터', 5331),
#  ('1749. ESA아파트 상가 앞', 5338),
#  ('2280. 서울서초고용센터앞', 5355),
#  ('1285. 위례별 유치원 뒤', 5376),
#  ('384. 종로학원본원 ', 5381),
#  ('1845. 롯데캐슬골드파크1차 서문', 5384),
#  ('2741.마곡수명산파크5-6단지', 5392),
#  ('1858. 석수역1번출구 앞 (SK주유소)', 5396),
#  ('1348. 성북제일새마을금고 본점 앞', 5404),
#  ('2901.공릉동풍림아파트 101동', 5422),
#  ('2904.중계3차청구아파트', 5422),
#  ('1924. 삼부르네상스파크빌', 5422),
#  ('115. 사루비아 빌딩 앞', 5436),
#  ('2178. 서울대학교 정문', 5438),
#  ('2285. LH서초3단지 301동 맞은편', 5439),
#  ('3405.파크팰리스', 5440),
#  ('654. 전농동 텃골공원', 5440),
#  ('811. 녹사평역1번출구', 5451),
#  ('492.성산시영아파트 후문', 5457),
#  ('271. 샛강생태공원방문자센터 앞', 5465),
#  ('1032. 선사고등학교', 5495),
#  ('2410. 포스코피앤에스타워 (역삼역 3번출구 부근)', 5515),
#  ('164. 북가좌1동 주민센터 ', 5517),
#  ('125. 서강대 남문 옆', 5539),
#  ('954. 은평뉴타운구파발9단지', 5542),
#  ('817. 삼각지역 4번출구 앞', 5544),
#  ('669.청계한신휴플러스앞 삼거리', 5546),
#  ('946. 독바위역 ', 5548),
#  ('1428. 원묵고등학교', 5552),
#  ('397. 종묘공영주차장 건너편', 5560),
#  ('2356. 강남구청', 5563),
#  ('1703. 도봉산광역환승센터앞 ', 5571),
#  ('2370. 한티역 3번출구', 5572),
#  ('925. 불광역 2번출구', 5586),
#  ('960. 구파발역 환승센터', 5591),
#  ('707. 신정3동주민센터', 5609),
#  ('2235.KT 서초지사 앞', 5610),
#  ('3544.한양대역 3번 출구', 5614),
#  ('2729.넥센 유니버시티 앞', 5634),
#  ('169. 북가좌 삼거리', 5638),
#  ('1854. 가산아네스트 오피스텔 앞', 5660),
#  ('2638.쌍용아파트', 5661),
#  ('3214.영등포 푸르지오', 5674),
#  ('810. 이태원지하보도', 5681),
#  ('1826. 한신코아 앞', 5688),
#  ('2310. 청담동 맥도날드 옆(위치)', 5696),
#  ('3421.혜화역 1번출구', 5710),
#  ('2530.삼호3차아파트 앞', 5714),
#  ('2205. 내곡3단지 어린이공원 앞', 5718),
#  ('371. 동대입구역 6번출구 뒤', 5721),
#  ('1381.석계역 4번출구 뒤', 5723),
#  ('1441. 신내능말공원', 5728),
#  ('1825. 한신아파트 앞 육교 아래', 5729),
#  ('1325. 상월곡역 4번출구', 5738),
#  ('2656.풍납동 아이파크 107동 앞', 5741),
#  ('2719.마곡문화공원', 5745),
#  ('1470.중화동 우리은행 앞', 5746),
#  ('555. 구의3동주민센터', 5752),
#  ('1289. 풍납동 자전거보관소', 5775),
#  ('1344. 아리랑시네센터 앞', 5780),
#  ('1412. 면목초등학교', 5786),
#  ('793.목동5단지아파트 534동', 5798),
#  ('2711.가로공원공영주차장 1번 출구', 5803),
#  ('768.목동5단지아파트 501동', 5817),
#  ('142. 아현역 4번출구 앞', 5820),
#  ('2129. 낙성대 과학전시관', 5831),
#  ('864.순천향대학병원(한남오거리)', 5832),
#  ('405. DMC빌 앞', 5836),
#  ('2344. 리엔파크 2단지 앞', 5842),
#  ('1425. 용마문화복지센터', 5843),
#  ('733. 신정이펜하우스314동', 5846),
#  ('1026. 대명초교 입구 교차로', 5851),
#  ('1478.홈플러스 상봉점 앞', 5858),
#  ('285. 대림3동사거리(하나은행)', 5858),
#  ('2408. 강남한양수자인아파트', 5866),
#  ('1518. SK telecom(수유직영점) 앞', 5875),
#  ('1646. 삼육대 입구', 5875),
#  ('2233. 서초신동아1차아파트 옆', 5877),
#  ('3119.연희 브라운스톤 아파트 앞', 5888),
#  ('3011.경의선(노고산동)', 5889),
#  ('322. 명동성당 앞', 5892),
#  ('674.고대앞사거리 교통섬', 5892),
#  ('1993. 금강수목원아파트 앞', 5899),
#  ('1025. 상일초등학교', 5903),
#  ('2167. 낙성대역 1번출구', 5911),
#  ('2732.마곡수명산 1-2단지 ', 5915),
#  ('2290. 서래마을파리15구공원앞', 5927),
#  ('2048. 삼일초등학교 인근', 5932),
#  ('939. 은평구청 교차로', 5958),
#  ('2080.빕스 대방점 앞', 5974),
#  ('3566.우성4차아파트', 5983),
#  ('452. 동대문 종합시장 버스정류장', 5984),
#  ('1057. 능골근린공원', 5986),
#  ('1767.태양중앙교회 앞', 5988),
#  ('2144. 난우길입구', 5989),
#  ('1719. 신도봉사거리 버스정류장', 5990),
#  ('2739.수명산파크1단지교차로', 5991),
#  ('3537. 아차산 휴먼시아 아파트 옆', 6005),
#  ('1187. 강서수산물도매시장', 6021),
#  ('2330. 스타벅스 앞', 6029),
#  ('3510. 중곡SK아파트앞', 6030),
#  ('1840. 솔브레인이엔지 뒤편', 6032),
#  ('1436. 영풍마드레빌', 6041),
#  ('535. 응봉삼거리', 6042),
#  ('1808. 에이스하이엔드타워8차 앞', 6058),
#  ('1279. 마천금호어울림 1차아파트 건너편', 6074),
#  ('446. 상명대입구', 6084),
#  ('2268. 서초4동주민센터 ', 6088),
#  ('2385. 학동역', 6099),
#  ('1839. 수출의 다리 아래', 6109),
#  ('1186. 송정중학교', 6127),
#  ('140. 이화여대 후문', 6153),
#  ('2243.서울가정법원', 6153),
#  ('192. 연서어린이공원', 6161),
#  ('628. 휘봉고등학교 앞', 6180),
#  ('1552. 강북구청사거리(던킨도너츠 앞)', 6195),
#  ('2128. 관악구청교차로', 6232),
#  ('1981. 천왕이펜하우스5단지 앞', 6236),
#  ('1041. 묘곡초등학교', 6236),
#  ...]

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19026024 entries, 0 to 19026023
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 1.7+ GB

# %%
pd.options.display.float_format = '{:3}'.format

# %%
round(df_2020.describe(), 1)
# Out:
#             대여시간      대여소번호       이용건수         운동량        탄소량    이동거리(M)  \
# count 19026024.0 19026024.0 19026024.0  18906625.0 18906625.0 19026024.0
# mean        14.1     1320.0        1.2       178.3        0.8     3444.5
# std          6.0      926.6        0.7     89165.7       26.2   112634.5
# min          0.0        3.0        1.0         0.0        0.0        0.0
# 25%         10.0      568.0        1.0         0.0        0.0        0.0
# 50%         15.0     1190.0        1.0         0.0        0.0        0.0
# 75%         19.0     1961.0        1.0        43.2        0.4     1630.0
# max         23.0    99999.0       89.0 100000000.0     9175.4 39549190.9
#
#          이용시간(분)
# count 19026024.0
# mean        37.0
# std         49.4
# min          0.0
# 25%         10.0
# 50%         21.0
# 75%         48.0
# max      15814.0

# %%
df_2020.shape
# Out:
# (19026024, 12)

# %%
df_2020.isnull().sum()
# Out:
# 대여일자             0
# 대여시간             0
# 대여소번호            0
# 대여소명             0
# 대여구분코드           0
# 성별         9495977
# 연령대코드            0
# 이용건수             0
# 운동량         119399
# 탄소량         119399
# 이동거리(M)          0
# 이용시간(분)          0
# dtype: int64

# %%
df_2020['대여시간'].value_counts()
# Out:
# 대여시간
# 18    1643772
# 17    1461791
# 19    1293033
# 16    1202450
# 20    1147485
# 15    1072244
# 21    1062030
# 8      998040
# 14     982335
# 13     910746
# 22     895745
# 12     849483
# 11     732324
# 9      698533
# 7      661918
# 23     660096
# 10     619735
# 0      559640
# 1      441839
# 2      309555
# 6      299784
# 3      215831
# 5      158157
# 4      149458
# Name: count, dtype: int64

# %% [markdown]
# ## 1. 가설 1) 따릉이 최다 사용량이 출퇴근 시간이고

# %% [markdown]
# ### - 최다 사용량이 출퇴근 시간인 것을 확인한다.

# %% [markdown]
# - 대여일자 컬럼을 datetime 형식으로 변환

# %%
df_2020['대여일자'] = pd.to_datetime(df_2020['대여일자'], format='%Y-%m-%d')
# df_2020['대여시간'].astype('datetime64[ns]')

# %%
print(df_2020['대여일자'].dtype)
# Out:
# datetime64[ns]

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)
# 0 0.32   1360.0        6
# 1 0.09    390.0        3
# 2 0.64   2750.0       24
# 3 0.18    780.0        3
# 4 0.41   1760.0       11

# %% [markdown]
# - datetime 형식으로 변경된 '대여일자' 컬럼에서 요일을 추출하여 새로운 컬럼으로 저장

# %%
# dt.weekday : 요일 정보를 숫자로 추출 
# 0 : 월요일, 1 : 화요일, .... 6 : 일요일
df_2020['요일_인덱스'] = df_2020['대여일자'].dt.weekday

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)  요일_인덱스
# 0 0.32   1360.0        6       5
# 1 0.09    390.0        3       5
# 2 0.64   2750.0       24       5
# 3 0.18    780.0        3       5
# 4 0.41   1760.0       11       5

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df_2020['요일'] = df_2020.apply(lambda x : weekday_list[x['요일_인덱스']], axis=1)

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0 0.32   1360.0        6       5  토
# 1 0.09    390.0        3       5  토
# 2 0.64   2750.0       24       5  토
# 3 0.18    780.0        3       5  토
# 4 0.41   1760.0       11       5  토

# %%
df_2020[['요일', '대여시간']].value_counts(ascending=False)
# Out:
# 요일  대여시간
# 목   18      272970
# 화   18      269778
# 금   18      263783
# 월   18      254281
# 수   18      237179
#              ...
# 월   3        20538
# 목   4        19857
# 화   4        19191
# 일   5        17388
# 월   4        16698
# Name: count, Length: 168, dtype: int64

# %%
grounded = df_2020.groupby(['요일', '대여시간'])['이용건수'].sum().unstack()
grounded
# Out:
# 대여시간      0      1      2      3      4      5      6       7       8   \
# 요일
# 금      99651  77095  52318  35770  24107  25460  51835  131547  216599
# 목      88400  68624  46368  30966  20884  23583  50118  131522  219838
# 수      94862  71408  48637  32985  22986  26403  56875  139088  225445
# 월      73300  50523  32471  22140  17576  24295  53203  134872  215519
# 일     102732  77642  55394  37999  24377  18394  22740   36186   57578
# 토     108712  88163  62613  44111  28182  22344  29159   48476   82154
# 화      82485  63274  42683  28865  20193  24845  55097  139492  227097
#
# 대여시간      9   ...      14      15      16      17      18      19      20  \
# 요일            ...
# 금     123793  ...  158636  178955  213478  293971  355896  255465  216595
# 목     123493  ...  156182  179273  213749  299107  372432  265818  231671
# 수     120972  ...  146341  160137  191101  265256  323228  228805  198168
# 월     117353  ...  140165  157236  187882  273273  351635  248319  213687
# 일      78736  ...  212198  230939  236789  234948  221133  201821  188424
# 토     101648  ...  210457  228437  243653  250064  229806  209150  204822
# 화     122513  ...  149647  170478  202789  290470  369691  261815  226446
#
# 대여시간      21      22      23
# 요일
# 금     201678  175420  128364
# 목     209450  174365  122222
# 수     185277  154365  107483
# 월     194995  157576  106004
# 일     170724  136863   94776
# 토     196227  165438  126217
# 화     209332  171383  117857
#
# [7 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df_2020
# Out:
#                대여일자  대여시간  대여소번호                    대여소명 대여구분코드    성별 연령대코드  \
# 0        2020-02-01     0   1442     1442. (구)신한은행 중랑교지점    정기권  None  ~10대
# 1        2020-02-01     0   1339      1339. 삼성전자서비스 성북센터    정기권  None  ~10대
# 2        2020-02-01     0   1960           1960. 화광신문사 앞    정기권  None  ~10대
# 3        2020-02-01     0    394         394. 경희궁 자이 3단지    정기권  None  ~10대
# 4        2020-02-01     0   1364        1364. 성북동 치안센터 앞    정기권  None  ~10대
# ...             ...   ...    ...                     ...    ...   ...   ...
# 19026019 2020-07-31    23   1985             1985. 구로도서관    단체권  None   30대
# 19026020 2020-07-31    23    810            810. 이태원지하보도    단체권     F   20대
# 19026021 2020-07-31    23   1044             1044. 굽은다리역    단체권     M  ~10대
# 19026022 2020-07-31    23   1814  1814. 두산위브아파트 옆 상가건물 앞    단체권     M  ~10대
# 19026023 2020-07-31    23    212        212. 여의도역 1번출구 옆    단체권     M   30대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0            1  53.86 0.32   1360.0        6       5  토
# 1            1  10.04 0.09    390.0        3       5  토
# 2            1  75.14 0.64   2750.0       24       5  토
# 3            1  28.42 0.18    780.0        3       5  토
# 4            1  52.97 0.41   1760.0       11       5  토
# ...        ...    ...  ...      ...      ...     ... ..
# 19026019     2    0.0  0.0      0.0      120       4  금
# 19026020     3   8.98  0.1    420.0       28       4  금
# 19026021     2    0.0  0.0      0.0       39       4  금
# 19026022     3 297.78  2.1   9060.0      100       4  금
# 19026023     2  36.81 0.33   1430.0       23       4  금
#
# [19026024 rows x 14 columns]

# %%
# # 요일 순서 정의
# weekday_order = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
weekday_order = ['월', '화', '수', '목', '금', '토', '일']
# # 데이터프레임의 '요일' 열을 범주형 데이터로 변환하고 순서 지정
# # df_2020['요일'] = pd.Categorical(df_2020['요일'], categories=weekday_order, ordered=True)

plt.figure(figsize=(10,6))
# plt.ticklabel_format(axis='y', useOffset=False, style='plain')  # y축(지수표시) - 일반 표시로 변경
sns.lineplot(x='대여시간', y='이용건수', hue='요일', data=df_2020, marker='o', hue_order=weekday_order)
plt.title('2020년 대여시간에 따른 요일별 이용건수')
# plt.yticks(np.arange())
plt.xticks(range(0,24)) # = plt.xticks(np.arange(0,24,1))
plt.xlabel('대여시간')
plt.ylabel('이용건수')
plt.show()

# %% [markdown]
# ## 2. 가설 2) 출퇴근 시간에 따릉이 대여량이 최다인 대여소는 지하철역 인근 대여소일 것이다.

# %% [markdown]
# ### - 출퇴근 시간 대여소별 사용량 확인

# %% [markdown]
# - 요일 : 월~금요일 추출한다.

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0 0.32   1360.0        6       5  토
# 1 0.09    390.0        3       5  토
# 2 0.64   2750.0       24       5  토
# 3 0.18    780.0        3       5  토
# 4 0.41   1760.0       11       5  토

# %%
df_2020.count()
# Out:
# 대여일자       19026024
# 대여시간       19026024
# 대여소번호      19026024
# 대여소명       19026024
# 대여구분코드     19026024
# 성별          9530047
# 연령대코드      19026024
# 이용건수       19026024
# 운동량        18906625
# 탄소량        18906625
# 이동거리(M)    19026024
# 이용시간(분)    19026024
# 요일_인덱스     19026024
# 요일         19026024
# dtype: int64

# %%
df_2020_day = df_2020[~(df_2020['요일'].isin(['토', '일']))]
df_2020_day
# Out:
#                대여일자  대여시간  대여소번호                    대여소명 대여구분코드    성별 연령대코드  \
# 44369    2020-02-03     0   1029            1029. 롯데 시네마    정기권  None  ~10대
# 44370    2020-02-03     0   1036          1036. 고덕동 주양쇼핑    정기권  None  ~10대
# 44371    2020-02-03     0   1447          1447. 면목역 3번출구    정기권  None  ~10대
# 44372    2020-02-03     0   1339      1339. 삼성전자서비스 성북센터    정기권  None  ~10대
# 44373    2020-02-03     0   1173     1173. 강서구청사거리(SH타워)    정기권  None  ~10대
# ...             ...   ...    ...                     ...    ...   ...   ...
# 19026019 2020-07-31    23   1985             1985. 구로도서관    단체권  None   30대
# 19026020 2020-07-31    23    810            810. 이태원지하보도    단체권     F   20대
# 19026021 2020-07-31    23   1044             1044. 굽은다리역    단체권     M  ~10대
# 19026022 2020-07-31    23   1814  1814. 두산위브아파트 옆 상가건물 앞    단체권     M  ~10대
# 19026023 2020-07-31    23    212        212. 여의도역 1번출구 옆    단체권     M   30대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 44369        1  87.01  0.7   3010.0       17       0  월
# 44370        1  76.68 0.67   2890.0       15       0  월
# 44371        1  40.99 0.35   1500.0        6       0  월
# 44372        1   10.3 0.09    400.0        2       0  월
# 44373        1  26.53 0.31   1340.0        7       0  월
# ...        ...    ...  ...      ...      ...     ... ..
# 19026019     2    0.0  0.0      0.0      120       4  금
# 19026020     3   8.98  0.1    420.0       28       4  금
# 19026021     2    0.0  0.0      0.0       39       4  금
# 19026022     3 297.78  2.1   9060.0      100       4  금
# 19026023     2  36.81 0.33   1430.0       23       4  금
#
# [13911077 rows x 14 columns]

# %% [markdown]
# - '출퇴근' 컬럼을 새로 만들어서 출근, 퇴근을 넣어준다. (월~금요일, 출퇴근)

# %%
df_2020_day.loc[df_2020_day['대여시간'].isin([7,8]),'출퇴근'] = '출근'
df_2020_day.loc[df_2020_day['대여시간'].isin([17,18]),'출퇴근'] = '퇴근'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4284\1375006739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_day.loc[df_2020_day['대여시간'].isin([7,8]),'출퇴근'] = '출근'

# %%
df_2020_day
# Out:
#                대여일자  대여시간  대여소번호                    대여소명 대여구분코드    성별 연령대코드  \
# 44369    2020-02-03     0   1029            1029. 롯데 시네마    정기권  None  ~10대
# 44370    2020-02-03     0   1036          1036. 고덕동 주양쇼핑    정기권  None  ~10대
# 44371    2020-02-03     0   1447          1447. 면목역 3번출구    정기권  None  ~10대
# 44372    2020-02-03     0   1339      1339. 삼성전자서비스 성북센터    정기권  None  ~10대
# 44373    2020-02-03     0   1173     1173. 강서구청사거리(SH타워)    정기권  None  ~10대
# ...             ...   ...    ...                     ...    ...   ...   ...
# 19026019 2020-07-31    23   1985             1985. 구로도서관    단체권  None   30대
# 19026020 2020-07-31    23    810            810. 이태원지하보도    단체권     F   20대
# 19026021 2020-07-31    23   1044             1044. 굽은다리역    단체권     M  ~10대
# 19026022 2020-07-31    23   1814  1814. 두산위브아파트 옆 상가건물 앞    단체권     M  ~10대
# 19026023 2020-07-31    23    212        212. 여의도역 1번출구 옆    단체권     M   30대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일  출퇴근
# 44369        1  87.01  0.7   3010.0       17       0  월  NaN
# 44370        1  76.68 0.67   2890.0       15       0  월  NaN
# 44371        1  40.99 0.35   1500.0        6       0  월  NaN
# 44372        1   10.3 0.09    400.0        2       0  월  NaN
# 44373        1  26.53 0.31   1340.0        7       0  월  NaN
# ...        ...    ...  ...      ...      ...     ... ..  ...
# 19026019     2    0.0  0.0      0.0      120       4  금  NaN
# 19026020     3   8.98  0.1    420.0       28       4  금  NaN
# 19026021     2    0.0  0.0      0.0       39       4  금  NaN
# 19026022     3 297.78  2.1   9060.0      100       4  금  NaN
# 19026023     2  36.81 0.33   1430.0       23       4  금  NaN
#
# [13911077 rows x 15 columns]

# %%
df_2020_day[df_2020_day['출퇴근'] == '출근'] # df_parquet[df_parquet['이용건수'] == '\\N']
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 46871    2020-02-03     7    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 46872    2020-02-03     7   2363    2363. 강남 을지병원 교차로    정기권  None  ~10대
# 46873    2020-02-03     7   3511       3511. 응봉역 1번출구    정기권  None  ~10대
# 46874    2020-02-03     7   1337         1337. 돈암성당 옆    정기권  None  ~10대
# 46875    2020-02-03     7   1976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 18967947 2020-07-31     8   1349   1349. 월계2교 버스정류장 앞    일일권     M  70대~
# 18967948 2020-07-31     8    363    363. 신설동역 11번출구 뒤    단체권  None   20대
# 18967949 2020-07-31     8   1308  1308. 안암로터리 버스정류장 앞    단체권  None   20대
# 18967950 2020-07-31     8    509     509. 이마트 버스정류소 옆    단체권     F   20대
# 18967951 2020-07-31     8   2024       2024. 상도역 1번출구    단체권     M   40대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 46871        1  15.21 0.14    600.0        3       0  월  출근
# 46872        1   22.2 0.22    950.0        6       0  월  출근
# 46873        1 101.49 1.08   4660.0       41       0  월  출근
# 46874        1   93.8 0.87   3760.0       12       0  월  출근
# 46875        1    0.0  0.0      0.0        7       0  월  출근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 18967947     1    0.0  0.0      0.0       29       4  금  출근
# 18967948     2    0.0  0.0      0.0       17       4  금  출근
# 18967949     2    0.0  0.0      0.0       27       4  금  출근
# 18967950     3    0.0  0.0      0.0       34       4  금  출근
# 18967951     2 316.59 2.35  10120.0      122       4  금  출근
#
# [1451278 rows x 15 columns]

# %%
df_2020_day[df_2020_day['출퇴근'] == '퇴근']
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 59719    2020-02-03    17    740            740. 으뜸공원    정기권  None  ~10대
# 59720    2020-02-03    17    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 59721    2020-02-03    17   1157           1157. 강서구청    정기권  None  ~10대
# 59722    2020-02-03    17   1259       1259. 방이역 1번출구    정기권  None  ~10대
# 59723    2020-02-03    17   1336         1336. 성북3교 위    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 19004633 2020-07-31    18    302     302. 경복궁역 4번출구 뒤    단체권     M  ~10대
# 19004634 2020-07-31    18    207    207. 여의나루역 1번출구 앞    단체권     M  ~10대
# 19004635 2020-07-31    18   2290   2290. 서래마을파리15구공원앞    단체권     M   20대
# 19004636 2020-07-31    18    515         515. 광양중학교 앞    단체권     M   30대
# 19004637 2020-07-31    18   2265      2265. 이수고가차도 남단    단체권     M   40대
#
#           이용건수     운동량   탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 59719        3 3598.79 32.26 139050.0       85       0  월  퇴근
# 59720        1   39.79  0.36   1570.0       13       0  월  퇴근
# 59721        1   27.66  0.29   1270.0        8       0  월  퇴근
# 59722        1   54.62  0.56   2420.0       26       0  월  퇴근
# 59723        1   10.53  0.06    280.0        2       0  월  퇴근
# ...        ...     ...   ...      ...      ...     ... ..  ..
# 19004633     2   50.49  0.39   1700.0       30       4  금  퇴근
# 19004634     2     0.0   0.0      0.0      121       4  금  퇴근
# 19004635     2     0.0   0.0      0.0      163       4  금  퇴근
# 19004636     2     0.0   0.0      0.0      233       4  금  퇴근
# 19004637     1     0.0   0.0      0.0        6       4  금  퇴근
#
# [2387415 rows x 15 columns]

# %%
df_2020_day['출퇴근'].unique()
# Out:
# array([nan, '출근', '퇴근'], dtype=object)

# %%
df_2020_day['출퇴근'].value_counts()
# Out:
# 출퇴근
# 퇴근    2387415
# 출근    1451278
# Name: count, dtype: int64

# %%
df_2020_day.count()
# Out:
# 대여일자       13911077
# 대여시간       13911077
# 대여소번호      13911077
# 대여소명       13911077
# 대여구분코드     13911077
# 성별          6982669
# 연령대코드      13911077
# 이용건수       13911077
# 운동량        13822377
# 탄소량        13822377
# 이동거리(M)    13911077
# 이용시간(분)    13911077
# 요일_인덱스     13911077
# 요일         13911077
# 출퇴근         3838693
# dtype: int64

# %%
df_2020_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13911077 entries, 44369 to 19026023
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 1.6+ GB

# %%
df_2020_time = df_2020_day[~df_2020_day['출퇴근'].isnull()] # df_2020_day.dropna(subset=['출퇴근'])

# %%
df_2020_time
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 46871    2020-02-03     7    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 46872    2020-02-03     7   2363    2363. 강남 을지병원 교차로    정기권  None  ~10대
# 46873    2020-02-03     7   3511       3511. 응봉역 1번출구    정기권  None  ~10대
# 46874    2020-02-03     7   1337         1337. 돈암성당 옆    정기권  None  ~10대
# 46875    2020-02-03     7   1976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 19004633 2020-07-31    18    302     302. 경복궁역 4번출구 뒤    단체권     M  ~10대
# 19004634 2020-07-31    18    207    207. 여의나루역 1번출구 앞    단체권     M  ~10대
# 19004635 2020-07-31    18   2290   2290. 서래마을파리15구공원앞    단체권     M   20대
# 19004636 2020-07-31    18    515         515. 광양중학교 앞    단체권     M   30대
# 19004637 2020-07-31    18   2265      2265. 이수고가차도 남단    단체권     M   40대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 46871        1  15.21 0.14    600.0        3       0  월  출근
# 46872        1   22.2 0.22    950.0        6       0  월  출근
# 46873        1 101.49 1.08   4660.0       41       0  월  출근
# 46874        1   93.8 0.87   3760.0       12       0  월  출근
# 46875        1    0.0  0.0      0.0        7       0  월  출근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 19004633     2  50.49 0.39   1700.0       30       4  금  퇴근
# 19004634     2    0.0  0.0      0.0      121       4  금  퇴근
# 19004635     2    0.0  0.0      0.0      163       4  금  퇴근
# 19004636     2    0.0  0.0      0.0      233       4  금  퇴근
# 19004637     1    0.0  0.0      0.0        6       4  금  퇴근
#
# [3838693 rows x 15 columns]

# %%
df_2020_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3838693 entries, 46871 to 19004637
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 453.9+ MB

# %%
df_2020_time.count()
# Out:
# 대여일자       3838693
# 대여시간       3838693
# 대여소번호      3838693
# 대여소명       3838693
# 대여구분코드     3838693
# 성별         1992554
# 연령대코드      3838693
# 이용건수       3838693
# 운동량        3814375
# 탄소량        3814375
# 이동거리(M)    3838693
# 이용시간(분)    3838693
# 요일_인덱스     3838693
# 요일         3838693
# 출퇴근        3838693
# dtype: int64

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본_최종.parquet'
start_time = time.time()
df_st = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df_st.head(5)
# Out:
# read_parquet time : 0.018054962158203125
#    대여소번호          대여소명  자치구                         상세주소          위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 126.8210602  2024-03-18  NaN 10.0   QR  2024-06  ST-3284   NaN
# 1 127.0669098  2020-03-24  NaN 12.0   QR  2024-06  ST-2068   NaN
# 2 127.0732651  2020-03-23  NaN 20.0   QR  2024-06  ST-2078   NaN
# 3 127.0719147  2020-03-23  NaN  7.0   QR  2024-06  ST-2077   NaN
# 4 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN

# %%
df_st.head()
# Out:
#    대여소번호          대여소명  자치구                         상세주소          위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 126.8210602  2024-03-18  NaN 10.0   QR  2024-06  ST-3284   NaN
# 1 127.0669098  2020-03-24  NaN 12.0   QR  2024-06  ST-2068   NaN
# 2 127.0732651  2020-03-23  NaN 20.0   QR  2024-06  ST-2078   NaN
# 3 127.0719147  2020-03-23  NaN  7.0   QR  2024-06  ST-2077   NaN
# 4 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN

# %%
df_st.info() # 대여소번호 int / object 다름.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2960 entries, 0 to 2959
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   2960 non-null   object
#  1   대여소명    2960 non-null   object
#  2   자치구     2960 non-null   object
#  3   상세주소    2960 non-null   object
#  4   위도      2959 non-null   float64
#  5   경도      2959 non-null   float64
#  6   설치시기    2921 non-null   object
#  7   LCD     1517 non-null   float64
#  8   QR      1752 non-null   float64
#  9   운영방식    2921 non-null   object
#  10  데이터등록월  2921 non-null   object
#  11  대여소ID   2701 non-null   object
#  12  거치대수    39 non-null     float64
# dtypes: float64(5), object(8)
# memory usage: 300.8+ KB

# %%
df_st.shape
# Out:
# (2960, 13)

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

import ExcelFile_EDA as ee
ee.ss_isnull(df_st)
# Out:
#      [컬럼명]  [sum]  [sum_isnull]     [mean_isnull(%)]
# 0    대여소번호   2960             0                  0.0
# 1     대여소명   2960             0                  0.0
# 2      자치구   2960             0                  0.0
# 3     상세주소   2960             0                  0.0
# 4       위도   2959             1 0.033783783783783786
# 5       경도   2959             1 0.033783783783783786
# 6     설치시기   2921            39   1.3175675675675675
# 7      LCD   1517          1443                48.75
# 8       QR   1752          1208    40.81081081081081
# 9     운영방식   2921            39   1.3175675675675675
# 10  데이터등록월   2921            39   1.3175675675675675
# 11   대여소ID   2701           259                 8.75
# 12    거치대수     39          2921    98.68243243243244

# %%
df_st_1 = df_st[['대여소번호', '대여소명', '자치구', '설치시기', '데이터등록월']]
df_st_1
# Out:
#       대여소번호            대여소명   자치구        설치시기   데이터등록월
# 0     06173     서울자동차운전전문학원   강서구  2024-03-18  2024-06
# 1     02902    공릉풍림아파트 108동   노원구  2020-03-24  2024-06
# 2     02912          대진고등학교   노원구  2020-03-23  2024-06
# 3     02911         상계역중앙시장   노원구  2020-03-23  2024-06
# 4     02910           도깨비시장   노원구  2020-03-25  2024-06
# ...     ...             ...   ...         ...      ...
# 2955  05884          GS강서타워  영등포구        None     None
# 2956  05885  신정교하부(도림천역 방면)  영등포구        None     None
# 2957  06060         신한은행 본점    중구        None     None
# 2958  06176      유광사 여성병원 앞   강서구        None     None
# 2959  06177      마곡롯데캐슬르웨스트   강서구        None     None
#
# [2960 rows x 5 columns]

# %% [markdown]
# - 시간대별 데이터, 대여소정보 데이터 에서 '대여소번호' 컬럼의 숫자 표현방식, 데이터 타입이 다르다.

# %% [markdown]
# - 따라서, 1. 시간대별 데이터(월~금 / 출퇴근 시간대 추출함)의 '대여소번호' 컬럼의 숫자를 object로 바꾸어준다.
# - 시간대별 - 대여소번호    int64 / 대여소정보 - 대여소번호 object
#      ##### 2. 시간대별 데이터의 '대여소번호' 컬럼의 숫자를 00000 자리로 바꾸어준다.

# %%
df_2020_time.head()
# Out:
#             대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 46871 2020-02-03     7    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대     1
# 46872 2020-02-03     7   2363    2363. 강남 을지병원 교차로    정기권  None  ~10대     1
# 46873 2020-02-03     7   3511       3511. 응봉역 1번출구    정기권  None  ~10대     1
# 46874 2020-02-03     7   1337         1337. 돈암성당 옆    정기권  None  ~10대     1
# 46875 2020-02-03     7   1976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대     1
#
#          운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 46871  15.21 0.14    600.0        3       0  월  출근
# 46872   22.2 0.22    950.0        6       0  월  출근
# 46873 101.49 1.08   4660.0       41       0  월  출근
# 46874   93.8 0.87   3760.0       12       0  월  출근
# 46875    0.0  0.0      0.0        7       0  월  출근

# %%
df_2020_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3838693 entries, 46871 to 19004637
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 453.9+ MB

# %%
df_2020_time.loc[:, '대여소번호'] = df_2020_time['대여소번호'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4284\2568160770.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['505' '2363' '3511' ... '2290' '515' '2265']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_2020_time.loc[:, '대여소번호'] = df_2020_time['대여소번호'].astype(str)

# %%
df_2020_time.dtypes
# Out:
# 대여일자       datetime64[ns]
# 대여시간                int64
# 대여소번호              object
# 대여소명               object
# 대여구분코드             object
# 성별                 object
# 연령대코드              object
# 이용건수                int64
# 운동량               float64
# 탄소량               float64
# 이동거리(M)           float64
# 이용시간(분)             int64
# 요일_인덱스              int32
# 요일                 object
# 출퇴근                object
# dtype: object

# %%
df_2020_time.loc[:,'대여소번호'] = df_2020_time['대여소번호'].str.zfill(5)

# %%
df_2020_time.head()
# Out:
#             대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 46871 2020-02-03     7  00505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대     1
# 46872 2020-02-03     7  02363    2363. 강남 을지병원 교차로    정기권  None  ~10대     1
# 46873 2020-02-03     7  03511       3511. 응봉역 1번출구    정기권  None  ~10대     1
# 46874 2020-02-03     7  01337         1337. 돈암성당 옆    정기권  None  ~10대     1
# 46875 2020-02-03     7  01976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대     1
#
#          운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 46871  15.21 0.14    600.0        3       0  월  출근
# 46872   22.2 0.22    950.0        6       0  월  출근
# 46873 101.49 1.08   4660.0       41       0  월  출근
# 46874   93.8 0.87   3760.0       12       0  월  출근
# 46875    0.0  0.0      0.0        7       0  월  출근

# %%
df_sum = pd.merge(df_2020_time, df_st_1, on='대여소번호', how='left')
df_sum
# Out:
#               대여일자  대여시간  대여소번호               대여소명_x 대여구분코드    성별 연령대코드  이용건수  \
# 0       2020-02-03     7  00505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대     1
# 1       2020-02-03     7  02363    2363. 강남 을지병원 교차로    정기권  None  ~10대     1
# 2       2020-02-03     7  03511       3511. 응봉역 1번출구    정기권  None  ~10대     1
# 3       2020-02-03     7  01337         1337. 돈암성당 옆    정기권  None  ~10대     1
# 4       2020-02-03     7  01976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대     1
# ...            ...   ...    ...                  ...    ...   ...   ...   ...
# 3838688 2020-07-31    18  00302     302. 경복궁역 4번출구 뒤    단체권     M  ~10대     2
# 3838689 2020-07-31    18  00207    207. 여의나루역 1번출구 앞    단체권     M  ~10대     2
# 3838690 2020-07-31    18  02290   2290. 서래마을파리15구공원앞    단체권     M   20대     2
# 3838691 2020-07-31    18  00515         515. 광양중학교 앞    단체권     M   30대     2
# 3838692 2020-07-31    18  02265      2265. 이수고가차도 남단    단체권     M   40대     1
#
#            운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근          대여소명_y   자치구  \
# 0        15.21 0.14    600.0        3       0  월  출근  자양사거리 광진아크로텔 앞   광진구
# 1         22.2 0.22    950.0        6       0  월  출근     강남 을지병원 교차로   강남구
# 2       101.49 1.08   4660.0       41       0  월  출근        응봉역 1번출구   성동구
# 3         93.8 0.87   3760.0       12       0  월  출근          돈암성당 옆   성북구
# 4          0.0  0.0      0.0        7       0  월  출근   남구로역 5번 출입구 앞   구로구
# ...        ...  ...      ...      ...     ... ..  ..             ...   ...
# 3838688  50.49 0.39   1700.0       30       4  금  퇴근     경복궁역 4번출구 뒤   종로구
# 3838689    0.0  0.0      0.0      121       4  금  퇴근    여의나루역 1번출구 앞  영등포구
# 3838690    0.0  0.0      0.0      163       4  금  퇴근             NaN   NaN
# 3838691    0.0  0.0      0.0      233       4  금  퇴근         광양중학교 앞   광진구
# 3838692    0.0  0.0      0.0        6       4  금  퇴근       이수고가차도 남단   서초구
#
#                설치시기   데이터등록월
# 0        2015-10-07  2024-06
# 1        2017-11-01  2024-06
# 2        2017-11-01  2024-06
# 3        2017-11-13  2024-06
# 4        2017-11-13  2024-06
# ...             ...      ...
# 3838688  2015-10-07  2024-06
# 3838689  2015-09-17  2024-06
# 3838690         NaN      NaN
# 3838691  2015-10-07  2024-06
# 3838692  2017-08-09  2024-06
#
# [3838693 rows x 19 columns]

# %%
group1 = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().reset_index()
group1
# Out:
#               대여소명_y 출퇴근  이용건수
# 0        (구)합정동 주민센터  출근  1057
# 1        (구)합정동 주민센터  퇴근   928
# 2        (시립)고덕평생학습관  출근    61
# 3        (시립)고덕평생학습관  퇴근   266
# 4       (재)FITI시험연구원  출근  1447
# ...              ...  ..   ...
# 4226         희훈타워빌 앞  퇴근    80
# 4227         힐스테이트에코  출근  1237
# 4228         힐스테이트에코  퇴근  2382
# 4229  힐스테이트창경궁 아파트 앞  출근   452
# 4230  힐스테이트창경궁 아파트 앞  퇴근   784
#
# [4231 rows x 3 columns]

# %% [markdown]
# - 출근 시간대 대여소별 이용건수

# %%
commute_data = group1[group1['출퇴근'] == '출근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data = commute_data.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data = top_20_commute_data.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
bars = plt.barh(top_20_commute_data['대여소명_y'], top_20_commute_data['이용건수'])
plt.title('2020년 출근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')

# 각 막대 끝에 이용건수 표시
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:,.0f}', 
             ha='left', va='center', fontweight='bold')

plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %%
top_20_commute_data.sort_values(by='이용건수', ascending=False)
# Out:
#                  대여소명_y 출퇴근   이용건수
# 1329      마곡나루역 5번출구 뒤편  출근  10897
# 2935       여의나루역 1번출구 앞  출근   7297
# 955             대방역6번출구  출근   6532
# 568          구로디지털단지역 앞  출근   5825
# 1130               동방1교  출근   5272
# 3494          장한평역 1번출구  출근   5082
# 2901        양천향교역 7번출구앞  출근   4851
# 3041        영등포구청역 1번출구  출근   4799
# 1278  롯데월드타워(잠실역2번출구 쪽)  출근   4620
# 1022            도림천 신화교  출근   4582
# 3448    잠실나루역 (2번 출구 쪽)  출근   4576
# 2811   아크로타워 스퀘어(영등포시장)  출근   4522
# 2621         신대방역 2번 출구  출근   4427
# 3432            자양중앙나들목  출근   4359
# 2405         성수역 2번출구 앞  출근   4229
# 1645  발산역 1번, 9번 인근 대여소  출근   4211
# 1235      뚝섬유원지역 1번출구 앞  출근   4210
# 2589        신길삼거리(우리은행)  출근   3992
# 2631       신도림역 1번 출구 앞  출근   3980
# 907         당산역 10번출구 앞  출근   3974

# %% [markdown]
# - 퇴근 시간대 대여소별 이용건수

# %%
commute_data_2 = group1[group1['출퇴근'] == '퇴근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data_2 = commute_data_2.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data_2 = top_20_commute_data_2.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
bars = plt.barh(top_20_commute_data_2['대여소명_y'], top_20_commute_data_2['이용건수'])
plt.title('2020년 퇴근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')

# 각 막대 끝에 이용건수 표시
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:,.0f}', 
             ha='left', va='center', fontweight='bold')
    
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %%
top_20_commute_data_2.sort_values(by='이용건수', ascending=False)
# Out:
#                        대여소명_y 출퇴근   이용건수
# 2936             여의나루역 1번출구 앞  퇴근  16987
# 1236            뚝섬유원지역 1번출구 앞  퇴근  16065
# 1330            마곡나루역 5번출구 뒤편  퇴근  11168
# 1279        롯데월드타워(잠실역2번출구 쪽)  퇴근  10921
# 645                    국민일보 앞  퇴근  10117
# 2632             신도림역 1번 출구 앞  퇴근  10019
# 1646        발산역 1번, 9번 인근 대여소  퇴근   9977
# 569                구로디지털단지역 앞  퇴근   9333
# 422   고속터미널역 8-1번, 8-2번 출구 사이  퇴근   9278
# 69                       IFC몰  퇴근   9072
# 1767                  봉림교 교통섬  퇴근   8911
# 2902              양천향교역 7번출구앞  퇴근   8863
# 3873                  태평양물산빌딩  퇴근   8356
# 910                     당산육갑문  퇴근   8258
# 2576             시범아파트버스정류장 옆  퇴근   8067
# 360          건대입구역 사거리(롯데백화점)  퇴근   8029
# 908               당산역 10번출구 앞  퇴근   7979
# 192                  가양역 8번출구  퇴근   7764
# 1396               마포구민체육센터 앞  퇴근   7753
# 3787               청계천 생태교실 앞  퇴근   7483

# %% [markdown]
# -------------------------------------------------
