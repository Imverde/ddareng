# %%
_year='2022'

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'
filename = '서울특별시 공공자전거 대여소별 이용정보(시간대별)_' + _year + '.parquet'
start_time = time.time()
df_2024 = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df_2024.head(5)
# Out:
# read_parquet time : 21.137447357177734
#          대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0  2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1  2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2  2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3  2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4  2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수    운동량   탄소량  이동거리(M)  이용시간(분)
# 0     1  13.54  0.13   570.00        3
# 1     1  32.81  0.36  1534.33       12
# 2     1  19.10  0.17   720.00        4
# 3     1  10.57  0.08   333.59        3
# 4     1   6.93  0.07   318.20       37

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2024)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  36160476             0          0.000000
# 1      대여시간  36160476             0          0.000000
# 2     대여소번호  36160476             0          0.000000
# 3      대여소명  36160476             0          0.000000
# 4    대여구분코드  36160476             0          0.000000
# 5        성별  23845360      12315116         34.056842
# 6     연령대코드  36160476             0          0.000000
# 7      이용건수  36160476             0          0.000000
# 8       운동량  36023075        137401          0.379976
# 9       탄소량  36023075        137401          0.379976
# 10  이동거리(M)  36160476             0          0.000000
# 11  이용시간(분)  36160476             0          0.000000

# %%
df_2024.head()
# Out:
#          대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0  2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1  2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2  2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3  2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4  2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수    운동량   탄소량  이동거리(M)  이용시간(분)
# 0     1  13.54  0.13   570.00        3
# 1     1  32.81  0.36  1534.33       12
# 2     1  19.10  0.17   720.00        4
# 3     1  10.57  0.08   333.59        3
# 4     1   6.93  0.07   318.20       37

# %%
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36160476 entries, 0 to 36160475
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 3.2+ GB

# %%
pd.options.display.float_format = '{:3}'.format

# %%
df_2024.shape
# Out:
# (36160476, 12)

# %%
df_2024.isnull().sum()
# Out:
# 대여일자              0
# 대여시간              0
# 대여소번호             0
# 대여소명              0
# 대여구분코드            0
# 성별         12315116
# 연령대코드             0
# 이용건수              0
# 운동량          137401
# 탄소량          137401
# 이동거리(M)           0
# 이용시간(분)           0
# dtype: int64

# %%
df_2024['대여시간'].value_counts()
# Out:
# 대여시간
# 18    3323780
# 17    2801910
# 19    2448683
# 8     2377375
# 16    2270279
# 20    2083776
# 21    1910878
# 15    1910591
# 14    1729642
# 13    1696613
# 12    1684826
# 22    1588994
# 7     1581374
# 9     1568101
# 11    1517422
# 10    1316501
# 23    1084131
# 0      871207
# 6      672591
# 1      583418
# 2      374086
# 5      325862
# 3      244012
# 4      194424
# Name: count, dtype: int64

# %% [markdown]
# ## 1. 가설 1) 따릉이 최다 사용량이 출퇴근 시간이고

# %% [markdown]
# ### - 최다 사용량이 출퇴근 시간인 것을 확인한다.

# %% [markdown]
# - 대여일자 컬럼을 datetime 형식으로 변환

# %%
df_2024['대여일자'] = pd.to_datetime(df_2024['대여일자'], format='%Y-%m-%d')
# df_2020['대여시간'].astype('datetime64[ns]')

# %%
print(df_2024['대여일자'].dtype)
# Out:
# datetime64[ns]

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)
# 0     1 13.54 0.13    570.0        3
# 1     1 32.81 0.36  1534.33       12
# 2     1  19.1 0.17    720.0        4
# 3     1 10.57 0.08   333.59        3
# 4     1  6.93 0.07    318.2       37

# %% [markdown]
# - datetime 형식으로 변경된 '대여일자' 컬럼에서 요일을 추출하여 새로운 컬럼으로 저장

# %%
# dt.weekday : 요일 정보를 숫자로 추출 
# 0 : 월요일, 1 : 화요일, .... 6 : 일요일
df_2024['요일_인덱스'] = df_2024['대여일자'].dt.weekday

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스
# 0     1 13.54 0.13    570.0        3       3
# 1     1 32.81 0.36  1534.33       12       3
# 2     1  19.1 0.17    720.0        4       3
# 3     1 10.57 0.08   333.59        3       3
# 4     1  6.93 0.07    318.2       37       3

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df_2024['요일'] = df_2024.apply(lambda x : weekday_list[x['요일_인덱스']], axis=1)

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0     1 13.54 0.13    570.0        3       3  목
# 1     1 32.81 0.36  1534.33       12       3  목
# 2     1  19.1 0.17    720.0        4       3  목
# 3     1 10.57 0.08   333.59        3       3  목
# 4     1  6.93 0.07    318.2       37       3  목

# %%
df_2024[['요일', '대여시간']].value_counts(ascending=False)
# Out:
# 요일  대여시간
# 금   18      558260
# 화   18      550419
# 수   18      548702
# 목   18      543856
# 월   18      499965
#              ...
# 화   3        26261
# 수   4        25880
# 월   3        24619
#     4        23211
# 화   4        22656
# Name: count, Length: 168, dtype: int64

# %%
grounded = df_2024.groupby(['요일', '대여시간'])['이용건수'].sum().unstack()
grounded
# Out:
# 대여시간      0       1      2      3      4      5       6       7       8   \
# 요일
# 금     141199   90263  55909  36128  30014  55212  124221  331413  539566
# 목     127208   84233  51024  33111  27425  53432  123239  332583  525539
# 수     120969   79163  48085  31130  26589  52309  120358  325569  517620
# 월     107551   61913  38667  25611  23874  49814  110544  288182  453720
# 일     172578  114889  74957  48772  33271  30957   44280   72926  116247
# 토     175019  127056  85279  52908  36349  40840   61085   99709  174740
# 화     109014   68791  42275  27096  23215  52337  122848  331431  529946
#
# 대여시간      9   ...      14      15      16      17      18      19      20  \
# 요일            ...
# 금     285808  ...  273142  316118  382588  537136  683590  449063  358919
# 목     271645  ...  243925  275657  366527  504322  676157  446377  368875
# 수     265461  ...  247046  280331  360071  511069  683745  440583  363503
# 월     240230  ...  229762  258434  327240  447657  624947  419984  349915
# 일     157283  ...  326761  362393  383316  371039  334985  293336  267951
# 토     221613  ...  347826  374207  400268  410761  382218  328620  308714
# 화     271129  ...  231392  259618  351525  496949  691653  459829  371495
#
# 대여시간      21      22      23
# 요일
# 금     338841  300695  205718
# 목     344182  290819  183968
# 수     321347  259345  164995
# 월     305747  239048  150182
# 일     244840  194785  138492
# 토     301289  261391  196614
# 화     334665  271430  165019
#
# [7 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 요일 순서 정의
day_order = ['일', '토', '금', '목', '수', '화', '월']

# 데이터프레임 재정렬
grounded_sorted = grounded.reindex(day_order)

# 히트맵 그리기
plt.figure(figsize=(10, 6))
sns.heatmap(grounded_sorted, annot=False, cmap='Greens', cbar_kws={'label': '이용건수'}, linewidths=1)

# 제목 및 축 레이블 설정
plt.title('요일 및 대여시간별 이용건수', fontsize=16)
plt.xlabel('대여시간', fontsize=12)
plt.ylabel('요일', fontsize=12)

# 그래프 표시
plt.tight_layout()
plt.show()

# %%
# 요일 순서 정의
weekday_order = ['월', '화', '수', '목', '금', '토', '일']

plt.figure(figsize=(10,6))
sns.lineplot(x='대여시간', y='이용건수', hue='요일', data=df_2024, marker='o', hue_order=weekday_order)
plt.title(_year + '년 대여시간에 따른 요일별 이용건수')
plt.xticks(range(0,24))
plt.xlabel('대여시간')
plt.ylabel('이용건수')
plt.show()

# %% [markdown]
# ## 2. 가설 2) 출퇴근 시간에 따릉이 대여량이 최다인 대여소는 지하철역 인근 대여소일 것이다.

# %% [markdown]
# ### - 출퇴근 시간 대여소별 사용량 확인

# %% [markdown]
# - 요일 : 월~금요일 추출한다.

# %%
df_2024.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0     1 13.54 0.13    570.0        3       3  목
# 1     1 32.81 0.36  1534.33       12       3  목
# 2     1  19.1 0.17    720.0        4       3  목
# 3     1 10.57 0.08   333.59        3       3  목
# 4     1  6.93 0.07    318.2       37       3  목

# %%
df_2024.count()
# Out:
# 대여일자       36160476
# 대여시간       36160476
# 대여소번호      36160476
# 대여소명       36160476
# 대여구분코드     36160476
# 성별         23845360
# 연령대코드      36160476
# 이용건수       36160476
# 운동량        36023075
# 탄소량        36023075
# 이동거리(M)    36160476
# 이용시간(분)    36160476
# 요일_인덱스     36160476
# 요일         36160476
# dtype: int64

# %%
df_2024_day = df_2024[~(df_2024['요일'].isin(['토', '일']))]
df_2024_day
# Out:
#                대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별  \
# 0        2022-12-01     0    746               746. 목동2단지 상가    정기권  None
# 1        2022-12-01     0   1653               1653. 노원역1번출구    정기권  None
# 2        2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None
# 3        2022-12-01     0   1355                  1355. 보문2교    정기권  None
# 4        2022-12-01     0   1184                1184. 마곡13단지    정기권  None
# ...             ...   ...    ...                         ...    ...   ...
# 36160471 2022-11-30    23   3010             3010.홍대입구역 3번출구    정기권     M
# 36160472 2022-11-30    23   3127               3127.홍은2파출소 옆    정기권     M
# 36160473 2022-11-30    23    232           232. 양평우림 이비즈센타 앞    정기권     M
# 36160474 2022-11-30    23   4594            4594. 양평교 영등포대여소    정기권     M
# 36160475 2022-11-30    23   5858              5858. 영등포역5번출구    정기권     M
#
#          연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0         ~10대     1 13.54 0.13    570.0        3       3  목
# 1         ~10대     1 32.81 0.36  1534.33       12       3  목
# 2         ~10대     1  19.1 0.17    720.0        4       3  목
# 3         ~10대     1 10.57 0.08   333.59        3       3  목
# 4         ~10대     1  6.93 0.07    318.2       37       3  목
# ...        ...   ...   ...  ...      ...      ...     ... ..
# 36160471    기타     1 24.37 0.22   946.92        4       2  수
# 36160472    기타     1  3.99 0.03   141.88        2       2  수
# 36160473    기타     1 14.24  0.1   438.61        3       2  수
# 36160474    기타     1 83.98 0.73  3165.07       79       2  수
# 36160475    기타     1 19.05 0.18   775.94        3       2  수
#
# [26936528 rows x 14 columns]

# %% [markdown]
# - '출퇴근' 컬럼을 새로 만들어서 출근, 퇴근을 넣어준다. (월~금요일, 출퇴근)

# %%
df_2024_day.loc[df_2024_day['대여시간'].isin([7,8]),'출퇴근'] = '출근'
df_2024_day.loc[df_2024_day['대여시간'].isin([17,18]),'출퇴근'] = '퇴근'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7236\2796379095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_day.loc[df_2024_day['대여시간'].isin([7,8]),'출퇴근'] = '출근'

# %%
df_2024_day
# Out:
#                대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별  \
# 0        2022-12-01     0    746               746. 목동2단지 상가    정기권  None
# 1        2022-12-01     0   1653               1653. 노원역1번출구    정기권  None
# 2        2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None
# 3        2022-12-01     0   1355                  1355. 보문2교    정기권  None
# 4        2022-12-01     0   1184                1184. 마곡13단지    정기권  None
# ...             ...   ...    ...                         ...    ...   ...
# 36160471 2022-11-30    23   3010             3010.홍대입구역 3번출구    정기권     M
# 36160472 2022-11-30    23   3127               3127.홍은2파출소 옆    정기권     M
# 36160473 2022-11-30    23    232           232. 양평우림 이비즈센타 앞    정기권     M
# 36160474 2022-11-30    23   4594            4594. 양평교 영등포대여소    정기권     M
# 36160475 2022-11-30    23   5858              5858. 영등포역5번출구    정기권     M
#
#          연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일  출퇴근
# 0         ~10대     1 13.54 0.13    570.0        3       3  목  NaN
# 1         ~10대     1 32.81 0.36  1534.33       12       3  목  NaN
# 2         ~10대     1  19.1 0.17    720.0        4       3  목  NaN
# 3         ~10대     1 10.57 0.08   333.59        3       3  목  NaN
# 4         ~10대     1  6.93 0.07    318.2       37       3  목  NaN
# ...        ...   ...   ...  ...      ...      ...     ... ..  ...
# 36160471    기타     1 24.37 0.22   946.92        4       2  수  NaN
# 36160472    기타     1  3.99 0.03   141.88        2       2  수  NaN
# 36160473    기타     1 14.24  0.1   438.61        3       2  수  NaN
# 36160474    기타     1 83.98 0.73  3165.07       79       2  수  NaN
# 36160475    기타     1 19.05 0.18   775.94        3       2  수  NaN
#
# [26936528 rows x 15 columns]

# %%
df_2024_day[df_2024_day['출퇴근'] == '출근'] # df_parquet[df_parquet['이용건수'] == '\\N']
# Out:
#                대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867     2022-12-01     7   1260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868     2022-12-01     7   1264             1264. 천호역 10번 출구 앞    정기권  None
# 5869     2022-12-01     7   1167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870     2022-12-01     7   1050              1050.  둔촌역 3번 출입구    정기권  None
# 5871     2022-12-01     7   1051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
# ...             ...   ...    ...                            ...    ...   ...
# 36109727 2022-11-30     8   2304                   2304. 대현그린타워    정기권     M
# 36109728 2022-11-30     8   1106                   1106. 신방화사거리    정기권     M
# 36109729 2022-11-30     8   1941                1941. 오류동역 2번출구    정기권     M
# 36109730 2022-11-30     8   2252            2252. 잔디마을 마을버스 정류장    정기권     M
# 36109731 2022-11-30     8   2360            2360. 도곡1동 주민센터 교차로    정기권     M
#
#          연령대코드  이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867      ~10대     1  15.22 0.14    620.0        3       3  목  출근
# 5868      ~10대     1  14.26 0.14    600.0        3       3  목  출근
# 5869      ~10대     1   13.9 0.13    540.0        4       3  목  출근
# 5870      ~10대     1  24.97 0.23    970.0        4       3  목  출근
# 5871      ~10대     1  45.86 0.31  1346.65        8       3  목  출근
# ...        ...   ...    ...  ...      ...      ...     ... ..  ..
# 36109727    기타     1  67.08 0.69  2971.86       22       2  수  출근
# 36109728    기타     1  44.98 0.34  1456.19        7       2  수  출근
# 36109729    기타     1  48.79 0.48  2053.27       12       2  수  출근
# 36109730    기타     1 168.28 1.54   6640.0       51       2  수  출근
# 36109731    기타     1  48.03 0.41  1783.69       19       2  수  출근
#
# [3515794 rows x 15 columns]

# %%
df_2024_day[df_2024_day['출퇴근'] == '퇴근']
# Out:
#                대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  \
# 42169    2022-12-01    17    729         729. 서부식자재마트 건너편    정기권  None  ~10대
# 42170    2022-12-01    17   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None  ~10대
# 42171    2022-12-01    17   1653            1653. 노원역1번출구    정기권  None  ~10대
# 42172    2022-12-01    17   1277               1277. 성내6교    정기권  None  ~10대
# 42173    2022-12-01    17   1682      1682. 중계종합사회복지관 교차로    정기권  None  ~10대
# ...             ...   ...    ...                      ...    ...   ...   ...
# 36147036 2022-11-30    18   2102            2102. 봉림교 교통섬    정기권     M    기타
# 36147037 2022-11-30    18   2305       2305. MCM 본사 직영점 앞    정기권     M    기타
# 36147038 2022-11-30    18   1227         1227. 거여역 8번출구 뒤    정기권     M    기타
# 36147039 2022-11-30    18   1925       1925. 동양미래대학교 정문 옆    정기권     M    기타
# 36147040 2022-11-30    18    723              723. SBS방송국    정기권     M    기타
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 42169        1  58.56 0.44  1895.75       10       3  목  퇴근
# 42170        1  58.92 0.43   1860.0       10       3  목  퇴근
# 42171        1  13.13 0.12    510.0        4       3  목  퇴근
# 42172        1    0.0  0.0      0.0        1       3  목  퇴근
# 42173        1  24.66 0.22   958.13        8       3  목  퇴근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 36147036     1  77.62 0.65   2800.0       22       2  수  퇴근
# 36147037     1 128.83 0.83  3575.15       19       2  수  퇴근
# 36147038     1  39.67 0.37   1590.0        7       2  수  퇴근
# 36147039     1 102.64 0.72  3122.75       20       2  수  퇴근
# 36147040     1  35.66 0.31  1324.27        9       2  수  퇴근
#
# [4824973 rows x 15 columns]

# %%
df_2024_day['출퇴근'].unique()
# Out:
# array([nan, '출근', '퇴근'], dtype=object)

# %%
df_2024_day['출퇴근'].value_counts()
# Out:
# 출퇴근
# 퇴근    4824973
# 출근    3515794
# Name: count, dtype: int64

# %%
df_2024_day.count()
# Out:
# 대여일자       26936528
# 대여시간       26936528
# 대여소번호      26936528
# 대여소명       26936528
# 대여구분코드     26936528
# 성별         17808304
# 연령대코드      26936528
# 이용건수       26936528
# 운동량        26832133
# 탄소량        26832133
# 이동거리(M)    26936528
# 이용시간(분)    26936528
# 요일_인덱스     26936528
# 요일         26936528
# 출퇴근         8340767
# dtype: int64

# %%
df_2024_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26936528 entries, 0 to 36160475
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 3.1+ GB

# %%
df_2024_day.loc[:, '이용건수'] = df_2024_day['이용건수'].astype(int)

# %%
df_2024_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26936528 entries, 0 to 36160475
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 3.1+ GB

# %%
df_2024_time = df_2024_day[~df_2024_day['출퇴근'].isnull()] # df_2020_day.dropna(subset=['출퇴근'])

# %%
df_2024_time
# Out:
#                대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867     2022-12-01     7   1260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868     2022-12-01     7   1264             1264. 천호역 10번 출구 앞    정기권  None
# 5869     2022-12-01     7   1167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870     2022-12-01     7   1050              1050.  둔촌역 3번 출입구    정기권  None
# 5871     2022-12-01     7   1051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
# ...             ...   ...    ...                            ...    ...   ...
# 36147036 2022-11-30    18   2102                  2102. 봉림교 교통섬    정기권     M
# 36147037 2022-11-30    18   2305             2305. MCM 본사 직영점 앞    정기권     M
# 36147038 2022-11-30    18   1227               1227. 거여역 8번출구 뒤    정기권     M
# 36147039 2022-11-30    18   1925             1925. 동양미래대학교 정문 옆    정기권     M
# 36147040 2022-11-30    18    723                    723. SBS방송국    정기권     M
#
#          연령대코드  이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867      ~10대     1  15.22 0.14    620.0        3       3  목  출근
# 5868      ~10대     1  14.26 0.14    600.0        3       3  목  출근
# 5869      ~10대     1   13.9 0.13    540.0        4       3  목  출근
# 5870      ~10대     1  24.97 0.23    970.0        4       3  목  출근
# 5871      ~10대     1  45.86 0.31  1346.65        8       3  목  출근
# ...        ...   ...    ...  ...      ...      ...     ... ..  ..
# 36147036    기타     1  77.62 0.65   2800.0       22       2  수  퇴근
# 36147037    기타     1 128.83 0.83  3575.15       19       2  수  퇴근
# 36147038    기타     1  39.67 0.37   1590.0        7       2  수  퇴근
# 36147039    기타     1 102.64 0.72  3122.75       20       2  수  퇴근
# 36147040    기타     1  35.66 0.31  1324.27        9       2  수  퇴근
#
# [8340767 rows x 15 columns]

# %%
df_2024_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8340767 entries, 5867 to 36147040
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 986.3+ MB

# %%
df_2024_time.count()
# Out:
# 대여일자       8340767
# 대여시간       8340767
# 대여소번호      8340767
# 대여소명       8340767
# 대여구분코드     8340767
# 성별         5545162
# 연령대코드      8340767
# 이용건수       8340767
# 운동량        8305855
# 탄소량        8305855
# 이동거리(M)    8340767
# 이용시간(분)    8340767
# 요일_인덱스     8340767
# 요일         8340767
# 출퇴근        8340767
# dtype: int64

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본_최종.parquet'
start_time = time.time()
df_st = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df_st.head(5)
# Out:
# read_parquet time : 0.09865522384643555
#    대여소번호          대여소명  자치구                         상세주소          위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 126.8210602  2024-03-18  NaN 10.0   QR  2024-06  ST-3284   NaN
# 1 127.0669098  2020-03-24  NaN 12.0   QR  2024-06  ST-2068   NaN
# 2 127.0732651  2020-03-23  NaN 20.0   QR  2024-06  ST-2078   NaN
# 3 127.0719147  2020-03-23  NaN  7.0   QR  2024-06  ST-2077   NaN
# 4 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN

# %%
df_st.head()
# Out:
#    대여소번호          대여소명  자치구                         상세주소          위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 126.8210602  2024-03-18  NaN 10.0   QR  2024-06  ST-3284   NaN
# 1 127.0669098  2020-03-24  NaN 12.0   QR  2024-06  ST-2068   NaN
# 2 127.0732651  2020-03-23  NaN 20.0   QR  2024-06  ST-2078   NaN
# 3 127.0719147  2020-03-23  NaN  7.0   QR  2024-06  ST-2077   NaN
# 4 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN

# %%
df_st.info() # 대여소번호 int / object 다름.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2960 entries, 0 to 2959
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   2960 non-null   object
#  1   대여소명    2960 non-null   object
#  2   자치구     2960 non-null   object
#  3   상세주소    2960 non-null   object
#  4   위도      2959 non-null   float64
#  5   경도      2959 non-null   float64
#  6   설치시기    2921 non-null   object
#  7   LCD     1517 non-null   float64
#  8   QR      1752 non-null   float64
#  9   운영방식    2921 non-null   object
#  10  데이터등록월  2921 non-null   object
#  11  대여소ID   2701 non-null   object
#  12  거치대수    39 non-null     float64
# dtypes: float64(5), object(8)
# memory usage: 300.8+ KB

# %%
df_st.shape
# Out:
# (2960, 13)

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

import ExcelFile_EDA as ee
ee.ss_isnull(df_st)
# Out:
#      [컬럼명]  [sum]  [sum_isnull]     [mean_isnull(%)]
# 0    대여소번호   2960             0                  0.0
# 1     대여소명   2960             0                  0.0
# 2      자치구   2960             0                  0.0
# 3     상세주소   2960             0                  0.0
# 4       위도   2959             1 0.033783783783783786
# 5       경도   2959             1 0.033783783783783786
# 6     설치시기   2921            39   1.3175675675675675
# 7      LCD   1517          1443                48.75
# 8       QR   1752          1208    40.81081081081081
# 9     운영방식   2921            39   1.3175675675675675
# 10  데이터등록월   2921            39   1.3175675675675675
# 11   대여소ID   2701           259                 8.75
# 12    거치대수     39          2921    98.68243243243244

# %%
df_st_1 = df_st[['대여소번호', '대여소명', '자치구', '설치시기', '데이터등록월']]
df_st_1
# Out:
#       대여소번호            대여소명   자치구        설치시기   데이터등록월
# 0     06173     서울자동차운전전문학원   강서구  2024-03-18  2024-06
# 1     02902    공릉풍림아파트 108동   노원구  2020-03-24  2024-06
# 2     02912          대진고등학교   노원구  2020-03-23  2024-06
# 3     02911         상계역중앙시장   노원구  2020-03-23  2024-06
# 4     02910           도깨비시장   노원구  2020-03-25  2024-06
# ...     ...             ...   ...         ...      ...
# 2955  05884          GS강서타워  영등포구        None     None
# 2956  05885  신정교하부(도림천역 방면)  영등포구        None     None
# 2957  06060         신한은행 본점    중구        None     None
# 2958  06176      유광사 여성병원 앞   강서구        None     None
# 2959  06177      마곡롯데캐슬르웨스트   강서구        None     None
#
# [2960 rows x 5 columns]

# %% [markdown]
# - 시간대별 데이터, 대여소정보 데이터 에서 '대여소번호' 컬럼의 숫자 표현방식, 데이터 타입이 다르다.

# %% [markdown]
# - 따라서, 1. 시간대별 데이터(월~금 / 출퇴근 시간대 추출함)의 '대여소번호' 컬럼의 숫자를 object로 바꾸어준다.
#      ##### 2. 시간대별 데이터의 '대여소번호' 컬럼의 숫자를 00000 자리로 바꾸어준다.

# %%
df_2024_time.head()
# Out:
#            대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867 2022-12-01     7   1260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868 2022-12-01     7   1264             1264. 천호역 10번 출구 앞    정기권  None
# 5869 2022-12-01     7   1167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870 2022-12-01     7   1050              1050.  둔촌역 3번 출입구    정기권  None
# 5871 2022-12-01     7   1051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
#
#      연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867  ~10대     1 15.22 0.14    620.0        3       3  목  출근
# 5868  ~10대     1 14.26 0.14    600.0        3       3  목  출근
# 5869  ~10대     1  13.9 0.13    540.0        4       3  목  출근
# 5870  ~10대     1 24.97 0.23    970.0        4       3  목  출근
# 5871  ~10대     1 45.86 0.31  1346.65        8       3  목  출근

# %%
df_2024_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8340767 entries, 5867 to 36147040
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 986.3+ MB

# %%
df_2024_time.loc[:, '대여소번호'] = df_2024_time['대여소번호'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7236\1832997655.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['1260' '1264' '1167' ... '1227' '1925' '723']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_2024_time.loc[:, '대여소번호'] = df_2024_time['대여소번호'].astype(str)

# %%
df_2024_time.dtypes
# Out:
# 대여일자       datetime64[ns]
# 대여시간                int64
# 대여소번호              object
# 대여소명               object
# 대여구분코드             object
# 성별                 object
# 연령대코드              object
# 이용건수                int64
# 운동량               float64
# 탄소량               float64
# 이동거리(M)           float64
# 이용시간(분)             int64
# 요일_인덱스              int32
# 요일                 object
# 출퇴근                object
# dtype: object

# %%
df_2024_time.loc[:,'대여소번호'] = df_2024_time['대여소번호'].str.zfill(5)

# %%
df_2024_time.head()
# Out:
#            대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867 2022-12-01     7  01260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868 2022-12-01     7  01264             1264. 천호역 10번 출구 앞    정기권  None
# 5869 2022-12-01     7  01167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870 2022-12-01     7  01050              1050.  둔촌역 3번 출입구    정기권  None
# 5871 2022-12-01     7  01051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
#
#      연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867  ~10대     1 15.22 0.14    620.0        3       3  목  출근
# 5868  ~10대     1 14.26 0.14    600.0        3       3  목  출근
# 5869  ~10대     1  13.9 0.13    540.0        4       3  목  출근
# 5870  ~10대     1 24.97 0.23    970.0        4       3  목  출근
# 5871  ~10대     1 45.86 0.31  1346.65        8       3  목  출근

# %%
df_sum = pd.merge(df_2024_time, df_st_1, on='대여소번호', how='left')
df_sum
# Out:
#               대여일자  대여시간  대여소번호                         대여소명_x 대여구분코드    성별  \
# 0       2022-12-01     7  01260            1260. 방이동 한양3차아파트 옆    정기권  None
# 1       2022-12-01     7  01264             1264. 천호역 10번 출구 앞    정기권  None
# 2       2022-12-01     7  01167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 3       2022-12-01     7  01050              1050.  둔촌역 3번 출입구    정기권  None
# 4       2022-12-01     7  01051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
# ...            ...   ...    ...                            ...    ...   ...
# 8340762 2022-11-30    18  02102                  2102. 봉림교 교통섬    정기권     M
# 8340763 2022-11-30    18  02305             2305. MCM 본사 직영점 앞    정기권     M
# 8340764 2022-11-30    18  01227               1227. 거여역 8번출구 뒤    정기권     M
# 8340765 2022-11-30    18  01925             1925. 동양미래대학교 정문 옆    정기권     M
# 8340766 2022-11-30    18  00723                    723. SBS방송국    정기권     M
#
#         연령대코드  이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근  \
# 0        ~10대     1  15.22 0.14    620.0        3       3  목  출근
# 1        ~10대     1  14.26 0.14    600.0        3       3  목  출근
# 2        ~10대     1   13.9 0.13    540.0        4       3  목  출근
# 3        ~10대     1  24.97 0.23    970.0        4       3  목  출근
# 4        ~10대     1  45.86 0.31  1346.65        8       3  목  출근
# ...       ...   ...    ...  ...      ...      ...     ... ..  ..
# 8340762    기타     1  77.62 0.65   2800.0       22       2  수  퇴근
# 8340763    기타     1 128.83 0.83  3575.15       19       2  수  퇴근
# 8340764    기타     1  39.67 0.37   1590.0        7       2  수  퇴근
# 8340765    기타     1 102.64 0.72  3122.75       20       2  수  퇴근
# 8340766    기타     1  35.66 0.31  1324.27        9       2  수  퇴근
#
#                           대여소명_y  자치구        설치시기   데이터등록월
# 0                  방이동 한양3차아파트 옆  송파구  2017-11-01  2024-06
# 1                   천호역 10번 출구 앞  송파구  2017-11-01  2024-06
# 2                 마곡수명산파크3단지 교차로  강서구  2017-12-22  2024-06
# 3                     둔촌역 3번 출입구  강동구  2018-02-26  2024-06
# 4        강일중,선사고 버스정류장(신암중학교 방면)  강동구  2018-02-26  2024-06
# ...                          ...  ...         ...      ...
# 8340762                  봉림교 교통섬  관악구  2017-05-12  2024-06
# 8340763             MCM 본사 직영점 앞  강남구  2017-06-13  2024-06
# 8340764               거여역 8번출구 뒤  송파구  2017-06-27  2024-06
# 8340765             동양미래대학교 정문 옆  구로구  2017-06-27  2024-06
# 8340766                   SBS방송국  양천구  2017-11-01  2024-06
#
# [8340767 rows x 19 columns]

# %%
group1 = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().reset_index()
group1
# Out:
#               대여소명_y 출퇴근  이용건수
# 0        (시립)고덕평생학습관  출근   694
# 1        (시립)고덕평생학습관  퇴근   981
# 2       (재)FITI시험연구원  출근  3624
# 3       (재)FITI시험연구원  퇴근  4033
# 4      3호선 매봉역 3번출구앞  출근  3042
# ...              ...  ..   ...
# 5486         힐스테이트에코  퇴근  8652
# 5487  힐스테이트창경궁 아파트 앞  출근   618
# 5488  힐스테이트창경궁 아파트 앞  퇴근   780
# 5489    힐스테이트클래시안아파트  출근  2681
# 5490    힐스테이트클래시안아파트  퇴근  1109
#
# [5491 rows x 3 columns]

# %% [markdown]
# - 출근 시간대 대여소별 이용건수

# %%
commute_data = group1[group1['출퇴근'] == '출근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data = commute_data.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data = top_20_commute_data.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
bars = plt.barh(top_20_commute_data['대여소명_y'], top_20_commute_data['이용건수'])
plt.title(_year + '년 출근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')

# 각 막대 끝에 이용건수 표시
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:,.0f}', 
             ha='left', va='center', fontweight='bold')
    
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %%
top_20_m = top_20_commute_data.sort_values(by='이용건수', ascending=False)

# %%
top_20_m
# Out:
#                  대여소명_y 출퇴근   이용건수
# 1731      마곡나루역 5번출구 뒤편  출근  32238
# 1727        마곡나루역 2번 출구  출근  22298
# 1239            대방역6번출구  출근  13934
# 1729        마곡나루역 3번 출구  출근  12931
# 1713             마곡13단지  출근  11536
# 878        그랜드아이파크아파트 앞  출근  11158
# 1659  롯데월드타워(잠실역2번출구 쪽)  출근  10661
# 3790       여의나루역 1번출구 앞  출근  10550
# 1715        마곡13단지 정문 앞  출근  10501
# 732          구로디지털단지역 앞  출근  10085
# 3093         성수역 2번출구 앞  출근   9887
# 3732           양천아파트 입구  출근   9879
# 3922        영등포구청역 1번출구  출근   9748
# 2021         문래동롯데캐슬아파트  출근   9726
# 4961             충북 미래관  출근   9175
# 1983   목동역5번출구 교통정보센터 앞  출근   8948
# 3616   아크로타워 스퀘어(영등포시장)  출근   8905
# 3387       신도림역 1번 출구 앞  출근   8712
# 1172        당산역 10번출구 앞  출근   8705
# 3237        수명산파크1단지교차로  출근   8488

# %% [markdown]
# ## 출근 시간대 top20 대여소 지도에 나타내기

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일/서울시 공공자전거 대여소 정보/공공자전거 대여소 정보_통합본_최종.parquet')
rental = rental.iloc[4:]
rental.reset_index(drop = True, inplace = True)

# %%
rental.head()
# Out:
#    대여소번호         대여소명  자치구                          상세주소          위도  \
# 0  02910        도깨비시장  노원구      서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1  02909    석계역 3번 출구  노원구  서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2  02908  광운대학교 중앙도서관  노원구        서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3  02907        월계중학교  노원구      서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4  02904    중계3차청구아파트  노원구     서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN
# 1 127.0674515  2020-03-25  NaN 13.0   QR  2024-06  ST-2075   NaN
# 2 127.0585632  2020-03-24  NaN 20.0   QR  2024-06  ST-2074   NaN
# 3 127.0531082  2020-03-24  NaN 15.0   QR  2024-06  ST-2073   NaN
# 4 127.0739822  2020-03-24  NaN  8.0   QR  2024-06  ST-2070   NaN

# %%
have_bikes = rental.groupby('자치구').size()

# %%
rental = rental.rename(columns={'대여소명':'대여소명_y'})
rental
# Out:
#       대여소번호          대여소명_y   자치구  \
# 0     02910           도깨비시장   노원구
# 1     02909       석계역 3번 출구   노원구
# 2     02908     광운대학교 중앙도서관   노원구
# 3     02907           월계중학교   노원구
# 4     02904       중계3차청구아파트   노원구
# ...     ...             ...   ...
# 2951  05884          GS강서타워  영등포구
# 2952  05885  신정교하부(도림천역 방면)  영등포구
# 2953  06060         신한은행 본점    중구
# 2954  06176      유광사 여성병원 앞   강서구
# 2955  06177      마곡롯데캐슬르웨스트   강서구
#
#                                                    상세주소          위도  \
# 0                              서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1                          서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2                                서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3                              서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4                             서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
# ...                                                 ...         ...
# 2951  GS 홈쇼핑본사(GS강서빌딩), 75, 선유로, 문래동4가, 문래동, 영등포구, 서... 37.52098083
# 2952         도림천로, 문래동5가, 문래동, 영등포구, 서울특별시, 07285, 대한민국 37.51594543
# 2953          세종대로9길, 서소문동, 소공동, 중구, 서울특별시, 04512, 대한민국 37.56077576
# 2954   유광사여성병원, 194, 강서로, 우장산동, 강서구, 서울특별시, 07698, 대한민국  37.5434494
# 2955          마곡중앙로, 마곡동, 방화1동, 강서구, 서울특별시, 07800, 대한민국 37.56356049
#
#                경도        설치시기  LCD   QR  운영방식   데이터등록월    대여소ID  거치대수
# 0     127.0740509  2020-03-25  NaN 10.0    QR  2024-06     None   NaN
# 1     127.0674515  2020-03-25  NaN 13.0    QR  2024-06  ST-2075   NaN
# 2     127.0585632  2020-03-24  NaN 20.0    QR  2024-06  ST-2074   NaN
# 3     127.0531082  2020-03-24  NaN 15.0    QR  2024-06  ST-2073   NaN
# 4     127.0739822  2020-03-24  NaN  8.0    QR  2024-06  ST-2070   NaN
# ...           ...         ...  ...  ...   ...      ...      ...   ...
# 2951 126.88929749        None  NaN  NaN  None     None  ST-3331   8.0
# 2952 126.88288879        None  NaN  NaN  None     None  ST-3341  10.0
# 2953 126.97480774        None  NaN  NaN  None     None  ST-3342   8.0
# 2954 126.83891296        None  NaN  NaN  None     None  ST-3327   7.0
# 2955 126.82462311        None  NaN  NaN  None     None  ST-3324  10.0
#
# [2956 rows x 13 columns]

# %%
top_20_m = pd.merge(top_20_m, rental, on='대여소명_y', how='left')
top_20_m
# Out:
#                대여소명_y 출퇴근   이용건수  대여소번호   자치구                           상세주소  \
# 0       마곡나루역 5번출구 뒤편  출근  32238  02701   강서구                  강서구 마곡동 761-5
# 1         마곡나루역 2번 출구  출근  22298  02715   강서구                   강서구 마곡중앙5로 6
# 2             대방역6번출구  출근  13934  00259  영등포구             서울특별시 영등포구 신길동1368
# 3         마곡나루역 3번 출구  출근  12931  02728   강서구                 강서구 마곡동 372-23
# 4              마곡13단지  출근  11536  01184   강서구                   강서구 공항동 1343
# 5        그랜드아이파크아파트 앞  출근  11158  03798   강서구
# 6   롯데월드타워(잠실역2번출구 쪽)  출근  10661  01210   송파구          서울특별시 송파구 올림픽로 293-19
# 7        여의나루역 1번출구 앞  출근  10550  00207  영등포구          서울특별시 영등포구 여의동로 지하343
# 8         마곡13단지 정문 앞  출근  10501  02733   강서구                강서구 마곡동 730-417
# 9          구로디지털단지역 앞  출근  10085  01911   구로구           서울특별시 구로구 시흥대로 577-2
# 10         성수역 2번출구 앞  출근   9887  00567   성동구  서울특별시 성동구 아차산로 113 성수역 2번출구 앞
# 11           양천아파트 입구  출근   9879  00787   양천구                   양천구 목동로3길 41
# 12        영등포구청역 1번출구  출근   9748  00230  영등포구           서울특별시 영등포구 당산로 111-2
# 13         문래동롯데캐슬아파트  출근   9726  04571  영등포구                  영등포구 선유로9길 30
# 14             충북 미래관  출근   9175  00293  영등포구               영등포구 당산동 121-258
# 15   목동역5번출구 교통정보센터 앞  출근   8948  00770   양천구                    양천구 목동로 186
# 16   아크로타워 스퀘어(영등포시장)  출근   8905  00283  영등포구                영등포구 영등포동7가 3-2
# 17       신도림역 1번 출구 앞  출근   8712  01906   구로구              서울특별시 구로구 경인로 688
# 18        당산역 10번출구 앞  출근   8705  00247  영등포구          서울특별시 영등포구 당산동5가 14-4
# 19        수명산파크1단지교차로  출근   8488  02739   강서구                     강서로47길 142
#
#             위도          경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  37.56520081 126.8273163  2018-11-14 26.0  NaN  LCD  2024-06  ST-1718   NaN
# 1  37.56692505 126.8274384  2020-05-27  NaN 25.0   QR  2024-06  ST-2031   NaN
# 2  37.51359177 126.9259338  2016-06-29 17.0 17.0   QR  2024-06   ST-307   NaN
# 3  37.56580353 126.8280792  2020-03-12  NaN 55.0   QR  2024-06  ST-2045   NaN
# 4  37.55644989  126.815979  2018-10-10 26.0  NaN  LCD  2024-06  ST-1645   NaN
# 5  37.55510712 126.8515472  2020-12-21  NaN 11.0   QR  2024-06  ST-2557   NaN
# 6  37.51312637 127.1009598  2017-06-27 30.0  NaN  LCD  2024-06   ST-891   NaN
# 7  37.52715683    126.9319  2015-09-17 46.0 46.0   QR  2024-06    ST-73   NaN
# 8   37.5586319 126.8199158  2020-03-20  NaN 15.0   QR  2024-06  ST-2050   NaN
# 9  37.48493958 126.9013214  2017-05-11 18.0  NaN  LCD  2024-06   ST-668   NaN
# 10    37.54459 127.0570831  2016-07-06 15.0 15.0   QR  2024-06   ST-368   NaN
# 11 37.50790405  126.862648  2020-03-09  NaN 14.0   QR  2024-06  ST-2013   NaN
# 12 37.52463531 126.8962174  2016-07-06 13.0 13.0   QR  2024-06   ST-413   NaN
# 13 37.51800156 126.8845978  2021-05-17  NaN 10.0   QR  2024-06  ST-2820   NaN
# 14 37.52917099 126.9075775  2018-12-04 15.0  NaN  LCD  2024-06  ST-1701   NaN
# 15 37.52571487 126.8648682  2020-03-13  NaN 15.0   QR  2024-06  ST-1996   NaN
# 16 37.52251816 126.9072189  2018-09-28 15.0  NaN  LCD  2024-06  ST-1649   NaN
# 17 37.50971985 126.8900986  2017-05-11 20.0  NaN  LCD  2024-06   ST-664   NaN
# 18 37.53342056 126.9022369  2016-06-29 15.0 14.0   QR  2024-06     None   NaN
# 19 37.55363083 126.8286133  2020-03-17  NaN 20.0   QR  2024-06  ST-2056   NaN

# %% [markdown]
# ### 자전거 도로 정보

# %%
geo_path = path_dateset + '_최종 병합 파일\\서울시 자전거 도로 데이터\\' + 'ddareng_road.geojson'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str = json.load(f)
# # ============================

# %% [markdown]
# ### 자치구 정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %% [markdown]
# ### 지하철역통합

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#     연번   역번호  호선    역명         역전화번호                      도로명주소  \
# 0  NaN  None NaN  <NA>          <NA>                       <NA>
# 1  NaN  None NaN  <NA>          <NA>                       <NA>
# 2 92.0   340 3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3  NaN  None NaN  <NA>          <NA>                       <NA>
# 4  NaN  None NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat        lng
# 0            943            419민주묘지 37.6482352 127.008614
# 1            109                 가능  37.748577 127.044213
# 2            350               가락시장  37.492522 127.118234
# 3           P142            가산디지털단지  37.481072 126.882343
# 4            907                 가양  37.561391 126.854456

# %%
b_출퇴근 = '출근'

if b_출퇴근 == '출근':
    df_출퇴근 = top_20_m
else:
    df_출퇴근 = top_20_e

# %%
# 지도 생성
center = [37.541, 126.986]
# center on Liberty Bell, add marker
bike_map = folium.Map(location=center, zoom_start=13)
# 스타일 지정 예시 (선의 색상, 두께 등)
style = {
    'color': 'red',
    'weight': 3,
    'opacity': 0.7,
}

fg0 = folium.FeatureGroup(name="bike_road", show=False).add_to(bike_map)
# 자전거 도로 표시
# GeoJSON 파일을 불러와 스타일 적용
folium.GeoJson(
    geo_str,
    name='bike_road',
    style_function=lambda x: style
).add_to(fg0)

fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)
# 자전거 대여소 표시
for i, row in top_20_m.iterrows():
  # folium.Marker(
    #folium.CircleMarker(
    folium.Circle(
      location = [row['위도'], row['경도']],
      radius = 100,
      color='black',                  # 외곽선 색상
      fill=False,                     # 채우기 여부
      fill_color='blue',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      #popup=row['대여소번호'],             # 클릭 시 표시되는 팝업
      tooltip=row['대여소명_y'],                 # 마우스 오버 시 표시되는 툴팁
      #icon=folium.Icon(icon = 'bookmark', color = 'blue')
  ).add_to(fg1)

fg2 = folium.FeatureGroup(name="train_station", show=False).add_to(bike_map)
# 지하철역 표시
for i, row in df_train_station.iterrows():
  folium.CircleMarker(
      location = [row['lat'], row['lng']],
      radius=2,                     # 반지름 (픽셀 단위)
      color='yellow',                  # 외곽선 색상
      fill=True,                     # 채우기 여부
      fill_color='yellow',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      popup=row[' seoulmetro_code'],             # 클릭 시 표시되는 팝업
      tooltip=row[' station_name(kor)']                 # 마우스 오버 시 표시되는 툴팁      
  ).add_to(fg2)

# 자치구 구분 표
geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))
choropleth = folium.Choropleth(geo_data = geo_str2,
                  data = have_bikes,
                  name = 'gu',
                  key_on = 'feature.properties.SIG_KOR_NM',
                  fill_color = 'Blues')
# 1. GeoJsonTooltip을 사용하는 방법:
# folium.GeoJsonTooltip(fields=['SIG_ENG_NM'],
#                       aliases=['지역:'],
#                       style=('background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;')
# ).add_to(choropleth.geojson)
# 2. GeoJsonPopup을 사용하는 방법:
folium.GeoJsonPopup(fields=['SIG_KOR_NM'],
                    aliases=['지역:'],
                    style='font-weight: bold;'
).add_to(choropleth.geojson)
choropleth.add_to(bike_map)

folium.LayerControl().add_to(bike_map)

# jupyter 에서 곧장 지도 표시하기
#bike_map

# web에서 표시하기
# 지도 저장
bike_map.save("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
import webbrowser
webbrowser.open("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
# Out:
# True

# %% [markdown]
# - 퇴근 시간대 대여소별 이용건수

# %%
commute_data_2 = group1[group1['출퇴근'] == '퇴근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data_2 = commute_data_2.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data_2 = top_20_commute_data_2.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
bars = plt.barh(top_20_commute_data_2['대여소명_y'], top_20_commute_data_2['이용건수'])
plt.title(_year + '년 퇴근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')

# 각 막대 끝에 이용건수 표시
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:,.0f}', 
             ha='left', va='center', fontweight='bold')

plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %%
top_20_e = top_20_commute_data_2.sort_values(by='이용건수', ascending=False)
top_20_e
# Out:
#                  대여소명_y 출퇴근   이용건수
# 1728        마곡나루역 2번 출구  퇴근  29452
# 1660  롯데월드타워(잠실역2번출구 쪽)  퇴근  22668
# 1732      마곡나루역 5번출구 뒤편  퇴근  20338
# 135         LG유플러스 마곡사옥  퇴근  19700
# 3791       여의나루역 1번출구 앞  퇴근  19397
# 733          구로디지털단지역 앞  퇴근  18190
# 4980      코오롱One&Only타워  퇴근  17847
# 829              국민일보 앞  퇴근  17301
# 1608      뚝섬유원지역 1번출구 앞  퇴근  16648
# 3188               송파구청  퇴근  15701
# 1730        마곡나루역 3번 출구  퇴근  14553
# 1197        대륭포스트타워6차 앞  퇴근  14508
# 1740         마곡센트럴타워 1차  퇴근  14215
# 1173        당산역 10번출구 앞  퇴근  14070
# 3725      양천구청, 보건소 사잇길  퇴근  13779
# 2144  발산역 1번, 9번 인근 대여소  퇴근  13775
# 3388       신도림역 1번 출구 앞  퇴근  13477
# 5008            태평양물산빌딩  퇴근  13403
# 1193          대륭포스트타워1차  퇴근  13020
# 3923        영등포구청역 1번출구  퇴근  12436

# %% [markdown]
# ## 퇴근 시간대 top20 대여소 지도에 나타내기

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일/서울시 공공자전거 대여소 정보/공공자전거 대여소 정보_통합본_최종.parquet')
rental = rental.iloc[4:]
rental.reset_index(drop = True, inplace = True)

# %%
rental.head()
# Out:
#    대여소번호         대여소명  자치구                          상세주소          위도  \
# 0  02910        도깨비시장  노원구      서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1  02909    석계역 3번 출구  노원구  서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2  02908  광운대학교 중앙도서관  노원구        서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3  02907        월계중학교  노원구      서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4  02904    중계3차청구아파트  노원구     서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
#
#            경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0 127.0740509  2020-03-25  NaN 10.0   QR  2024-06     None   NaN
# 1 127.0674515  2020-03-25  NaN 13.0   QR  2024-06  ST-2075   NaN
# 2 127.0585632  2020-03-24  NaN 20.0   QR  2024-06  ST-2074   NaN
# 3 127.0531082  2020-03-24  NaN 15.0   QR  2024-06  ST-2073   NaN
# 4 127.0739822  2020-03-24  NaN  8.0   QR  2024-06  ST-2070   NaN

# %%
have_bikes = rental.groupby('자치구').size()

# %%
rental = rental.rename(columns={'대여소명':'대여소명_y'})
rental
# Out:
#       대여소번호          대여소명_y   자치구  \
# 0     02910           도깨비시장   노원구
# 1     02909       석계역 3번 출구   노원구
# 2     02908     광운대학교 중앙도서관   노원구
# 3     02907           월계중학교   노원구
# 4     02904       중계3차청구아파트   노원구
# ...     ...             ...   ...
# 2951  05884          GS강서타워  영등포구
# 2952  05885  신정교하부(도림천역 방면)  영등포구
# 2953  06060         신한은행 본점    중구
# 2954  06176      유광사 여성병원 앞   강서구
# 2955  06177      마곡롯데캐슬르웨스트   강서구
#
#                                                    상세주소          위도  \
# 0                              서울특별시 노원구 동일로 1028 한의학명가 37.62186432
# 1                          서울특별시 노원구 화랑로 351-2 구두수선대196 37.61545944
# 2                                서울특별시 노원구 광운로 20 광운대학교 37.62000275
# 3                              서울특별시 노원구 초안산로 29 신계초등학교 37.63074875
# 4                             서울특별시 노원구 중계로 233 청구3차아파트 37.65050507
# ...                                                 ...         ...
# 2951  GS 홈쇼핑본사(GS강서빌딩), 75, 선유로, 문래동4가, 문래동, 영등포구, 서... 37.52098083
# 2952         도림천로, 문래동5가, 문래동, 영등포구, 서울특별시, 07285, 대한민국 37.51594543
# 2953          세종대로9길, 서소문동, 소공동, 중구, 서울특별시, 04512, 대한민국 37.56077576
# 2954   유광사여성병원, 194, 강서로, 우장산동, 강서구, 서울특별시, 07698, 대한민국  37.5434494
# 2955          마곡중앙로, 마곡동, 방화1동, 강서구, 서울특별시, 07800, 대한민국 37.56356049
#
#                경도        설치시기  LCD   QR  운영방식   데이터등록월    대여소ID  거치대수
# 0     127.0740509  2020-03-25  NaN 10.0    QR  2024-06     None   NaN
# 1     127.0674515  2020-03-25  NaN 13.0    QR  2024-06  ST-2075   NaN
# 2     127.0585632  2020-03-24  NaN 20.0    QR  2024-06  ST-2074   NaN
# 3     127.0531082  2020-03-24  NaN 15.0    QR  2024-06  ST-2073   NaN
# 4     127.0739822  2020-03-24  NaN  8.0    QR  2024-06  ST-2070   NaN
# ...           ...         ...  ...  ...   ...      ...      ...   ...
# 2951 126.88929749        None  NaN  NaN  None     None  ST-3331   8.0
# 2952 126.88288879        None  NaN  NaN  None     None  ST-3341  10.0
# 2953 126.97480774        None  NaN  NaN  None     None  ST-3342   8.0
# 2954 126.83891296        None  NaN  NaN  None     None  ST-3327   7.0
# 2955 126.82462311        None  NaN  NaN  None     None  ST-3324  10.0
#
# [2956 rows x 13 columns]

# %%
top_20_e = pd.merge(top_20_e, rental, on='대여소명_y', how='left')
top_20_e
# Out:
#                대여소명_y 출퇴근   이용건수  대여소번호   자치구                            상세주소  \
# 0         마곡나루역 2번 출구  퇴근  29452  02715   강서구                    강서구 마곡중앙5로 6
# 1   롯데월드타워(잠실역2번출구 쪽)  퇴근  22668  01210   송파구           서울특별시 송파구 올림픽로 293-19
# 2       마곡나루역 5번출구 뒤편  퇴근  20338  02701   강서구                   강서구 마곡동 761-5
# 3         LG유플러스 마곡사옥  퇴근  19700  02717   강서구                   강서구 마곡중앙8로 71
# 4        여의나루역 1번출구 앞  퇴근  19397  00207  영등포구           서울특별시 영등포구 여의동로 지하343
# 5          구로디지털단지역 앞  퇴근  18190  01911   구로구            서울특별시 구로구 시흥대로 577-2
# 6       코오롱One&Only타워  퇴근  17847  01195   강서구                 강서구 마곡동 727-525
# 7              국민일보 앞  퇴근  17301  00202  영등포구            서울특별시 영등포구 여의공원로 101
# 8       뚝섬유원지역 1번출구 앞  퇴근  16648  00502   광진구  서울특별시 광진구 능동로 10 뚝섬유원지역 1번출구 앞
# 9                송파구청  퇴근  15701  02608   송파구                    송파구 올림픽로 326
# 10        마곡나루역 3번 출구  퇴근  14553  02728   강서구                  강서구 마곡동 372-23
# 11        대륭포스트타워6차 앞  퇴근  14508  01867   금천구                         벚꽃로 298
# 12         마곡센트럴타워 1차  퇴근  14215  01193   강서구                강서구 마곡동 727-1136
# 13        당산역 10번출구 앞  퇴근  14070  00247  영등포구           서울특별시 영등포구 당산동5가 14-4
# 14      양천구청, 보건소 사잇길  퇴근  13779  00785   양천구                   양천구 신정동 321-8
# 15  발산역 1번, 9번 인근 대여소  퇴근  13775  01153   강서구              서울특별시 강서구 공항대로 281
# 16       신도림역 1번 출구 앞  퇴근  13477  01906   구로구               서울특별시 구로구 경인로 688
# 17            태평양물산빌딩  퇴근  13403  01986   구로구                  구로구 구로동 197-21
# 18          대륭포스트타워1차  퇴근  13020  02801   구로구                구로구 디지털로31길 33-1
# 19        영등포구청역 1번출구  퇴근  12436  00230  영등포구            서울특별시 영등포구 당산로 111-2
#
#             위도          경도        설치시기  LCD   QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  37.56692505 126.8274384  2020-05-27  NaN 25.0   QR  2024-06  ST-2031   NaN
# 1  37.51312637 127.1009598  2017-06-27 30.0  NaN  LCD  2024-06   ST-891   NaN
# 2  37.56520081 126.8273163  2018-11-14 26.0  NaN  LCD  2024-06  ST-1718   NaN
# 3  37.56133652 126.8339005  2020-03-15  NaN 62.0   QR  2024-06  ST-2033   NaN
# 4  37.52715683    126.9319  2015-09-17 46.0 46.0   QR  2024-06    ST-73   NaN
# 5  37.48493958 126.9013214  2017-05-11 18.0  NaN  LCD  2024-06   ST-668   NaN
# 6  37.56412888 126.8343124  2018-11-20 24.0  NaN  LCD  2024-06  ST-1712   NaN
# 7  37.52881622   126.92453  2015-09-11 30.0 30.0   QR  2024-06    ST-47   NaN
# 8  37.53186035 127.0671921  2015-10-07 17.0 33.0   QR  2024-06     None   NaN
# 9   37.5150528 127.1062698  2018-11-12 15.0 10.0   QR  2024-06  ST-1681   NaN
# 10 37.56580353 126.8280792  2020-03-12  NaN 55.0   QR  2024-06  ST-2045   NaN
# 11 37.48088837 126.8838043  2020-02-26  NaN 30.0   QR  2024-06  ST-1938   NaN
# 12 37.55947113  126.832077  2018-11-20 15.0 36.0   QR  2024-06  ST-1688   NaN
# 13 37.53342056 126.9022369  2016-06-29 15.0 14.0   QR  2024-06     None   NaN
# 14 37.51747513 126.8663254  2020-03-15  NaN 24.0   QR  2024-06  ST-2011   NaN
# 15 37.55894852 126.8371735  2017-11-01 17.0 15.0  LCD  2024-06  ST-1065   NaN
# 16 37.50971985 126.8900986  2017-05-11 20.0  NaN  LCD  2024-06   ST-664   NaN
# 17 37.48485947 126.8951874  2018-09-28 15.0  NaN  LCD  2024-06  ST-1521   NaN
# 18 37.48437119 126.8954239  2019-07-18 30.0  NaN  LCD  2024-06  ST-1753   NaN
# 19 37.52463531 126.8962174  2016-07-06 13.0 13.0   QR  2024-06   ST-413   NaN

# %% [markdown]
# ### 자전거도로정보

# %%
geo_path = path_dateset + '_최종 병합 파일\\서울시 자전거 도로 데이터\\' + 'ddareng_road.geojson'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str = json.load(f)
# # ============================

# %% [markdown]
# ### 자치구정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %% [markdown]
# ### 지하철역통합

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#     연번   역번호  호선    역명         역전화번호                      도로명주소  \
# 0  NaN  None NaN  <NA>          <NA>                       <NA>
# 1  NaN  None NaN  <NA>          <NA>                       <NA>
# 2 92.0   340 3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3  NaN  None NaN  <NA>          <NA>                       <NA>
# 4  NaN  None NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat        lng
# 0            943            419민주묘지 37.6482352 127.008614
# 1            109                 가능  37.748577 127.044213
# 2            350               가락시장  37.492522 127.118234
# 3           P142            가산디지털단지  37.481072 126.882343
# 4            907                 가양  37.561391 126.854456

# %%
b_출퇴근 = '퇴근'

if b_출퇴근 == '출근':
    df_출퇴근 = top_20_m
else:
    df_출퇴근 = top_20_e

# %%
# 지도 생성
center = [37.541, 126.986]
# center on Liberty Bell, add marker
bike_map = folium.Map(location=center, zoom_start=13)
# 스타일 지정 예시 (선의 색상, 두께 등)
style = {
    'color': 'red',
    'weight': 3,
    'opacity': 0.7,
}

fg0 = folium.FeatureGroup(name="bike_road", show=False).add_to(bike_map)
# 자전거 도로 표시
# GeoJSON 파일을 불러와 스타일 적용
folium.GeoJson(
    geo_str,
    name='bike_road',
    style_function=lambda x: style
).add_to(fg0)

fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)
# 자전거 대여소 표시
for i, row in df_출퇴근.iterrows():
  # folium.Marker(
    #folium.CircleMarker(
    folium.Circle(
      location = [row['위도'], row['경도']],
      radius = 100,
      color='black',                  # 외곽선 색상
      fill=False,                     # 채우기 여부
      fill_color='blue',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      #popup=row['대여소번호'],             # 클릭 시 표시되는 팝업
      tooltip=row['대여소명_y'],                 # 마우스 오버 시 표시되는 툴팁
      #icon=folium.Icon(icon = 'bookmark', color = 'blue')
  ).add_to(fg1)

fg2 = folium.FeatureGroup(name="train_station", show=False).add_to(bike_map)
# 지하철역 표시
for i, row in df_train_station.iterrows():
  folium.CircleMarker(
      location = [row['lat'], row['lng']],
      radius=2,                     # 반지름 (픽셀 단위)
      color='yellow',                  # 외곽선 색상
      fill=True,                     # 채우기 여부
      fill_color='yellow',             # 채우기 색상
      fill_opacity=0.6,              # 채우기 불투명도
      popup=row[' seoulmetro_code'],             # 클릭 시 표시되는 팝업
      tooltip=row[' station_name(kor)']                 # 마우스 오버 시 표시되는 툴팁      
  ).add_to(fg2)

# 자치구 구분 표
geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))
choropleth = folium.Choropleth(geo_data = geo_str2,
                  data = have_bikes,
                  name = 'gu',
                  key_on = 'feature.properties.SIG_KOR_NM',
                  fill_color = 'Blues')
# 1. GeoJsonTooltip을 사용하는 방법:
# folium.GeoJsonTooltip(fields=['SIG_ENG_NM'],
#                       aliases=['지역:'],
#                       style=('background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;')
# ).add_to(choropleth.geojson)
# 2. GeoJsonPopup을 사용하는 방법:
folium.GeoJsonPopup(fields=['SIG_KOR_NM'],
                    aliases=['지역:'],
                    style='font-weight: bold;'
).add_to(choropleth.geojson)
choropleth.add_to(bike_map)

folium.LayerControl().add_to(bike_map)

# jupyter 에서 곧장 지도 표시하기
#bike_map

# web에서 표시하기
# 지도 저장

bike_map.save("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
import webbrowser
webbrowser.open("folium_bike_" + _year + '_' + b_출퇴근 + ".html")
# Out:
# True

# %% [markdown]
# -------------------------------------------------
