# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'
filename = '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2020'
df_2020 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)

# 서울특별시 공공자전거 대여소별 이용정보(시간대별)_2020.parquet
# Out:
# read_parquet time : 4.895917892456055

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2020)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]   [mean_isnull(%)]
# 0      대여일자  19026024             0                0.0
# 1      대여시간  19026024             0                0.0
# 2     대여소번호  19026024             0                0.0
# 3      대여소명  19026024             0                0.0
# 4    대여구분코드  19026024             0                0.0
# 5        성별   9530047       9495977 49.910464740294664
# 6     연령대코드  19026024             0                0.0
# 7      이용건수  19026024             0                0.0
# 8       운동량  18906625        119399 0.6275562356065566
# 9       탄소량  18906625        119399 0.6275562356065566
# 10  이동거리(M)  19026024             0                0.0
# 11  이용시간(분)  19026024             0                0.0

# %%
df_2020.head()
# Out:
#          대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0  2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1
# 1  2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1
# 2  2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1
# 3  2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1
# 4  2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1
#
#     운동량  탄소량  이동거리(M)  이용시간(분)
# 0 53.86 0.32   1360.0        6
# 1 10.04 0.09    390.0        3
# 2 75.14 0.64   2750.0       24
# 3 28.42 0.18    780.0        3
# 4 52.97 0.41   1760.0       11

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19026024 entries, 0 to 19026023
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 1.7+ GB

# %%
df_2020.describe()
# Out:
#                    대여시간              대여소번호               이용건수  \
# count        19026024.0         19026024.0         19026024.0
# mean  14.10221925505823 1320.0414105963496 1.2231528247835701
# std     6.0232109512046  926.5531510852235 0.6884706127401732
# min                 0.0                3.0                1.0
# 25%                10.0              568.0                1.0
# 50%                15.0             1190.0                1.0
# 75%                19.0             1961.0                1.0
# max                23.0            99999.0               89.0
#
#                      운동량                탄소량            이동거리(M)  \
# count         18906625.0         18906625.0         19026024.0
# mean  178.32485436612828 0.8041762641402137 3444.5208466503595
# std    89165.66125591451 26.213512909498153 112634.51287964378
# min                  0.0                0.0                0.0
# 25%                  0.0                0.0                0.0
# 50%                  0.0                0.0                0.0
# 75%                43.24               0.38             1630.0
# max          99999999.99            9175.43        39549190.92
#
#                  이용시간(분)
# count         19026024.0
# mean   37.02016669378742
# std   49.353090322493564
# min                  0.0
# 25%                 10.0
# 50%                 21.0
# 75%                 48.0
# max              15814.0

# %%
pd.options.display.float_format = '{:3}'.format

# %%
round(df_2020.describe(), 1)
# Out:
#             대여시간      대여소번호       이용건수         운동량        탄소량    이동거리(M)  \
# count 19026024.0 19026024.0 19026024.0  18906625.0 18906625.0 19026024.0
# mean        14.1     1320.0        1.2       178.3        0.8     3444.5
# std          6.0      926.6        0.7     89165.7       26.2   112634.5
# min          0.0        3.0        1.0         0.0        0.0        0.0
# 25%         10.0      568.0        1.0         0.0        0.0        0.0
# 50%         15.0     1190.0        1.0         0.0        0.0        0.0
# 75%         19.0     1961.0        1.0        43.2        0.4     1630.0
# max         23.0    99999.0       89.0 100000000.0     9175.4 39549190.9
#
#          이용시간(분)
# count 19026024.0
# mean        37.0
# std         49.4
# min          0.0
# 25%         10.0
# 50%         21.0
# 75%         48.0
# max      15814.0

# %%
df_2020.shape
# Out:
# (19026024, 12)

# %%
df_2020.isnull().sum()
# Out:
# 대여일자             0
# 대여시간             0
# 대여소번호            0
# 대여소명             0
# 대여구분코드           0
# 성별         9495977
# 연령대코드            0
# 이용건수             0
# 운동량         119399
# 탄소량         119399
# 이동거리(M)          0
# 이용시간(분)          0
# dtype: int64

# %%
df_2020['대여시간'].value_counts()
# Out:
# 대여시간
# 18    1643772
# 17    1461791
# 19    1293033
# 16    1202450
# 20    1147485
# 15    1072244
# 21    1062030
# 8      998040
# 14     982335
# 13     910746
# 22     895745
# 12     849483
# 11     732324
# 9      698533
# 7      661918
# 23     660096
# 10     619735
# 0      559640
# 1      441839
# 2      309555
# 6      299784
# 3      215831
# 5      158157
# 4      149458
# Name: count, dtype: int64

# %% [markdown]
# ## 1. 가설 1) 따릉이 최다 사용량이 출퇴근 시간이고

# %% [markdown]
# ### - 최다 사용량이 출퇴근 시간인 것을 확인한다.

# %% [markdown]
# - 대여일자 컬럼을 datetime 형식으로 변환

# %%
df_2020['대여일자'] = pd.to_datetime(df_2020['대여일자'], format='%Y-%m-%d')
# df_2020['대여시간'].astype('datetime64[ns]')

# %%
print(df_2020['대여일자'].dtype)
# Out:
# datetime64[ns]

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)
# 0 0.32   1360.0        6
# 1 0.09    390.0        3
# 2 0.64   2750.0       24
# 3 0.18    780.0        3
# 4 0.41   1760.0       11

# %% [markdown]
# - datetime 형식으로 변경된 '대여일자' 컬럼에서 요일을 추출하여 새로운 컬럼으로 저장

# %%
# dt.weekday : 요일 정보를 숫자로 추출 
# 0 : 월요일, 1 : 화요일, .... 6 : 일요일
df_2020['요일_인덱스'] = df_2020['대여일자'].dt.weekday

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)  요일_인덱스
# 0 0.32   1360.0        6       5
# 1 0.09    390.0        3       5
# 2 0.64   2750.0       24       5
# 3 0.18    780.0        3       5
# 4 0.41   1760.0       11       5

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df_2020['요일'] = df_2020.apply(lambda x : weekday_list[x['요일_인덱스']], axis=1)

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0 0.32   1360.0        6       5  토
# 1 0.09    390.0        3       5  토
# 2 0.64   2750.0       24       5  토
# 3 0.18    780.0        3       5  토
# 4 0.41   1760.0       11       5  토

# %%
df_2020[['요일', '대여시간']].value_counts(ascending=False)
# Out:
# 요일  대여시간
# 목   18      272970
# 화   18      269778
# 금   18      263783
# 월   18      254281
# 수   18      237179
#              ...
# 월   3        20538
# 목   4        19857
# 화   4        19191
# 일   5        17388
# 월   4        16698
# Name: count, Length: 168, dtype: int64

# %%
grounded = df_2020.groupby(['요일', '대여시간'])['이용건수'].sum().unstack()
grounded
# Out:
# 대여시간      0      1      2      3      4      5      6       7       8   \
# 요일
# 금      99651  77095  52318  35770  24107  25460  51835  131547  216599
# 목      88400  68624  46368  30966  20884  23583  50118  131522  219838
# 수      94862  71408  48637  32985  22986  26403  56875  139088  225445
# 월      73300  50523  32471  22140  17576  24295  53203  134872  215519
# 일     102732  77642  55394  37999  24377  18394  22740   36186   57578
# 토     108712  88163  62613  44111  28182  22344  29159   48476   82154
# 화      82485  63274  42683  28865  20193  24845  55097  139492  227097
#
# 대여시간      9   ...      14      15      16      17      18      19      20  \
# 요일            ...
# 금     123793  ...  158636  178955  213478  293971  355896  255465  216595
# 목     123493  ...  156182  179273  213749  299107  372432  265818  231671
# 수     120972  ...  146341  160137  191101  265256  323228  228805  198168
# 월     117353  ...  140165  157236  187882  273273  351635  248319  213687
# 일      78736  ...  212198  230939  236789  234948  221133  201821  188424
# 토     101648  ...  210457  228437  243653  250064  229806  209150  204822
# 화     122513  ...  149647  170478  202789  290470  369691  261815  226446
#
# 대여시간      21      22      23
# 요일
# 금     201678  175420  128364
# 목     209450  174365  122222
# 수     185277  154365  107483
# 월     194995  157576  106004
# 일     170724  136863   94776
# 토     196227  165438  126217
# 화     209332  171383  117857
#
# [7 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,6))
# plt.ticklabel_format(axis='y', useOffset=False, style='plain')  # y축(지수표시) - 일반 표시로 변경
sns.lineplot(x='대여시간', y='이용건수', hue='요일', data=df_2020, marker='o')
plt.title('2020년 대여시간에 따른 요일별 이용건수')
# plt.yticks(np.arange())
plt.xticks(range(0,24)) # = plt.xticks(np.arange(0,24,1))
plt.xlabel('대여시간')
plt.ylabel('이용건수')
plt.show()

# %% [markdown]
# ## 2. 가설 2) 출퇴근 시간에 따릉이 대여량이 최다인 대여소는 지하철역 인근 대여소일 것이다.

# %% [markdown]
# ### - 출퇴근 시간 대여소별 사용량 확인

# %% [markdown]
# - 요일 : 월~금요일 추출한다.

# %%
df_2020.head()
# Out:
#         대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수   운동량  \
# 0 2020-02-01     0   1442  1442. (구)신한은행 중랑교지점    정기권  None  ~10대     1 53.86
# 1 2020-02-01     0   1339   1339. 삼성전자서비스 성북센터    정기권  None  ~10대     1 10.04
# 2 2020-02-01     0   1960        1960. 화광신문사 앞    정기권  None  ~10대     1 75.14
# 3 2020-02-01     0    394      394. 경희궁 자이 3단지    정기권  None  ~10대     1 28.42
# 4 2020-02-01     0   1364     1364. 성북동 치안센터 앞    정기권  None  ~10대     1 52.97
#
#    탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0 0.32   1360.0        6       5  토
# 1 0.09    390.0        3       5  토
# 2 0.64   2750.0       24       5  토
# 3 0.18    780.0        3       5  토
# 4 0.41   1760.0       11       5  토

# %%
df_2020.count()
# Out:
# 대여일자       19026024
# 대여시간       19026024
# 대여소번호      19026024
# 대여소명       19026024
# 대여구분코드     19026024
# 성별          9530047
# 연령대코드      19026024
# 이용건수       19026024
# 운동량        18906625
# 탄소량        18906625
# 이동거리(M)    19026024
# 이용시간(분)    19026024
# 요일_인덱스     19026024
# 요일         19026024
# dtype: int64

# %%
df_2020['요일'] != '토'
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 19026019     True
# 19026020     True
# 19026021     True
# 19026022     True
# 19026023     True
# Name: 요일, Length: 19026024, dtype: bool

# %%
df_2020['요일'] != '일'
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#             ...
# 19026019    True
# 19026020    True
# 19026021    True
# 19026022    True
# 19026023    True
# Name: 요일, Length: 19026024, dtype: bool

# %%
#df_2020[(df_2020['요일'] != '토') & (df_2020['요일'] != '일')]
df_2020_day = df_2020[~(df_2020['요일'].isin(['토', '일']))]
df_2020_day
# Out:
#                대여일자  대여시간  대여소번호                    대여소명 대여구분코드    성별 연령대코드  \
# 44369    2020-02-03     0   1029            1029. 롯데 시네마    정기권  None  ~10대
# 44370    2020-02-03     0   1036          1036. 고덕동 주양쇼핑    정기권  None  ~10대
# 44371    2020-02-03     0   1447          1447. 면목역 3번출구    정기권  None  ~10대
# 44372    2020-02-03     0   1339      1339. 삼성전자서비스 성북센터    정기권  None  ~10대
# 44373    2020-02-03     0   1173     1173. 강서구청사거리(SH타워)    정기권  None  ~10대
# ...             ...   ...    ...                     ...    ...   ...   ...
# 19026019 2020-07-31    23   1985             1985. 구로도서관    단체권  None   30대
# 19026020 2020-07-31    23    810            810. 이태원지하보도    단체권     F   20대
# 19026021 2020-07-31    23   1044             1044. 굽은다리역    단체권     M  ~10대
# 19026022 2020-07-31    23   1814  1814. 두산위브아파트 옆 상가건물 앞    단체권     M  ~10대
# 19026023 2020-07-31    23    212        212. 여의도역 1번출구 옆    단체권     M   30대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 44369        1  87.01  0.7   3010.0       17       0  월
# 44370        1  76.68 0.67   2890.0       15       0  월
# 44371        1  40.99 0.35   1500.0        6       0  월
# 44372        1   10.3 0.09    400.0        2       0  월
# 44373        1  26.53 0.31   1340.0        7       0  월
# ...        ...    ...  ...      ...      ...     ... ..
# 19026019     2    0.0  0.0      0.0      120       4  금
# 19026020     3   8.98  0.1    420.0       28       4  금
# 19026021     2    0.0  0.0      0.0       39       4  금
# 19026022     3 297.78  2.1   9060.0      100       4  금
# 19026023     2  36.81 0.33   1430.0       23       4  금
#
# [13911077 rows x 14 columns]

# %% [markdown]
# - '출퇴근' 컬럼을 새로 만들어서 출근, 퇴근을 넣어준다. (월~금요일, 출퇴근)

# %%
df_2020_day.loc[df_2020_day['대여시간'].isin([7,8,9]),'출퇴근'] = '출근'
df_2020_day.loc[df_2020_day['대여시간'].isin([17,18,19]),'출퇴근'] = '퇴근'

# %%
df_2020_day
# Out:
#                대여일자  대여시간  대여소번호                    대여소명 대여구분코드    성별 연령대코드  \
# 44369    2020-02-03     0   1029            1029. 롯데 시네마    정기권  None  ~10대
# 44370    2020-02-03     0   1036          1036. 고덕동 주양쇼핑    정기권  None  ~10대
# 44371    2020-02-03     0   1447          1447. 면목역 3번출구    정기권  None  ~10대
# 44372    2020-02-03     0   1339      1339. 삼성전자서비스 성북센터    정기권  None  ~10대
# 44373    2020-02-03     0   1173     1173. 강서구청사거리(SH타워)    정기권  None  ~10대
# ...             ...   ...    ...                     ...    ...   ...   ...
# 19026019 2020-07-31    23   1985             1985. 구로도서관    단체권  None   30대
# 19026020 2020-07-31    23    810            810. 이태원지하보도    단체권     F   20대
# 19026021 2020-07-31    23   1044             1044. 굽은다리역    단체권     M  ~10대
# 19026022 2020-07-31    23   1814  1814. 두산위브아파트 옆 상가건물 앞    단체권     M  ~10대
# 19026023 2020-07-31    23    212        212. 여의도역 1번출구 옆    단체권     M   30대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일  출퇴근
# 44369        1  87.01  0.7   3010.0       17       0  월  NaN
# 44370        1  76.68 0.67   2890.0       15       0  월  NaN
# 44371        1  40.99 0.35   1500.0        6       0  월  NaN
# 44372        1   10.3 0.09    400.0        2       0  월  NaN
# 44373        1  26.53 0.31   1340.0        7       0  월  NaN
# ...        ...    ...  ...      ...      ...     ... ..  ...
# 19026019     2    0.0  0.0      0.0      120       4  금  NaN
# 19026020     3   8.98  0.1    420.0       28       4  금  NaN
# 19026021     2    0.0  0.0      0.0       39       4  금  NaN
# 19026022     3 297.78  2.1   9060.0      100       4  금  NaN
# 19026023     2  36.81 0.33   1430.0       23       4  금  NaN
#
# [13911077 rows x 15 columns]

# %%
df_2020_day[df_2020_day['출퇴근'] == '출근'] # df_parquet[df_parquet['이용건수'] == '\\N']
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 46871    2020-02-03     7    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 46872    2020-02-03     7   2363    2363. 강남 을지병원 교차로    정기권  None  ~10대
# 46873    2020-02-03     7   3511       3511. 응봉역 1번출구    정기권  None  ~10대
# 46874    2020-02-03     7   1337         1337. 돈암성당 옆    정기권  None  ~10대
# 46875    2020-02-03     7   1976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 18970809 2020-07-31     9    839  839. 보광동 삼성리버빌아파트 앞    일일권     M   60대
# 18970810 2020-07-31     9    583      583. 청계천 생태교실 앞    일일권     M   60대
# 18970811 2020-07-31     9   1226    1226. 잠실4동 주민센터 옆    일일권     M  70대~
# 18970812 2020-07-31     9    614         614. 용두동 사거리    단체권  None   20대
# 18970813 2020-07-31     9    420  420. 서울시 공공자전거 상암센터    단체권     M   50대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 46871        1  15.21 0.14    600.0        3       0  월  출근
# 46872        1   22.2 0.22    950.0        6       0  월  출근
# 46873        1 101.49 1.08   4660.0       41       0  월  출근
# 46874        1   93.8 0.87   3760.0       12       0  월  출근
# 46875        1    0.0  0.0      0.0        7       0  월  출근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 18970809     1 139.51 1.26   5420.0       26       4  금  출근
# 18970810     1    0.0  0.0      0.0       59       4  금  출근
# 18970811     1    0.0  0.0      0.0       18       4  금  출근
# 18970812     1    0.0  0.0      0.0       16       4  금  출근
# 18970813     3 232.94 1.59   6840.0      131       4  금  출근
#
# [1986309 rows x 15 columns]

# %%
df_2020_day[df_2020_day['출퇴근'] == '퇴근']
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 59719    2020-02-03    17    740            740. 으뜸공원    정기권  None  ~10대
# 59720    2020-02-03    17    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 59721    2020-02-03    17   1157           1157. 강서구청    정기권  None  ~10대
# 59722    2020-02-03    17   1259       1259. 방이역 1번출구    정기권  None  ~10대
# 59723    2020-02-03    17   1336         1336. 성북3교 위    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 19010309 2020-07-31    19   1184         1184. 마곡13단지    단체권     M   30대
# 19010310 2020-07-31    19    257     257. 신길삼거리(우리은행)    단체권     M   30대
# 19010311 2020-07-31    19    152      152. 마포구민체육센터 앞    단체권     M   40대
# 19010312 2020-07-31    19   3550           3550.금호나들목    단체권     M   40대
# 19010313 2020-07-31    19   1953     1953. 천왕역 4번출구 뒤    단체권     M   50대
#
#           이용건수     운동량   탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 59719        3 3598.79 32.26 139050.0       85       0  월  퇴근
# 59720        1   39.79  0.36   1570.0       13       0  월  퇴근
# 59721        1   27.66  0.29   1270.0        8       0  월  퇴근
# 59722        1   54.62  0.56   2420.0       26       0  월  퇴근
# 59723        1   10.53  0.06    280.0        2       0  월  퇴근
# ...        ...     ...   ...      ...      ...     ... ..  ..
# 19010309     2     0.0   0.0      0.0       17       4  금  퇴근
# 19010310     2     0.0   0.0      0.0       35       4  금  퇴근
# 19010311     2     0.0   0.0      0.0      164       4  금  퇴근
# 19010312     2     0.0   0.0      0.0      142       4  금  퇴근
# 19010313     2   22.52  0.18    790.0       15       4  금  퇴근
#
# [3366892 rows x 15 columns]

# %%
df_2020_day['출퇴근'].unique()
# Out:
# array([nan, '출근', '퇴근'], dtype=object)

# %%
df_2020_day['출퇴근'].value_counts()
# Out:
# 출퇴근
# 퇴근    3366892
# 출근    1986309
# Name: count, dtype: int64

# %%
df_2020_day.count()
# Out:
# 대여일자       13911077
# 대여시간       13911077
# 대여소번호      13911077
# 대여소명       13911077
# 대여구분코드     13911077
# 성별          6982669
# 연령대코드      13911077
# 이용건수       13911077
# 운동량        13822377
# 탄소량        13822377
# 이동거리(M)    13911077
# 이용시간(분)    13911077
# 요일_인덱스     13911077
# 요일         13911077
# 출퇴근         5353201
# dtype: int64

# %%
df_2020_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13911077 entries, 44369 to 19026023
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 1.6+ GB

# %%
df_2020_time = df_2020_day[~df_2020_day['출퇴근'].isnull()] # df_2020_day.dropna(subset=['출퇴근'])

# %%
df_2020_time
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 46871    2020-02-03     7    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 46872    2020-02-03     7   2363    2363. 강남 을지병원 교차로    정기권  None  ~10대
# 46873    2020-02-03     7   3511       3511. 응봉역 1번출구    정기권  None  ~10대
# 46874    2020-02-03     7   1337         1337. 돈암성당 옆    정기권  None  ~10대
# 46875    2020-02-03     7   1976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 19010309 2020-07-31    19   1184         1184. 마곡13단지    단체권     M   30대
# 19010310 2020-07-31    19    257     257. 신길삼거리(우리은행)    단체권     M   30대
# 19010311 2020-07-31    19    152      152. 마포구민체육센터 앞    단체권     M   40대
# 19010312 2020-07-31    19   3550           3550.금호나들목    단체권     M   40대
# 19010313 2020-07-31    19   1953     1953. 천왕역 4번출구 뒤    단체권     M   50대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 46871        1  15.21 0.14    600.0        3       0  월  출근
# 46872        1   22.2 0.22    950.0        6       0  월  출근
# 46873        1 101.49 1.08   4660.0       41       0  월  출근
# 46874        1   93.8 0.87   3760.0       12       0  월  출근
# 46875        1    0.0  0.0      0.0        7       0  월  출근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 19010309     2    0.0  0.0      0.0       17       4  금  퇴근
# 19010310     2    0.0  0.0      0.0       35       4  금  퇴근
# 19010311     2    0.0  0.0      0.0      164       4  금  퇴근
# 19010312     2    0.0  0.0      0.0      142       4  금  퇴근
# 19010313     2  22.52 0.18    790.0       15       4  금  퇴근
#
# [5353201 rows x 15 columns]

# %%
df_2020_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5353201 entries, 46871 to 19010313
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 633.0+ MB

# %%
df_2020_time.count()
# Out:
# 대여일자       5353201
# 대여시간       5353201
# 대여소번호      5353201
# 대여소명       5353201
# 대여구분코드     5353201
# 성별         2765568
# 연령대코드      5353201
# 이용건수       5353201
# 운동량        5318989
# 탄소량        5318989
# 이동거리(M)    5353201
# 이용시간(분)    5353201
# 요일_인덱스     5353201
# 요일         5353201
# 출퇴근        5353201
# dtype: int64

# %% [markdown]
# - 출근 시간대 추출한다.

# %%
# df_2020_time_1 = df_2020_day[(df_2020_day['대여시간'].isin([7, 8, 9]))]
# df_2020_time_1
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 46871    2020-02-03     7    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 46872    2020-02-03     7   2363    2363. 강남 을지병원 교차로    정기권  None  ~10대
# 46873    2020-02-03     7   3511       3511. 응봉역 1번출구    정기권  None  ~10대
# 46874    2020-02-03     7   1337         1337. 돈암성당 옆    정기권  None  ~10대
# 46875    2020-02-03     7   1976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 18970809 2020-07-31     9    839  839. 보광동 삼성리버빌아파트 앞    일일권     M   60대
# 18970810 2020-07-31     9    583      583. 청계천 생태교실 앞    일일권     M   60대
# 18970811 2020-07-31     9   1226    1226. 잠실4동 주민센터 옆    일일권     M  70대~
# 18970812 2020-07-31     9    614         614. 용두동 사거리    단체권  None   20대
# 18970813 2020-07-31     9    420  420. 서울시 공공자전거 상암센터    단체권     M   50대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분) 요일  요일_인덱스
# 46871        1  15.21 0.14    600.0        3  월       0
# 46872        1   22.2 0.22    950.0        6  월       0
# 46873        1 101.49 1.08   4660.0       41  월       0
# 46874        1   93.8 0.87   3760.0       12  월       0
# 46875        1    0.0  0.0      0.0        7  월       0
# ...        ...    ...  ...      ...      ... ..     ...
# 18970809     1 139.51 1.26   5420.0       26  금       4
# 18970810     1    0.0  0.0      0.0       59  금       4
# 18970811     1    0.0  0.0      0.0       18  금       4
# 18970812     1    0.0  0.0      0.0       16  금       4
# 18970813     3 232.94 1.59   6840.0      131  금       4
#
# [1986309 rows x 14 columns]

# %% [markdown]
# - 퇴근 시간대 추출한다.

# %%
# df_2020_time_2 = df_2020_day[(df_2020_day['대여시간'].isin([17, 18, 19]))]
# df_2020_time_2
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 59719    2020-02-03    17    740            740. 으뜸공원    정기권  None  ~10대
# 59720    2020-02-03    17    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대
# 59721    2020-02-03    17   1157           1157. 강서구청    정기권  None  ~10대
# 59722    2020-02-03    17   1259       1259. 방이역 1번출구    정기권  None  ~10대
# 59723    2020-02-03    17   1336         1336. 성북3교 위    정기권  None  ~10대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 19010309 2020-07-31    19   1184         1184. 마곡13단지    단체권     M   30대
# 19010310 2020-07-31    19    257     257. 신길삼거리(우리은행)    단체권     M   30대
# 19010311 2020-07-31    19    152      152. 마포구민체육센터 앞    단체권     M   40대
# 19010312 2020-07-31    19   3550           3550.금호나들목    단체권     M   40대
# 19010313 2020-07-31    19   1953     1953. 천왕역 4번출구 뒤    단체권     M   50대
#
#           이용건수     운동량   탄소량  이동거리(M)  이용시간(분) 요일  요일_인덱스
# 59719        3 3598.79 32.26 139050.0       85  월       0
# 59720        1   39.79  0.36   1570.0       13  월       0
# 59721        1   27.66  0.29   1270.0        8  월       0
# 59722        1   54.62  0.56   2420.0       26  월       0
# 59723        1   10.53  0.06    280.0        2  월       0
# ...        ...     ...   ...      ...      ... ..     ...
# 19010309     2     0.0   0.0      0.0       17  금       4
# 19010310     2     0.0   0.0      0.0       35  금       4
# 19010311     2     0.0   0.0      0.0      164  금       4
# 19010312     2     0.0   0.0      0.0      142  금       4
# 19010313     2   22.52  0.18    790.0       15  금       4
#
# [3366892 rows x 14 columns]

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본'
df_st = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 0.10034370422363281

# %%
df_st.head()
# Out:
#        대여소번호          대여소명  자치구                         상세주소          위도  \
# 20852  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 19007  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 19015  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 19014  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 19013  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#                경도        설치시기  LCD   QR 운영방식   데이터등록월
# 20852 126.8210602  2024-03-18  NaN 10.0   QR  2024-06
# 19007 127.0669098  2020-03-24  NaN 12.0   QR  2024-06
# 19015 127.0732651  2020-03-23  NaN 20.0   QR  2024-06
# 19014 127.0719147  2020-03-23  NaN  7.0   QR  2024-06
# 19013 127.0740509  2020-03-25  NaN 10.0   QR  2024-06

# %%
df_st.info() # 대여소번호 int / object 다름.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2921 entries, 20852 to 1174
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   2921 non-null   object
#  1   대여소명    2921 non-null   object
#  2   자치구     2921 non-null   object
#  3   상세주소    2921 non-null   object
#  4   위도      2920 non-null   float64
#  5   경도      2920 non-null   float64
#  6   설치시기    2921 non-null   object
#  7   LCD     1517 non-null   float64
#  8   QR      1752 non-null   float64
#  9   운영방식    2921 non-null   object
#  10  데이터등록월  2921 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 273.8+ KB

# %%
df_st.shape
# Out:
# (2921, 11)

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

import ExcelFile_EDA as ee
ee.ss_isnull(df_st)
# Out:
#      [컬럼명]  [sum]  [sum_isnull]     [mean_isnull(%)]
# 0    대여소번호   2921             0                  0.0
# 1     대여소명   2921             0                  0.0
# 2      자치구   2921             0                  0.0
# 3     상세주소   2921             0                  0.0
# 4       위도   2920             1 0.034234851078397806
# 5       경도   2920             1 0.034234851078397806
# 6     설치시기   2921             0                  0.0
# 7      LCD   1517          1404    48.06573091407053
# 8       QR   1752          1169    40.02054091064704
# 9     운영방식   2921             0                  0.0
# 10  데이터등록월   2921             0                  0.0

# %%
df_st_1 = df_st[['대여소번호', '대여소명', '자치구', '설치시기', '데이터등록월']]
df_st_1
# Out:
#        대여소번호           대여소명  자치구        설치시기   데이터등록월
# 20852  06173    서울자동차운전전문학원  강서구  2024-03-18  2024-06
# 19007  02902   공릉풍림아파트 108동  노원구  2020-03-24  2024-06
# 19015  02912         대진고등학교  노원구  2020-03-23  2024-06
# 19014  02911        상계역중앙시장  노원구  2020-03-23  2024-06
# 19013  02910          도깨비시장  노원구  2020-03-25  2024-06
# ...      ...            ...  ...         ...      ...
# 1689   02200      관악문화원 건너편  관악구  2020-04-28  2021-01
# 1690   03304     낙성대역 5번 출구  관악구  2020-04-29  2021-01
# 1079   04205  디지털미디어씨티역2번출구  마포구  2020-12-02  2021-01
# 1258   02714    발산1동주민센터교차로  강서구  2020-03-17  2021-01
# 1174   01114  서남물재생센터 버스정류장  강서구  2017-04-24  2021-01
#
# [2921 rows x 5 columns]

# %% [markdown]
# - 시간대별 데이터, 대여소정보 데이터 에서 '대여소번호' 컬럼의 숫자 표현방식, 데이터 타입이 다르다.

# %% [markdown]
# - 따라서, 1. 시간대별 데이터(월~금 / 출퇴근 시간대 추출함)의 '대여소번호' 컬럼의 숫자를 object로 바꾸어준다.
#      ##### 2. 시간대별 데이터의 '대여소번호' 컬럼의 숫자를 00000 자리로 바꾸어준다.

# %%
df_2020_time.head()
# Out:
#             대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 46871 2020-02-03     7    505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대     1
# 46872 2020-02-03     7   2363    2363. 강남 을지병원 교차로    정기권  None  ~10대     1
# 46873 2020-02-03     7   3511       3511. 응봉역 1번출구    정기권  None  ~10대     1
# 46874 2020-02-03     7   1337         1337. 돈암성당 옆    정기권  None  ~10대     1
# 46875 2020-02-03     7   1976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대     1
#
#          운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 46871  15.21 0.14    600.0        3       0  월  출근
# 46872   22.2 0.22    950.0        6       0  월  출근
# 46873 101.49 1.08   4660.0       41       0  월  출근
# 46874   93.8 0.87   3760.0       12       0  월  출근
# 46875    0.0  0.0      0.0        7       0  월  출근

# %%
df_2020_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5353201 entries, 46871 to 19010313
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    object
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(3), object(7)
# memory usage: 633.0+ MB

# %%
df_2020_time.loc[:, '대여소번호'] = df_2020_time['대여소번호'].astype(str)

# %%
df_2020_time.dtypes
# Out:
# 대여일자       datetime64[ns]
# 대여시간                int64
# 대여소번호              object
# 대여소명               object
# 대여구분코드             object
# 성별                 object
# 연령대코드              object
# 이용건수                int64
# 운동량               float64
# 탄소량               float64
# 이동거리(M)           float64
# 이용시간(분)             int64
# 요일_인덱스              int32
# 요일                 object
# 출퇴근                object
# dtype: object

# %%
# df_2020_time['대여소번호'] = df_2020_time['대여소번호'].str.zfill(5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9408\2405587269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_time['대여소번호'] = df_2020_time['대여소번호'].str.zfill(5)

# %%
df_2020_time.loc[:,'대여소번호'] = df_2020_time['대여소번호'].str.zfill(5)

# %%
df_sum = pd.merge(df_2020_time, df_st_1, on='대여소번호', how='left')
df_sum
# Out:
#               대여일자  대여시간  대여소번호               대여소명_x 대여구분코드    성별 연령대코드  이용건수  \
# 0       2020-02-03     7  00505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대     1
# 1       2020-02-03     7  02363    2363. 강남 을지병원 교차로    정기권  None  ~10대     1
# 2       2020-02-03     7  03511       3511. 응봉역 1번출구    정기권  None  ~10대     1
# 3       2020-02-03     7  01337         1337. 돈암성당 옆    정기권  None  ~10대     1
# 4       2020-02-03     7  01976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대     1
# ...            ...   ...    ...                  ...    ...   ...   ...   ...
# 5353196 2020-07-31    19  01184         1184. 마곡13단지    단체권     M   30대     2
# 5353197 2020-07-31    19  00257     257. 신길삼거리(우리은행)    단체권     M   30대     2
# 5353198 2020-07-31    19  00152      152. 마포구민체육센터 앞    단체권     M   40대     2
# 5353199 2020-07-31    19  03550           3550.금호나들목    단체권     M   40대     2
# 5353200 2020-07-31    19  01953     1953. 천왕역 4번출구 뒤    단체권     M   50대     2
#
#            운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근          대여소명_y   자치구  \
# 0        15.21 0.14    600.0        3       0  월  출근  자양사거리 광진아크로텔 앞   광진구
# 1         22.2 0.22    950.0        6       0  월  출근     강남 을지병원 교차로   강남구
# 2       101.49 1.08   4660.0       41       0  월  출근        응봉역 1번출구   성동구
# 3         93.8 0.87   3760.0       12       0  월  출근          돈암성당 옆   성북구
# 4          0.0  0.0      0.0        7       0  월  출근   남구로역 5번 출입구 앞   구로구
# ...        ...  ...      ...      ...     ... ..  ..             ...   ...
# 5353196    0.0  0.0      0.0       17       4  금  퇴근          마곡13단지   강서구
# 5353197    0.0  0.0      0.0       35       4  금  퇴근     신길삼거리(우리은행)  영등포구
# 5353198    0.0  0.0      0.0      164       4  금  퇴근      마포구민체육센터 앞   마포구
# 5353199    0.0  0.0      0.0      142       4  금  퇴근           금호나들목   성동구
# 5353200  22.52 0.18    790.0       15       4  금  퇴근      천왕역 4번출구 뒤   구로구
#
#                설치시기   데이터등록월
# 0        2015-10-07  2024-06
# 1        2017-11-01  2024-06
# 2        2017-11-01  2024-06
# 3        2017-11-13  2024-06
# 4        2017-11-13  2024-06
# ...             ...      ...
# 5353196  2018-10-10  2024-06
# 5353197  2016-06-29  2021-06
# 5353198  2020-09-24  2021-06
# 5353199  2020-04-16  2024-06
# 5353200  2017-06-22  2024-06
#
# [5353201 rows x 19 columns]

# %%
# group = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().unstack()
# group
# Out:
# 출퇴근                출근     퇴근
# 대여소명_y
# (구)합정동 주민센터    1303.0 1412.0
# (시립)고덕평생학습관     100.0  421.0
# (재)FITI시험연구원   1720.0 2159.0
# 3호선 매봉역 3번출구앞   970.0 2437.0
# 4.19민주묘지 입구사거리  323.0  490.0
# ...               ...    ...
# 흥국사 정류장          23.0   89.0
# 희성오피앙          1571.0 2154.0
# 희훈타워빌 앞         107.0  104.0
# 힐스테이트에코        1706.0 3153.0
# 힐스테이트창경궁 아파트 앞  572.0 1121.0
#
# [2134 rows x 2 columns]

# %%
group1 = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().reset_index()
group1
# Out:
#               대여소명_y 출퇴근  이용건수
# 0        (구)합정동 주민센터  출근  1303
# 1        (구)합정동 주민센터  퇴근  1412
# 2        (시립)고덕평생학습관  출근   100
# 3        (시립)고덕평생학습관  퇴근   421
# 4       (재)FITI시험연구원  출근  1720
# ...              ...  ..   ...
# 4237         희훈타워빌 앞  퇴근   104
# 4238         힐스테이트에코  출근  1706
# 4239         힐스테이트에코  퇴근  3153
# 4240  힐스테이트창경궁 아파트 앞  출근   572
# 4241  힐스테이트창경궁 아파트 앞  퇴근  1121
#
# [4242 rows x 3 columns]

# %%
group1

# %%
# group.sort_values(by = '출근', ascending = False)
# Out:
# 출퇴근                출근      퇴근
# 대여소명_y
# 마곡나루역 5번출구 뒤편 13759.0 14948.0
# 여의나루역 1번출구 앞   8520.0 23455.0
# 구로디지털단지역 앞     7709.0 12253.0
# 대방역6번출구        7491.0  6128.0
# 영등포구청역 1번출구    6900.0  8484.0
# ...               ...     ...
# 중부경찰서앞 사거리        NaN     7.0
# 증미역 2번출구          NaN    18.0
# 풍전아파트 건너편         NaN     2.0
# 행당중학교 후문          NaN     1.0
# 효창공원앞역 5번출구 옆     NaN     2.0
#
# [2134 rows x 2 columns]

# %%
group.sort_values(by = '퇴근', ascending = False)
# Out:
# 출퇴근                    출근      퇴근
# 대여소명_y
# 뚝섬유원지역 1번출구 앞      5303.0 23934.0
# 여의나루역 1번출구 앞       8520.0 23455.0
# 마곡나루역 5번출구 뒤편     13759.0 14948.0
# 봉림교 교통섬            4489.0 14481.0
# 발산역 1번, 9번 인근 대여소  5335.0 14472.0
# ...                   ...     ...
# 문소빌딩                  NaN     1.0
# 중앙일보                  1.0     1.0
# 겸재정선미술관               3.0     NaN
# 송천센트레빌                2.0     NaN
# 휘경sk뷰아파트 앞            2.0     NaN
#
# [2134 rows x 2 columns]

# %%
group.sort_values(by = ['출근','퇴근'], ascending = False)
# Out:
# 출퇴근                출근      퇴근
# 대여소명_y
# 마곡나루역 5번출구 뒤편 13759.0 14948.0
# 여의나루역 1번출구 앞   8520.0 23455.0
# 구로디지털단지역 앞     7709.0 12253.0
# 대방역6번출구        7491.0  6128.0
# 영등포구청역 1번출구    6900.0  8484.0
# ...               ...     ...
# 문소빌딩              NaN     1.0
# 원효로다목적체육관 앞       NaN     1.0
# 을지로지하쇼핑센터         NaN     1.0
# 장안동근린공원 입구        NaN     1.0
# 행당중학교 후문          NaN     1.0
#
# [2134 rows x 2 columns]

# %%
group_sorted = group.sort_values(by='출근', ascending=False)
group_sorted
# Out:
# 출퇴근                출근      퇴근
# 대여소명_y
# 마곡나루역 5번출구 뒤편 13759.0 14948.0
# 여의나루역 1번출구 앞   8520.0 23455.0
# 구로디지털단지역 앞     7709.0 12253.0
# 대방역6번출구        7491.0  6128.0
# 영등포구청역 1번출구    6900.0  8484.0
# ...               ...     ...
# 중부경찰서앞 사거리        NaN     7.0
# 증미역 2번출구          NaN    18.0
# 풍전아파트 건너편         NaN     2.0
# 행당중학교 후문          NaN     1.0
# 효창공원앞역 5번출구 옆     NaN     2.0
#
# [2134 rows x 2 columns]

# %%
df_sum.head()


grouped_df = group
'대여소명_y')['이용건수'].sum().reset_index()
# Out:
#         대여일자  대여시간  대여소번호               대여소명_x 대여구분코드    성별 연령대코드  이용건수  \
# 0 2020-02-03     7  00505  505. 자양사거리 광진아크로텔 앞    정기권  None  ~10대     1
# 1 2020-02-03     7  02363    2363. 강남 을지병원 교차로    정기권  None  ~10대     1
# 2 2020-02-03     7  03511       3511. 응봉역 1번출구    정기권  None  ~10대     1
# 3 2020-02-03     7  01337         1337. 돈암성당 옆    정기권  None  ~10대     1
# 4 2020-02-03     7  01976  1976. 남구로역 5번 출입구 앞    정기권  None  ~10대     1
#
#      운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근          대여소명_y  자치구  \
# 0  15.21 0.14    600.0        3       0  월  출근  자양사거리 광진아크로텔 앞  광진구
# 1   22.2 0.22    950.0        6       0  월  출근     강남 을지병원 교차로  강남구
# 2 101.49 1.08   4660.0       41       0  월  출근        응봉역 1번출구  성동구
# 3   93.8 0.87   3760.0       12       0  월  출근          돈암성당 옆  성북구
# 4    0.0  0.0      0.0        7       0  월  출근   남구로역 5번 출입구 앞  구로구
#
#          설치시기   데이터등록월
# 0  2015-10-07  2024-06
# 1  2017-11-01  2024-06
# 2  2017-11-01  2024-06
# 3  2017-11-13  2024-06
# 4  2017-11-13  2024-06

# %%
group1.head()
# Out:
#          대여소명_y 출퇴근  이용건수
# 0   (구)합정동 주민센터  출근  1303
# 1   (구)합정동 주민센터  퇴근  1412
# 2   (시립)고덕평생학습관  출근   100
# 3   (시립)고덕평생학습관  퇴근   421
# 4  (재)FITI시험연구원  출근  1720

# %%
commute_data = group1[group1['출퇴근'] == '출근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data = commute_data.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data = top_20_commute_data.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
plt.barh(top_20_commute_data['대여소명_y'], top_20_commute_data['이용건수'])
plt.title('2020년 출근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(group1[['대여소명_y',']], group1['출근'], color='b')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '출근'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[304], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 plt.bar(group1[['대여소명_y','출퇴근']], group1['출근'], color='b')
#       3 plt.xlabel('대여소명')
#       4 plt.ylabel('이용건수')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '출근'

# %% [markdown]
# -------------------------------------------------

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.lineplot(x='대여시간', y='요일', data=grounded, marker='O')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 3
#       1 import seaborn as sns
#       2 plt.figure(figsize=(10,6))
# ----> 3 sns.lineplot(x='대여시간', y='요일', data=grounded, marker='O')
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~\anaconda3\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~\anaconda3\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `대여시간` for `x`. An entry with this name does not appear in `data`.

# %%
sorted_df = df_2020.sort_values(by=['요일', '대여시간'], ascending=False)
sorted_df
# Out:
#                대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  \
# 109440   2020-02-05    23   1035           1035. 고덕역 4번출구    정기권  None  ~10대
# 109441   2020-02-05    23   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None  ~10대
# 109442   2020-02-05    23   2173              2173. 당곡사거리    정기권  None  ~10대
# 109443   2020-02-05    23   1458             1458. 상봉터미널2    정기권  None  ~10대
# 109444   2020-02-05    23    609                609. 제기2교    정기권  None  ~10대
# ...             ...   ...    ...                      ...    ...   ...   ...
# 18951673 2020-07-31     0   1571         1571.북서울 꿈의 숲 입구    단체권     F   20대
# 18951674 2020-07-31     0    647           647. 신이문역 1번출구    단체권     M   20대
# 18951675 2020-07-31     0   2538              2538.사평리 공원    단체권     M   20대
# 18951676 2020-07-31     0    816         816. 신용산역 6번출구 앞    단체권     M   20대
# 18951677 2020-07-31     0   2015      2015. 신대방삼거리역 6번출구쪽    단체권     M   20대
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)         요일
# 109440       1  52.27 0.61   2640.0       14  Wednesday
# 109441       1  31.31 0.27   1180.0        7  Wednesday
# 109442       1  65.46  0.4   1740.0       11  Wednesday
# 109443       1   15.7 0.14    610.0        6  Wednesday
# 109444       1  51.48 0.46   2000.0        6  Wednesday
# ...        ...    ...  ...      ...      ...        ...
# 18951673     2    0.0  0.0      0.0      108     Friday
# 18951674     2 287.73 2.41  10380.0      113     Friday
# 18951675     1    0.0  0.0      0.0       34     Friday
# 18951676     3  46.59 0.42   1810.0       34     Friday
# 18951677     2    0.0  0.0      0.0      173     Friday
#
# [19026024 rows x 13 columns]

# %%
sorted_df.sort_values(['이용건수'], ascending=False)
# Out:
#                대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 15158425 2020-05-01    17    502  502. 뚝섬유원지역 1번출구 앞    일일권  None   20대    89
# 15163357 2020-05-01    18    207   207. 여의나루역 1번출구 앞    일일권  None   20대    89
# 15163449 2020-05-01    18    502  502. 뚝섬유원지역 1번출구 앞    일일권  None   20대    88
# 16392503 2020-05-23    17    502  502. 뚝섬유원지역 1번출구 앞    일일권  None   20대    79
# 15224035 2020-05-02    17    207   207. 여의나루역 1번출구 앞    일일권  None   20대    78
# ...             ...   ...    ...                 ...    ...   ...   ...   ...
# 11684521 2020-08-06    16    758        758. 한사랑교회 앞    일일권  None  ~10대     1
# 11684522 2020-08-06    16   2504    2504. 신사역 4번출구 뒤    일일권  None  ~10대     1
# 11684523 2020-08-06    16   1370    1370. 복자사랑 피정의 집    일일권  None  ~10대     1
# 11684524 2020-08-06    16   1184        1184. 마곡13단지    일일권  None  ~10대     1
# 16945300 2020-05-31    16    534          534. 금호사거리    일일권     F   20대     1
#
#               운동량    탄소량  이동거리(M)  이용시간(분)        요일
# 15158425  7104.82  74.18 319770.0     5902    Friday
# 15163357 17068.26 168.43 726020.0     5932    Friday
# 15163449 21471.32 189.38 816370.0     5024    Friday
# 16392503  6762.93  59.26 255480.0     4744  Saturday
# 15224035  8579.51  81.74 352210.0     5455  Saturday
# ...           ...    ...      ...      ...       ...
# 11684521      0.0    0.0      0.0       74  Thursday
# 11684522  1194.85  12.73  54860.0       51  Thursday
# 11684523      0.0    0.0      0.0       25  Thursday
# 11684524      0.0    0.0      0.0       10  Thursday
# 16945300      0.0    0.0      0.0       98    Sunday
#
# [19026024 rows x 13 columns]

# %%
weekday_filter = df_2020['요일'].isin(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])

# %%
time_filter = df_2020['대여시간'].between(7, 9) | df_2020['대여시간'].between(17, 19)

# %%
time_filter
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 19026019    False
# 19026020    False
# 19026021    False
# 19026022    False
# 19026023    False
# Name: 대여시간, Length: 19026024, dtype: bool

# %% [markdown]
# ### - 조건을 만족하는 행들의 '이용건수' 합계 구하기

# %%
df_2020_t_d = df_2020.loc[weekday_filter & time_filter]

# %%
df_2020_t_d['이용건수'].sum()
# Out:
# 6844324
