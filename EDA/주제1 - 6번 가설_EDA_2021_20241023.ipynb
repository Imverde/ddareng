# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'
filename = '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2021'
df_2021 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 6.305268049240112

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2021)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  25421727             0          0.000000
# 1      대여시간  25421727             0          0.000000
# 2     대여소번호  25421727             0          0.000000
# 3      대여소명  25421727             0          0.000000
# 4    대여구분코드  25421727             0          0.000000
# 5        성별  14657620      10764107         42.342155
# 6     연령대코드  25421727             0          0.000000
# 7      이용건수  25421727             0          0.000000
# 8       운동량  25273392        148335          0.583497
# 9       탄소량  25273392        148335          0.583497
# 10  이동거리(M)  25421727             0          0.000000
# 11  이용시간(분)  25421727             0          0.000000

# %%
df_2021.head()
# Out:
#          대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0  2021-01-01     0   1347  1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대   2.0
# 1  2021-01-01     0   1349       1349. 월계2교 버스정류장 앞    정기권  None  ~10대   1.0
# 2  2021-01-01     0   1168        1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 3  2021-01-01     0   2619         2619. 석촌고분역 4번출구    정기권  None  ~10대   1.0
# 4  2021-01-01     0    536          536. 행당역 2번출구 앞    정기권  None  ~10대   1.0
#
#      운동량   탄소량  이동거리(M)  이용시간(분)
# 0  28.90  0.23   992.78     13.0
# 1  34.38  0.26  1127.50     10.0
# 2   0.00  0.00     0.00      7.0
# 3  38.75  0.38  1658.34     14.0
# 4  12.96  0.17   743.88      5.0

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25421727 entries, 0 to 25421726
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 2.3+ GB

# %%
df_2021.describe()
# Out:
#                대여시간         대여소번호          이용건수           운동량           탄소량  \
# count  2.542173e+07  2.542173e+07  2.542173e+07  2.527339e+07  2.527339e+07
# mean   1.445541e+01  1.714754e+03  1.124693e+00  1.503918e+02  7.221298e-01
# std    5.535994e+00  1.266433e+03  4.354779e-01  7.897388e+04  1.016561e+00
# min    0.000000e+00  3.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+01  6.770000e+02  1.000000e+00  2.023000e+01  1.800000e-01
# 50%    1.600000e+01  1.384000e+03  1.000000e+00  4.415000e+01  3.900000e-01
# 75%    1.900000e+01  2.431000e+03  1.000000e+00  9.718000e+01  8.600000e-01
# max    2.300000e+01  9.999900e+04  2.900000e+01  1.000000e+08  1.097820e+03
#
#             이동거리(M)       이용시간(분)
# count  2.542173e+07  2.542173e+07
# mean   3.094502e+03  2.837335e+01
# std    4.375324e+03  3.345653e+01
# min    0.000000e+00  0.000000e+00
# 25%    7.708850e+02  8.000000e+00
# 50%    1.678990e+03  1.600000e+01
# 75%    3.672390e+03  3.700000e+01
# max    4.731984e+06  2.701000e+03

# %%
pd.options.display.float_format = '{:3}'.format

# %%
round(df_2021.describe(), 1)
# Out:
#             대여시간      대여소번호       이용건수         운동량        탄소량    이동거리(M)  \
# count 25421727.0 25421727.0 25421727.0  25273392.0 25273392.0 25421727.0
# mean        14.5     1714.8        1.1       150.4        0.7     3094.5
# std          5.5     1266.4        0.4     78973.9        1.0     4375.3
# min          0.0        3.0        1.0         0.0        0.0        0.0
# 25%         10.0      677.0        1.0        20.2        0.2      770.9
# 50%         16.0     1384.0        1.0        44.2        0.4     1679.0
# 75%         19.0     2431.0        1.0        97.2        0.9     3672.4
# max         23.0    99999.0       29.0 100000000.0     1097.8  4731983.6
#
#          이용시간(분)
# count 25421727.0
# mean        28.4
# std         33.5
# min          0.0
# 25%          8.0
# 50%         16.0
# 75%         37.0
# max       2701.0

# %%
df_2021.shape
# Out:
# (25421727, 12)

# %%
df_2021.isnull().sum()
# Out:
# 대여일자              0
# 대여시간              0
# 대여소번호             0
# 대여소명              0
# 대여구분코드            0
# 성별         10764107
# 연령대코드             0
# 이용건수              0
# 운동량          148335
# 탄소량          148335
# 이동거리(M)           0
# 이용시간(분)           0
# dtype: int64

# %%
df_2021['대여시간'].value_counts()
# Out:
# 대여시간
# 18    2434768
# 17    2039193
# 19    1797231
# 16    1636612
# 20    1548668
# 8     1546828
# 21    1456276
# 15    1417783
# 14    1293876
# 13    1230384
# 22    1225879
# 12    1198500
# 11    1071671
# 9     1034646
# 7      995474
# 10     904878
# 23     681792
# 0      489233
# 6      428093
# 1      321509
# 2      208966
# 5      197326
# 3      142570
# 4      119571
# Name: count, dtype: int64

# %% [markdown]
# ## 1. 가설 1) 따릉이 최다 사용량이 출퇴근 시간이고

# %% [markdown]
# ### - 최다 사용량이 출퇴근 시간인 것을 확인한다.

# %% [markdown]
# - 대여일자 컬럼을 datetime 형식으로 변환

# %%
df_2021['대여일자'] = pd.to_datetime(df_2021['대여일자'], format='%Y-%m-%d')
# df_2020['대여시간'].astype('datetime64[ns]')

# %%
print(df_2021['대여일자'].dtype)
# Out:
# datetime64[ns]

# %%
df_2021.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2021-01-01     0   1347  1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대   2.0
# 1 2021-01-01     0   1349       1349. 월계2교 버스정류장 앞    정기권  None  ~10대   1.0
# 2 2021-01-01     0   1168        1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 3 2021-01-01     0   2619         2619. 석촌고분역 4번출구    정기권  None  ~10대   1.0
# 4 2021-01-01     0    536          536. 행당역 2번출구 앞    정기권  None  ~10대   1.0
#
#     운동량  탄소량  이동거리(M)  이용시간(분)
# 0  28.9 0.23   992.78     13.0
# 1 34.38 0.26   1127.5     10.0
# 2   0.0  0.0      0.0      7.0
# 3 38.75 0.38  1658.34     14.0
# 4 12.96 0.17   743.88      5.0

# %% [markdown]
# - datetime 형식으로 변경된 '대여일자' 컬럼에서 요일을 추출하여 새로운 컬럼으로 저장

# %%
# dt.weekday : 요일 정보를 숫자로 추출 
# 0 : 월요일, 1 : 화요일, .... 6 : 일요일
df_2021['요일_인덱스'] = df_2021['대여일자'].dt.weekday

# %%
df_2021.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2021-01-01     0   1347  1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대   2.0
# 1 2021-01-01     0   1349       1349. 월계2교 버스정류장 앞    정기권  None  ~10대   1.0
# 2 2021-01-01     0   1168        1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 3 2021-01-01     0   2619         2619. 석촌고분역 4번출구    정기권  None  ~10대   1.0
# 4 2021-01-01     0    536          536. 행당역 2번출구 앞    정기권  None  ~10대   1.0
#
#     운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스
# 0  28.9 0.23   992.78     13.0       4
# 1 34.38 0.26   1127.5     10.0       4
# 2   0.0  0.0      0.0      7.0       4
# 3 38.75 0.38  1658.34     14.0       4
# 4 12.96 0.17   743.88      5.0       4

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df_2021['요일'] = df_2021.apply(lambda x : weekday_list[x['요일_인덱스']], axis=1)

# %%
df_2021.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2021-01-01     0   1347  1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대   2.0
# 1 2021-01-01     0   1349       1349. 월계2교 버스정류장 앞    정기권  None  ~10대   1.0
# 2 2021-01-01     0   1168        1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 3 2021-01-01     0   2619         2619. 석촌고분역 4번출구    정기권  None  ~10대   1.0
# 4 2021-01-01     0    536          536. 행당역 2번출구 앞    정기권  None  ~10대   1.0
#
#     운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0  28.9 0.23   992.78     13.0       4  금
# 1 34.38 0.26   1127.5     10.0       4  금
# 2   0.0  0.0      0.0      7.0       4  금
# 3 38.75 0.38  1658.34     14.0       4  금
# 4 12.96 0.17   743.88      5.0       4  금

# %%
df_2021[['요일', '대여시간']].value_counts(ascending=False)
# Out:
# 요일  대여시간
# 수   18      437524
# 금   18      410733
# 목   18      400182
# 월   18      373544
# 화   18      349759
#              ...
# 수   4        16976
# 화   4        15889
# 일   4        15438
# 월   4        15394
#     3        14745
# Name: count, Length: 168, dtype: int64

# %%
grounded = df_2021.groupby(['요일', '대여시간'])['이용건수'].sum().unstack()
grounded
# Out:
# 대여시간      0       1       2       3       4       5       6        7   \
# 요일
# 금    76432.0 49092.0 30882.0 21042.0 17720.0 31243.0 73080.0 190225.0
# 목    81127.0 51301.0 32471.0 22241.0 18909.0 34641.0 82917.0 216237.0
# 수    65358.0 44254.0 28834.0 19927.0 17338.0 31504.0 75085.0 191735.0
# 월    58257.0 35783.0 22231.0 15251.0 15704.0 31223.0 72446.0 187495.0
# 일    80956.0 52278.0 34917.0 22907.0 15980.0 17410.0 28170.0  47823.0
# 토    97039.0 65024.0 42604.0 28012.0 20682.0 24390.0 38069.0  65347.0
# 화    66010.0 41943.0 26775.0 18341.0 16219.0 31129.0 74078.0 186996.0
#
# 대여시간       8        9   ...       14       15       16       17       18  \
# 요일                      ...
# 금    313082.0 170893.0  ... 191490.0 216848.0 270550.0 384582.0 496019.0
# 목    354935.0 187598.0  ... 187387.0 206587.0 253156.0 361916.0 489828.0
# 수    325703.0 176905.0  ... 204088.0 230430.0 277825.0 395994.0 537258.0
# 월    304330.0 166408.0  ... 173100.0 192461.0 232403.0 325631.0 457947.0
# 일     78622.0 107857.0  ... 266703.0 297153.0 311816.0 307449.0 281275.0
# 토    113813.0 142745.0  ... 235266.0 252890.0 267685.0 271800.0 255405.0
# 화    306526.0 161643.0  ... 165505.0 182134.0 226185.0 318526.0 425629.0
#
# 대여시간       19       20       21       22       23
# 요일
# 금    332553.0 275113.0 265809.0 233992.0 129470.0
# 목    326258.0 274692.0 260157.0 217759.0 111912.0
# 수    363874.0 302148.0 281684.0 233102.0 115903.0
# 월    307960.0 256708.0 237344.0 194344.0  98690.0
# 일    236514.0 214596.0 197404.0 153007.0  86827.0
# 토    225166.0 214907.0 216062.0 188120.0 111866.0
# 화    285250.0 238016.0 223393.0 186830.0  93596.0
#
# [7 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,6))
# plt.ticklabel_format(axis='y', useOffset=False, style='plain')  # y축(지수표시) - 일반 표시로 변경
sns.lineplot(x='대여시간', y='이용건수', hue='요일', data=df_2021, marker='o')
plt.title('2021년 대여시간에 따른 요일별 이용건수')
plt.xticks(range(0,24)) # = plt.xticks(np.arange(0,24,1))
plt.xlabel('대여시간')
plt.ylabel('이용건수')
plt.show()

# %% [markdown]
# ## 2. 가설 2) 출퇴근 시간에 따릉이 대여량이 최다인 대여소는 지하철역 인근 대여소일 것이다.

# %% [markdown]
# ### - 출퇴근 시간 대여소별 사용량 확인

# %% [markdown]
# - 요일 : 월~금요일 추출한다.

# %%
df_2021.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2021-01-01     0   1347  1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대   2.0
# 1 2021-01-01     0   1349       1349. 월계2교 버스정류장 앞    정기권  None  ~10대   1.0
# 2 2021-01-01     0   1168        1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 3 2021-01-01     0   2619         2619. 석촌고분역 4번출구    정기권  None  ~10대   1.0
# 4 2021-01-01     0    536          536. 행당역 2번출구 앞    정기권  None  ~10대   1.0
#
#     운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0  28.9 0.23   992.78     13.0       4  금
# 1 34.38 0.26   1127.5     10.0       4  금
# 2   0.0  0.0      0.0      7.0       4  금
# 3 38.75 0.38  1658.34     14.0       4  금
# 4 12.96 0.17   743.88      5.0       4  금

# %%
df_2021.count()
# Out:
# 대여일자       25421727
# 대여시간       25421727
# 대여소번호      25421727
# 대여소명       25421727
# 대여구분코드     25421727
# 성별         14657620
# 연령대코드      25421727
# 이용건수       25421727
# 운동량        25273392
# 탄소량        25273392
# 이동거리(M)    25421727
# 이용시간(분)    25421727
# 요일_인덱스     25421727
# 요일         25421727
# dtype: int64

# %%
#df_2020[(df_2020['요일'] != '토') & (df_2020['요일'] != '일')]
df_2021_day = df_2021[~(df_2021['요일'].isin(['토', '일']))]
df_2021_day
# Out:
#                대여일자  대여시간  대여소번호                      대여소명 대여구분코드    성별 연령대코드  \
# 0        2021-01-01     0   1347   1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대
# 1        2021-01-01     0   1349        1349. 월계2교 버스정류장 앞    정기권  None  ~10대
# 2        2021-01-01     0   1168         1168. 마곡엠밸리10단지 앞    정기권  None  ~10대
# 3        2021-01-01     0   2619          2619. 석촌고분역 4번출구    정기권  None  ~10대
# 4        2021-01-01     0    536           536. 행당역 2번출구 앞    정기권  None  ~10대
# ...             ...   ...    ...                       ...    ...   ...   ...
# 25421722 2021-12-31    23   4561            4561. 양평역 1번출구    정기권     M   50대
# 25421723 2021-12-31    23    815       815. LIG강촌아파트 103동앞    정기권     M   50대
# 25421724 2021-12-31    23   2173               2173. 당곡사거리    정기권     M   60대
# 25421725 2021-12-31    23   2718           2718.마곡수명산파크1단지    정기권     M   60대
# 25421726 2021-12-31    23   4620  4620. 삼각지역 14번 출구 앞(교통섬)    정기권     M  70대~
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0          2.0  28.9 0.23   992.78     13.0       4  금
# 1          1.0 34.38 0.26   1127.5     10.0       4  금
# 2          1.0   0.0  0.0      0.0      7.0       4  금
# 3          1.0 38.75 0.38  1658.34     14.0       4  금
# 4          1.0 12.96 0.17   743.88      5.0       4  금
# ...        ...   ...  ...      ...      ...     ... ..
# 25421722   1.0 22.95 0.19    840.0      4.0       4  금
# 25421723   1.0  30.2 0.21   907.98      8.0       4  금
# 25421724   1.0 64.55 0.48  2063.26     13.0       4  금
# 25421725   1.0 27.84 0.22    950.0      8.0       4  금
# 25421726   1.0  29.8 0.23    990.0      8.0       4  금
#
# [18979008 rows x 14 columns]

# %% [markdown]
# - '출퇴근' 컬럼을 새로 만들어서 출근, 퇴근을 넣어준다. (월~금요일, 출퇴근)

# %%
df_2021_day.loc[df_2021_day['대여시간'].isin([7,8,9]),'출퇴근'] = '출근'
df_2021_day.loc[df_2021_day['대여시간'].isin([17,18,19]),'출퇴근'] = '퇴근'

# %%
df_2021_day
# Out:
#                대여일자  대여시간  대여소번호                      대여소명 대여구분코드    성별 연령대코드  \
# 0        2021-01-01     0   1347   1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대
# 1        2021-01-01     0   1349        1349. 월계2교 버스정류장 앞    정기권  None  ~10대
# 2        2021-01-01     0   1168         1168. 마곡엠밸리10단지 앞    정기권  None  ~10대
# 3        2021-01-01     0   2619          2619. 석촌고분역 4번출구    정기권  None  ~10대
# 4        2021-01-01     0    536           536. 행당역 2번출구 앞    정기권  None  ~10대
# ...             ...   ...    ...                       ...    ...   ...   ...
# 25421722 2021-12-31    23   4561            4561. 양평역 1번출구    정기권     M   50대
# 25421723 2021-12-31    23    815       815. LIG강촌아파트 103동앞    정기권     M   50대
# 25421724 2021-12-31    23   2173               2173. 당곡사거리    정기권     M   60대
# 25421725 2021-12-31    23   2718           2718.마곡수명산파크1단지    정기권     M   60대
# 25421726 2021-12-31    23   4620  4620. 삼각지역 14번 출구 앞(교통섬)    정기권     M  70대~
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일  출퇴근
# 0          2.0  28.9 0.23   992.78     13.0       4  금  NaN
# 1          1.0 34.38 0.26   1127.5     10.0       4  금  NaN
# 2          1.0   0.0  0.0      0.0      7.0       4  금  NaN
# 3          1.0 38.75 0.38  1658.34     14.0       4  금  NaN
# 4          1.0 12.96 0.17   743.88      5.0       4  금  NaN
# ...        ...   ...  ...      ...      ...     ... ..  ...
# 25421722   1.0 22.95 0.19    840.0      4.0       4  금  NaN
# 25421723   1.0  30.2 0.21   907.98      8.0       4  금  NaN
# 25421724   1.0 64.55 0.48  2063.26     13.0       4  금  NaN
# 25421725   1.0 27.84 0.22    950.0      8.0       4  금  NaN
# 25421726   1.0  29.8 0.23    990.0      8.0       4  금  NaN
#
# [18979008 rows x 15 columns]

# %%
df_2021_day[df_2021_day['출퇴근'] == '출근'] # df_parquet[df_parquet['이용건수'] == '\\N']
# Out:
#                대여일자  대여시간  대여소번호                      대여소명 대여구분코드    성별 연령대코드  \
# 1679     2021-01-01     7   1528           1528. 삼각산동 주민센터    정기권  None  ~10대
# 1680     2021-01-01     7   1667               1667. 중계중학교    정기권  None  ~10대
# 1681     2021-01-01     7   1375  1375. 생명의 전화 종합복지관 앞 교차로    정기권  None  ~10대
# 1682     2021-01-01     7    782               782.서남병원 후문    정기권  None  ~10대
# 1683     2021-01-01     7   1573            1573.현대성우아파트 옆    정기권  None  ~10대
# ...             ...   ...    ...                       ...    ...   ...   ...
# 25395605 2021-12-31     9   1215       1215. 올림픽공원역 1번출구 앞    정기권     M   60대
# 25395606 2021-12-31     9   2013          2013. 장승배기역 5번출구    정기권     M   60대
# 25395607 2021-12-31     9    320        320. 을지로입구역 4번출구 앞    정기권     M  70대~
# 25395608 2021-12-31     9   3711            3711. 월계2교 교차로    정기권     M  70대~
# 25395609 2021-12-31     9    608              608. 전농삼성아파트    정기권     M  70대~
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 1679       1.0  315.0 2.84 12237.81     90.0       4  금  출근
# 1680       1.0    0.0  0.0      0.0     15.0       4  금  출근
# 1681       1.0   11.3 0.11   475.54      5.0       4  금  출근
# 1682       1.0 103.38 1.06  4580.14     48.0       4  금  출근
# 1683       1.0    0.0  0.0      0.0      3.0       4  금  출근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 25395605   1.0   29.6 0.27   1150.0      7.0       4  금  출근
# 25395606   1.0  610.5 5.34  23010.0     95.0       4  금  출근
# 25395607   1.0    0.0  0.0      0.0      2.0       4  금  출근
# 25395608   1.0    0.0  0.0      0.0     87.0       4  금  출근
# 25395609   1.0 115.15 0.89  3825.98     29.0       4  금  출근
#
# [3047088 rows x 15 columns]

# %%
df_2021_day[df_2021_day['출퇴근'] == '퇴근']
# Out:
#                대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 12890    2021-01-01    17   1723     1723. 방학동학마을도서관    정기권  None  ~10대   1.0
# 12891    2021-01-01    17   1451         1451. 중랑세무서    정기권  None  ~10대   1.0
# 12892    2021-01-01    17    962    962. 은평뉴타운 힐데스하임    정기권  None  ~10대   1.0
# 12893    2021-01-01    17   2613         2613. 잠실나들목    정기권  None  ~10대   1.0
# 12894    2021-01-01    17   2702     2702. 마곡 엠밸리2단지    정기권  None  ~10대   1.0
# ...             ...   ...    ...                 ...    ...   ...   ...   ...
# 25417593 2021-12-31    19   1332  1332. 석계역 5번출구 건너편    정기권     M   60대   1.0
# 25417594 2021-12-31    19    419         419. 홈플러스 앞    정기권     M   60대   1.0
# 25417595 2021-12-31    19   1158      1158. 가양역 8번출구    정기권     M  70대~   1.0
# 25417596 2021-12-31    19   2279     2279. 교대역 5번출구뒤    정기권     M  70대~   1.0
# 25417597 2021-12-31    19   1050   1050.  둔촌역 3번 출입구    정기권     M  70대~   1.0
#
#             운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 12890    309.09 3.18 13693.53     56.0       4  금  퇴근
# 12891     63.32 0.57   2460.0     14.0       4  금  퇴근
# 12892     47.05 0.37  1584.07     12.0       4  금  퇴근
# 12893       0.0  0.0      0.0     33.0       4  금  퇴근
# 12894     73.51 0.54  2320.37     27.0       4  금  퇴근
# ...         ...  ...      ...      ...     ... ..  ..
# 25417593 593.21 4.63 19973.28     53.0       4  금  퇴근
# 25417594   5.01 0.04    160.0     57.0       4  금  퇴근
# 25417595  33.89 0.31  1316.63     12.0       4  금  퇴근
# 25417596  26.43 0.21    890.0     15.0       4  금  퇴근
# 25417597  38.61 0.32  1392.99     17.0       4  금  퇴근
#
# [4908320 rows x 15 columns]

# %%
df_2021_day['출퇴근'].unique()
# Out:
# array([nan, '출근', '퇴근'], dtype=object)

# %%
df_2021_day['출퇴근'].value_counts()
# Out:
# 출퇴근
# 퇴근    4908320
# 출근    3047088
# Name: count, dtype: int64

# %%
df_2021_day.count()
# Out:
# 대여일자       18979008
# 대여시간       18979008
# 대여소번호      18979008
# 대여소명       18979008
# 대여구분코드     18979008
# 성별         10945626
# 연령대코드      18979008
# 이용건수       18979008
# 운동량        18865390
# 탄소량        18865390
# 이동거리(M)    18979008
# 이용시간(분)    18979008
# 요일_인덱스     18979008
# 요일         18979008
# 출퇴근         7955408
# dtype: int64

# %%
df_2021_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18979008 entries, 0 to 25421726
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(6)
# memory usage: 2.2+ GB

# %%
df_2021_day.loc[:, '이용건수'] = df_2021_day['이용건수'].astype(int)

# %%
df_2021_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18979008 entries, 0 to 25421726
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int32
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 2.1+ GB

# %%
df_2021_time = df_2021_day[~df_2021_day['출퇴근'].isnull()] # df_2020_day.dropna(subset=['출퇴근'])

# %%
df_2021_time
# Out:
#                대여일자  대여시간  대여소번호                      대여소명 대여구분코드    성별 연령대코드  \
# 1679     2021-01-01     7   1528           1528. 삼각산동 주민센터    정기권  None  ~10대
# 1680     2021-01-01     7   1667               1667. 중계중학교    정기권  None  ~10대
# 1681     2021-01-01     7   1375  1375. 생명의 전화 종합복지관 앞 교차로    정기권  None  ~10대
# 1682     2021-01-01     7    782               782.서남병원 후문    정기권  None  ~10대
# 1683     2021-01-01     7   1573            1573.현대성우아파트 옆    정기권  None  ~10대
# ...             ...   ...    ...                       ...    ...   ...   ...
# 25417593 2021-12-31    19   1332        1332. 석계역 5번출구 건너편    정기권     M   60대
# 25417594 2021-12-31    19    419               419. 홈플러스 앞    정기권     M   60대
# 25417595 2021-12-31    19   1158            1158. 가양역 8번출구    정기권     M  70대~
# 25417596 2021-12-31    19   2279           2279. 교대역 5번출구뒤    정기권     M  70대~
# 25417597 2021-12-31    19   1050         1050.  둔촌역 3번 출입구    정기권     M  70대~
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 1679         1  315.0 2.84 12237.81     90.0       4  금  출근
# 1680         1    0.0  0.0      0.0     15.0       4  금  출근
# 1681         1   11.3 0.11   475.54      5.0       4  금  출근
# 1682         1 103.38 1.06  4580.14     48.0       4  금  출근
# 1683         1    0.0  0.0      0.0      3.0       4  금  출근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 25417593     1 593.21 4.63 19973.28     53.0       4  금  퇴근
# 25417594     1   5.01 0.04    160.0     57.0       4  금  퇴근
# 25417595     1  33.89 0.31  1316.63     12.0       4  금  퇴근
# 25417596     1  26.43 0.21    890.0     15.0       4  금  퇴근
# 25417597     1  38.61 0.32  1392.99     17.0       4  금  퇴근
#
# [7955408 rows x 15 columns]

# %%
df_2021_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7955408 entries, 1679 to 25417597
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int32
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 910.4+ MB

# %%
df_2021_time.count()
# Out:
# 대여일자       7955408
# 대여시간       7955408
# 대여소번호      7955408
# 대여소명       7955408
# 대여구분코드     7955408
# 성별         4645871
# 연령대코드      7955408
# 이용건수       7955408
# 운동량        7904594
# 탄소량        7904594
# 이동거리(M)    7955408
# 이용시간(분)    7955408
# 요일_인덱스     7955408
# 요일         7955408
# 출퇴근        7955408
# dtype: int64

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본'
df_st = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 0.15987825393676758

# %%
df_st.head()
# Out:
#        대여소번호          대여소명  자치구                         상세주소          위도  \
# 20852  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 19007  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 19015  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 19014  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 19013  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#                경도        설치시기  LCD   QR 운영방식   데이터등록월
# 20852 126.8210602  2024-03-18  NaN 10.0   QR  2024-06
# 19007 127.0669098  2020-03-24  NaN 12.0   QR  2024-06
# 19015 127.0732651  2020-03-23  NaN 20.0   QR  2024-06
# 19014 127.0719147  2020-03-23  NaN  7.0   QR  2024-06
# 19013 127.0740509  2020-03-25  NaN 10.0   QR  2024-06

# %%
df_st.info() # 대여소번호 int / object 다름.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2921 entries, 20852 to 1174
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   2921 non-null   object
#  1   대여소명    2921 non-null   object
#  2   자치구     2921 non-null   object
#  3   상세주소    2921 non-null   object
#  4   위도      2920 non-null   float64
#  5   경도      2920 non-null   float64
#  6   설치시기    2921 non-null   object
#  7   LCD     1517 non-null   float64
#  8   QR      1752 non-null   float64
#  9   운영방식    2921 non-null   object
#  10  데이터등록월  2921 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 273.8+ KB

# %%
df_st.shape
# Out:
# (2921, 11)

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

import ExcelFile_EDA as ee
ee.ss_isnull(df_st)
# Out:
#      [컬럼명]  [sum]  [sum_isnull]     [mean_isnull(%)]
# 0    대여소번호   2921             0                  0.0
# 1     대여소명   2921             0                  0.0
# 2      자치구   2921             0                  0.0
# 3     상세주소   2921             0                  0.0
# 4       위도   2920             1 0.034234851078397806
# 5       경도   2920             1 0.034234851078397806
# 6     설치시기   2921             0                  0.0
# 7      LCD   1517          1404    48.06573091407053
# 8       QR   1752          1169    40.02054091064704
# 9     운영방식   2921             0                  0.0
# 10  데이터등록월   2921             0                  0.0

# %%
df_st_1 = df_st[['대여소번호', '대여소명', '자치구', '설치시기', '데이터등록월']]
df_st_1
# Out:
#        대여소번호           대여소명  자치구        설치시기   데이터등록월
# 20852  06173    서울자동차운전전문학원  강서구  2024-03-18  2024-06
# 19007  02902   공릉풍림아파트 108동  노원구  2020-03-24  2024-06
# 19015  02912         대진고등학교  노원구  2020-03-23  2024-06
# 19014  02911        상계역중앙시장  노원구  2020-03-23  2024-06
# 19013  02910          도깨비시장  노원구  2020-03-25  2024-06
# ...      ...            ...  ...         ...      ...
# 1689   02200      관악문화원 건너편  관악구  2020-04-28  2021-01
# 1690   03304     낙성대역 5번 출구  관악구  2020-04-29  2021-01
# 1079   04205  디지털미디어씨티역2번출구  마포구  2020-12-02  2021-01
# 1258   02714    발산1동주민센터교차로  강서구  2020-03-17  2021-01
# 1174   01114  서남물재생센터 버스정류장  강서구  2017-04-24  2021-01
#
# [2921 rows x 5 columns]

# %% [markdown]
# - 시간대별 데이터, 대여소정보 데이터 에서 '대여소번호' 컬럼의 숫자 표현방식, 데이터 타입이 다르다.

# %% [markdown]
# - 따라서, 1. 시간대별 데이터(월~금 / 출퇴근 시간대 추출함)의 '대여소번호' 컬럼의 숫자를 object로 바꾸어준다.
#      ##### 2. 시간대별 데이터의 '대여소번호' 컬럼의 숫자를 00000 자리로 바꾸어준다.

# %%
df_2021_time.head()
# Out:
#            대여일자  대여시간  대여소번호                      대여소명 대여구분코드    성별 연령대코드  \
# 1679 2021-01-01     7   1528           1528. 삼각산동 주민센터    정기권  None  ~10대
# 1680 2021-01-01     7   1667               1667. 중계중학교    정기권  None  ~10대
# 1681 2021-01-01     7   1375  1375. 생명의 전화 종합복지관 앞 교차로    정기권  None  ~10대
# 1682 2021-01-01     7    782               782.서남병원 후문    정기권  None  ~10대
# 1683 2021-01-01     7   1573            1573.현대성우아파트 옆    정기권  None  ~10대
#
#       이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 1679     1  315.0 2.84 12237.81     90.0       4  금  출근
# 1680     1    0.0  0.0      0.0     15.0       4  금  출근
# 1681     1   11.3 0.11   475.54      5.0       4  금  출근
# 1682     1 103.38 1.06  4580.14     48.0       4  금  출근
# 1683     1    0.0  0.0      0.0      3.0       4  금  출근

# %%
df_2021_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7955408 entries, 1679 to 25417597
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int32
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 910.4+ MB

# %%
df_2021_time.loc[:, '대여소번호'] = df_2021_time['대여소번호'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10664\2147831927.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['1528' '1667' '1375' ... '1158' '2279' '1050']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_2021_time.loc[:, '대여소번호'] = df_2021_time['대여소번호'].astype(str)

# %%
df_2021_time.dtypes
# Out:
# 대여일자       datetime64[ns]
# 대여시간                int64
# 대여소번호              object
# 대여소명               object
# 대여구분코드             object
# 성별                 object
# 연령대코드              object
# 이용건수                int32
# 운동량               float64
# 탄소량               float64
# 이동거리(M)           float64
# 이용시간(분)           float64
# 요일_인덱스              int32
# 요일                 object
# 출퇴근                object
# dtype: object

# %%
df_2021_time.loc[:,'대여소번호'] = df_2021_time['대여소번호'].str.zfill(5)

# %%
df_2021_time.head()
# Out:
#            대여일자  대여시간  대여소번호                      대여소명 대여구분코드    성별 연령대코드  \
# 1679 2021-01-01     7  01528           1528. 삼각산동 주민센터    정기권  None  ~10대
# 1680 2021-01-01     7  01667               1667. 중계중학교    정기권  None  ~10대
# 1681 2021-01-01     7  01375  1375. 생명의 전화 종합복지관 앞 교차로    정기권  None  ~10대
# 1682 2021-01-01     7  00782               782.서남병원 후문    정기권  None  ~10대
# 1683 2021-01-01     7  01573            1573.현대성우아파트 옆    정기권  None  ~10대
#
#       이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 1679     1  315.0 2.84 12237.81     90.0       4  금  출근
# 1680     1    0.0  0.0      0.0     15.0       4  금  출근
# 1681     1   11.3 0.11   475.54      5.0       4  금  출근
# 1682     1 103.38 1.06  4580.14     48.0       4  금  출근
# 1683     1    0.0  0.0      0.0      3.0       4  금  출근

# %%
df_sum = pd.merge(df_2021_time, df_st_1, on='대여소번호', how='left')
df_sum
# Out:
#               대여일자  대여시간  대여소번호                    대여소명_x 대여구분코드    성별 연령대코드  \
# 0       2021-01-01     7  01528           1528. 삼각산동 주민센터    정기권  None  ~10대
# 1       2021-01-01     7  01667               1667. 중계중학교    정기권  None  ~10대
# 2       2021-01-01     7  01375  1375. 생명의 전화 종합복지관 앞 교차로    정기권  None  ~10대
# 3       2021-01-01     7  00782               782.서남병원 후문    정기권  None  ~10대
# 4       2021-01-01     7  01573            1573.현대성우아파트 옆    정기권  None  ~10대
# ...            ...   ...    ...                       ...    ...   ...   ...
# 7955403 2021-12-31    19  01332        1332. 석계역 5번출구 건너편    정기권     M   60대
# 7955404 2021-12-31    19  00419               419. 홈플러스 앞    정기권     M   60대
# 7955405 2021-12-31    19  01158            1158. 가양역 8번출구    정기권     M  70대~
# 7955406 2021-12-31    19  02279           2279. 교대역 5번출구뒤    정기권     M  70대~
# 7955407 2021-12-31    19  01050         1050.  둔촌역 3번 출입구    정기권     M  70대~
#
#          이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근  \
# 0           1  315.0 2.84 12237.81     90.0       4  금  출근
# 1           1    0.0  0.0      0.0     15.0       4  금  출근
# 2           1   11.3 0.11   475.54      5.0       4  금  출근
# 3           1 103.38 1.06  4580.14     48.0       4  금  출근
# 4           1    0.0  0.0      0.0      3.0       4  금  출근
# ...       ...    ...  ...      ...      ...     ... ..  ..
# 7955403     1 593.21 4.63 19973.28     53.0       4  금  퇴근
# 7955404     1   5.01 0.04    160.0     57.0       4  금  퇴근
# 7955405     1  33.89 0.31  1316.63     12.0       4  금  퇴근
# 7955406     1  26.43 0.21    890.0     15.0       4  금  퇴근
# 7955407     1  38.61 0.32  1392.99     17.0       4  금  퇴근
#
#                      대여소명_y  자치구        설치시기   데이터등록월
# 0                 삼각산동 주민센터  강북구  2017-11-01  2024-06
# 1                     중계중학교  노원구  2017-11-28  2024-06
# 2        생명의 전화 종합복지관 앞 교차로  성북구  2018-12-27  2024-06
# 3                   서남병원 후문  양천구  2020-03-15  2024-06
# 4                 현대성우아파트 옆  강북구  2020-05-05  2024-06
# ...                     ...  ...         ...      ...
# 7955403        석계역 5번출구 건너편  성북구  2017-04-26  2024-06
# 7955404          홈플러스 마포점 앞  마포구  2015-10-07  2024-06
# 7955405            가양역 8번출구  강서구  2017-11-28  2024-06
# 7955406           교대역 5번출구뒤  서초구  2017-11-28  2024-06
# 7955407          둔촌역 3번 출입구  강동구  2018-02-26  2024-06
#
# [7955408 rows x 19 columns]

# %%
group1 = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().reset_index()
group1
# Out:
#               대여소명_y 출퇴근  이용건수
# 0        (구)합정동 주민센터  출근   119
# 1        (구)합정동 주민센터  퇴근   111
# 2        (시립)고덕평생학습관  출근   462
# 3        (시립)고덕평생학습관  퇴근  1074
# 4       (재)FITI시험연구원  출근  4766
# ...              ...  ..   ...
# 5244         힐스테이트에코  퇴근  9208
# 5245  힐스테이트창경궁 아파트 앞  출근   782
# 5246  힐스테이트창경궁 아파트 앞  퇴근  1183
# 5247    힐스테이트클래시안아파트  출근  1155
# 5248    힐스테이트클래시안아파트  퇴근   638
#
# [5249 rows x 3 columns]

# %% [markdown]
# - 출근 시간대 대여소별 이용건수

# %%
commute_data = group1[group1['출퇴근'] == '출근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data = commute_data.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data = top_20_commute_data.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
plt.barh(top_20_commute_data['대여소명_y'], top_20_commute_data['이용건수'])
plt.title('2021년 출근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# - 퇴근 시간대 대여소별 이용건수

# %%
commute_data_2 = group1[group1['출퇴근'] == '퇴근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data_2 = commute_data_2.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data_2 = top_20_commute_data_2.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
plt.barh(top_20_commute_data_2['대여소명_y'], top_20_commute_data_2['이용건수'])
plt.title('2021년 퇴근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# -------------------------------------------------
