# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'
filename = '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2022'
df_2022 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 27.733935356140137

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2022)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  36160476             0          0.000000
# 1      대여시간  36160476             0          0.000000
# 2     대여소번호  36160476             0          0.000000
# 3      대여소명  36160476             0          0.000000
# 4    대여구분코드  36160476             0          0.000000
# 5        성별  23845360      12315116         34.056842
# 6     연령대코드  36160476             0          0.000000
# 7      이용건수  36160476             0          0.000000
# 8       운동량  36023075        137401          0.379976
# 9       탄소량  36023075        137401          0.379976
# 10  이동거리(M)  36160476             0          0.000000
# 11  이용시간(분)  36160476             0          0.000000

# %%
df_2022.head()
# Out:
#          대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0  2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1  2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2  2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3  2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4  2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수    운동량   탄소량  이동거리(M)  이용시간(분)
# 0     1  13.54  0.13   570.00        3
# 1     1  32.81  0.36  1534.33       12
# 2     1  19.10  0.17   720.00        4
# 3     1  10.57  0.08   333.59        3
# 4     1   6.93  0.07   318.20       37

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36160476 entries, 0 to 36160475
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 3.2+ GB

# %%
df_2022.describe()
# Out:
#                대여시간         대여소번호          이용건수           운동량           탄소량  \
# count  3.616048e+07  3.616048e+07  3.616048e+07  3.602308e+07  3.602308e+07
# mean   1.409602e+01  2.002511e+03  1.132457e+00  1.148579e+02  6.774260e-01
# std    5.749855e+00  1.465612e+03  4.704803e-01  5.651154e+04  1.263741e+00
# min    0.000000e+00  3.000000e+00  1.000000e+00 -3.799500e+02 -3.180000e+00
# 25%    1.000000e+01  7.700000e+02  1.000000e+00  2.346000e+01  2.100000e-01
# 50%    1.500000e+01  1.637000e+03  1.000000e+00  4.407000e+01  3.900000e-01
# 75%    1.900000e+01  3.116000e+03  1.000000e+00  8.864000e+01  7.800000e-01
# max    2.300000e+01  9.999900e+04  3.800000e+01  1.000000e+08  3.273580e+03
#
#             이동거리(M)       이용시간(분)
# count  3.616048e+07  3.616048e+07
# mean   2.908868e+03  2.531282e+01
# std    5.439750e+03  3.162412e+01
# min   -1.370678e+04  0.000000e+00
# 25%    9.000000e+02  7.000000e+00
# 50%    1.680000e+03  1.400000e+01
# 75%    3.350000e+03  3.200000e+01
# max    1.411028e+07  3.205000e+03

# %%
pd.options.display.float_format = '{:3}'.format

# %%
round(df_2022.describe(), 1)
# Out:
#             대여시간      대여소번호       이용건수         운동량        탄소량    이동거리(M)  \
# count 36160476.0 36160476.0 36160476.0  36023075.0 36023075.0 36160476.0
# mean        14.1     2002.5        1.1       114.9        0.7     2908.9
# std          5.7     1465.6        0.5     56511.5        1.3     5439.8
# min          0.0        3.0        1.0      -380.0       -3.2   -13706.8
# 25%         10.0      770.0        1.0        23.5        0.2      900.0
# 50%         15.0     1637.0        1.0        44.1        0.4     1680.0
# 75%         19.0     3116.0        1.0        88.6        0.8     3350.0
# max         23.0    99999.0       38.0 100000000.0     3273.6 14110279.1
#
#          이용시간(분)
# count 36160476.0
# mean        25.3
# std         31.6
# min          0.0
# 25%          7.0
# 50%         14.0
# 75%         32.0
# max       3205.0

# %%
df_2022.shape
# Out:
# (36160476, 12)

# %%
df_2022.isnull().sum()
# Out:
# 대여일자              0
# 대여시간              0
# 대여소번호             0
# 대여소명              0
# 대여구분코드            0
# 성별         12315116
# 연령대코드             0
# 이용건수              0
# 운동량          137401
# 탄소량          137401
# 이동거리(M)           0
# 이용시간(분)           0
# dtype: int64

# %%
df_2022['대여시간'].value_counts()
# Out:
# 대여시간
# 18    3323780
# 17    2801910
# 19    2448683
# 8     2377375
# 16    2270279
# 20    2083776
# 21    1910878
# 15    1910591
# 14    1729642
# 13    1696613
# 12    1684826
# 22    1588994
# 7     1581374
# 9     1568101
# 11    1517422
# 10    1316501
# 23    1084131
# 0      871207
# 6      672591
# 1      583418
# 2      374086
# 5      325862
# 3      244012
# 4      194424
# Name: count, dtype: int64

# %% [markdown]
# ## 1. 가설 1) 따릉이 최다 사용량이 출퇴근 시간이고

# %% [markdown]
# ### - 최다 사용량이 출퇴근 시간인 것을 확인한다.

# %% [markdown]
# - 대여일자 컬럼을 datetime 형식으로 변환

# %%
df_2022['대여일자'] = pd.to_datetime(df_2022['대여일자'], format='%Y-%m-%d')
# df_2020['대여시간'].astype('datetime64[ns]')

# %%
print(df_2022['대여일자'].dtype)
# Out:
# datetime64[ns]

# %%
df_2022.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)
# 0     1 13.54 0.13    570.0        3
# 1     1 32.81 0.36  1534.33       12
# 2     1  19.1 0.17    720.0        4
# 3     1 10.57 0.08   333.59        3
# 4     1  6.93 0.07    318.2       37

# %% [markdown]
# - datetime 형식으로 변경된 '대여일자' 컬럼에서 요일을 추출하여 새로운 컬럼으로 저장

# %%
# dt.weekday : 요일 정보를 숫자로 추출 
# 0 : 월요일, 1 : 화요일, .... 6 : 일요일
df_2022['요일_인덱스'] = df_2022['대여일자'].dt.weekday

# %%
df_2022.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스
# 0     1 13.54 0.13    570.0        3       3
# 1     1 32.81 0.36  1534.33       12       3
# 2     1  19.1 0.17    720.0        4       3
# 3     1 10.57 0.08   333.59        3       3
# 4     1  6.93 0.07    318.2       37       3

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df_2022['요일'] = df_2022.apply(lambda x : weekday_list[x['요일_인덱스']], axis=1)

# %%
df_2022.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0     1 13.54 0.13    570.0        3       3  목
# 1     1 32.81 0.36  1534.33       12       3  목
# 2     1  19.1 0.17    720.0        4       3  목
# 3     1 10.57 0.08   333.59        3       3  목
# 4     1  6.93 0.07    318.2       37       3  목

# %%
df_2022[['요일', '대여시간']].value_counts(ascending=False)
# Out:
# 요일  대여시간
# 금   18      558260
# 화   18      550419
# 수   18      548702
# 목   18      543856
# 월   18      499965
#              ...
# 화   3        26261
# 수   4        25880
# 월   3        24619
#     4        23211
# 화   4        22656
# Name: count, Length: 168, dtype: int64

# %%
grounded = df_2022.groupby(['요일', '대여시간'])['이용건수'].sum().unstack()
grounded
# Out:
# 대여시간      0       1      2      3      4      5       6       7       8   \
# 요일
# 금     141199   90263  55909  36128  30014  55212  124221  331413  539566
# 목     127208   84233  51024  33111  27425  53432  123239  332583  525539
# 수     120969   79163  48085  31130  26589  52309  120358  325569  517620
# 월     107551   61913  38667  25611  23874  49814  110544  288182  453720
# 일     172578  114889  74957  48772  33271  30957   44280   72926  116247
# 토     175019  127056  85279  52908  36349  40840   61085   99709  174740
# 화     109014   68791  42275  27096  23215  52337  122848  331431  529946
#
# 대여시간      9   ...      14      15      16      17      18      19      20  \
# 요일            ...
# 금     285808  ...  273142  316118  382588  537136  683590  449063  358919
# 목     271645  ...  243925  275657  366527  504322  676157  446377  368875
# 수     265461  ...  247046  280331  360071  511069  683745  440583  363503
# 월     240230  ...  229762  258434  327240  447657  624947  419984  349915
# 일     157283  ...  326761  362393  383316  371039  334985  293336  267951
# 토     221613  ...  347826  374207  400268  410761  382218  328620  308714
# 화     271129  ...  231392  259618  351525  496949  691653  459829  371495
#
# 대여시간      21      22      23
# 요일
# 금     338841  300695  205718
# 목     344182  290819  183968
# 수     321347  259345  164995
# 월     305747  239048  150182
# 일     244840  194785  138492
# 토     301289  261391  196614
# 화     334665  271430  165019
#
# [7 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,6))
# plt.ticklabel_format(axis='y', useOffset=False, style='plain')  # y축(지수표시) - 일반 표시로 변경
sns.lineplot(x='대여시간', y='이용건수', hue='요일', data=df_2022, marker='o')
plt.title('2022년 대여시간에 따른 요일별 이용건수')
plt.xticks(range(0,24)) # = plt.xticks(np.arange(0,24,1))
plt.xlabel('대여시간')
plt.ylabel('이용건수')
plt.show()

# %% [markdown]
# ## 2. 가설 2) 출퇴근 시간에 따릉이 대여량이 최다인 대여소는 지하철역 인근 대여소일 것이다.

# %% [markdown]
# ### - 출퇴근 시간 대여소별 사용량 확인

# %% [markdown]
# - 요일 : 월~금요일 추출한다.

# %%
df_2022.head()
# Out:
#         대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별 연령대코드  \
# 0 2022-12-01     0    746               746. 목동2단지 상가    정기권  None  ~10대
# 1 2022-12-01     0   1653               1653. 노원역1번출구    정기권  None  ~10대
# 2 2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None  ~10대
# 3 2022-12-01     0   1355                  1355. 보문2교    정기권  None  ~10대
# 4 2022-12-01     0   1184                1184. 마곡13단지    정기권  None  ~10대
#
#    이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0     1 13.54 0.13    570.0        3       3  목
# 1     1 32.81 0.36  1534.33       12       3  목
# 2     1  19.1 0.17    720.0        4       3  목
# 3     1 10.57 0.08   333.59        3       3  목
# 4     1  6.93 0.07    318.2       37       3  목

# %%
df_2022.count()
# Out:
# 대여일자       36160476
# 대여시간       36160476
# 대여소번호      36160476
# 대여소명       36160476
# 대여구분코드     36160476
# 성별         23845360
# 연령대코드      36160476
# 이용건수       36160476
# 운동량        36023075
# 탄소량        36023075
# 이동거리(M)    36160476
# 이용시간(분)    36160476
# 요일_인덱스     36160476
# 요일         36160476
# dtype: int64

# %%
#df_2020[(df_2020['요일'] != '토') & (df_2020['요일'] != '일')]
df_2022_day = df_2022[~(df_2022['요일'].isin(['토', '일']))]
df_2022_day
# Out:
#                대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별  \
# 0        2022-12-01     0    746               746. 목동2단지 상가    정기권  None
# 1        2022-12-01     0   1653               1653. 노원역1번출구    정기권  None
# 2        2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None
# 3        2022-12-01     0   1355                  1355. 보문2교    정기권  None
# 4        2022-12-01     0   1184                1184. 마곡13단지    정기권  None
# ...             ...   ...    ...                         ...    ...   ...
# 36160471 2022-11-30    23   3010             3010.홍대입구역 3번출구    정기권     M
# 36160472 2022-11-30    23   3127               3127.홍은2파출소 옆    정기권     M
# 36160473 2022-11-30    23    232           232. 양평우림 이비즈센타 앞    정기권     M
# 36160474 2022-11-30    23   4594            4594. 양평교 영등포대여소    정기권     M
# 36160475 2022-11-30    23   5858              5858. 영등포역5번출구    정기권     M
#
#          연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0         ~10대     1 13.54 0.13    570.0        3       3  목
# 1         ~10대     1 32.81 0.36  1534.33       12       3  목
# 2         ~10대     1  19.1 0.17    720.0        4       3  목
# 3         ~10대     1 10.57 0.08   333.59        3       3  목
# 4         ~10대     1  6.93 0.07    318.2       37       3  목
# ...        ...   ...   ...  ...      ...      ...     ... ..
# 36160471    기타     1 24.37 0.22   946.92        4       2  수
# 36160472    기타     1  3.99 0.03   141.88        2       2  수
# 36160473    기타     1 14.24  0.1   438.61        3       2  수
# 36160474    기타     1 83.98 0.73  3165.07       79       2  수
# 36160475    기타     1 19.05 0.18   775.94        3       2  수
#
# [26936528 rows x 14 columns]

# %% [markdown]
# - '출퇴근' 컬럼을 새로 만들어서 출근, 퇴근을 넣어준다. (월~금요일, 출퇴근)

# %%
df_2022_day.loc[df_2022_day['대여시간'].isin([7,8,9]),'출퇴근'] = '출근'
df_2022_day.loc[df_2022_day['대여시간'].isin([17,18,19]),'출퇴근'] = '퇴근'

# %%
df_2022_day
# Out:
#                대여일자  대여시간  대여소번호                        대여소명 대여구분코드    성별  \
# 0        2022-12-01     0    746               746. 목동2단지 상가    정기권  None
# 1        2022-12-01     0   1653               1653. 노원역1번출구    정기권  None
# 2        2022-12-01     0   1974  1974. 신도림2차e편한세상아파트 203동 앞    정기권  None
# 3        2022-12-01     0   1355                  1355. 보문2교    정기권  None
# 4        2022-12-01     0   1184                1184. 마곡13단지    정기권  None
# ...             ...   ...    ...                         ...    ...   ...
# 36160471 2022-11-30    23   3010             3010.홍대입구역 3번출구    정기권     M
# 36160472 2022-11-30    23   3127               3127.홍은2파출소 옆    정기권     M
# 36160473 2022-11-30    23    232           232. 양평우림 이비즈센타 앞    정기권     M
# 36160474 2022-11-30    23   4594            4594. 양평교 영등포대여소    정기권     M
# 36160475 2022-11-30    23   5858              5858. 영등포역5번출구    정기권     M
#
#          연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일  출퇴근
# 0         ~10대     1 13.54 0.13    570.0        3       3  목  NaN
# 1         ~10대     1 32.81 0.36  1534.33       12       3  목  NaN
# 2         ~10대     1  19.1 0.17    720.0        4       3  목  NaN
# 3         ~10대     1 10.57 0.08   333.59        3       3  목  NaN
# 4         ~10대     1  6.93 0.07    318.2       37       3  목  NaN
# ...        ...   ...   ...  ...      ...      ...     ... ..  ...
# 36160471    기타     1 24.37 0.22   946.92        4       2  수  NaN
# 36160472    기타     1  3.99 0.03   141.88        2       2  수  NaN
# 36160473    기타     1 14.24  0.1   438.61        3       2  수  NaN
# 36160474    기타     1 83.98 0.73  3165.07       79       2  수  NaN
# 36160475    기타     1 19.05 0.18   775.94        3       2  수  NaN
#
# [26936528 rows x 15 columns]

# %%
df_2022_day[df_2022_day['출퇴근'] == '출근'] # df_parquet[df_parquet['이용건수'] == '\\N']
# Out:
#                대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867     2022-12-01     7   1260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868     2022-12-01     7   1264             1264. 천호역 10번 출구 앞    정기권  None
# 5869     2022-12-01     7   1167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870     2022-12-01     7   1050              1050.  둔촌역 3번 출입구    정기권  None
# 5871     2022-12-01     7   1051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
# ...             ...   ...    ...                            ...    ...   ...
# 36113855 2022-11-30     9   2233             2233. 서초신동아1차아파트 옆    정기권     M
# 36113856 2022-11-30     9   1249                 1249. 아주중학교건너편    정기권     M
# 36113857 2022-11-30     9   2360            2360. 도곡1동 주민센터 교차로    정기권     M
# 36113858 2022-11-30     9   2350             2350. 래미안그레이튼102동앞    정기권     M
# 36113859 2022-11-30     9   3501                   3501. 광진구청 앞    정기권     M
#
#          연령대코드  이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867      ~10대     1  15.22 0.14    620.0        3       3  목  출근
# 5868      ~10대     1  14.26 0.14    600.0        3       3  목  출근
# 5869      ~10대     1   13.9 0.13    540.0        4       3  목  출근
# 5870      ~10대     1  24.97 0.23    970.0        4       3  목  출근
# 5871      ~10대     1  45.86 0.31  1346.65        8       3  목  출근
# ...        ...   ...    ...  ...      ...      ...     ... ..  ..
# 36113855    기타     1  26.12 0.23    970.0        6       2  수  출근
# 36113856    기타     1  20.16 0.16   678.64        2       2  수  출근
# 36113857    기타     1  35.05 0.27   1180.0        6       2  수  출근
# 36113858    기타     1  17.63 0.14   593.57        3       2  수  출근
# 36113859    기타     3 221.97 1.44  6227.82      110       2  수  출근
#
# [4728247 rows x 15 columns]

# %%
df_2022_day[df_2022_day['출퇴근'] == '퇴근']
# Out:
#                대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  \
# 42169    2022-12-01    17    729         729. 서부식자재마트 건너편    정기권  None  ~10대
# 42170    2022-12-01    17   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None  ~10대
# 42171    2022-12-01    17   1653            1653. 노원역1번출구    정기권  None  ~10대
# 42172    2022-12-01    17   1277               1277. 성내6교    정기권  None  ~10대
# 42173    2022-12-01    17   1682      1682. 중계종합사회복지관 교차로    정기권  None  ~10대
# ...             ...   ...    ...                      ...    ...   ...   ...
# 36151168 2022-11-30    19   2230           2230.이수역 4번 출구    정기권     M    기타
# 36151169 2022-11-30    19    408             408. LG CNS앞    정기권     M    기타
# 36151170 2022-11-30    19   1946             1946. 구로역 광장    정기권     M    기타
# 36151171 2022-11-30    19   1925       1925. 동양미래대학교 정문 옆    정기권     M    기타
# 36151172 2022-11-30    19    500      500. 어린이대공원역 3번출구 앞    정기권     M    기타
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 42169        1 58.56 0.44  1895.75       10       3  목  퇴근
# 42170        1 58.92 0.43   1860.0       10       3  목  퇴근
# 42171        1 13.13 0.12    510.0        4       3  목  퇴근
# 42172        1   0.0  0.0      0.0        1       3  목  퇴근
# 42173        1 24.66 0.22   958.13        8       3  목  퇴근
# ...        ...   ...  ...      ...      ...     ... ..  ..
# 36151168     1 49.79 0.39  1676.59       67       2  수  퇴근
# 36151169     1 33.19 0.29   1270.0        6       2  수  퇴근
# 36151170     1 26.14  0.2    880.0        6       2  수  퇴근
# 36151171     1 88.03 0.79   3420.0       16       2  수  퇴근
# 36151172     1 47.74 0.32   1370.0       54       2  수  퇴근
#
# [6731849 rows x 15 columns]

# %%
df_2022_day['출퇴근'].unique()
# Out:
# array([nan, '출근', '퇴근'], dtype=object)

# %%
df_2022_day['출퇴근'].value_counts()
# Out:
# 출퇴근
# 퇴근    6731849
# 출근    4728247
# Name: count, dtype: int64

# %%
df_2022_day.count()
# Out:
# 대여일자       26936528
# 대여시간       26936528
# 대여소번호      26936528
# 대여소명       26936528
# 대여구분코드     26936528
# 성별         17808304
# 연령대코드      26936528
# 이용건수       26936528
# 운동량        26832133
# 탄소량        26832133
# 이동거리(M)    26936528
# 이용시간(분)    26936528
# 요일_인덱스     26936528
# 요일         26936528
# 출퇴근        11460096
# dtype: int64

# %%
df_2022_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26936528 entries, 0 to 36160475
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 3.1+ GB

# %%
df_2022_day.loc[:, '이용건수'] = df_2022_day['이용건수'].astype(int)

# %%
df_2022_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26936528 entries, 0 to 36160475
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 3.1+ GB

# %%
df_2022_time = df_2022_day[~df_2022_day['출퇴근'].isnull()] # df_2020_day.dropna(subset=['출퇴근'])

# %%
df_2022_time
# Out:
#                대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867     2022-12-01     7   1260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868     2022-12-01     7   1264             1264. 천호역 10번 출구 앞    정기권  None
# 5869     2022-12-01     7   1167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870     2022-12-01     7   1050              1050.  둔촌역 3번 출입구    정기권  None
# 5871     2022-12-01     7   1051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
# ...             ...   ...    ...                            ...    ...   ...
# 36151168 2022-11-30    19   2230                 2230.이수역 4번 출구    정기권     M
# 36151169 2022-11-30    19    408                   408. LG CNS앞    정기권     M
# 36151170 2022-11-30    19   1946                   1946. 구로역 광장    정기권     M
# 36151171 2022-11-30    19   1925             1925. 동양미래대학교 정문 옆    정기권     M
# 36151172 2022-11-30    19    500            500. 어린이대공원역 3번출구 앞    정기권     M
#
#          연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867      ~10대     1 15.22 0.14    620.0        3       3  목  출근
# 5868      ~10대     1 14.26 0.14    600.0        3       3  목  출근
# 5869      ~10대     1  13.9 0.13    540.0        4       3  목  출근
# 5870      ~10대     1 24.97 0.23    970.0        4       3  목  출근
# 5871      ~10대     1 45.86 0.31  1346.65        8       3  목  출근
# ...        ...   ...   ...  ...      ...      ...     ... ..  ..
# 36151168    기타     1 49.79 0.39  1676.59       67       2  수  퇴근
# 36151169    기타     1 33.19 0.29   1270.0        6       2  수  퇴근
# 36151170    기타     1 26.14  0.2    880.0        6       2  수  퇴근
# 36151171    기타     1 88.03 0.79   3420.0       16       2  수  퇴근
# 36151172    기타     1 47.74 0.32   1370.0       54       2  수  퇴근
#
# [11460096 rows x 15 columns]

# %%
df_2022_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11460096 entries, 5867 to 36151172
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 1.3+ GB

# %%
df_2022_time.count()
# Out:
# 대여일자       11460096
# 대여시간       11460096
# 대여소번호      11460096
# 대여소명       11460096
# 대여구분코드     11460096
# 성별          7622030
# 연령대코드      11460096
# 이용건수       11460096
# 운동량        11412453
# 탄소량        11412453
# 이동거리(M)    11460096
# 이용시간(분)    11460096
# 요일_인덱스     11460096
# 요일         11460096
# 출퇴근        11460096
# dtype: int64

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본'
df_st = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 0.11160731315612793

# %%
df_st.head()
# Out:
#        대여소번호          대여소명  자치구                         상세주소          위도  \
# 20852  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 19007  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 19015  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 19014  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 19013  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#                경도        설치시기  LCD   QR 운영방식   데이터등록월
# 20852 126.8210602  2024-03-18  NaN 10.0   QR  2024-06
# 19007 127.0669098  2020-03-24  NaN 12.0   QR  2024-06
# 19015 127.0732651  2020-03-23  NaN 20.0   QR  2024-06
# 19014 127.0719147  2020-03-23  NaN  7.0   QR  2024-06
# 19013 127.0740509  2020-03-25  NaN 10.0   QR  2024-06

# %%
df_st.info() # 대여소번호 int / object 다름.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2921 entries, 20852 to 1174
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   2921 non-null   object
#  1   대여소명    2921 non-null   object
#  2   자치구     2921 non-null   object
#  3   상세주소    2921 non-null   object
#  4   위도      2920 non-null   float64
#  5   경도      2920 non-null   float64
#  6   설치시기    2921 non-null   object
#  7   LCD     1517 non-null   float64
#  8   QR      1752 non-null   float64
#  9   운영방식    2921 non-null   object
#  10  데이터등록월  2921 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 273.8+ KB

# %%
df_st.shape
# Out:
# (2921, 11)

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

import ExcelFile_EDA as ee
ee.ss_isnull(df_st)
# Out:
#      [컬럼명]  [sum]  [sum_isnull]     [mean_isnull(%)]
# 0    대여소번호   2921             0                  0.0
# 1     대여소명   2921             0                  0.0
# 2      자치구   2921             0                  0.0
# 3     상세주소   2921             0                  0.0
# 4       위도   2920             1 0.034234851078397806
# 5       경도   2920             1 0.034234851078397806
# 6     설치시기   2921             0                  0.0
# 7      LCD   1517          1404    48.06573091407053
# 8       QR   1752          1169    40.02054091064704
# 9     운영방식   2921             0                  0.0
# 10  데이터등록월   2921             0                  0.0

# %%
df_st_1 = df_st[['대여소번호', '대여소명', '자치구', '설치시기', '데이터등록월']]
df_st_1
# Out:
#        대여소번호           대여소명  자치구        설치시기   데이터등록월
# 20852  06173    서울자동차운전전문학원  강서구  2024-03-18  2024-06
# 19007  02902   공릉풍림아파트 108동  노원구  2020-03-24  2024-06
# 19015  02912         대진고등학교  노원구  2020-03-23  2024-06
# 19014  02911        상계역중앙시장  노원구  2020-03-23  2024-06
# 19013  02910          도깨비시장  노원구  2020-03-25  2024-06
# ...      ...            ...  ...         ...      ...
# 1689   02200      관악문화원 건너편  관악구  2020-04-28  2021-01
# 1690   03304     낙성대역 5번 출구  관악구  2020-04-29  2021-01
# 1079   04205  디지털미디어씨티역2번출구  마포구  2020-12-02  2021-01
# 1258   02714    발산1동주민센터교차로  강서구  2020-03-17  2021-01
# 1174   01114  서남물재생센터 버스정류장  강서구  2017-04-24  2021-01
#
# [2921 rows x 5 columns]

# %% [markdown]
# - 시간대별 데이터, 대여소정보 데이터 에서 '대여소번호' 컬럼의 숫자 표현방식, 데이터 타입이 다르다.

# %% [markdown]
# - 따라서, 1. 시간대별 데이터(월~금 / 출퇴근 시간대 추출함)의 '대여소번호' 컬럼의 숫자를 object로 바꾸어준다.
#      ##### 2. 시간대별 데이터의 '대여소번호' 컬럼의 숫자를 00000 자리로 바꾸어준다.

# %%
df_2022_time.head()
# Out:
#            대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867 2022-12-01     7   1260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868 2022-12-01     7   1264             1264. 천호역 10번 출구 앞    정기권  None
# 5869 2022-12-01     7   1167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870 2022-12-01     7   1050              1050.  둔촌역 3번 출입구    정기권  None
# 5871 2022-12-01     7   1051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
#
#      연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867  ~10대     1 15.22 0.14    620.0        3       3  목  출근
# 5868  ~10대     1 14.26 0.14    600.0        3       3  목  출근
# 5869  ~10대     1  13.9 0.13    540.0        4       3  목  출근
# 5870  ~10대     1 24.97 0.23    970.0        4       3  목  출근
# 5871  ~10대     1 45.86 0.31  1346.65        8       3  목  출근

# %%
df_2022_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11460096 entries, 5867 to 36151172
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(6)
# memory usage: 1.3+ GB

# %%
df_2022_time.loc[:, '대여소번호'] = df_2022_time['대여소번호'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15492\1162110550.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['1260' '1264' '1167' ... '1946' '1925' '500']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_2022_time.loc[:, '대여소번호'] = df_2022_time['대여소번호'].astype(str)

# %%
df_2022_time.dtypes
# Out:
# 대여일자       datetime64[ns]
# 대여시간                int64
# 대여소번호              object
# 대여소명               object
# 대여구분코드             object
# 성별                 object
# 연령대코드              object
# 이용건수                int64
# 운동량               float64
# 탄소량               float64
# 이동거리(M)           float64
# 이용시간(분)             int64
# 요일_인덱스              int32
# 요일                 object
# 출퇴근                object
# dtype: object

# %%
df_2022_time.loc[:,'대여소번호'] = df_2022_time['대여소번호'].str.zfill(5)

# %%
df_2022_time.head()
# Out:
#            대여일자  대여시간  대여소번호                           대여소명 대여구분코드    성별  \
# 5867 2022-12-01     7  01260            1260. 방이동 한양3차아파트 옆    정기권  None
# 5868 2022-12-01     7  01264             1264. 천호역 10번 출구 앞    정기권  None
# 5869 2022-12-01     7  01167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 5870 2022-12-01     7  01050              1050.  둔촌역 3번 출입구    정기권  None
# 5871 2022-12-01     7  01051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
#
#      연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 5867  ~10대     1 15.22 0.14    620.0        3       3  목  출근
# 5868  ~10대     1 14.26 0.14    600.0        3       3  목  출근
# 5869  ~10대     1  13.9 0.13    540.0        4       3  목  출근
# 5870  ~10대     1 24.97 0.23    970.0        4       3  목  출근
# 5871  ~10대     1 45.86 0.31  1346.65        8       3  목  출근

# %%
df_sum = pd.merge(df_2022_time, df_st_1, on='대여소번호', how='left')
df_sum
# Out:
#                대여일자  대여시간  대여소번호                         대여소명_x 대여구분코드    성별  \
# 0        2022-12-01     7  01260            1260. 방이동 한양3차아파트 옆    정기권  None
# 1        2022-12-01     7  01264             1264. 천호역 10번 출구 앞    정기권  None
# 2        2022-12-01     7  01167           1167. 마곡수명산파크3단지 교차로    정기권  None
# 3        2022-12-01     7  01050              1050.  둔촌역 3번 출입구    정기권  None
# 4        2022-12-01     7  01051  1051. 강일중,선사고 버스정류장(신암중학교 방면)    정기권  None
# ...             ...   ...    ...                            ...    ...   ...
# 11460091 2022-11-30    19  02230                 2230.이수역 4번 출구    정기권     M
# 11460092 2022-11-30    19  00408                   408. LG CNS앞    정기권     M
# 11460093 2022-11-30    19  01946                   1946. 구로역 광장    정기권     M
# 11460094 2022-11-30    19  01925             1925. 동양미래대학교 정문 옆    정기권     M
# 11460095 2022-11-30    19  00500            500. 어린이대공원역 3번출구 앞    정기권     M
#
#          연령대코드  이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근  \
# 0         ~10대     1 15.22 0.14    620.0        3       3  목  출근
# 1         ~10대     1 14.26 0.14    600.0        3       3  목  출근
# 2         ~10대     1  13.9 0.13    540.0        4       3  목  출근
# 3         ~10대     1 24.97 0.23    970.0        4       3  목  출근
# 4         ~10대     1 45.86 0.31  1346.65        8       3  목  출근
# ...        ...   ...   ...  ...      ...      ...     ... ..  ..
# 11460091    기타     1 49.79 0.39  1676.59       67       2  수  퇴근
# 11460092    기타     1 33.19 0.29   1270.0        6       2  수  퇴근
# 11460093    기타     1 26.14  0.2    880.0        6       2  수  퇴근
# 11460094    기타     1 88.03 0.79   3420.0       16       2  수  퇴근
# 11460095    기타     1 47.74 0.32   1370.0       54       2  수  퇴근
#
#                            대여소명_y  자치구        설치시기   데이터등록월
# 0                   방이동 한양3차아파트 옆  송파구  2017-11-01  2024-06
# 1                    천호역 10번 출구 앞  송파구  2017-11-01  2024-06
# 2                  마곡수명산파크3단지 교차로  강서구  2017-12-22  2024-06
# 3                      둔촌역 3번 출입구  강동구  2018-02-26  2024-06
# 4         강일중,선사고 버스정류장(신암중학교 방면)  강동구  2018-02-26  2024-06
# ...                           ...  ...         ...      ...
# 11460091                이수역 4번 출구  서초구  2017-06-01  2024-06
# 11460092                  LG CNS앞  마포구  2015-10-07  2024-06
# 11460093                   구로역 광장  구로구  2017-06-22  2024-06
# 11460094             동양미래대학교 정문 옆  구로구  2017-06-27  2024-06
# 11460095           어린이대공원역 3번출구 앞  광진구  2015-10-07  2024-06
#
# [11460096 rows x 19 columns]

# %%
df_sum.isnull().sum() # 대여소명 null값 659개
# Out:
# 대여일자             0
# 대여시간             0
# 대여소번호            0
# 대여소명_x           0
# 대여구분코드           0
# 성별         3838066
# 연령대코드            0
# 이용건수             0
# 운동량          47643
# 탄소량          47643
# 이동거리(M)          0
# 이용시간(분)          0
# 요일_인덱스           0
# 요일               0
# 출퇴근              0
# 대여소명_y         659
# 자치구            659
# 설치시기           659
# 데이터등록월         659
# dtype: int64

# %%
group1 = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().reset_index()
group1
# Out:
#               대여소명_y 출퇴근   이용건수
# 0        (시립)고덕평생학습관  출근    904
# 1        (시립)고덕평생학습관  퇴근   1430
# 2       (재)FITI시험연구원  출근   4724
# 3       (재)FITI시험연구원  퇴근   5312
# 4      3호선 매봉역 3번출구앞  출근   4014
# ...              ...  ..    ...
# 5487         힐스테이트에코  퇴근  11534
# 5488  힐스테이트창경궁 아파트 앞  출근    928
# 5489  힐스테이트창경궁 아파트 앞  퇴근   1157
# 5490    힐스테이트클래시안아파트  출근   3082
# 5491    힐스테이트클래시안아파트  퇴근   1696
#
# [5492 rows x 3 columns]

# %% [markdown]
# - 출근 시간대 대여소별 이용건수

# %%
commute_data = group1[group1['출퇴근'] == '출근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data = commute_data.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data = top_20_commute_data.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
plt.barh(top_20_commute_data['대여소명_y'], top_20_commute_data['이용건수'])
plt.title('2022년 출근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# - 퇴근 시간대 대여소별 이용건수

# %%
commute_data_2 = group1[group1['출퇴근'] == '퇴근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data_2 = commute_data_2.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data_2 = top_20_commute_data_2.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
plt.barh(top_20_commute_data_2['대여소명_y'], top_20_commute_data_2['이용건수'])
plt.title('2022년 퇴근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# -------------------------------------------------
