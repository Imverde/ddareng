# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'
filename = '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2023'
df_2023 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 12.20274019241333

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2023)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  39993697             0          0.000000
# 1      대여시간  39993697             0          0.000000
# 2     대여소번호  39993697             0          0.000000
# 3      대여소명  39993697             0          0.000000
# 4    대여구분코드  39993697             0          0.000000
# 5        성별  27853187      12140510         30.356058
# 6     연령대코드  39993697             0          0.000000
# 7      이용건수  39993697             0          0.000000
# 8       운동량  39848716        144981          0.362510
# 9       탄소량  39848716        144981          0.362510
# 10  이동거리(M)  39993697             0          0.000000
# 11  이용시간(분)  39993697             0          0.000000

# %%
df_2023.head()
# Out:
#          대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0  2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1  2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2  2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3  2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4  2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#       운동량   탄소량  이동거리(M)  이용시간(분)
# 0   44.24  0.42  1831.45      8.0
# 1    7.11  0.06   276.06      4.0
# 2   25.05  0.24  1020.46      7.0
# 3   34.05  0.20   859.74      4.0
# 4  141.49  1.31  5675.10     78.0

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39993697 entries, 0 to 39993696
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 3.6+ GB

# %%
df_2023.describe()
# Out:
#                대여시간         대여소번호          이용건수           운동량           탄소량  \
# count  3.999370e+07  3.999370e+07  3.999370e+07  3.984872e+07  3.984872e+07
# mean   1.406418e+01  2.147385e+03  1.122777e+00  7.227186e+01  6.295088e-01
# std    5.782524e+00  1.545287e+03  4.594380e-01  9.474189e+01  7.992871e-01
# min    0.000000e+00  1.100000e+01  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    9.000000e+00  8.000000e+02  1.000000e+00  2.337000e+01  2.100000e-01
# 50%    1.500000e+01  1.726000e+03  1.000000e+00  4.202000e+01  3.700000e-01
# 75%    1.900000e+01  3.545000e+03  1.000000e+00  8.144000e+01  7.100000e-01
# max    2.300000e+01  9.980000e+03  3.800000e+01  1.784858e+04  1.608700e+02
#
#             이동거리(M)       이용시간(분)
# count  3.999370e+07  3.999370e+07
# mean   2.710990e+03  2.351612e+01
# std    3.446453e+03  2.979681e+01
# min    0.000000e+00  0.000000e+00
# 25%    9.000000e+02  6.000000e+00
# 50%    1.602720e+03  1.300000e+01
# 75%    3.070710e+03  2.900000e+01
# max    6.934180e+05  5.739000e+03

# %%
pd.options.display.float_format = '{:3}'.format

# %%
round(df_2023.describe(), 1)
# Out:
#             대여시간      대여소번호       이용건수        운동량        탄소량    이동거리(M)  \
# count 39993697.0 39993697.0 39993697.0 39848716.0 39848716.0 39993697.0
# mean        14.1     2147.4        1.1       72.3        0.6     2711.0
# std          5.8     1545.3        0.5       94.7        0.8     3446.5
# min          0.0       11.0        1.0        0.0        0.0        0.0
# 25%          9.0      800.0        1.0       23.4        0.2      900.0
# 50%         15.0     1726.0        1.0       42.0        0.4     1602.7
# 75%         19.0     3545.0        1.0       81.4        0.7     3070.7
# max         23.0     9980.0       38.0    17848.6      160.9   693418.0
#
#          이용시간(분)
# count 39993697.0
# mean        23.5
# std         29.8
# min          0.0
# 25%          6.0
# 50%         13.0
# 75%         29.0
# max       5739.0

# %%
df_2023.shape
# Out:
# (39993697, 12)

# %%
df_2023.isnull().sum()
# Out:
# 대여일자              0
# 대여시간              0
# 대여소번호             0
# 대여소명              0
# 대여구분코드            0
# 성별         12140510
# 연령대코드             0
# 이용건수              0
# 운동량          144981
# 탄소량          144981
# 이동거리(M)           0
# 이용시간(분)           0
# dtype: int64

# %%
df_2023['대여시간'].value_counts()
# Out:
# 대여시간
# 18    3682252
# 17    3127036
# 8     2727067
# 19    2720692
# 16    2464183
# 20    2332242
# 21    2124363
# 15    2032202
# 7     1924402
# 14    1820087
# 22    1798498
# 13    1783497
# 12    1774547
# 9     1734464
# 11    1606910
# 10    1408992
# 23    1195675
# 0      905703
# 6      864106
# 1      624178
# 5      415190
# 2      412158
# 3      283384
# 4      231869
# Name: count, dtype: int64

# %% [markdown]
# ## 1. 가설 1) 따릉이 최다 사용량이 출퇴근 시간이고

# %% [markdown]
# ### - 최다 사용량이 출퇴근 시간인 것을 확인한다.

# %% [markdown]
# - 대여일자 컬럼을 datetime 형식으로 변환

# %%
df_2023['대여일자'] = pd.to_datetime(df_2023['대여일자'], format='%Y-%m-%d')
# df_2020['대여시간'].astype('datetime64[ns]')

# %%
print(df_2023['대여일자'].dtype)
# Out:
# datetime64[ns]

# %%
df_2023.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)
# 0  44.24 0.42  1831.45      8.0
# 1   7.11 0.06   276.06      4.0
# 2  25.05 0.24  1020.46      7.0
# 3  34.05  0.2   859.74      4.0
# 4 141.49 1.31   5675.1     78.0

# %% [markdown]
# - datetime 형식으로 변경된 '대여일자' 컬럼에서 요일을 추출하여 새로운 컬럼으로 저장

# %%
# dt.weekday : 요일 정보를 숫자로 추출 
# 0 : 월요일, 1 : 화요일, .... 6 : 일요일
df_2023['요일_인덱스'] = df_2023['대여일자'].dt.weekday

# %%
df_2023.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스
# 0  44.24 0.42  1831.45      8.0       6
# 1   7.11 0.06   276.06      4.0       6
# 2  25.05 0.24  1020.46      7.0       6
# 3  34.05  0.2   859.74      4.0       6
# 4 141.49 1.31   5675.1     78.0       6

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df_2023['요일'] = df_2023.apply(lambda x : weekday_list[x['요일_인덱스']], axis=1)

# %%
df_2023.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0  44.24 0.42  1831.45      8.0       6  일
# 1   7.11 0.06   276.06      4.0       6  일
# 2  25.05 0.24  1020.46      7.0       6  일
# 3  34.05  0.2   859.74      4.0       6  일
# 4 141.49 1.31   5675.1     78.0       6  일

# %%
df_2023[['요일', '대여시간']].value_counts(ascending=False)
# Out:
# 요일  대여시간
# 월   18      618107
# 수   18      601533
# 금   18      601238
# 화   18      592667
# 목   18      578621
#              ...
# 금   4        33380
# 화   4        32805
# 수   4        31363
# 월   3        29581
#     4        27754
# Name: count, Length: 168, dtype: int64

# %%
grounded = df_2023.groupby(['요일', '대여시간'])['이용건수'].sum().unstack()
grounded
# Out:
# 대여시간       0        1       2       3       4       5        6        7   \
# 요일
# 금    133759.0  91370.0 58584.0 40473.0 34142.0 65184.0 149673.0 383018.0
# 목    138914.0  95226.0 61324.0 40483.0 34610.0 71762.0 167307.0 415710.0
# 수    125810.0  85411.0 54714.0 37436.0 32025.0 68881.0 159854.0 416491.0
# 월    113619.0  68251.0 43538.0 30628.0 28378.0 65437.0 147722.0 368782.0
# 일    164416.0 108103.0 74820.0 50532.0 34771.0 34601.0  50854.0  78422.0
# 토    168175.0 125231.0 84219.0 56174.0 40393.0 47108.0  72342.0 113097.0
# 화    129960.0  86778.0 54493.0 38032.0 33570.0 73350.0 167320.0 416929.0
#
# 대여시간       8        9   ...       14       15       16       17       18  \
# 요일                      ...
# 금    576630.0 299526.0  ... 281298.0 335632.0 416171.0 586130.0 725387.0
# 목    595936.0 291979.0  ... 242821.0 277273.0 384196.0 539849.0 707951.0
# 수    628777.0 313675.0  ... 256092.0 294530.0 374328.0 546919.0 738234.0
# 월    531899.0 281485.0  ... 274536.0 319727.0 409248.0 577403.0 761672.0
# 일    128723.0 171201.0  ... 341366.0 381037.0 411223.0 425629.0 393399.0
# 토    190351.0 230198.0  ... 335232.0 358759.0 391964.0 408463.0 386847.0
# 화    599403.0 301112.0  ... 247679.0 277433.0 389282.0 550542.0 726578.0
#
# 대여시간       19       20       21       22       23
# 요일
# 금    473031.0 381962.0 352154.0 318463.0 212500.0
# 목    470653.0 390103.0 360875.0 311691.0 190628.0
# 수    486130.0 406863.0 375600.0 317952.0 196196.0
# 월    511342.0 424148.0 372342.0 305594.0 184183.0
# 일    338286.0 306296.0 276997.0 222208.0 155586.0
# 토    339279.0 316457.0 302855.0 258765.0 193191.0
# 화    487007.0 407889.0 361114.0 299060.0 179339.0
#
# [7 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,6))
# plt.ticklabel_format(axis='y', useOffset=False, style='plain')  # y축(지수표시) - 일반 표시로 변경
sns.lineplot(x='대여시간', y='이용건수', hue='요일', data=df_2023, marker='o')
plt.title('2023년 대여시간에 따른 요일별 이용건수')
plt.xticks(range(0,24)) # = plt.xticks(np.arange(0,24,1))
plt.xlabel('대여시간')
plt.ylabel('이용건수')
plt.show()

# %% [markdown]
# ## 2. 가설 2) 출퇴근 시간에 따릉이 대여량이 최다인 대여소는 지하철역 인근 대여소일 것이다.

# %% [markdown]
# ### - 출퇴근 시간 대여소별 사용량 확인

# %% [markdown]
# - 요일 : 월~금요일 추출한다.

# %%
df_2023.head()
# Out:
#         대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0 2023-01-01     0    433         433. 을지로입구역 2번출구    정기권  None  ~10대   1.0
# 1 2023-01-01     0   2032         2032. 이수역 11번출구쪽    정기권  None  ~10대   1.0
# 2 2023-01-01     0    744          744. 신목동역 2번 출구    정기권  None   20대   1.0
# 3 2023-01-01     0   1029              1029. 성내어울터    정기권  None   20대   1.0
# 4 2023-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  None   20대   2.0
#
#      운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 0  44.24 0.42  1831.45      8.0       6  일
# 1   7.11 0.06   276.06      4.0       6  일
# 2  25.05 0.24  1020.46      7.0       6  일
# 3  34.05  0.2   859.74      4.0       6  일
# 4 141.49 1.31   5675.1     78.0       6  일

# %%
df_2023.count()
# Out:
# 대여일자       39993697
# 대여시간       39993697
# 대여소번호      39993697
# 대여소명       39993697
# 대여구분코드     39993697
# 성별         27853187
# 연령대코드      39993697
# 이용건수       39993697
# 운동량        39848716
# 탄소량        39848716
# 이동거리(M)    39993697
# 이용시간(분)    39993697
# 요일_인덱스     39993697
# 요일         39993697
# dtype: int64

# %%
#df_2020[(df_2020['요일'] != '토') & (df_2020['요일'] != '일')]
df_2023_day = df_2023[~(df_2023['요일'].isin(['토', '일']))]
df_2023_day
# Out:
#                대여일자  대여시간  대여소번호                   대여소명 대여구분코드    성별 연령대코드  \
# 36119    2023-01-02     0    954       954. 은평뉴타운구파발9단지    정기권  None  ~10대
# 36120    2023-01-02     0   1743  1743.창동19단지아파트 관리사무소앞    정기권  None  ~10대
# 36121    2023-01-02     0   3558     3558.마장동 금호어울림APT앞    정기권  None  ~10대
# 36122    2023-01-02     0   3904          3904. 테크노마트 앞    정기권  None  ~10대
# 36123    2023-01-02     0   3798     3798. 그랜드아이파크아파트 앞    정기권  None  ~10대
# ...             ...   ...    ...                    ...    ...   ...   ...
# 39950727 2023-12-29    23   1637   1637. KT 전화국 버스정류장 옆    정기권     M    기타
# 39950728 2023-12-29    23   1908      1908. 해원리바파크 육교 밑    정기권     M    기타
# 39950729 2023-12-29    23   1103        1103. 방화역 4번출구앞    정기권     M    기타
# 39950730 2023-12-29    23   1941        1941. 오류동역 2번출구    정기권     M    기타
# 39950731 2023-12-29    23    107        107. 신한은행 서교동지점    정기권     M    기타
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일
# 36119      1.0  28.0 0.23   1010.0      5.0       0  월
# 36120      1.0   4.1 0.03    150.0      2.0       0  월
# 36121      1.0 10.28 0.12   518.95      2.0       0  월
# 36122      1.0 57.98 0.52   2252.6     14.0       0  월
# 36123      1.0 82.08 0.76   3290.0     20.0       0  월
# ...        ...   ...  ...      ...      ...     ... ..
# 39950727   1.0 21.66 0.19   804.37     10.0       4  금
# 39950728   1.0   0.0  0.0      0.0      2.0       4  금
# 39950729   1.0 43.97 0.32  1388.06      7.0       4  금
# 39950730   1.0 44.93 0.24   1050.6      8.0       4  금
# 39950731   1.0 41.06 0.33   1440.0     15.0       4  금
#
# [30240905 rows x 14 columns]

# %% [markdown]
# - '출퇴근' 컬럼을 새로 만들어서 출근, 퇴근을 넣어준다. (월~금요일, 출퇴근)

# %%
df_2023_day.loc[df_2023_day['대여시간'].isin([7,8,9]),'출퇴근'] = '출근'
df_2023_day.loc[df_2023_day['대여시간'].isin([17,18,19]),'출퇴근'] = '퇴근'

# %%
df_2023_day
# Out:
#                대여일자  대여시간  대여소번호                   대여소명 대여구분코드    성별 연령대코드  \
# 36119    2023-01-02     0    954       954. 은평뉴타운구파발9단지    정기권  None  ~10대
# 36120    2023-01-02     0   1743  1743.창동19단지아파트 관리사무소앞    정기권  None  ~10대
# 36121    2023-01-02     0   3558     3558.마장동 금호어울림APT앞    정기권  None  ~10대
# 36122    2023-01-02     0   3904          3904. 테크노마트 앞    정기권  None  ~10대
# 36123    2023-01-02     0   3798     3798. 그랜드아이파크아파트 앞    정기권  None  ~10대
# ...             ...   ...    ...                    ...    ...   ...   ...
# 39950727 2023-12-29    23   1637   1637. KT 전화국 버스정류장 옆    정기권     M    기타
# 39950728 2023-12-29    23   1908      1908. 해원리바파크 육교 밑    정기권     M    기타
# 39950729 2023-12-29    23   1103        1103. 방화역 4번출구앞    정기권     M    기타
# 39950730 2023-12-29    23   1941        1941. 오류동역 2번출구    정기권     M    기타
# 39950731 2023-12-29    23    107        107. 신한은행 서교동지점    정기권     M    기타
#
#           이용건수   운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일  출퇴근
# 36119      1.0  28.0 0.23   1010.0      5.0       0  월  NaN
# 36120      1.0   4.1 0.03    150.0      2.0       0  월  NaN
# 36121      1.0 10.28 0.12   518.95      2.0       0  월  NaN
# 36122      1.0 57.98 0.52   2252.6     14.0       0  월  NaN
# 36123      1.0 82.08 0.76   3290.0     20.0       0  월  NaN
# ...        ...   ...  ...      ...      ...     ... ..  ...
# 39950727   1.0 21.66 0.19   804.37     10.0       4  금  NaN
# 39950728   1.0   0.0  0.0      0.0      2.0       4  금  NaN
# 39950729   1.0 43.97 0.32  1388.06      7.0       4  금  NaN
# 39950730   1.0 44.93 0.24   1050.6      8.0       4  금  NaN
# 39950731   1.0 41.06 0.33   1440.0     15.0       4  금  NaN
#
# [30240905 rows x 15 columns]

# %%
df_2023_day[df_2023_day['출퇴근'] == '출근'] # df_parquet[df_parquet['이용건수'] == '\\N']
# Out:
#                대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 40208    2023-01-02     7   1168   1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 40209    2023-01-02     7   1088      1088.풍납사거리(강동)    정기권  None  ~10대   1.0
# 40210    2023-01-02     7    726  726. 목동3단지 시내버스정류장    정기권  None  ~10대   1.0
# 40211    2023-01-02     7    748          748. 목동운동장    정기권  None   20대   1.0
# 40212    2023-01-02     7   1150      1150. 송정역 1번출구    정기권  None   20대   1.0
# ...             ...   ...    ...                 ...    ...   ...   ...   ...
# 39893798 2023-12-29     9   1013  1013. 강동구청역 1번 출입구    정기권     M    기타   1.0
# 39893799 2023-12-29     9    589        589. 성수역3번출구    정기권     M    기타   1.0
# 39893800 2023-12-29     9   1333      1333. 석관초등학교 앞    정기권     M    기타   1.0
# 39893801 2023-12-29     9   2105    2105. 미성동 신림체육센터    정기권     M    기타   1.0
# 39893802 2023-12-29     9    207   207. 여의나루역 1번출구 앞    정기권     M    기타   1.0
#
#            운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208    24.63 0.24  1036.67      5.0       0  월  출근
# 40209    39.05 0.39   1700.0      3.0       0  월  출근
# 40210    25.19 0.28   1200.0      8.0       0  월  출근
# 40211    18.18  0.2    850.0      5.0       0  월  출근
# 40212    31.66 0.29   1230.0      6.0       0  월  출근
# ...        ...  ...      ...      ...     ... ..  ..
# 39893798 43.16 0.25   1090.0     10.0       4  금  출근
# 39893799 16.25 0.13    540.0     31.0       4  금  출근
# 39893800 89.91  0.6   2580.0     15.0       4  금  출근
# 39893801  70.7 0.52   2260.0     14.0       4  금  출근
# 39893802 44.23 0.28  1213.91    123.0       4  금  출근
#
# [5517165 rows x 15 columns]

# %%
df_2023_day[df_2023_day['출퇴근'] == '퇴근']
# Out:
#                대여일자  대여시간  대여소번호                         대여소명 대여구분코드    성별  \
# 67029    2023-01-02    17    746                746. 목동2단지 상가    정기권  None
# 67030    2023-01-02    17   1450              1450. 화랑대역 7번출구    정기권  None
# 67031    2023-01-02    17   1180  1180. 마곡엠밸리 15단지(1502동) 건너편    정기권  None
# 67032    2023-01-02    17   1184                 1184. 마곡13단지    정기권  None
# 67033    2023-01-02    17   1197            1197. 엠펠리체 호텔 건너편    정기권  None
# ...             ...   ...    ...                          ...    ...   ...
# 39939620 2023-12-29    19   1924              1924. 삼부르네상스파크빌    정기권     M
# 39939621 2023-12-29    19    401          401. 상암월드컵파크 10단지 앞    정기권     M
# 39939622 2023-12-29    19   2242            2242.양재역 10번 출구 앞    정기권     M
# 39939623 2023-12-29    19   1955              1955. 디지털입구 교차로    정기권     M
# 39939624 2023-12-29    19   1640              1640. 한내근린공원 북측    정기권     M
#
#          연령대코드  이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 67029     ~10대   1.0  21.81 0.24  1019.99      6.0       0  월  퇴근
# 67030     ~10대   1.0  27.26 0.25  1059.13      7.0       0  월  퇴근
# 67031     ~10대   1.0  29.95 0.29  1260.48      7.0       0  월  퇴근
# 67032     ~10대   1.0  46.57 0.45   1960.0     13.0       0  월  퇴근
# 67033     ~10대   1.0  39.16 0.48   2060.0     15.0       0  월  퇴근
# ...        ...   ...    ...  ...      ...      ...     ... ..  ..
# 39939620    기타   1.0  25.78 0.22    930.0      7.0       4  금  퇴근
# 39939621    기타   1.0  60.62 0.55  2354.95     25.0       4  금  퇴근
# 39939622    기타   1.0  51.23 0.45   1960.0     98.0       4  금  퇴근
# 39939623    기타   1.0  27.55 0.27  1159.41      8.0       4  금  퇴근
# 39939624    기타   1.0 116.85 0.98  4215.24    106.0       4  금  퇴근
#
# [7499724 rows x 15 columns]

# %%
df_2023_day['출퇴근'].unique()
# Out:
# array([nan, '출근', '퇴근'], dtype=object)

# %%
df_2023_day['출퇴근'].value_counts()
# Out:
# 출퇴근
# 퇴근    7499724
# 출근    5517165
# Name: count, dtype: int64

# %%
df_2023_day.count()
# Out:
# 대여일자       30240905
# 대여시간       30240905
# 대여소번호      30240905
# 대여소명       30240905
# 대여구분코드     30240905
# 성별         21098207
# 연령대코드      30240905
# 이용건수       30240905
# 운동량        30127257
# 탄소량        30127257
# 이동거리(M)    30240905
# 이용시간(분)    30240905
# 요일_인덱스     30240905
# 요일         30240905
# 출퇴근        13016889
# dtype: int64

# %%
df_2023_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30240905 entries, 36119 to 39950731
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     float64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(6)
# memory usage: 3.5+ GB

# %%
df_2023_day['이용건수'] = df_2023_day['이용건수'].astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4688\1261299962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_day['이용건수'] = df_2023_day['이용건수'].astype(int)

# %%
df_2023_day['이용건수']
# Out:
# 36119       1
# 36120       1
# 36121       1
# 36122       1
# 36123       1
#            ..
# 39950727    1
# 39950728    1
# 39950729    1
# 39950730    1
# 39950731    1
# Name: 이용건수, Length: 30240905, dtype: int32

# %%
df_2023_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30240905 entries, 36119 to 39950731
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int32
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 3.4+ GB

# %%
df_2023_time = df_2023_day[~df_2023_day['출퇴근'].isnull()] # df_2020_day.dropna(subset=['출퇴근'])

# %%
df_2023_time
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드    성별 연령대코드  \
# 40208    2023-01-02     7   1168    1168. 마곡엠밸리10단지 앞    정기권  None  ~10대
# 40209    2023-01-02     7   1088       1088.풍납사거리(강동)    정기권  None  ~10대
# 40210    2023-01-02     7    726   726. 목동3단지 시내버스정류장    정기권  None  ~10대
# 40211    2023-01-02     7    748           748. 목동운동장    정기권  None   20대
# 40212    2023-01-02     7   1150       1150. 송정역 1번출구    정기권  None   20대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 39939620 2023-12-29    19   1924      1924. 삼부르네상스파크빌    정기권     M    기타
# 39939621 2023-12-29    19    401  401. 상암월드컵파크 10단지 앞    정기권     M    기타
# 39939622 2023-12-29    19   2242    2242.양재역 10번 출구 앞    정기권     M    기타
# 39939623 2023-12-29    19   1955      1955. 디지털입구 교차로    정기권     M    기타
# 39939624 2023-12-29    19   1640      1640. 한내근린공원 북측    정기권     M    기타
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208        1  24.63 0.24  1036.67      5.0       0  월  출근
# 40209        1  39.05 0.39   1700.0      3.0       0  월  출근
# 40210        1  25.19 0.28   1200.0      8.0       0  월  출근
# 40211        1  18.18  0.2    850.0      5.0       0  월  출근
# 40212        1  31.66 0.29   1230.0      6.0       0  월  출근
# ...        ...    ...  ...      ...      ...     ... ..  ..
# 39939620     1  25.78 0.22    930.0      7.0       4  금  퇴근
# 39939621     1  60.62 0.55  2354.95     25.0       4  금  퇴근
# 39939622     1  51.23 0.45   1960.0     98.0       4  금  퇴근
# 39939623     1  27.55 0.27  1159.41      8.0       4  금  퇴근
# 39939624     1 116.85 0.98  4215.24    106.0       4  금  퇴근
#
# [13016889 rows x 15 columns]

# %%
df_2023_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13016889 entries, 40208 to 39939624
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int32
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 1.5+ GB

# %%
df_2023_time.count()
# Out:
# 대여일자       13016889
# 대여시간       13016889
# 대여소번호      13016889
# 대여소명       13016889
# 대여구분코드     13016889
# 성별          9089976
# 연령대코드      13016889
# 이용건수       13016889
# 운동량        12961675
# 탄소량        12961675
# 이동거리(M)    13016889
# 이용시간(분)    13016889
# 요일_인덱스     13016889
# 요일         13016889
# 출퇴근        13016889
# dtype: int64

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본'
df_st = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 0.10308623313903809

# %%
df_st.head()
# Out:
#        대여소번호          대여소명  자치구                         상세주소          위도  \
# 20852  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216 37.54613495
# 19007  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트 37.62862015
# 19015  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97 37.63815689
# 19014  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.6588707
# 19013  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가 37.62186432
#
#                경도        설치시기  LCD   QR 운영방식   데이터등록월
# 20852 126.8210602  2024-03-18  NaN 10.0   QR  2024-06
# 19007 127.0669098  2020-03-24  NaN 12.0   QR  2024-06
# 19015 127.0732651  2020-03-23  NaN 20.0   QR  2024-06
# 19014 127.0719147  2020-03-23  NaN  7.0   QR  2024-06
# 19013 127.0740509  2020-03-25  NaN 10.0   QR  2024-06

# %%
df_st.info() # 대여소번호 int / object 다름.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2921 entries, 20852 to 1174
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   2921 non-null   object
#  1   대여소명    2921 non-null   object
#  2   자치구     2921 non-null   object
#  3   상세주소    2921 non-null   object
#  4   위도      2920 non-null   float64
#  5   경도      2920 non-null   float64
#  6   설치시기    2921 non-null   object
#  7   LCD     1517 non-null   float64
#  8   QR      1752 non-null   float64
#  9   운영방식    2921 non-null   object
#  10  데이터등록월  2921 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 273.8+ KB

# %%
df_st.shape
# Out:
# (2921, 11)

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

import ExcelFile_EDA as ee
ee.ss_isnull(df_st)
# Out:
#      [컬럼명]  [sum]  [sum_isnull]     [mean_isnull(%)]
# 0    대여소번호   2921             0                  0.0
# 1     대여소명   2921             0                  0.0
# 2      자치구   2921             0                  0.0
# 3     상세주소   2921             0                  0.0
# 4       위도   2920             1 0.034234851078397806
# 5       경도   2920             1 0.034234851078397806
# 6     설치시기   2921             0                  0.0
# 7      LCD   1517          1404    48.06573091407053
# 8       QR   1752          1169    40.02054091064704
# 9     운영방식   2921             0                  0.0
# 10  데이터등록월   2921             0                  0.0

# %%
df_st_1 = df_st[['대여소번호', '대여소명', '자치구', '설치시기', '데이터등록월']]
df_st_1
# Out:
#        대여소번호           대여소명  자치구        설치시기   데이터등록월
# 20852  06173    서울자동차운전전문학원  강서구  2024-03-18  2024-06
# 19007  02902   공릉풍림아파트 108동  노원구  2020-03-24  2024-06
# 19015  02912         대진고등학교  노원구  2020-03-23  2024-06
# 19014  02911        상계역중앙시장  노원구  2020-03-23  2024-06
# 19013  02910          도깨비시장  노원구  2020-03-25  2024-06
# ...      ...            ...  ...         ...      ...
# 1689   02200      관악문화원 건너편  관악구  2020-04-28  2021-01
# 1690   03304     낙성대역 5번 출구  관악구  2020-04-29  2021-01
# 1079   04205  디지털미디어씨티역2번출구  마포구  2020-12-02  2021-01
# 1258   02714    발산1동주민센터교차로  강서구  2020-03-17  2021-01
# 1174   01114  서남물재생센터 버스정류장  강서구  2017-04-24  2021-01
#
# [2921 rows x 5 columns]

# %% [markdown]
# - 시간대별 데이터, 대여소정보 데이터 에서 '대여소번호' 컬럼의 숫자 표현방식, 데이터 타입이 다르다.

# %% [markdown]
# - 따라서, 1. 시간대별 데이터(월~금 / 출퇴근 시간대 추출함)의 '대여소번호' 컬럼의 숫자를 object로 바꾸어준다.
#      ##### 2. 시간대별 데이터의 '대여소번호' 컬럼의 숫자를 00000 자리로 바꾸어준다.

# %%
df_2023_time.head()
# Out:
#             대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 40208 2023-01-02     7   1168   1168. 마곡엠밸리10단지 앞    정기권  None  ~10대     1
# 40209 2023-01-02     7   1088      1088.풍납사거리(강동)    정기권  None  ~10대     1
# 40210 2023-01-02     7    726  726. 목동3단지 시내버스정류장    정기권  None  ~10대     1
# 40211 2023-01-02     7    748          748. 목동운동장    정기권  None   20대     1
# 40212 2023-01-02     7   1150      1150. 송정역 1번출구    정기권  None   20대     1
#
#         운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208 24.63 0.24  1036.67      5.0       0  월  출근
# 40209 39.05 0.39   1700.0      3.0       0  월  출근
# 40210 25.19 0.28   1200.0      8.0       0  월  출근
# 40211 18.18  0.2    850.0      5.0       0  월  출근
# 40212 31.66 0.29   1230.0      6.0       0  월  출근

# %%
df_2023_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13016889 entries, 40208 to 39939624
# Data columns (total 15 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     datetime64[ns]
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int32
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  float64
#  12  요일_인덱스   int32
#  13  요일       object
#  14  출퇴근      object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 1.5+ GB

# %%
df_2023_time.loc[:, '대여소번호'] = df_2023_time['대여소번호'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4688\1857891113.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['1168' '1088' '726' ... '2242' '1955' '1640']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_2023_time.loc[:, '대여소번호'] = df_2023_time['대여소번호'].astype(str)

# %%
df_2023_time.dtypes
# Out:
# 대여일자       datetime64[ns]
# 대여시간                int64
# 대여소번호              object
# 대여소명               object
# 대여구분코드             object
# 성별                 object
# 연령대코드              object
# 이용건수                int32
# 운동량               float64
# 탄소량               float64
# 이동거리(M)           float64
# 이용시간(분)           float64
# 요일_인덱스              int32
# 요일                 object
# 출퇴근                object
# dtype: object

# %%
df_2023_time.loc[:,'대여소번호'] = df_2023_time['대여소번호'].str.zfill(5)

# %%
df_2023_time.head()
# Out:
#             대여일자  대여시간  대여소번호                대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 40208 2023-01-02     7  01168   1168. 마곡엠밸리10단지 앞    정기권  None  ~10대     1
# 40209 2023-01-02     7  01088      1088.풍납사거리(강동)    정기권  None  ~10대     1
# 40210 2023-01-02     7  00726  726. 목동3단지 시내버스정류장    정기권  None  ~10대     1
# 40211 2023-01-02     7  00748          748. 목동운동장    정기권  None   20대     1
# 40212 2023-01-02     7  01150      1150. 송정역 1번출구    정기권  None   20대     1
#
#         운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근
# 40208 24.63 0.24  1036.67      5.0       0  월  출근
# 40209 39.05 0.39   1700.0      3.0       0  월  출근
# 40210 25.19 0.28   1200.0      8.0       0  월  출근
# 40211 18.18  0.2    850.0      5.0       0  월  출근
# 40212 31.66 0.29   1230.0      6.0       0  월  출근

# %%
df_sum = pd.merge(df_2023_time, df_st_1, on='대여소번호', how='left')
df_sum
# Out:
#                대여일자  대여시간  대여소번호               대여소명_x 대여구분코드    성별 연령대코드  \
# 0        2023-01-02     7  01168    1168. 마곡엠밸리10단지 앞    정기권  None  ~10대
# 1        2023-01-02     7  01088       1088.풍납사거리(강동)    정기권  None  ~10대
# 2        2023-01-02     7  00726   726. 목동3단지 시내버스정류장    정기권  None  ~10대
# 3        2023-01-02     7  00748           748. 목동운동장    정기권  None   20대
# 4        2023-01-02     7  01150       1150. 송정역 1번출구    정기권  None   20대
# ...             ...   ...    ...                  ...    ...   ...   ...
# 13016884 2023-12-29    19  01924      1924. 삼부르네상스파크빌    정기권     M    기타
# 13016885 2023-12-29    19  00401  401. 상암월드컵파크 10단지 앞    정기권     M    기타
# 13016886 2023-12-29    19  02242    2242.양재역 10번 출구 앞    정기권     M    기타
# 13016887 2023-12-29    19  01955      1955. 디지털입구 교차로    정기권     M    기타
# 13016888 2023-12-29    19  01640      1640. 한내근린공원 북측    정기권     M    기타
#
#           이용건수    운동량  탄소량  이동거리(M)  이용시간(분)  요일_인덱스 요일 출퇴근          대여소명_y  \
# 0            1  24.63 0.24  1036.67      5.0       0  월  출근     마곡엠밸리10단지 앞
# 1            1  39.05 0.39   1700.0      3.0       0  월  출근       풍납사거리(강동)
# 2            1  25.19 0.28   1200.0      8.0       0  월  출근   목동3단지 시내버스정류장
# 3            1  18.18  0.2    850.0      5.0       0  월  출근           목동운동장
# 4            1  31.66 0.29   1230.0      6.0       0  월  출근        송정역 1번출구
# ...        ...    ...  ...      ...      ...     ... ..  ..             ...
# 13016884     1  25.78 0.22    930.0      7.0       4  금  퇴근       삼부르네상스파크빌
# 13016885     1  60.62 0.55  2354.95     25.0       4  금  퇴근  상암월드컵파크 10단지 앞
# 13016886     1  51.23 0.45   1960.0     98.0       4  금  퇴근    양재역 11번 출구 앞
# 13016887     1  27.55 0.27  1159.41      8.0       4  금  퇴근       디지털입구 교차로
# 13016888     1 116.85 0.98  4215.24    106.0       4  금  퇴근       한내근린공원 북측
#
#           자치구        설치시기   데이터등록월
# 0         강서구  2018-02-26  2024-06
# 1         강동구  2020-01-14  2024-06
# 2         양천구  2017-11-01  2024-06
# 3         양천구  2017-11-01  2024-06
# 4         강서구  2017-11-01  2024-06
# ...       ...         ...      ...
# 13016884  구로구  2017-05-11  2024-06
# 13016885  마포구  2015-10-07  2024-06
# 13016886  서초구  2017-06-01  2024-06
# 13016887  구로구  2017-07-27  2024-06
# 13016888  노원구  2017-08-30  2024-06
#
# [13016889 rows x 19 columns]

# %%
df_sum.isnull().sum() # 대여소 null값 59개
# Out:
# 대여일자             0
# 대여시간             0
# 대여소번호            0
# 대여소명_x           0
# 대여구분코드           0
# 성별         3926913
# 연령대코드            0
# 이용건수             0
# 운동량          55214
# 탄소량          55214
# 이동거리(M)          0
# 이용시간(분)          0
# 요일_인덱스           0
# 요일               0
# 출퇴근              0
# 대여소명_y          59
# 자치구             59
# 설치시기            59
# 데이터등록월          59
# dtype: int64

# %%
group1 = df_sum.groupby(['대여소명_y', '출퇴근'])['이용건수'].sum().reset_index()
group1
# Out:
#               대여소명_y 출퇴근  이용건수
# 0        (시립)고덕평생학습관  출근   831
# 1        (시립)고덕평생학습관  퇴근  1344
# 2       (재)FITI시험연구원  출근  6722
# 3       (재)FITI시험연구원  퇴근  5436
# 4      3호선 매봉역 3번출구앞  출근  4223
# ...              ...  ..   ...
# 5563         힐스테이트에코  퇴근  9633
# 5564  힐스테이트창경궁 아파트 앞  출근  1930
# 5565  힐스테이트창경궁 아파트 앞  퇴근  2226
# 5566    힐스테이트클래시안아파트  출근  3542
# 5567    힐스테이트클래시안아파트  퇴근  1642
#
# [5568 rows x 3 columns]

# %% [markdown]
# - 출근 시간대 대여소별 이용건수

# %%
commute_data = group1[group1['출퇴근'] == '출근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data = commute_data.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data = top_20_commute_data.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
plt.barh(top_20_commute_data['대여소명_y'], top_20_commute_data['이용건수'])
plt.title('2023년 출근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# - 퇴근 시간대 대여소별 이용건수

# %%
commute_data_2 = group1[group1['출퇴근'] == '퇴근']

# Creating a bar graph for the '출근' data
import matplotlib.pyplot as plt
top_20_commute_data_2 = commute_data_2.sort_values(by='이용건수', ascending=False).head(20)
top_20_commute_data_2 = top_20_commute_data_2.sort_values(by='이용건수', ascending=True)

plt.figure(figsize=(10,8))
plt.barh(top_20_commute_data_2['대여소명_y'], top_20_commute_data_2['이용건수'])
plt.title('2023년 퇴근 시간대 대여소별 이용건수')
plt.xlabel('대여소명')
plt.ylabel('이용건수')
plt.xticks(rotation=75)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# -------------------------------------------------
