# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\'
filename = '연도별 자치구별 출퇴근 이동인구 2020-2024.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 0.008733034133911133
#      연도 출퇴근  자치구         이동인구
# 0  2020  출근  강남구  42087137.37
# 1  2020  출근  강동구   8690787.78
# 2  2020  출근  강북구   4228968.36
# 3  2020  출근  강서구  12350053.62
# 4  2020  출근  관악구   6552387.52

# %%
df
# Out:
#        연도 출퇴근  자치구         이동인구
# 0    2020  출근  강남구  42087137.37
# 1    2020  출근  강동구   8690787.78
# 2    2020  출근  강북구   4228968.36
# 3    2020  출근  강서구  12350053.62
# 4    2020  출근  관악구   6552387.52
# ..    ...  ..  ...          ...
# 245  2024  퇴근  용산구   8638774.97
# 246  2024  퇴근  은평구  17598681.48
# 247  2024  퇴근  종로구   6011493.14
# 248  2024  퇴근   중구   4834166.40
# 249  2024  퇴근  중랑구  13623038.79
#
# [250 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      250 non-null    object
#  1   출퇴근     250 non-null    object
#  2   자치구     250 non-null    object
#  3   이동인구    250 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 7.9+ KB

# %%
df_year = df[df['연도'] == '2024']
df_year
# Out:
#        연도 출퇴근   자치구         이동인구
# 200  2024  출근   강남구  44904151.17
# 201  2024  출근   강동구  13038618.21
# 202  2024  출근   강북구   5803004.16
# 203  2024  출근   강서구  16328231.44
# 204  2024  출근   관악구   9282364.87
# 205  2024  출근   광진구   8434285.94
# 206  2024  출근   구로구  12075879.50
# 207  2024  출근   금천구  10620282.28
# 208  2024  출근   노원구  10627911.14
# 209  2024  출근   도봉구   5441955.65
# 210  2024  출근  동대문구  10208506.04
# 211  2024  출근   동작구   8000823.90
# 212  2024  출근   마포구  14644735.04
# 213  2024  출근  서대문구  11818650.13
# 214  2024  출근   서초구  27691565.02
# 215  2024  출근   성동구  12122873.31
# 216  2024  출근   성북구   9039584.48
# 217  2024  출근   송파구  23114998.50
# 218  2024  출근   양천구   7559775.59
# 219  2024  출근  영등포구  27080281.21
# 220  2024  출근   용산구  10252816.61
# 221  2024  출근   은평구   7996820.42
# 222  2024  출근   종로구  18857049.82
# 223  2024  출근    중구  26897204.03
# 224  2024  출근   중랑구   7404466.64
# 225  2024  퇴근   강남구  21597789.01
# 226  2024  퇴근   강동구  20950420.71
# 227  2024  퇴근   강북구  10508866.58
# 228  2024  퇴근   강서구  19318424.40
# 229  2024  퇴근   관악구  16472059.56
# 230  2024  퇴근   광진구  13623811.42
# 231  2024  퇴근   구로구  15256755.58
# 232  2024  퇴근   금천구   7458451.18
# 233  2024  퇴근   노원구  18504245.70
# 234  2024  퇴근   도봉구  10518450.35
# 235  2024  퇴근  동대문구  12609141.46
# 236  2024  퇴근   동작구  14423193.77
# 237  2024  퇴근   마포구  14261434.97
# 238  2024  퇴근  서대문구  12101423.98
# 239  2024  퇴근   서초구  16100046.09
# 240  2024  퇴근   성동구  11957803.98
# 241  2024  퇴근   성북구  16091017.02
# 242  2024  퇴근   송파구  26777253.97
# 243  2024  퇴근   양천구  13846689.39
# 244  2024  퇴근  영등포구  15722979.60
# 245  2024  퇴근   용산구   8638774.97
# 246  2024  퇴근   은평구  17598681.48
# 247  2024  퇴근   종로구   6011493.14
# 248  2024  퇴근    중구   4834166.40
# 249  2024  퇴근   중랑구  13623038.79

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'
save_name = '(folium)지도테마_자치구구분_출퇴근이동인구_이용량적은대여소_2024'

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# ### 자전거 대여소 정보

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일\\서울시 공공자전거 대여소 정보\\공공자전거 대여소 정보_통합본_최종.parquet')
rental.head()
# Out:
#    대여소번호          대여소명  자치구                         상세주소         위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216  37.546135
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트  37.628620
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97  37.638157
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.658871
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가  37.621864
#
#            경도        설치시기  LCD    QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  126.821060  2024-03-18  NaN  10.0   QR  2024-06  ST-3284   NaN
# 1  127.066910  2020-03-24  NaN  12.0   QR  2024-06  ST-2068   NaN
# 2  127.073265  2020-03-23  NaN  20.0   QR  2024-06  ST-2078   NaN
# 3  127.071915  2020-03-23  NaN   7.0   QR  2024-06  ST-2077   NaN
# 4  127.074051  2020-03-25  NaN  10.0   QR  2024-06     None   NaN

# %% [markdown]
# ### 자치구 정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %%
rental[rental['위도'].isnull()]
# Out:
#       대여소번호           대여소명  자치구            상세주소  위도  경도        설치시기  LCD  \
# 2918  04205  디지털미디어씨티역2번출구  마포구  마포구 상암동 1171-1 NaN NaN  2020-12-02  NaN
#
#         QR 운영방식   데이터등록월 대여소ID  거치대수
# 2918  10.0   QR  2021-01  None   NaN

# %% [markdown]
# ### 지하철역통합_20241031.parquet

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#      연번   역번호   호선    역명         역전화번호                      도로명주소  \
# 0   NaN  None  NaN  <NA>          <NA>                       <NA>
# 1   NaN  None  NaN  <NA>          <NA>                       <NA>
# 2  92.0   340  3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3   NaN  None  NaN  <NA>          <NA>                       <NA>
# 4   NaN  None  NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat         lng
# 0            943            419민주묘지  37.648235  127.008614
# 1            109                 가능  37.748577  127.044213
# 2            350               가락시장  37.492522  127.118234
# 3           P142            가산디지털단지  37.481072  126.882343
# 4            907                 가양  37.561391  126.854456

# %%
move = df_year.groupby('자치구')['이동인구'].sum().reset_index()
move
# Out:
#      자치구         이동인구
# 0    강남구  66501940.18
# 1    강동구  33989038.92
# 2    강북구  16311870.74
# 3    강서구  35646655.84
# 4    관악구  25754424.43
# 5    광진구  22058097.36
# 6    구로구  27332635.08
# 7    금천구  18078733.46
# 8    노원구  29132156.84
# 9    도봉구  15960406.00
# 10  동대문구  22817647.50
# 11   동작구  22424017.67
# 12   마포구  28906170.01
# 13  서대문구  23920074.11
# 14   서초구  43791611.11
# 15   성동구  24080677.29
# 16   성북구  25130601.50
# 17   송파구  49892252.47
# 18   양천구  21406464.98
# 19  영등포구  42803260.81
# 20   용산구  18891591.58
# 21   은평구  25595501.90
# 22   종로구  24868542.96
# 23    중구  31731370.43
# 24   중랑구  21027505.43

# %%
move.sort_values(ascending = False, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 move.sort_values(ascending = False, inplace = True)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
import ast

text = '"\ub3c4\ubd09\uad6c"'
decoded_text = ast.literal_eval(text)
print(decoded_text)
# Out:
# 도봉구

# %% [markdown]
# ### 이용량 적은 top10 대여소 선정하기

# %%
_year='2024'

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '서울특별시 공공자전거 대여이력 정보_' + _year + '_preprocessed.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 13.99517297744751
#        자전거번호 대여대여소번호           대여대여소명  대여거치대 반납대여소번호         반납대여소명 반납거치대  \
# 0  SPB-46712   04804          동서울농협 앞      0   01416       상봉역 3번출구     0
# 1  SPB-35089   04169           신대방삼거리      0   00251  서울지방병무청 버스정류장     0
# 2  SPB-36386   00540  군자역 7번출구 베스트샵 앞      0   03509       세종사이버대학교     0
# 3  SPB-61278   01139        용문사 버스정류장      0   00701       목동사거리 부근     0
# 4  SPB-36848   03416        동묘앞역 6번출구      0   00346         맥스타일 앞     0
#
#    이용시간(분)  이용거리(M)        대여일자      대여시간        반납일자      반납시간  \
# 0        1     0.00  2024-01-01  00:04:10  2024-01-01  00:05:13
# 1        6  1147.58  2024-01-01  00:00:10  2024-01-01  00:06:23
# 2        3   642.13  2024-01-01  00:03:13  2024-01-01  00:06:33
# 3        4   830.00  2024-01-01  00:02:42  2024-01-01  00:07:24
# 4        4   791.08  2024-01-01  00:03:02  2024-01-01  00:07:33
#
#             대여시간차  이용시간-대여시간차  이용속도(km/h)
# 0 0 days 00:01:03   -0.050000      0.0000
# 1 0 days 00:06:13   -0.216667     11.4758
# 2 0 days 00:03:20   -0.333333     12.8426
# 3 0 days 00:04:42   -0.700000     12.4500
# 4 0 days 00:04:31   -0.516667     11.8662

# %%
df.shape
# Out:
# (21621807, 16)

# %%
df.isnull().sum()
# Out:
# 자전거번호              0
# 대여대여소번호            0
# 대여대여소명             0
# 대여거치대              0
# 반납대여소번호        79037
# 반납대여소명         79037
# 반납거치대          93089
# 이용시간(분)            0
# 이용거리(M)            0
# 대여일자               0
# 대여시간               0
# 반납일자               0
# 반납시간               0
# 대여시간차              0
# 이용시간-대여시간차         0
# 이용속도(km/h)    542928
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#               자전거번호 대여대여소번호              대여대여소명  대여거치대 반납대여소번호  \
# 9         SPB-63233   01601  석계역 문화광장 내 자전거 보관소      0   01601
# 10        SPB-51653   05768               방이삼거리      0   05768
# 18        SPB-64748   00108             서교동 사거리      0   00108
# 50        SPB-53094   03774      마곡9단지 910동 상가앞      0   03774
# 55        SPB-30425   04217          한강공원 망원나들목      0   04217
# ...             ...     ...                 ...    ...     ...
# 22107533  SPB-60147   00931               역촌파출소      0    None
# 22107535  SPB-83444   00124          서강대 정문 건너편     99    None
# 22107536  SPB-52120   00334        종로3가역 2번출구 뒤      0    None
# 22107538  SPB-50402   03569              건대병원후문      0    None
# 22107539  SPB-56869   02547          반포래미안 리오센트      0    None
#
#                       반납대여소명 반납거치대  이용시간(분)  이용거리(M)        대여일자      대여시간  \
# 9         석계역 문화광장 내 자전거 보관소     0        0      0.0  2024-01-01  00:07:59
# 10                     방이삼거리     0        0      0.0  2024-01-01  00:07:49
# 18                   서교동 사거리     0        0      0.0  2024-01-01  00:08:39
# 50            마곡9단지 910동 상가앞     0        0      0.0  2024-01-01  00:12:36
# 55                한강공원 망원나들목     0        0      0.0  2024-01-01  00:13:23
# ...                      ...   ...      ...      ...         ...       ...
# 22107533                None  None       60   1345.0  2024-06-30  19:40:14
# 22107535                None  None       60   3633.0  2024-06-30  23:49:29
# 22107536                None  None       60   4348.0  2024-06-30  22:42:25
# 22107538                None  None      870    848.0  2024-06-30  23:57:41
# 22107539                None  None      870   2119.0  2024-06-30  18:35:04
#
#                 반납일자      반납시간           대여시간차   이용시간-대여시간차  이용속도(km/h)
# 9         2024-01-01  00:08:16 0 days 00:00:17    -0.283333         NaN
# 10        2024-01-01  00:08:25 0 days 00:00:36    -0.600000         NaN
# 18        2024-01-01  00:08:48 0 days 00:00:09    -0.150000         NaN
# 50        2024-01-01  00:12:45 0 days 00:00:09    -0.150000         NaN
# 55        2024-01-01  00:13:32 0 days 00:00:09    -0.150000         NaN
# ...              ...       ...             ...          ...         ...
# 22107533  2024-07-01  21:03:46 1 days 01:23:32 -1463.533333    1.345000
# 22107535  2024-07-02  11:24:17 1 days 11:34:48 -2074.800000    3.633000
# 22107536  2024-07-02  11:24:51 1 days 12:42:26 -2142.433333    4.348000
# 22107538  2024-07-02  13:00:21 1 days 13:02:40 -1352.666667    0.058483
# 22107539  2024-07-02  13:00:59 1 days 18:25:55 -1675.916667    0.146138
#
# [635315 rows x 16 columns]

# %%
df_rent = df.groupby(['대여대여소번호']).agg({
        '자전거번호': 'count'  # count를 이용해 이용량 계산
    }).rename(columns={'자전거번호': '대여수'}).reset_index()
df_rent = df_rent.rename(columns={'대여대여소번호': '대여소번호'})
df_rent
# Out:
#       대여소번호    대여수
# 0     00102  20551
# 1     00103  17263
# 2     00104  10534
# 3     00105   6501
# 4     00106  17556
# ...     ...    ...
# 2754  06059    517
# 2755  06171   7606
# 2756  06172   2096
# 2757  06173   1100
# 2758  09980     28
#
# [2759 rows x 2 columns]

# %%
df_return = df.groupby(['반납대여소번호']).agg({
        '자전거번호': 'count'  # count를 이용해 이용량 계산
    }).rename(columns={'자전거번호': '반납수'}).reset_index()
df_return = df_return.rename(columns={'반납대여소번호': '대여소번호'})
df_return
# Out:
#       대여소번호    반납수
# 0     00003    609
# 1     00005     48
# 2     00102  21752
# 3     00103  19172
# 4     00104   9037
# ...     ...    ...
# 2763  09993      1
# 2764  09997    121
# 2765  09998     78
# 2766  09999      1
# 2767  88888     47
#
# [2768 rows x 2 columns]

# %%
use = pd.merge(df_rent, df_return, on='대여소번호', how='left')
use
# Out:
#       대여소번호    대여수    반납수
# 0     00102  20551  21752
# 1     00103  17263  19172
# 2     00104  10534   9037
# 3     00105   6501   5414
# 4     00106  17556  17439
# ...     ...    ...    ...
# 2754  06059    517    530
# 2755  06171   7606   7271
# 2756  06172   2096   2022
# 2757  06173   1100   1084
# 2758  09980     28     15
#
# [2759 rows x 3 columns]

# %%
use['총이용량'] = use['대여수'] + use['반납수']
use
# Out:
#       대여소번호    대여수    반납수   총이용량
# 0     00102  20551  21752  42303
# 1     00103  17263  19172  36435
# 2     00104  10534   9037  19571
# 3     00105   6501   5414  11915
# 4     00106  17556  17439  34995
# ...     ...    ...    ...    ...
# 2754  06059    517    530   1047
# 2755  06171   7606   7271  14877
# 2756  06172   2096   2022   4118
# 2757  06173   1100   1084   2184
# 2758  09980     28     15     43
#
# [2759 rows x 4 columns]

# %%
use.loc[use['대여소번호'] == '01868']
# Out:
#       대여소번호   대여수   반납수  총이용량
# 1264  01868  2336  2197  4533

# %%
lowest_usage_11 = use.nsmallest(11, '총이용량')
lowest_usage_11
# Out:
#       대여소번호  대여수  반납수  총이용량
# 1220  01816    8    5    13
# 2758  09980   28   15    43
# 2284  04314  121   33   154
# 2299  04335  127   39   166
# 1509  02286  174   51   225
# 2305  04343  127  148   275
# 1848  03306  185   96   281
# 1595  02391  181  120   301
# 2302  04338  247  110   357
# 2339  04426  180  192   372
# 1911  03538  187  194   381

# %%
merge = pd.merge(lowest_usage_11, rental, on='대여소번호', how='left')
merge
# Out:
#     대여소번호  대여수  반납수  총이용량               대여소명  자치구  \
# 0   01816    8    5    13           금천폭포공원 앞  금천구
# 1   09980   28   15    43                NaN  NaN
# 2   04314  121   33   154       탑성마을 버스정거장 옆  서초구
# 3   04335  127   39   166          인재개발원 배움관  서초구
# 4   02286  174   51   225             탑성마을입구  서초구
# 5   04343  127  148   275             헌인릉 입구  서초구
# 6   03306  185   96   281           서울신우초등학교  관악구
# 7   02391  181  120   301  구룡터널 입구(개포1단지아파트)  강남구
# 8   04338  247  110   357      새정이마을 버스정류장 앞  서초구
# 9   04426  180  192   372         천주교 보문동 성당  성북구
# 10  03538  187  194   381           서울숲 IT캐슬  성동구
#
#                            상세주소         위도          경도        설치시기   LCD  \
# 0          서울특별시 금천구 시흥대로38길 61  37.446861  126.903831  2017-05-08  14.0
# 1                           NaN        NaN         NaN         NaN   NaN
# 2                    염곡동 189-19  37.459167  127.055443  2021-02-19   NaN
# 3                   서초구 서초동 391  37.479755  127.019852  2022-10-14   NaN
# 4              서울특별시 서초구 탑성말길 2  37.458549  127.055885  2017-11-28   7.0
# 5                서초구 내곡동 1-3244  37.460663  127.081299  2023-08-18   NaN
# 6                       호암로 498  37.462147  126.931778  2020-04-28   NaN
# 7                 강남구 개포동 146-1  37.475986  127.059624  2018-10-08   7.0
# 8                     서초구 새정길 4  37.434746  127.065949  2023-03-02   NaN
# 9                    성북구 보문로 75  37.582047  127.020996  2024-06-17   NaN
# 10  서울특별시 성동구 광나루로 130 서울숲 IT캐슬  37.550892  127.044762  2018-10-29   9.0
#
#       QR 운영방식   데이터등록월    대여소ID  거치대수
# 0    NaN  LCD  2024-06     None   NaN
# 1    NaN  NaN      NaN      NaN   NaN
# 2   10.0   QR  2024-06     None   NaN
# 3   24.0   QR  2023-12     None   NaN
# 4    NaN  LCD  2024-06  ST-1312   NaN
# 5    5.0   QR  2024-06  ST-3257   NaN
# 6   10.0   QR  2024-06     None   NaN
# 7    NaN  LCD  2024-06  ST-1561   NaN
# 8    5.0   QR  2024-06  ST-3216   NaN
# 9    8.0   QR  2024-06     None   NaN
# 10   NaN  LCD  2024-06     None   NaN

# %% [markdown]
# ### 두번째로 이용량 적은 대여소(09980). 대여소 정보 없음. 2024년 6월 대여소 정보에 없음.
# ### 따라서 사라진 것으로 추정되어 제외함

# %%
merge_2 = merge.drop(index=[1])
merge_2.reset_index()
merge_2
# Out:
#     대여소번호  대여수  반납수  총이용량               대여소명  자치구  \
# 0   01816    8    5    13           금천폭포공원 앞  금천구
# 2   04314  121   33   154       탑성마을 버스정거장 옆  서초구
# 3   04335  127   39   166          인재개발원 배움관  서초구
# 4   02286  174   51   225             탑성마을입구  서초구
# 5   04343  127  148   275             헌인릉 입구  서초구
# 6   03306  185   96   281           서울신우초등학교  관악구
# 7   02391  181  120   301  구룡터널 입구(개포1단지아파트)  강남구
# 8   04338  247  110   357      새정이마을 버스정류장 앞  서초구
# 9   04426  180  192   372         천주교 보문동 성당  성북구
# 10  03538  187  194   381           서울숲 IT캐슬  성동구
#
#                            상세주소         위도          경도        설치시기   LCD  \
# 0          서울특별시 금천구 시흥대로38길 61  37.446861  126.903831  2017-05-08  14.0
# 2                    염곡동 189-19  37.459167  127.055443  2021-02-19   NaN
# 3                   서초구 서초동 391  37.479755  127.019852  2022-10-14   NaN
# 4              서울특별시 서초구 탑성말길 2  37.458549  127.055885  2017-11-28   7.0
# 5                서초구 내곡동 1-3244  37.460663  127.081299  2023-08-18   NaN
# 6                       호암로 498  37.462147  126.931778  2020-04-28   NaN
# 7                 강남구 개포동 146-1  37.475986  127.059624  2018-10-08   7.0
# 8                     서초구 새정길 4  37.434746  127.065949  2023-03-02   NaN
# 9                    성북구 보문로 75  37.582047  127.020996  2024-06-17   NaN
# 10  서울특별시 성동구 광나루로 130 서울숲 IT캐슬  37.550892  127.044762  2018-10-29   9.0
#
#       QR 운영방식   데이터등록월    대여소ID  거치대수
# 0    NaN  LCD  2024-06     None   NaN
# 2   10.0   QR  2024-06     None   NaN
# 3   24.0   QR  2023-12     None   NaN
# 4    NaN  LCD  2024-06  ST-1312   NaN
# 5    5.0   QR  2024-06  ST-3257   NaN
# 6   10.0   QR  2024-06     None   NaN
# 7    NaN  LCD  2024-06  ST-1561   NaN
# 8    5.0   QR  2024-06  ST-3216   NaN
# 9    8.0   QR  2024-06     None   NaN
# 10   NaN  LCD  2024-06     None   NaN

# %%
merge_2['합친컬럼'] = merge_2['대여소명'] + '\n' +' (' + merge_2['자치구'] + ') '
merge_2
# Out:
#     대여소번호  대여수  반납수  총이용량               대여소명  자치구  \
# 0   01816    8    5    13           금천폭포공원 앞  금천구
# 2   04314  121   33   154       탑성마을 버스정거장 옆  서초구
# 3   04335  127   39   166          인재개발원 배움관  서초구
# 4   02286  174   51   225             탑성마을입구  서초구
# 5   04343  127  148   275             헌인릉 입구  서초구
# 6   03306  185   96   281           서울신우초등학교  관악구
# 7   02391  181  120   301  구룡터널 입구(개포1단지아파트)  강남구
# 8   04338  247  110   357      새정이마을 버스정류장 앞  서초구
# 9   04426  180  192   372         천주교 보문동 성당  성북구
# 10  03538  187  194   381           서울숲 IT캐슬  성동구
#
#                            상세주소         위도          경도        설치시기   LCD  \
# 0          서울특별시 금천구 시흥대로38길 61  37.446861  126.903831  2017-05-08  14.0
# 2                    염곡동 189-19  37.459167  127.055443  2021-02-19   NaN
# 3                   서초구 서초동 391  37.479755  127.019852  2022-10-14   NaN
# 4              서울특별시 서초구 탑성말길 2  37.458549  127.055885  2017-11-28   7.0
# 5                서초구 내곡동 1-3244  37.460663  127.081299  2023-08-18   NaN
# 6                       호암로 498  37.462147  126.931778  2020-04-28   NaN
# 7                 강남구 개포동 146-1  37.475986  127.059624  2018-10-08   7.0
# 8                     서초구 새정길 4  37.434746  127.065949  2023-03-02   NaN
# 9                    성북구 보문로 75  37.582047  127.020996  2024-06-17   NaN
# 10  서울특별시 성동구 광나루로 130 서울숲 IT캐슬  37.550892  127.044762  2018-10-29   9.0
#
#       QR 운영방식   데이터등록월    대여소ID  거치대수                        합친컬럼
# 0    NaN  LCD  2024-06     None   NaN           금천폭포공원 앞\n (금천구)
# 2   10.0   QR  2024-06     None   NaN       탑성마을 버스정거장 옆\n (서초구)
# 3   24.0   QR  2023-12     None   NaN          인재개발원 배움관\n (서초구)
# 4    NaN  LCD  2024-06  ST-1312   NaN             탑성마을입구\n (서초구)
# 5    5.0   QR  2024-06  ST-3257   NaN             헌인릉 입구\n (서초구)
# 6   10.0   QR  2024-06     None   NaN           서울신우초등학교\n (관악구)
# 7    NaN  LCD  2024-06  ST-1561   NaN  구룡터널 입구(개포1단지아파트)\n (강남구)
# 8    5.0   QR  2024-06  ST-3216   NaN      새정이마을 버스정류장 앞\n (서초구)
# 9    8.0   QR  2024-06     None   NaN         천주교 보문동 성당\n (성북구)
# 10   NaN  LCD  2024-06     None   NaN           서울숲 IT캐슬\n (성동구)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
bars = plt.bar(merge_2['합친컬럼'], merge_2['총이용량'], color='skyblue')
plt.xlabel('대여소명')
plt.ylabel('총이용량')
plt.title('2024년 대여소별 총이용량 적은 10개 대여소')
plt.xticks(rotation=45, ha='right')

# Add 'Total Usage' labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height,
             f'{height:,.0f}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# import folium
# import pandas as pd
# import json
# import webbrowser

# # 지도 생성
# center = [37.541, 126.986]
# bike_map = folium.Map(location=center, zoom_start=13, tiles='openstreetmap', name='OpenStreetMap')

# # 상위 10개와 20개 데이터로 나누기
# top_10 = top_20.nlargest(10, '퇴근반납수-출근대여수')
# top_10_ids = top_10.index  # 상위 10개의 인덱스를 가져와서 색상 구분에 사용

# fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)

# # 자전거 대여소 표시 (원 크기를 '퇴근반납수-출근대여수' 값에 비례하여 설정)
# max_value = top_20['퇴근반납수-출근대여수'].max()  # '퇴근반납수-출근대여수'의 최대값
# min_radius, max_radius = 10, 1000  # 최소 및 최대 원 크기

# seq = 1
# for i, row in top_20.iterrows():
#     # '퇴근반납수-출근대여수' 값을 원 크기로 변환
#     radius = min_radius + (row['퇴근반납수-출근대여수'] / max_value) * (max_radius - min_radius)
    
#     # 색상 설정: 상위 10개 대여소는 빨간색, 나머지는 파란색
#     fill_color = 'coral' if i in top_10_ids else 'turquoise'
    
#     folium.Circle(
#         location=[row['위도'], row['경도']],
#         radius=radius,
#         color='black',
#         fill=True,
#         fill_color=fill_color,
#         fill_opacity=0.9,
#         popup=row['대여소번호'],
#         tooltip=str(seq) + '. ' + row['대여소명']
#     ).add_to(fg1)

#     seq = seq + 1

# # 자치구 구분 JSON 파일 로드
# geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))

# # Choropleth 생성
# choropleth = folium.Choropleth(
#     geo_data=geo_str2,
#     data=move,
#     columns=['자치구', '이동인구'],
#     key_on='feature.properties.SIG_KOR_NM',
#     fill_color='BuGn',
#     fill_opacity=0.3
# )

# # GeoJsonPopup 추가
# folium.GeoJsonPopup(fields=['SIG_KOR_NM'], aliases=['지역:'], style='font-weight: bold;').add_to(choropleth.geojson)

# # Choropleth를 지도에 추가
# choropleth.add_to(bike_map)

# # 타일 레이어 및 레이어 컨트롤 추가
# folium.TileLayer('cartodbpositron', name='CartoDB Positron').add_to(bike_map)
# folium.TileLayer('cartodbdark_matter', name='CartoDB Dark Matter').add_to(bike_map)
# folium.LayerControl().add_to(bike_map)

# # 지도 저장 및 웹 브라우저에서 열기
# save_name = "(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2024"
# bike_map.save(save_name + ".html")
# webbrowser.open(save_name + ".html")
# Out:
# True
