# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\'
filename = '연도별 자치구별 출퇴근 이동인구 2020-2024.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 0.0323793888092041
#      연도 출퇴근  자치구         이동인구
# 0  2020  출근  강남구  42087137.37
# 1  2020  출근  강동구   8690787.78
# 2  2020  출근  강북구   4228968.36
# 3  2020  출근  강서구  12350053.62
# 4  2020  출근  관악구   6552387.52

# %%
df
# Out:
#        연도 출퇴근  자치구         이동인구
# 0    2020  출근  강남구  42087137.37
# 1    2020  출근  강동구   8690787.78
# 2    2020  출근  강북구   4228968.36
# 3    2020  출근  강서구  12350053.62
# 4    2020  출근  관악구   6552387.52
# ..    ...  ..  ...          ...
# 245  2024  퇴근  용산구   8638774.97
# 246  2024  퇴근  은평구  17598681.48
# 247  2024  퇴근  종로구   6011493.14
# 248  2024  퇴근   중구   4834166.40
# 249  2024  퇴근  중랑구  13623038.79
#
# [250 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      250 non-null    object
#  1   출퇴근     250 non-null    object
#  2   자치구     250 non-null    object
#  3   이동인구    250 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 7.9+ KB

# %%
# 2021년부터 2024년까지의 데이터만 필터링
filtered_df = df[(df['연도'] >= '2021') & (df['연도'] <= '2024')]
filtered_df
# 자치구별로 '이동인구' 합계 계산
df_year = filtered_df.groupby('자치구')['이동인구'].sum().reset_index()
df_year
# Out:
#      자치구          이동인구
# 0    강남구  3.455090e+08
# 1    강동구  1.720160e+08
# 2    강북구  8.727530e+07
# 3    강서구  1.830385e+08
# 4    관악구  1.335957e+08
# 5    광진구  1.153812e+08
# 6    구로구  1.438451e+08
# 7    금천구  9.770442e+07
# 8    노원구  1.544253e+08
# 9    도봉구  8.286289e+07
# 10  동대문구  1.201531e+08
# 11   동작구  1.178883e+08
# 12   마포구  1.535210e+08
# 13  서대문구  1.233598e+08
# 14   서초구  2.286345e+08
# 15   성동구  1.275411e+08
# 16   성북구  1.311045e+08
# 17   송파구  2.607269e+08
# 18   양천구  1.145599e+08
# 19  영등포구  2.235431e+08
# 20   용산구  1.018436e+08
# 21   은평구  1.319481e+08
# 22   종로구  1.332255e+08
# 23    중구  1.635335e+08
# 24   중랑구  1.110031e+08

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'
save_name = '(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2021~2024'

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# ### 자전거 대여소 정보

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일\\서울시 공공자전거 대여소 정보\\공공자전거 대여소 정보_통합본_최종.parquet')
rental.head()
# Out:
#    대여소번호          대여소명  자치구                         상세주소         위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216  37.546135
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트  37.628620
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97  37.638157
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.658871
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가  37.621864
#
#            경도        설치시기  LCD    QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  126.821060  2024-03-18  NaN  10.0   QR  2024-06  ST-3284   NaN
# 1  127.066910  2020-03-24  NaN  12.0   QR  2024-06  ST-2068   NaN
# 2  127.073265  2020-03-23  NaN  20.0   QR  2024-06  ST-2078   NaN
# 3  127.071915  2020-03-23  NaN   7.0   QR  2024-06  ST-2077   NaN
# 4  127.074051  2020-03-25  NaN  10.0   QR  2024-06     None   NaN

# %% [markdown]
# ### 자치구 정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %%
rental[rental['위도'].isnull()]
# Out:
#       대여소번호           대여소명  자치구            상세주소  위도  경도        설치시기  LCD  \
# 2918  04205  디지털미디어씨티역2번출구  마포구  마포구 상암동 1171-1 NaN NaN  2020-12-02  NaN
#
#         QR 운영방식   데이터등록월 대여소ID  거치대수
# 2918  10.0   QR  2021-01  None   NaN

# %% [markdown]
# ### 지하철역통합_20241031.parquet

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#      연번   역번호   호선    역명         역전화번호                      도로명주소  \
# 0   NaN  None  NaN  <NA>          <NA>                       <NA>
# 1   NaN  None  NaN  <NA>          <NA>                       <NA>
# 2  92.0   340  3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3   NaN  None  NaN  <NA>          <NA>                       <NA>
# 4   NaN  None  NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat         lng
# 0            943            419민주묘지  37.648235  127.008614
# 1            109                 가능  37.748577  127.044213
# 2            350               가락시장  37.492522  127.118234
# 3           P142            가산디지털단지  37.481072  126.882343
# 4            907                 가양  37.561391  126.854456

# %%
move = df_year.groupby('자치구')['이동인구'].sum().reset_index()
move
# Out:
#      자치구          이동인구
# 0    강남구  3.455090e+08
# 1    강동구  1.720160e+08
# 2    강북구  8.727530e+07
# 3    강서구  1.830385e+08
# 4    관악구  1.335957e+08
# 5    광진구  1.153812e+08
# 6    구로구  1.438451e+08
# 7    금천구  9.770442e+07
# 8    노원구  1.544253e+08
# 9    도봉구  8.286289e+07
# 10  동대문구  1.201531e+08
# 11   동작구  1.178883e+08
# 12   마포구  1.535210e+08
# 13  서대문구  1.233598e+08
# 14   서초구  2.286345e+08
# 15   성동구  1.275411e+08
# 16   성북구  1.311045e+08
# 17   송파구  2.607269e+08
# 18   양천구  1.145599e+08
# 19  영등포구  2.235431e+08
# 20   용산구  1.018436e+08
# 21   은평구  1.319481e+08
# 22   종로구  1.332255e+08
# 23    중구  1.635335e+08
# 24   중랑구  1.110031e+08

# %%
move.sort_values(ascending = False, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 move.sort_values(ascending = False, inplace = True)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
import ast

text = '"\ub3c4\ubd09\uad6c"'
decoded_text = ast.literal_eval(text)
print(decoded_text)
# Out:
# 도봉구

# %% [markdown]
# ### 출근대여 퇴근반납 차

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '평일출퇴근대여반납차이_2021_2024.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 0.015518426895141602
#    대여소번호   출근대여수   출근반납수   퇴근대여수   퇴근반납수         대여소명                상세주소  \
# 0  00003     2.0   233.0    16.0     NaN         None                None
# 1  00005     NaN    46.0     1.0     NaN         None                None
# 2  00010     2.0     2.0   140.0   138.0         None                None
# 3  00101    63.0    10.0    69.0    84.0  (구)합정동 주민센터  서울특별시 마포구 동교로8길 58
# 4  00102  1362.0  1534.0  3219.0  4047.0   망원역 1번출구 앞   서울특별시 마포구 월드컵로 72
#
#           위도          경도    연도
# 0        NaN         NaN  2021
# 1        NaN         NaN  2021
# 2        NaN         NaN  2021
# 3  37.549561  126.905754  2021
# 4  37.555649  126.910629  2021

# %%
df.shape
# Out:
# (10824, 10)

# %%
df.isnull().sum()
# Out:
# 대여소번호     0
# 출근대여수    36
# 출근반납수    26
# 퇴근대여수    21
# 퇴근반납수    21
# 대여소명     47
# 상세주소     47
# 위도       48
# 경도       48
# 연도        0
# dtype: int64

# %%
df = df.dropna(subset=['대여소명', '위도', '경도', '출근대여수', '퇴근반납수'])
df
# Out:
#        대여소번호   출근대여수   출근반납수   퇴근대여수   퇴근반납수         대여소명                상세주소  \
# 3      00101    63.0    10.0    69.0    84.0  (구)합정동 주민센터  서울특별시 마포구 동교로8길 58
# 4      00102  1362.0  1534.0  3219.0  4047.0   망원역 1번출구 앞   서울특별시 마포구 월드컵로 72
# 5      00103   836.0   936.0  2388.0  2994.0   망원역 2번출구 앞   서울특별시 마포구 월드컵로 79
# 6      00104   492.0   947.0  1725.0  1416.0   합정역 1번출구 앞    서울특별시 마포구 양화로 59
# 7      00105   239.0   477.0  1064.0   975.0   합정역 5번출구 앞    서울특별시 마포구 양화로 48
# ...      ...     ...     ...     ...     ...          ...                 ...
# 10815  06058   380.0   305.0   916.0  1098.0  서울도시건축전시관 옆         중구 세종대로 101
# 10816  06059    54.0    53.0    63.0    58.0        덕수중학교      중구 인현동2가 240-2
# 10817  06171   411.0   224.0   765.0   961.0       월드빌딩 앞          화곡동 1066-8
# 10818  06172   365.0   169.0   145.0   311.0     가양5단지아파트         강서구 가양동1481
# 10819  06173    11.0   192.0   138.0   108.0  서울자동차운전전문학원       강서구 남부순환로 216
#
#               위도          경도    연도
# 3      37.549561  126.905754  2021
# 4      37.555649  126.910629  2021
# 5      37.554951  126.910835  2021
# 6      37.550629  126.914986  2021
# 7      37.550007  126.914825  2021
# ...          ...         ...   ...
# 10815  37.566540  126.976845  2024
# 10816  37.564392  126.997299  2024
# 10817  37.540981  126.837433  2024
# 10818  37.564480  126.854645  2024
# 10819  37.546135  126.821060  2024
#
# [10762 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# 대여소번호     0
# 출근대여수     0
# 출근반납수    10
# 퇴근대여수     0
# 퇴근반납수     0
# 대여소명      0
# 상세주소      0
# 위도        0
# 경도        0
# 연도        0
# dtype: int64

# %%
year_sum = df.groupby('대여소번호')[['출근대여수', '퇴근반납수']].sum().reset_index()
year_sum
# Out:
#       대여소번호   출근대여수    퇴근반납수
# 0     00101    63.0     84.0
# 1     00102  6656.0  16790.0
# 2     00103  3117.0  13317.0
# 3     00104  2607.0   6669.0
# 4     00105   917.0   4365.0
# ...     ...     ...      ...
# 2909  06058   380.0   1098.0
# 2910  06059    54.0     58.0
# 2911  06171   447.0   1087.0
# 2912  06172   365.0    311.0
# 2913  06173    11.0    108.0
#
# [2914 rows x 3 columns]

# %%
year_sum['퇴근반납수-출근대여수'] = year_sum['퇴근반납수'] - year_sum['출근대여수']
year_sum
# Out:
#       대여소번호   출근대여수    퇴근반납수  퇴근반납수-출근대여수
# 0     00101    63.0     84.0         21.0
# 1     00102  6656.0  16790.0      10134.0
# 2     00103  3117.0  13317.0      10200.0
# 3     00104  2607.0   6669.0       4062.0
# 4     00105   917.0   4365.0       3448.0
# ...     ...     ...      ...          ...
# 2909  06058   380.0   1098.0        718.0
# 2910  06059    54.0     58.0          4.0
# 2911  06171   447.0   1087.0        640.0
# 2912  06172   365.0    311.0        -54.0
# 2913  06173    11.0    108.0         97.0
#
# [2914 rows x 4 columns]

# %%
year_sum_top_20 = year_sum.nlargest(20, '퇴근반납수-출근대여수')
year_sum_top_20
# Out:
#       대여소번호    출근대여수    퇴근반납수  퇴근반납수-출근대여수
# 843   01153  20974.0  62956.0      41982.0
# 1844  02728  39868.0  79684.0      39816.0
# 1466  02102  12664.0  39337.0      26673.0
# 2381  04217   6814.0  30369.0      23555.0
# 554   00765   9458.0  32820.0      23362.0
# 354   00502  18990.0  40849.0      21859.0
# 2558  04565   5492.0  25468.0      19976.0
# 2020  03533  10538.0  29736.0      19198.0
# 576   00792   5017.0  23839.0      18822.0
# 893   01210  28184.0  45357.0      17173.0
# 538   00746   5166.0  22033.0      16867.0
# 1832  02715  64170.0  80994.0      16824.0
# 839   01149  11217.0  28025.0      16808.0
# 558   00769   3944.0  20087.0      16143.0
# 1179  01637   6480.0  22391.0      15911.0
# 821   01124  14319.0  29731.0      15412.0
# 155   00272  11138.0  26304.0      15166.0
# 2891  05858  13223.0  27870.0      14647.0
# 95    00207  26256.0  40845.0      14589.0
# 421   00583   6849.0  20615.0      13766.0

# %%
df_selected = df[['대여소번호', '대여소명', '상세주소', '위도', '경도']]
df_selected_no_duplicates = df_selected.drop_duplicates(subset='대여소번호', keep='first')
df_selected_no_duplicates
# Out:
#        대여소번호         대여소명                상세주소         위도          경도
# 3      00101  (구)합정동 주민센터  서울특별시 마포구 동교로8길 58  37.549561  126.905754
# 4      00102   망원역 1번출구 앞   서울특별시 마포구 월드컵로 72  37.555649  126.910629
# 5      00103   망원역 2번출구 앞   서울특별시 마포구 월드컵로 79  37.554951  126.910835
# 6      00104   합정역 1번출구 앞    서울특별시 마포구 양화로 59  37.550629  126.914986
# 7      00105   합정역 5번출구 앞    서울특별시 마포구 양화로 48  37.550007  126.914825
# ...      ...          ...                 ...        ...         ...
# 10814  06057  을지로5가(방산시장)          중구 동호로 369  37.567398  127.002014
# 10815  06058  서울도시건축전시관 옆         중구 세종대로 101  37.566540  126.976845
# 10816  06059        덕수중학교      중구 인현동2가 240-2  37.564392  126.997299
# 10818  06172     가양5단지아파트         강서구 가양동1481  37.564480  126.854645
# 10819  06173  서울자동차운전전문학원       강서구 남부순환로 216  37.546135  126.821060
#
# [2914 rows x 5 columns]

# %%
df_final = pd.merge(year_sum_top_20, df_selected_no_duplicates, on='대여소번호', how='inner')
df_final
# Out:
#     대여소번호    출근대여수    퇴근반납수  퇴근반납수-출근대여수               대여소명  \
# 0   01153  20974.0  62956.0      41982.0  발산역 1번, 9번 인근 대여소
# 1   02728  39868.0  79684.0      39816.0        마곡나루역 3번 출구
# 2   02102  12664.0  39337.0      26673.0            봉림교 교통섬
# 3   04217   6814.0  30369.0      23555.0         한강공원 망원나들목
# 4   00765   9458.0  32820.0      23362.0          오목교역 3번출구
# 5   00502  18990.0  40849.0      21859.0      뚝섬유원지역 1번출구 앞
# 6   04565   5492.0  25468.0      19976.0         영등포 신세계백화점
# 7   03533  10538.0  29736.0      19198.0   건대입구역 사거리(롯데백화점)
# 8   00792   5017.0  23839.0      18822.0     목동트라팰리스 웨스턴에비뉴
# 9   01210  28184.0  45357.0      17173.0  롯데월드타워(잠실역2번출구 쪽)
# 10  00746   5166.0  22033.0      16867.0           목동2단지 상가
# 11  02715  64170.0  80994.0      16824.0        마곡나루역 2번 출구
# 12  01149  11217.0  28025.0      16808.0          신방화역환승주차장
# 13  00769   3944.0  20087.0      16143.0           CBS방송국 앞
# 14  01637   6480.0  22391.0      15911.0     KT 전화국 버스정류장 옆
# 15  01124  14319.0  29731.0      15412.0        발산역 6번 출구 뒤
# 16  00272  11138.0  26304.0      15166.0              당산육갑문
# 17  05858  13223.0  27870.0      14647.0           영등포역5번출구
# 18  00207  26256.0  40845.0      14589.0       여의나루역 1번출구 앞
# 19  00583   6849.0  20615.0      13766.0         청계천 생태교실 앞
#
#                                  상세주소         위도          경도
# 0                  서울특별시 강서구 공항대로 281  37.558949  126.837174
# 1                      강서구 마곡동 372-23  37.565804  126.828079
# 2                    서울특별시 관악구 관천로 52  37.484085  126.926888
# 3                       마포구 망원동 462-8  37.555576  126.896889
# 4                  서울특별시 양천구 목동동로 270  37.524776  126.875481
# 5      서울특별시 광진구 능동로 10 뚝섬유원지역 1번출구 앞  37.531860  127.067192
# 6                    영등포구 영등포4가 442-6  37.518036  126.903648
# 7   서울특별시 광진구 능동로 92 건대입구역 사거리(롯데백화점)  37.539139  127.070618
# 8                    오목로299(이마트 출입구측)  37.525372  126.870926
# 9               서울특별시 송파구 올림픽로 293-19  37.513126  127.100960
# 10                서울특별시  양천구 목동 902-5  37.536503  126.877747
# 11                       강서구 마곡중앙5로 6  37.566925  126.827438
# 12             서울특별시 강서구 마곡서1로 111-12  37.567284  126.818275
# 13                       양천구 목동 917-1  37.527855  126.874672
# 14    서울특별시 노원구 노해로 489 노원구 상계동 719-1  37.654701  127.063400
# 15                 서울특별시 강서구 공항대로 280  37.558178  126.838455
# 16                서울특별시 영등포구 당산로52길 3  37.535339  126.903679
# 17                            경인로 846  37.516693  126.908073
# 18              서울특별시 영등포구 여의동로 지하343  37.527157  126.931900
# 19     서울특별시 성동구 마장로39길 51 청계천 생태교실 앞  37.567970  127.046890

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# 그래프 생성 (가로 세로 비율 조정)
fig, ax = plt.subplots(figsize=(14, 14))  # 가로 길이를 늘림

# 데이터 정렬 및 차이 계산
top_20_sorted = df_final.sort_values('퇴근반납수-출근대여수', ascending=True)
top_20_sorted['차이'] = top_20_sorted['퇴근반납수'] - top_20_sorted['출근대여수']

# 색상 설정
colors = ['#ff9999', '#66b3ff']

# 막대 그리기
ax.barh(top_20_sorted['대여소명'], top_20_sorted['출근대여수'], label='출근대여수', color=colors[0])
ax.barh(top_20_sorted['대여소명'], top_20_sorted['퇴근반납수'], left=top_20_sorted['출근대여수'], label='퇴근반납수', color=colors[1])

# 그래프 스타일링
ax.set_xlabel('수량', fontsize=12)
ax.set_title('2021~2024년 출근대여수, 퇴근반납수, 및 그 차이', fontsize=16, pad=20)
ax.legend(loc='lower right', fontsize=10)

# y축 레이블 정렬
plt.yticks(rotation=0, ha='right')

# x축에 천 단위 구분자 추가
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))

# 그리드 추가
ax.grid(axis='x', linestyle='--', alpha=0.7)

# 각 막대에 값 표시
def add_value_labels(bars):
    for bar in bars:
        width = bar.get_width()
        ax.text(width, bar.get_y() + bar.get_height()/2, f'{int(width):,}',
                ha='right', va='center', fontweight='bold', fontsize=8, color='white')

bars1 = ax.barh(top_20_sorted['대여소명'], top_20_sorted['출근대여수'], color=colors[0])
bars2 = ax.barh(top_20_sorted['대여소명'], top_20_sorted['퇴근반납수'], left=top_20_sorted['출근대여수'], color=colors[1])

add_value_labels(bars1)
add_value_labels(bars2)

# 차이 값 표시 (가장 오른쪽에)
max_value = top_20_sorted[['출근대여수', '퇴근반납수']].sum(axis=1).max()
for i, value in enumerate(top_20_sorted['차이']):
    ax.text(max_value * 1.05, i, f'{int(value):,}', 
            va='center', ha='left', fontweight='bold', fontsize=9)

# x축 범위 조정
ax.set_xlim(0, max_value * 1.2)

plt.tight_layout()
plt.show()

# %%
import folium
import pandas as pd
import json
import webbrowser

# 지도 생성
center = [37.541, 126.986]
bike_map = folium.Map(location=center, zoom_start=13, tiles='openstreetmap', name='OpenStreetMap')

# 상위 10개와 20개 데이터로 나누기
top_10 = df_final.nlargest(10, '퇴근반납수-출근대여수')
top_10_ids = top_10.index  # 상위 10개의 인덱스를 가져와서 색상 구분에 사용

fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)

# 자전거 대여소 표시 (원 크기를 '퇴근반납수-출근대여수' 값에 비례하여 설정)
max_value = df_final['퇴근반납수-출근대여수'].max()  # '퇴근반납수-출근대여수'의 최대값
min_radius, max_radius = 10, 1000  # 최소 및 최대 원 크기

seq = 1
for i, row in df_final.iterrows():
    # '퇴근반납수-출근대여수' 값을 원 크기로 변환
    radius = min_radius + (row['퇴근반납수-출근대여수'] / max_value) * (max_radius - min_radius)
    
    # 색상 설정: 상위 10개 대여소는 빨간색, 나머지는 파란색
    fill_color = 'coral' if i in top_10_ids else 'turquoise'
    
    folium.Circle(
        location=[row['위도'], row['경도']],
        radius=radius,
        color='black',
        fill=True,
        fill_color=fill_color,
        fill_opacity=0.9,
        popup=row['대여소번호'],
        tooltip=str(seq) + '. ' + row['대여소명']
    ).add_to(fg1)

    seq = seq + 1

# 자치구 구분 JSON 파일 로드
geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))

# Choropleth 생성
choropleth = folium.Choropleth(
    geo_data=geo_str2,
    data=move,
    columns=['자치구', '이동인구'],
    key_on='feature.properties.SIG_KOR_NM',
    fill_color='BuGn',
    fill_opacity=0.3
)

# GeoJsonPopup 추가
folium.GeoJsonPopup(fields=['SIG_KOR_NM'], aliases=['지역:'], style='font-weight: bold;').add_to(choropleth.geojson)

# Choropleth를 지도에 추가
choropleth.add_to(bike_map)

# 타일 레이어 및 레이어 컨트롤 추가
folium.TileLayer('cartodbpositron', name='CartoDB Positron').add_to(bike_map)
folium.TileLayer('cartodbdark_matter', name='CartoDB Dark Matter').add_to(bike_map)
folium.LayerControl().add_to(bike_map)

# 지도 저장 및 웹 브라우저에서 열기
save_name = "(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2021~2024"
bike_map.save(save_name + ".html")
webbrowser.open(save_name + ".html")
# Out:
# True
