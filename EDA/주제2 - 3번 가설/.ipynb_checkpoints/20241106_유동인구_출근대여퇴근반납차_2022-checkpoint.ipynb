# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\'
filename = '연도별 자치구별 출퇴근 이동인구 2020-2024.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 0.010529279708862305
#      연도 출퇴근  자치구         이동인구
# 0  2020  출근  강남구  42087137.37
# 1  2020  출근  강동구   8690787.78
# 2  2020  출근  강북구   4228968.36
# 3  2020  출근  강서구  12350053.62
# 4  2020  출근  관악구   6552387.52

# %%
df
# Out:
#        연도 출퇴근  자치구         이동인구
# 0    2020  출근  강남구  42087137.37
# 1    2020  출근  강동구   8690787.78
# 2    2020  출근  강북구   4228968.36
# 3    2020  출근  강서구  12350053.62
# 4    2020  출근  관악구   6552387.52
# ..    ...  ..  ...          ...
# 245  2024  퇴근  용산구   8638774.97
# 246  2024  퇴근  은평구  17598681.48
# 247  2024  퇴근  종로구   6011493.14
# 248  2024  퇴근   중구   4834166.40
# 249  2024  퇴근  중랑구  13623038.79
#
# [250 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      250 non-null    object
#  1   출퇴근     250 non-null    object
#  2   자치구     250 non-null    object
#  3   이동인구    250 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 7.9+ KB

# %%
df_year = df[df['연도'] == '2022']
df_year
# Out:
#        연도 출퇴근   자치구         이동인구
# 100  2022  출근   강남구  79866381.86
# 101  2022  출근   강동구  22139740.72
# 102  2022  출근   강북구  11247330.37
# 103  2022  출근   강서구  27881865.68
# 104  2022  출근   관악구  16016768.39
# 105  2022  출근   광진구  15337163.09
# 106  2022  출근   구로구  22254449.73
# 107  2022  출근   금천구  20006609.67
# 108  2022  출근   노원구  19883308.52
# 109  2022  출근   도봉구   9835790.82
# 110  2022  출근  동대문구  18904859.91
# 111  2022  출근   동작구  15276476.58
# 112  2022  출근   마포구  26644238.37
# 113  2022  출근  서대문구  20355331.34
# 114  2022  출근   서초구  48883691.64
# 115  2022  출근   성동구  22730802.16
# 116  2022  출근   성북구  16519994.62
# 117  2022  출근   송파구  41235453.59
# 118  2022  출근   양천구  14512246.18
# 119  2022  출근  영등포구  47440472.45
# 120  2022  출근   용산구  18246686.30
# 121  2022  출근   은평구  14424499.27
# 122  2022  출근   종로구  34047631.41
# 123  2022  출근    중구  45523380.87
# 124  2022  출근   중랑구  13683142.46
# 125  2022  퇴근   강남구  36072529.75
# 126  2022  퇴근   강동구  35269906.68
# 127  2022  퇴근   강북구  18557121.31
# 128  2022  퇴근   강서구  33301341.72
# 129  2022  퇴근   관악구  28855042.88
# 130  2022  퇴근   광진구  23885567.43
# 131  2022  퇴근   구로구  26242708.71
# 132  2022  퇴근   금천구  12931778.46
# 133  2022  퇴근   노원구  32687400.48
# 134  2022  퇴근   도봉구  18123310.86
# 135  2022  퇴근  동대문구  21546229.71
# 136  2022  퇴근   동작구  24844392.26
# 137  2022  퇴근   마포구  25066288.41
# 138  2022  퇴근  서대문구  20857240.88
# 139  2022  퇴근   서초구  27751064.09
# 140  2022  퇴근   성동구  20408299.64
# 141  2022  퇴근   성북구  27719881.46
# 142  2022  퇴근   송파구  46363343.20
# 143  2022  퇴근   양천구  24426133.08
# 144  2022  퇴근  영등포구  27304925.10
# 145  2022  퇴근   용산구  15909535.42
# 146  2022  퇴근   은평구  30344338.43
# 147  2022  퇴근   종로구  10564393.89
# 148  2022  퇴근    중구   8463048.48
# 149  2022  퇴근   중랑구  24073495.74

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'
save_name = '(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2022'

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# ### 자전거 대여소 정보

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일\\서울시 공공자전거 대여소 정보\\공공자전거 대여소 정보_통합본_최종.parquet')
rental.head()
# Out:
#    대여소번호          대여소명  자치구                         상세주소         위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216  37.546135
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트  37.628620
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97  37.638157
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.658871
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가  37.621864
#
#            경도        설치시기  LCD    QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  126.821060  2024-03-18  NaN  10.0   QR  2024-06  ST-3284   NaN
# 1  127.066910  2020-03-24  NaN  12.0   QR  2024-06  ST-2068   NaN
# 2  127.073265  2020-03-23  NaN  20.0   QR  2024-06  ST-2078   NaN
# 3  127.071915  2020-03-23  NaN   7.0   QR  2024-06  ST-2077   NaN
# 4  127.074051  2020-03-25  NaN  10.0   QR  2024-06     None   NaN

# %% [markdown]
# ### 자치구 정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %%
rental[rental['위도'].isnull()]
# Out:
#       대여소번호           대여소명  자치구            상세주소  위도  경도        설치시기  LCD  \
# 2918  04205  디지털미디어씨티역2번출구  마포구  마포구 상암동 1171-1 NaN NaN  2020-12-02  NaN
#
#         QR 운영방식   데이터등록월 대여소ID  거치대수
# 2918  10.0   QR  2021-01  None   NaN

# %% [markdown]
# ### 지하철역통합_20241031.parquet

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#      연번   역번호   호선    역명         역전화번호                      도로명주소  \
# 0   NaN  None  NaN  <NA>          <NA>                       <NA>
# 1   NaN  None  NaN  <NA>          <NA>                       <NA>
# 2  92.0   340  3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3   NaN  None  NaN  <NA>          <NA>                       <NA>
# 4   NaN  None  NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat         lng
# 0            943            419민주묘지  37.648235  127.008614
# 1            109                 가능  37.748577  127.044213
# 2            350               가락시장  37.492522  127.118234
# 3           P142            가산디지털단지  37.481072  126.882343
# 4            907                 가양  37.561391  126.854456

# %%
move = df_year.groupby('자치구')['이동인구'].sum().reset_index()
move
# Out:
#      자치구          이동인구
# 0    강남구  1.159389e+08
# 1    강동구  5.740965e+07
# 2    강북구  2.980445e+07
# 3    강서구  6.118321e+07
# 4    관악구  4.487181e+07
# 5    광진구  3.922273e+07
# 6    구로구  4.849716e+07
# 7    금천구  3.293839e+07
# 8    노원구  5.257071e+07
# 9    도봉구  2.795910e+07
# 10  동대문구  4.045109e+07
# 11   동작구  4.012087e+07
# 12   마포구  5.171053e+07
# 13  서대문구  4.121257e+07
# 14   서초구  7.663476e+07
# 15   성동구  4.313910e+07
# 16   성북구  4.423988e+07
# 17   송파구  8.759880e+07
# 18   양천구  3.893838e+07
# 19  영등포구  7.474540e+07
# 20   용산구  3.415622e+07
# 21   은평구  4.476884e+07
# 22   종로구  4.461203e+07
# 23    중구  5.398643e+07
# 24   중랑구  3.775664e+07

# %%
move.sort_values(ascending = False, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 move.sort_values(ascending = False, inplace = True)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
import ast

text = '"\ub3c4\ubd09\uad6c"'
decoded_text = ast.literal_eval(text)
print(decoded_text)
# Out:
# 도봉구

# %% [markdown]
# ### 출근대여 퇴근반납 차

# %%
_year='2022'

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '출퇴근대여반납차이_' + _year + '.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 0.012776851654052734
#    대여소번호   출근대여수   출근반납수   퇴근대여수   퇴근반납수        대여소명               상세주소  \
# 0  00003     4.0   309.0    57.0     7.0        None               None
# 1  00005     NaN    45.0    16.0     6.0        None               None
# 2  00011     NaN     NaN     4.0     4.0        None               None
# 3  00102  2229.0  2221.0  4491.0  4981.0  망원역 1번출구 앞  서울특별시 마포구 월드컵로 72
# 4  00103   798.0   861.0  2880.0  3846.0  망원역 2번출구 앞  서울특별시 마포구 월드컵로 79
#
#           위도          경도
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3  37.555649  126.910629
# 4  37.554951  126.910835

# %%
df.isnull().sum()
# Out:
# 대여소번호     0
# 출근대여수    12
# 출근반납수    12
# 퇴근대여수     5
# 퇴근반납수     7
# 대여소명     17
# 상세주소     17
# 위도       17
# 경도       17
# dtype: int64

# %%
df = df.dropna(subset=['대여소명', '위도', '경도', '출근대여수', '퇴근반납수'])
df
# Out:
#       대여소번호   출근대여수   출근반납수   퇴근대여수   퇴근반납수        대여소명               상세주소  \
# 3     00102  2229.0  2221.0  4491.0  4981.0  망원역 1번출구 앞  서울특별시 마포구 월드컵로 72
# 4     00103   798.0   861.0  2880.0  3846.0  망원역 2번출구 앞  서울특별시 마포구 월드컵로 79
# 5     00104   738.0  1574.0  2186.0  1899.0  합정역 1번출구 앞   서울특별시 마포구 양화로 59
# 6     00105   249.0   450.0  1371.0  1374.0  합정역 5번출구 앞   서울특별시 마포구 양화로 48
# 7     00106   616.0   953.0  3439.0  3688.0  합정역 7번출구 앞    서울특별시 마포구 독막로 4
# ...     ...     ...     ...     ...     ...         ...                ...
# 2751  05859   165.0   203.0   339.0   242.0   여의도 삼부아파트          여의도동 30-2
# 2752  05860   101.0    44.0    49.0    60.0     어울림병원 앞         영등포로 384-1
# 2753  05861    32.0    49.0    51.0    45.0     보라주유소 앞          신길동 70-23
# 2754  05862    29.0    64.0    25.0    31.0    당산역11번출구         당산동5가 14-4
# 2755  06053    28.0    75.0    63.0    33.0     중부세무서 앞  서울특별시 중구 남학동 12-1
#
#              위도          경도
# 3     37.555649  126.910629
# 4     37.554951  126.910835
# 5     37.550629  126.914986
# 6     37.550007  126.914825
# 7     37.548645  126.912826
# ...         ...         ...
# 2751  37.525394  126.930458
# 2752  37.513500  126.920868
# 2753  37.513199  126.923523
# 2754  37.533630  126.901459
# 2755  37.560925  126.990662
#
# [2741 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# 대여소번호    0
# 출근대여수    0
# 출근반납수    3
# 퇴근대여수    0
# 퇴근반납수    0
# 대여소명     0
# 상세주소     0
# 위도       0
# 경도       0
# dtype: int64

# %%
df['퇴근반납수-출근대여수'] = df['퇴근반납수'] - df['출근대여수']
top_20 = df.nlargest(20, '퇴근반납수-출근대여수')
top_20
# Out:
#       대여소번호    출근대여수    출근반납수    퇴근대여수    퇴근반납수               대여소명  \
# 825   01153   5870.0   5139.0  11258.0  17901.0  발산역 1번, 9번 인근 대여소
# 1806  02728  11442.0  10031.0  12011.0  22387.0        마곡나루역 3번 출구
# 2316  04217   2536.0   1689.0   7102.0  11625.0         한강공원 망원나들목
# 1438  02102   4096.0   4748.0   8646.0  12390.0            봉림교 교통섬
# 2476  04565   1584.0   3701.0   8955.0   8441.0         영등포 신세계백화점
# 539   00765   2531.0   5061.0   8571.0   9339.0          오목교역 3번출구
# 342   00502   5646.0   9990.0  11408.0  12303.0      뚝섬유원지역 1번출구 앞
# 561   00792   1640.0   6685.0   8411.0   7150.0     목동트라팰리스 웨스턴에비뉴
# 1979  03533   2979.0   6262.0   7560.0   8483.0   건대입구역 사거리(롯데백화점)
# 821   01149   3192.0   2971.0   6245.0   8556.0          신방화역환승주차장
# 1985  03541   1626.0   1422.0   4784.0   6951.0             커먼그라운드
# 523   00746   1730.0   1831.0   5248.0   6873.0           목동2단지 상가
# 803   01124   4451.0   4837.0   8881.0   9526.0        발산역 6번 출구 뒤
# 875   01210   9392.0  14248.0  18276.0  14411.0  롯데월드타워(잠실역2번출구 쪽)
# 265   00415   4864.0   3462.0   5338.0   9769.0        DMC역 9번출구 앞
# 543   00769    836.0   6068.0   8364.0   5658.0           CBS방송국 앞
# 1156  01637   1978.0   2469.0   7276.0   6773.0     KT 전화국 버스정류장 옆
# 1746  02620   4987.0   3242.0   6005.0   9491.0       송파나루역 4번 출구옆
# 795   01112   2777.0   3422.0   5981.0   7236.0        마곡엠밸리4단지 정문
# 151   00272   3454.0   3381.0   5234.0   7842.0              당산육갑문
#
#                                    상세주소         위도          경도  퇴근반납수-출근대여수
# 825                  서울특별시 강서구 공항대로 281  37.558949  126.837174      12031.0
# 1806                     강서구 마곡동 372-23  37.565804  126.828079      10945.0
# 2316                      마포구 망원동 462-8  37.555576  126.896889       9089.0
# 1438                   서울특별시 관악구 관천로 52  37.484085  126.926888       8294.0
# 2476                   영등포구 영등포4가 442-6  37.518036  126.903648       6857.0
# 539                  서울특별시 양천구 목동동로 270  37.524776  126.875481       6808.0
# 342      서울특별시 광진구 능동로 10 뚝섬유원지역 1번출구 앞  37.531860  127.067192       6657.0
# 561                    오목로299(이마트 출입구측)  37.525372  126.870926       5510.0
# 1979  서울특별시 광진구 능동로 92 건대입구역 사거리(롯데백화점)  37.539139  127.070618       5504.0
# 821              서울특별시 강서구 마곡서1로 111-12  37.567284  126.818275       5364.0
# 1985          서울특별시 광진구 아차산로 200 커먼그라운드  37.541248  127.066040       5325.0
# 523                 서울특별시  양천구 목동 902-5  37.536503  126.877747       5143.0
# 803                  서울특별시 강서구 공항대로 280  37.558178  126.838455       5075.0
# 875               서울특별시 송파구 올림픽로 293-19  37.513126  127.100960       5019.0
# 265                 서울특별시 마포구 성암로 지하184  37.577469  126.897362       4905.0
# 543                        양천구 목동 917-1  37.527855  126.874672       4822.0
# 1156    서울특별시 노원구 노해로 489 노원구 상계동 719-1  37.654701  127.063400       4795.0
# 1746                       송파구 송파동 3-15  37.509979  127.112312       4504.0
# 795                  서울특별시 강서구 마곡서로 175  37.568577  126.824776       4459.0
# 151                 서울특별시 영등포구 당산로52길 3  37.535339  126.903679       4388.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# 그래프 생성 (가로 세로 비율 조정)
fig, ax = plt.subplots(figsize=(14, 14))  # 가로 길이를 늘림

# 데이터 정렬 및 차이 계산
top_20_sorted = top_20.sort_values('퇴근반납수-출근대여수', ascending=True)
top_20_sorted['차이'] = top_20_sorted['퇴근반납수'] - top_20_sorted['출근대여수']

# 색상 설정
colors = ['#ff9999', '#66b3ff']

# 막대 그리기
ax.barh(top_20_sorted['대여소명'], top_20_sorted['출근대여수'], label='출근대여수', color=colors[0])
ax.barh(top_20_sorted['대여소명'], top_20_sorted['퇴근반납수'], left=top_20_sorted['출근대여수'], label='퇴근반납수', color=colors[1])

# 그래프 스타일링
ax.set_xlabel('수량', fontsize=12)
ax.set_title('2022년 출근대여수, 퇴근반납수, 및 그 차이', fontsize=16, pad=20)
ax.legend(loc='lower right', fontsize=10)

# y축 레이블 정렬
plt.yticks(rotation=0, ha='right')

# x축에 천 단위 구분자 추가
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))

# 그리드 추가
ax.grid(axis='x', linestyle='--', alpha=0.7)

# 각 막대에 값 표시
def add_value_labels(bars):
    for bar in bars:
        width = bar.get_width()
        ax.text(width, bar.get_y() + bar.get_height()/2, f'{int(width):,}',
                ha='right', va='center', fontweight='bold', fontsize=8, color='white')

bars1 = ax.barh(top_20_sorted['대여소명'], top_20_sorted['출근대여수'], color=colors[0])
bars2 = ax.barh(top_20_sorted['대여소명'], top_20_sorted['퇴근반납수'], left=top_20_sorted['출근대여수'], color=colors[1])

add_value_labels(bars1)
add_value_labels(bars2)

# 차이 값 표시 (가장 오른쪽에)
max_value = top_20_sorted[['출근대여수', '퇴근반납수']].sum(axis=1).max()
for i, value in enumerate(top_20_sorted['차이']):
    ax.text(max_value * 1.05, i, f'{int(value):,}', 
            va='center', ha='left', fontweight='bold', fontsize=9)

# x축 범위 조정
ax.set_xlim(0, max_value * 1.2)

plt.tight_layout()
plt.show()

# %%
import folium
import pandas as pd
import json
import webbrowser

# 지도 생성
center = [37.541, 126.986]
bike_map = folium.Map(location=center, zoom_start=13, tiles='openstreetmap', name='OpenStreetMap')

# 상위 10개와 20개 데이터로 나누기
top_10 = top_20.nlargest(10, '퇴근반납수-출근대여수')
top_10_ids = top_10.index  # 상위 10개의 인덱스를 가져와서 색상 구분에 사용

fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)

# 자전거 대여소 표시 (원 크기를 '퇴근반납수-출근대여수' 값에 비례하여 설정)
max_value = top_20['퇴근반납수-출근대여수'].max()  # '퇴근반납수-출근대여수'의 최대값
min_radius, max_radius = 10, 1000  # 최소 및 최대 원 크기

seq = 1
for i, row in top_20.iterrows():
    # '퇴근반납수-출근대여수' 값을 원 크기로 변환
    radius = min_radius + (row['퇴근반납수-출근대여수'] / max_value) * (max_radius - min_radius)
    
    # 색상 설정: 상위 10개 대여소는 빨간색, 나머지는 파란색
    fill_color = 'coral' if i in top_10_ids else 'turquoise'
    
    folium.Circle(
        location=[row['위도'], row['경도']],
        radius=radius,
        color='black',
        fill=True,
        fill_color=fill_color,
        fill_opacity=0.9,
        popup=row['대여소번호'],
        tooltip=str(seq) + '. ' + row['대여소명']
    ).add_to(fg1)

    seq = seq + 1

# 자치구 구분 JSON 파일 로드
geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))

# Choropleth 생성
choropleth = folium.Choropleth(
    geo_data=geo_str2,
    data=move,
    columns=['자치구', '이동인구'],
    key_on='feature.properties.SIG_KOR_NM',
    fill_color='BuGn',
    fill_opacity=0.3
)

# GeoJsonPopup 추가
folium.GeoJsonPopup(fields=['SIG_KOR_NM'], aliases=['지역:'], style='font-weight: bold;').add_to(choropleth.geojson)

# Choropleth를 지도에 추가
choropleth.add_to(bike_map)

# 타일 레이어 및 레이어 컨트롤 추가
folium.TileLayer('cartodbpositron', name='CartoDB Positron').add_to(bike_map)
folium.TileLayer('cartodbdark_matter', name='CartoDB Dark Matter').add_to(bike_map)
folium.LayerControl().add_to(bike_map)

# 지도 저장 및 웹 브라우저에서 열기
save_name = "(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2022"
bike_map.save(save_name + ".html")
webbrowser.open(save_name + ".html")
# Out:
# True
