# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\'
filename = '연도별 자치구별 출퇴근 이동인구 2020-2024.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 0.034224748611450195
#      연도 출퇴근  자치구         이동인구
# 0  2020  출근  강남구  42087137.37
# 1  2020  출근  강동구   8690787.78
# 2  2020  출근  강북구   4228968.36
# 3  2020  출근  강서구  12350053.62
# 4  2020  출근  관악구   6552387.52

# %%
df
# Out:
#        연도 출퇴근  자치구         이동인구
# 0    2020  출근  강남구  42087137.37
# 1    2020  출근  강동구   8690787.78
# 2    2020  출근  강북구   4228968.36
# 3    2020  출근  강서구  12350053.62
# 4    2020  출근  관악구   6552387.52
# ..    ...  ..  ...          ...
# 245  2024  퇴근  용산구   8638774.97
# 246  2024  퇴근  은평구  17598681.48
# 247  2024  퇴근  종로구   6011493.14
# 248  2024  퇴근   중구   4834166.40
# 249  2024  퇴근  중랑구  13623038.79
#
# [250 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      250 non-null    object
#  1   출퇴근     250 non-null    object
#  2   자치구     250 non-null    object
#  3   이동인구    250 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 7.9+ KB

# %%
df_year = df[df['연도'] == '2024']
df_year
# Out:
#        연도 출퇴근   자치구         이동인구
# 200  2024  출근   강남구  44904151.17
# 201  2024  출근   강동구  13038618.21
# 202  2024  출근   강북구   5803004.16
# 203  2024  출근   강서구  16328231.44
# 204  2024  출근   관악구   9282364.87
# 205  2024  출근   광진구   8434285.94
# 206  2024  출근   구로구  12075879.50
# 207  2024  출근   금천구  10620282.28
# 208  2024  출근   노원구  10627911.14
# 209  2024  출근   도봉구   5441955.65
# 210  2024  출근  동대문구  10208506.04
# 211  2024  출근   동작구   8000823.90
# 212  2024  출근   마포구  14644735.04
# 213  2024  출근  서대문구  11818650.13
# 214  2024  출근   서초구  27691565.02
# 215  2024  출근   성동구  12122873.31
# 216  2024  출근   성북구   9039584.48
# 217  2024  출근   송파구  23114998.50
# 218  2024  출근   양천구   7559775.59
# 219  2024  출근  영등포구  27080281.21
# 220  2024  출근   용산구  10252816.61
# 221  2024  출근   은평구   7996820.42
# 222  2024  출근   종로구  18857049.82
# 223  2024  출근    중구  26897204.03
# 224  2024  출근   중랑구   7404466.64
# 225  2024  퇴근   강남구  21597789.01
# 226  2024  퇴근   강동구  20950420.71
# 227  2024  퇴근   강북구  10508866.58
# 228  2024  퇴근   강서구  19318424.40
# 229  2024  퇴근   관악구  16472059.56
# 230  2024  퇴근   광진구  13623811.42
# 231  2024  퇴근   구로구  15256755.58
# 232  2024  퇴근   금천구   7458451.18
# 233  2024  퇴근   노원구  18504245.70
# 234  2024  퇴근   도봉구  10518450.35
# 235  2024  퇴근  동대문구  12609141.46
# 236  2024  퇴근   동작구  14423193.77
# 237  2024  퇴근   마포구  14261434.97
# 238  2024  퇴근  서대문구  12101423.98
# 239  2024  퇴근   서초구  16100046.09
# 240  2024  퇴근   성동구  11957803.98
# 241  2024  퇴근   성북구  16091017.02
# 242  2024  퇴근   송파구  26777253.97
# 243  2024  퇴근   양천구  13846689.39
# 244  2024  퇴근  영등포구  15722979.60
# 245  2024  퇴근   용산구   8638774.97
# 246  2024  퇴근   은평구  17598681.48
# 247  2024  퇴근   종로구   6011493.14
# 248  2024  퇴근    중구   4834166.40
# 249  2024  퇴근   중랑구  13623038.79

# %%
import pandas as pd
import numpy as np
import json

import folium

# %%
# 나의 루트 경로 설정
path_dateset = 'G:/내 드라이브/DataSet/'
save_name = '(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2024'

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# ### 자전거 대여소 정보

# %%
rental = pd.read_parquet(path_dateset + '_파킷 파일\\서울시 공공자전거 대여소 정보\\공공자전거 대여소 정보_통합본_최종.parquet')
rental.head()
# Out:
#    대여소번호          대여소명  자치구                         상세주소         위도  \
# 0  06173   서울자동차운전전문학원  강서구                강서구 남부순환로 216  37.546135
# 1  02902  공릉풍림아파트 108동  노원구    서울특별시 노원구 섬밭로 139 공릉풍림아파트  37.628620
# 2  02912        대진고등학교  노원구           서울특별시 노원구 한글비석로 97  37.638157
# 3  02911       상계역중앙시장  노원구  서울특별시 노원구 한글비석로 389-2 가로판매대  37.658871
# 4  02910         도깨비시장  노원구     서울특별시 노원구 동일로 1028 한의학명가  37.621864
#
#            경도        설치시기  LCD    QR 운영방식   데이터등록월    대여소ID  거치대수
# 0  126.821060  2024-03-18  NaN  10.0   QR  2024-06  ST-3284   NaN
# 1  127.066910  2020-03-24  NaN  12.0   QR  2024-06  ST-2068   NaN
# 2  127.073265  2020-03-23  NaN  20.0   QR  2024-06  ST-2078   NaN
# 3  127.071915  2020-03-23  NaN   7.0   QR  2024-06  ST-2077   NaN
# 4  127.074051  2020-03-25  NaN  10.0   QR  2024-06     None   NaN

# %% [markdown]
# ### 자치구 정보

# %%
geo_path = path_dateset + 'seoul_municipalities_geo_simple.json'
# geo_str = json.load(open(geo_path, encoding='cp949'))
# encoding을 UTF-8로 지정
with open(geo_path, 'rt', encoding='utf-8') as f:
    geo_str2 = json.load(f)
# # ============================

# %%
rental[rental['위도'].isnull()]
# Out:
#       대여소번호           대여소명  자치구            상세주소  위도  경도        설치시기  LCD  \
# 2918  04205  디지털미디어씨티역2번출구  마포구  마포구 상암동 1171-1 NaN NaN  2020-12-02  NaN
#
#         QR 운영방식   데이터등록월 대여소ID  거치대수
# 2918  10.0   QR  2021-01  None   NaN

# %% [markdown]
# ### 지하철역통합_20241031.parquet

# %%
filename = '_최종 병합 파일\\서울교통공사 역주소 및 전화번호\\지하철역통합_20241031.parquet'
df_train_station = pd.read_parquet(path_dateset + filename)
df_train_station.head()
# Out:
#      연번   역번호   호선    역명         역전화번호                      도로명주소  \
# 0   NaN  None  NaN  <NA>          <NA>                       <NA>
# 1   NaN  None  NaN  <NA>          <NA>                       <NA>
# 2  92.0   340  3.0  가락시장  02-6110-3501  서울특별시 송파구 송파대로 지하257(가락동)
# 3   NaN  None  NaN  <NA>          <NA>                       <NA>
# 4   NaN  None  NaN  <NA>          <NA>                       <NA>
#
#                               지번주소  station_code  seoulmetro_code  \
# 0                             <NA>         651.0             4703
# 1                             <NA>         335.0             1907
# 2  서울특별시 송파구 가락동 184-23 가락시장역(3호선)          78.0              340
# 3                             <NA>         230.0             1702
# 4                             <NA>         580.0             4107
#
#    external_code  station_name(kor)        lat         lng
# 0            943            419민주묘지  37.648235  127.008614
# 1            109                 가능  37.748577  127.044213
# 2            350               가락시장  37.492522  127.118234
# 3           P142            가산디지털단지  37.481072  126.882343
# 4            907                 가양  37.561391  126.854456

# %%
move = df_year.groupby('자치구')['이동인구'].sum().reset_index()
move
# Out:
#      자치구         이동인구
# 0    강남구  66501940.18
# 1    강동구  33989038.92
# 2    강북구  16311870.74
# 3    강서구  35646655.84
# 4    관악구  25754424.43
# 5    광진구  22058097.36
# 6    구로구  27332635.08
# 7    금천구  18078733.46
# 8    노원구  29132156.84
# 9    도봉구  15960406.00
# 10  동대문구  22817647.50
# 11   동작구  22424017.67
# 12   마포구  28906170.01
# 13  서대문구  23920074.11
# 14   서초구  43791611.11
# 15   성동구  24080677.29
# 16   성북구  25130601.50
# 17   송파구  49892252.47
# 18   양천구  21406464.98
# 19  영등포구  42803260.81
# 20   용산구  18891591.58
# 21   은평구  25595501.90
# 22   종로구  24868542.96
# 23    중구  31731370.43
# 24   중랑구  21027505.43

# %%
move.sort_values(ascending = False, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 move.sort_values(ascending = False, inplace = True)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
import ast

text = '"\ub3c4\ubd09\uad6c"'
decoded_text = ast.literal_eval(text)
print(decoded_text)

# %% [markdown]
# ### 출근대여 퇴근반납 차

# %%
_year='2024'

# %%
import time
import pandas as  pd

filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '출퇴근대여반납차이_' + _year + '.parquet'
start_time = time.time()
df = pd.read_parquet(filepath + filename)
print("read_parquet time :", time.time() - start_time)
df.head(5)
# Out:
# read_parquet time : 0.017177343368530273
#    대여소번호   출근대여수   출근반납수   퇴근대여수   퇴근반납수        대여소명               상세주소  \
# 0  00003     NaN   172.0     NaN     6.0        None               None
# 1  00005     NaN    15.0     NaN     5.0        None               None
# 2  00102  1008.0  1118.0  2088.0  2461.0  망원역 1번출구 앞  서울특별시 마포구 월드컵로 72
# 3  00103   362.0   585.0  1415.0  1937.0  망원역 2번출구 앞  서울특별시 마포구 월드컵로 79
# 4  00104   458.0   929.0  1227.0  1062.0  합정역 1번출구 앞   서울특별시 마포구 양화로 59
#
#           위도          경도
# 0        NaN         NaN
# 1        NaN         NaN
# 2  37.555649  126.910629
# 3  37.554951  126.910835
# 4  37.550629  126.914986

# %%
df = df.dropna(subset=['대여소명', '위도', '경도', '출근대여수', '퇴근반납수'])
df
# Out:
#       대여소번호   출근대여수   출근반납수   퇴근대여수   퇴근반납수         대여소명               상세주소  \
# 2     00102  1008.0  1118.0  2088.0  2461.0   망원역 1번출구 앞  서울특별시 마포구 월드컵로 72
# 3     00103   362.0   585.0  1415.0  1937.0   망원역 2번출구 앞  서울특별시 마포구 월드컵로 79
# 4     00104   458.0   929.0  1227.0  1062.0   합정역 1번출구 앞   서울특별시 마포구 양화로 59
# 5     00105   177.0   218.0   626.0   607.0   합정역 5번출구 앞   서울특별시 마포구 양화로 48
# 6     00106   570.0   597.0  1642.0  1971.0   합정역 7번출구 앞    서울특별시 마포구 독막로 4
# ...     ...     ...     ...     ...     ...          ...                ...
# 2755  06058   380.0   305.0   916.0  1098.0  서울도시건축전시관 옆        중구 세종대로 101
# 2756  06059    54.0    53.0    63.0    58.0        덕수중학교     중구 인현동2가 240-2
# 2757  06171   411.0   224.0   765.0   961.0       월드빌딩 앞         화곡동 1066-8
# 2758  06172   365.0   169.0   145.0   311.0     가양5단지아파트        강서구 가양동1481
# 2759  06173    11.0   192.0   138.0   108.0  서울자동차운전전문학원      강서구 남부순환로 216
#
#              위도          경도
# 2     37.555649  126.910629
# 3     37.554951  126.910835
# 4     37.550629  126.914986
# 5     37.550007  126.914825
# 6     37.548645  126.912826
# ...         ...         ...
# 2755  37.566540  126.976845
# 2756  37.564392  126.997299
# 2757  37.540981  126.837433
# 2758  37.564480  126.854645
# 2759  37.546135  126.821060
#
# [2756 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# 대여소번호    0
# 출근대여수    0
# 출근반납수    4
# 퇴근대여수    0
# 퇴근반납수    0
# 대여소명     0
# 상세주소     0
# 위도       0
# 경도       0
# dtype: int64

# %%
df['퇴근반납수-출근대여수'] = df['퇴근반납수'] - df['출근대여수']
top_20 = df.nlargest(20, '퇴근반납수-출근대여수')
top_20
# Out:
#       대여소번호    출근대여수    출근반납수    퇴근대여수    퇴근반납수               대여소명  \
# 1744  02728   7312.0   6883.0   7978.0  15134.0        마곡나루역 3번 출구
# 793   01153   3526.0   2975.0   6535.0  10677.0  발산역 1번, 9번 인근 대여소
# 2248  04217   1427.0    828.0   4221.0   6193.0         한강공원 망원나들목
# 2737  05858   4196.0   2836.0   2868.0   8212.0           영등포역5번출구
# 518   00765   1501.0   2752.0   3764.0   5409.0          오목교역 3번출구
# 2417  04565   1126.0   2287.0   4917.0   4735.0         영등포 신세계백화점
# 90    00207   2610.0   1083.0   5581.0   5935.0       여의나루역 1번출구 앞
# 330   00502   3231.0   5685.0   6526.0   6502.0      뚝섬유원지역 1번출구 앞
# 539   00792    797.0   2984.0   4424.0   4018.0     목동트라팰리스 웨스턴에비뉴
# 1390  02102   1705.0   2340.0   3459.0   4850.0            봉림교 교통섬
# 1910  03534   2261.0   1822.0   3128.0   5277.0       건대입구역 5번출구 뒤
# 503   00746    882.0    853.0   2725.0   3733.0           목동2단지 상가
# 2722  05768   2011.0   2870.0   3379.0   4790.0              방이삼거리
# 1909  03533   1748.0   4331.0   4400.0   4502.0   건대입구역 사거리(롯데백화점)
# 393   00583   1371.0    864.0   2574.0   3996.0         청계천 생태교실 앞
# 842   01210   4692.0   9504.0  11063.0   7317.0  롯데월드타워(잠실역2번출구 쪽)
# 1733  02715  10988.0  14713.0  15378.0  13516.0        마곡나루역 2번 출구
# 789   01149   1803.0   1564.0   3092.0   4327.0          신방화역환승주차장
# 522   00769    924.0   3461.0   5219.0   3447.0           CBS방송국 앞
# 534   00785   1513.0   6149.0   6598.0   4023.0      양천구청, 보건소 사잇길
#
#                                    상세주소         위도          경도  퇴근반납수-출근대여수
# 1744                     강서구 마곡동 372-23  37.565804  126.828079       7822.0
# 793                  서울특별시 강서구 공항대로 281  37.558949  126.837174       7151.0
# 2248                      마포구 망원동 462-8  37.555576  126.896889       4766.0
# 2737                            경인로 846  37.516693  126.908073       4016.0
# 518                  서울특별시 양천구 목동동로 270  37.524776  126.875481       3908.0
# 2417                   영등포구 영등포4가 442-6  37.518036  126.903648       3609.0
# 90                서울특별시 영등포구 여의동로 지하343  37.527157  126.931900       3325.0
# 330      서울특별시 광진구 능동로 10 뚝섬유원지역 1번출구 앞  37.531860  127.067192       3271.0
# 539                    오목로299(이마트 출입구측)  37.525372  126.870926       3221.0
# 1390                   서울특별시 관악구 관천로 52  37.484085  126.926888       3145.0
# 1910    서울특별시 광진구 아차산로 236 건대입구역 5번출구 뒤  37.540127  127.069496       3016.0
# 503                 서울특별시  양천구 목동 902-5  37.536503  126.877747       2851.0
# 2722                       송파구 방이동 66-3  37.512291  127.108254       2779.0
# 1909  서울특별시 광진구 능동로 92 건대입구역 사거리(롯데백화점)  37.539139  127.070618       2754.0
# 393      서울특별시 성동구 마장로39길 51 청계천 생태교실 앞  37.567970  127.046890       2625.0
# 842               서울특별시 송파구 올림픽로 293-19  37.513126  127.100960       2625.0
# 1733                       강서구 마곡중앙5로 6  37.566925  126.827438       2528.0
# 789              서울특별시 강서구 마곡서1로 111-12  37.567284  126.818275       2524.0
# 522                        양천구 목동 917-1  37.527855  126.874672       2523.0
# 534                       양천구 신정동 321-8  37.517475  126.866325       2510.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 한글 폰트 설정 (Windows: Malgun Gothic)
plt.rcParams['font.family'] = 'Malgun Gothic'
# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# 그래프 생성 (가로 세로 비율 조정)
fig, ax = plt.subplots(figsize=(14, 14))  # 가로 길이를 늘림

# 데이터 정렬 및 차이 계산
top_20_sorted = top_20.sort_values('퇴근반납수-출근대여수', ascending=True)
top_20_sorted['차이'] = top_20_sorted['퇴근반납수'] - top_20_sorted['출근대여수']

# 색상 설정
colors = ['#ff9999', '#66b3ff']

# 막대 그리기
ax.barh(top_20_sorted['대여소명'], top_20_sorted['출근대여수'], label='출근대여수', color=colors[0])
ax.barh(top_20_sorted['대여소명'], top_20_sorted['퇴근반납수'], left=top_20_sorted['출근대여수'], label='퇴근반납수', color=colors[1])

# 그래프 스타일링
ax.set_xlabel('수량', fontsize=12)
ax.set_title('2024년 출근대여수, 퇴근반납수, 및 그 차이', fontsize=16, pad=20)
ax.legend(loc='lower right', fontsize=10)

# y축 레이블 정렬
plt.yticks(rotation=0, ha='right')

# x축에 천 단위 구분자 추가
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))

# 그리드 추가
ax.grid(axis='x', linestyle='--', alpha=0.7)

# 각 막대에 값 표시
def add_value_labels(bars):
    for bar in bars:
        width = bar.get_width()
        ax.text(width, bar.get_y() + bar.get_height()/2, f'{int(width):,}',
                ha='right', va='center', fontweight='bold', fontsize=8, color='white')

bars1 = ax.barh(top_20_sorted['대여소명'], top_20_sorted['출근대여수'], color=colors[0])
bars2 = ax.barh(top_20_sorted['대여소명'], top_20_sorted['퇴근반납수'], left=top_20_sorted['출근대여수'], color=colors[1])

add_value_labels(bars1)
add_value_labels(bars2)

# 차이 값 표시 (가장 오른쪽에)
max_value = top_20_sorted[['출근대여수', '퇴근반납수']].sum(axis=1).max()
for i, value in enumerate(top_20_sorted['차이']):
    ax.text(max_value * 1.05, i, f'{int(value):,}', 
            va='center', ha='left', fontweight='bold', fontsize=9)

# x축 범위 조정
ax.set_xlim(0, max_value * 1.2)

plt.tight_layout()
plt.show()

# %%
# # 지도 생성
# center = [37.541, 126.986]
# bike_map = folium.Map(location=center, zoom_start=13, tiles='openstreetmap', name='OpenStreetMap')

# fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)
# # 자전거 대여소 표시
# for i, row in top_20.iterrows():
#   # folium.Marker(
#     #folium.CircleMarker(
#     folium.Circle(
#       location = [row['위도'], row['경도']],
#       radius = 100,
#       color='black',                  # 외곽선 색상
#       fill=False,                     # 채우기 여부
#       fill_color='blue',             # 채우기 색상
#       fill_opacity=0.6,              # 채우기 불투명도
#       popup=row['대여소번호'],             # 클릭 시 표시되는 팝업
#       tooltip=row['대여소명'],                 # 마우스 오버 시 표시되는 툴팁
#       #icon=folium.Icon(icon = 'bookmark', color = 'blue')
#   ).add_to(fg1)


# # 자치구 구분 JSON 파일 로드
# geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))

# # Choropleth 생성 (columns 매개변수 추가)
# choropleth = folium.Choropleth(
#     geo_data=geo_str2,
#     data=move,
#     columns=['자치구', '이동인구'],  # '자치구'를 키로 하고, '이동인구' 값을 사용할 열로 지정
#     key_on='feature.properties.SIG_KOR_NM',
#     fill_color='Blues',
#     fill_opacity=0.3
# )

# # GeoJsonPopup 추가
# folium.GeoJsonPopup(fields=['SIG_KOR_NM'], aliases=['지역:'], style='font-weight: bold;').add_to(choropleth.geojson)

# # Choropleth를 지도에 추가
# choropleth.add_to(bike_map)

# # 타일 레이어 및 레이어 컨트롤 추가
# folium.TileLayer('cartodbpositron', name='CartoDB Positron').add_to(bike_map)
# folium.TileLayer('cartodbdark_matter', name='CartoDB Dark Matter').add_to(bike_map)
# folium.LayerControl().add_to(bike_map)

# # 지도 저장
# save_name = "(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2024"
# bike_map.save(save_name + ".html")

# # 웹 브라우저에서 지도 열기
# import webbrowser
# webbrowser.open(save_name + ".html")
# Out:
# True

# %%
# # 지도 생성
# center = [37.541, 126.986]
# bike_map = folium.Map(location=center, zoom_start=13, tiles='openstreetmap', name='OpenStreetMap')

# fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)

# # 자전거 대여소 표시 (원 크기를 '퇴근반납수-출근대여수' 값에 비례하여 설정)
# max_value = top_20['퇴근반납수-출근대여수'].max()  # '퇴근반납수-출근대여수'의 최대값
# min_radius, max_radius = 10, 1000  # 최소 및 최대 원 크기

# for i, row in top_20.iterrows():
#     # '퇴근반납수-출근대여수' 값을 원 크기로 변환
#     radius = min_radius + (row['퇴근반납수-출근대여수'] / max_value) * (max_radius - min_radius)
    
#     folium.Circle(
#         location=[row['위도'], row['경도']],
#         radius=radius,
#         color='black',
#         fill=True,
#         fill_color='blue',
#         fill_opacity=0.6,
#         popup=row['대여소번호'],
#         tooltip=row['대여소명']
#     ).add_to(fg1)

# # 자치구 구분 JSON 파일 로드
# geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))

# # Choropleth 생성
# choropleth = folium.Choropleth(
#     geo_data=geo_str2,
#     data=move,
#     columns=['자치구', '이동인구'],
#     key_on='feature.properties.SIG_KOR_NM',
#     fill_color='Blues',
#     fill_opacity=0.3
# )

# # GeoJsonPopup 추가
# folium.GeoJsonPopup(fields=['SIG_KOR_NM'], aliases=['지역:'], style='font-weight: bold;').add_to(choropleth.geojson)

# # Choropleth를 지도에 추가
# choropleth.add_to(bike_map)

# # 타일 레이어 및 레이어 컨트롤 추가
# folium.TileLayer('cartodbpositron', name='CartoDB Positron').add_to(bike_map)
# folium.TileLayer('cartodbdark_matter', name='CartoDB Dark Matter').add_to(bike_map)
# folium.LayerControl().add_to(bike_map)

# # 지도 저장 및 웹 브라우저에서 열기
# save_name = "(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2024"
# bike_map.save(save_name + ".html")
# webbrowser.open(save_name + ".html")
# Out:
# True

# %%
import folium
import pandas as pd
import json
import webbrowser

# 지도 생성
center = [37.541, 126.986]
bike_map = folium.Map(location=center, zoom_start=13, tiles='openstreetmap', name='OpenStreetMap')

# 상위 10개와 20개 데이터로 나누기
top_10 = top_20.nlargest(10, '퇴근반납수-출근대여수')
top_10_ids = top_10.index  # 상위 10개의 인덱스를 가져와서 색상 구분에 사용

fg1 = folium.FeatureGroup(name="bike_rental", show=False).add_to(bike_map)

# 자전거 대여소 표시 (원 크기를 '퇴근반납수-출근대여수' 값에 비례하여 설정)
max_value = top_20['퇴근반납수-출근대여수'].max()  # '퇴근반납수-출근대여수'의 최대값
min_radius, max_radius = 10, 1000  # 최소 및 최대 원 크기

seq = 1
for i, row in top_20.iterrows():
    # '퇴근반납수-출근대여수' 값을 원 크기로 변환
    radius = min_radius + (row['퇴근반납수-출근대여수'] / max_value) * (max_radius - min_radius)
    
    # 색상 설정: 상위 10개 대여소는 빨간색, 나머지는 파란색
    fill_color = 'coral' if i in top_10_ids else 'turquoise'
    
    folium.Circle(
        location=[row['위도'], row['경도']],
        radius=radius,
        color='black',
        fill=True,
        fill_color=fill_color,
        fill_opacity=0.9,
        popup=row['대여소번호'],
        tooltip=str(seq) + '. ' + row['대여소명']
    ).add_to(fg1)

    seq = seq + 1

# 자치구 구분 JSON 파일 로드
geo_str2 = json.load(open('G:\\내 드라이브\\DataSet\\seoul_municipalities_geo_simple.json', encoding='utf-8'))

# Choropleth 생성
choropleth = folium.Choropleth(
    geo_data=geo_str2,
    data=move,
    columns=['자치구', '이동인구'],
    key_on='feature.properties.SIG_KOR_NM',
    fill_color='BuGn',
    fill_opacity=0.3
)

# GeoJsonPopup 추가
folium.GeoJsonPopup(fields=['SIG_KOR_NM'], aliases=['지역:'], style='font-weight: bold;').add_to(choropleth.geojson)

# Choropleth를 지도에 추가
choropleth.add_to(bike_map)

# 타일 레이어 및 레이어 컨트롤 추가
folium.TileLayer('cartodbpositron', name='CartoDB Positron').add_to(bike_map)
folium.TileLayer('cartodbdark_matter', name='CartoDB Dark Matter').add_to(bike_map)
folium.LayerControl().add_to(bike_map)

# 지도 저장 및 웹 브라우저에서 열기
save_name = "(folium)지도테마_자치구구분_출퇴근이동인구_출근대여퇴근반납차_2024"
bike_map.save(save_name + ".html")
webbrowser.open(save_name + ".html")
# Out:
# True
