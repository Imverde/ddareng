# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '서울특별시 공공자전거 대여이력 정보_2020'
df_2020 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 51.36266374588013

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df_2020)
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0     자전거번호  23287911             0          0.000000
# 1   대여대여소번호  23287911             0          0.000000
# 2    대여대여소명  23287911             0          0.000000
# 3     대여거치대  23287911             0          0.000000
# 4   반납대여소번호  23287911             0          0.000000
# 5    반납대여소명  23287911             0          0.000000
# 6     반납거치대  23287911             0          0.000000
# 7   이용시간(분)  23287911             0          0.000000
# 8   이용거리(M)  23287808           103          0.000442
# 9      대여일자  23287911             0          0.000000
# 10     대여시간  23287911             0          0.000000
# 11     반납일자  23287911             0          0.000000
# 12     반납시간  23287911             0          0.000000

# %%
df_2020
# Out:
#               자전거번호 대여대여소번호                대여대여소명 대여거치대 반납대여소번호        반납대여소명  \
# 0         SPB-04061   00429                  송도병원     2   00372    약수역 3번출구 뒤
# 1         SPB-06686   01637           KT 노원점 건물 앞    14   01656  중앙하이츠 아파트 입구
# 2         SPB-15937   01924             삼부르네상스파크빌    10   01955     디지털입구 교차로
# 3         SPB-14805   00437              대흥역 1번출구     1   00126      서강대 후문 옆
# 4         SPB-09038   01168           마곡엠밸리10단지 앞     5   01152        마곡역교차로
# ...             ...     ...                   ...   ...     ...           ...
# 23287906  SPB-21898   01149             신방화역환승주차장     7   01165      마곡중학교 후문
# 23287907  SPB-34153   01222         잠실새내역 5번 출구 뒤     0   01221   삼전사거리 포스코더샵
# 23287908  SPB-30675   01257           가락시장역 롯데마트앞     0   01271         송파도서관
# 23287909  SPB-35362   00913               이마트 은평점     0   00131          증산2교
# 23287910  SPB-33088   01359  장위뉴타운 꿈에 숲 코오롱 하늘채 앞     0   01373    성북구보건소 건너편
#
# ...

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23287911 entries, 0 to 23287910
# Data columns (total 13 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   자전거번호    object
#  1   대여대여소번호  object
#  2   대여대여소명   object
#  3   대여거치대    object
#  4   반납대여소번호  object
#  5   반납대여소명   object
#  6   반납거치대    int64
#  7   이용시간(분)  float64
#  8   이용거리(M)  float64
#  9   대여일자     object
#  10  대여시간     object
#  11  반납일자     object
#  12  반납시간     object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ GB

# %%
df_2020['자전거번호'].unique
# Out:
# <bound method Series.unique of 0           SPB-04061
# 1           SPB-06686
# 2           SPB-15937
# 3           SPB-14805
# 4           SPB-09038
#               ...
# 23287906    SPB-21898
# 23287907    SPB-34153
# 23287908    SPB-30675
# 23287909    SPB-35362
# 23287910    SPB-33088
# Name: 자전거번호, Length: 23287911, dtype: object>

# %%
df_2020['자전거번호'].min()
# Out:
# 'SPB-00003'

# %%
df_2020['자전거번호'].max()
# Out:
# 'SPB-90005'
