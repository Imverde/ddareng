# %% [markdown]
# ## 1. 용량이 커서 사용할 컬럼만 추출후 저장

# %%
import pandas as pd

df_1 = pd.read_parquet('G:/내 드라이브/DataSet/_파킷 파일/서울특별시 공공자전거 대여이력 정보/서울특별시 공공자전거 대여이력 정보_2021.parquet', columns=['자전거번호', '대여대여소번호', '반납대여소번호', 
       '이용시간(분)', '이용거리(M)', '대여일자', '대여시간', '반납일자', '반납시간'])
df_2 = pd.read_parquet('G:/내 드라이브/DataSet/_파킷 파일/서울특별시 공공자전거 대여이력 정보/서울특별시 공공자전거 대여이력 정보_2022.parquet', columns=['자전거번호', '대여대여소번호', '반납대여소번호', 
       '이용시간(분)', '이용거리(M)', '대여일자', '대여시간', '반납일자', '반납시간'])
df_3 = pd.read_parquet('G:/내 드라이브/DataSet/_파킷 파일/서울특별시 공공자전거 대여이력 정보/서울특별시 공공자전거 대여이력 정보_2023.parquet', columns=['자전거번호', '대여대여소번호', '반납대여소번호', 
       '이용시간(분)', '이용거리(M)', '대여일자', '대여시간', '반납일자', '반납시간'])
df_4 = pd.read_parquet('G:/내 드라이브/DataSet/_파킷 파일/서울특별시 공공자전거 대여이력 정보/서울특별시 공공자전거 대여이력 정보_2024.parquet', columns=['자전거번호', '대여대여소번호', '반납대여소번호', 
       '이용시간(분)', '이용거리(M)', '대여일자', '대여시간', '반납일자', '반납시간'])

#excel = pd.concat([excel, df], ignore_index=True)

# %% [markdown]
# ## 2. concat으로 데이터프레임 합친다.

# %%
df = pd.concat([df_1, df_2, df_3, df_4], ignore_index=True)

# %%
pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\users\user\anaconda3\lib\site-packages (14.0.2)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\user\anaconda3\lib\site-packages (from pyarrow) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 3. parquet으로 저장

# %%
df.to_parquet('G:/내 드라이브/DataSet/_파킷 파일/서울특별시 공공자전거 대여이력 정보/서울특별시 공공자전거 대여이력 정보_21~24.parquet', engine='pyarrow', compression='gzip')

# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여이력 정보\\'
filename = '서울특별시 공공자전거 대여이력 정보_21~24'
df = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 111.07624697685242

# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
import ExcelFile_EDA as ee
ee.ss_isnull(df)
# Out:
#      [컬럼명]      [sum]  [sum_isnull]  [mean_isnull(%)]
# 0    자전거번호  140876284             0          0.000000
# 1  대여대여소번호  140876284             0          0.000000
# 2  반납대여소번호  140493981        382303          0.271375
# 3  이용시간(분)  140876284             0          0.000000
# 4  이용거리(M)  140876161           123          0.000087
# 5     대여일자  140876284             0          0.000000
# 6     대여시간  140876284             0          0.000000
# 7     반납일자  140876284             0          0.000000
# 8     반납시간  140876284             0          0.000000

# %%
df
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)   이용거리(M)        대여일자      대여시간  \
# 0          SPB-53145   00003   00668     25.0      0.00  2021-01-02  20:50:36
# 1          SPB-53074   00003   00668     14.0      0.00  2021-01-04  16:02:12
# 2          SPB-50952   00003   00668     11.0   1853.99  2021-01-13  21:02:05
# 3          SPB-52380   00003   00668     10.0      0.00  2021-01-14  21:02:55
# 4          SPB-52380   00003   00540     13.0   2291.05  2021-01-18  18:02:08
# ...              ...     ...     ...      ...       ...         ...       ...
# 140876279  SPB-52120   00334    None     60.0   4348.00  2024-06-30  22:42:25
# 140876280  SPB-57512   04217    None     60.0  32253.00  2024-06-30  21:46:13
# 140876281  SPB-50402   03569    None    870.0    848.00  2024-06-30  23:57:41
# 140876282  SPB-56869   02547    None    870.0   2119.00  2024-06-30  18:35:04
# 140876283  SPB-45157   02255    None    870.0      0.00  2024-06-30  08:03:43
#
#                  반납일자      반납시간
# 0          2021-01-02  21:15:41
# 1          2021-01-04  16:17:06
# 2          2021-01-13  21:14:04
# 3          2021-01-14  21:13:41
# 4          2021-01-18  18:15:22
# ...               ...       ...
# 140876279  2024-07-02  11:24:51
# 140876280  2024-07-02  11:25:54
# 140876281  2024-07-02  13:00:21
# 140876282  2024-07-02  13:00:59
# 140876283  2024-07-02  13:01:37
#
# [140876284 rows x 9 columns]

# %%
df = df.drop(['대여시간', '반납일자', '반납시간'], axis=1)

# %%
df
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)   이용거리(M)        대여일자
# 0          SPB-53145   00003   00668     25.0      0.00  2021-01-02
# 1          SPB-53074   00003   00668     14.0      0.00  2021-01-04
# 2          SPB-50952   00003   00668     11.0   1853.99  2021-01-13
# 3          SPB-52380   00003   00668     10.0      0.00  2021-01-14
# 4          SPB-52380   00003   00540     13.0   2291.05  2021-01-18
# ...              ...     ...     ...      ...       ...         ...
# 140876279  SPB-52120   00334    None     60.0   4348.00  2024-06-30
# 140876280  SPB-57512   04217    None     60.0  32253.00  2024-06-30
# 140876281  SPB-50402   03569    None    870.0    848.00  2024-06-30
# 140876282  SPB-56869   02547    None    870.0   2119.00  2024-06-30
# 140876283  SPB-45157   02255    None    870.0      0.00  2024-06-30
#
# [140876284 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140876284 entries, 0 to 140876283
# Data columns (total 6 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   자전거번호    object
#  1   대여대여소번호  object
#  2   반납대여소번호  object
#  3   이용시간(분)  float64
#  4   이용거리(M)  float64
#  5   대여일자     object
# dtypes: float64(2), object(4)
# memory usage: 6.3+ GB

# %%
pd.options.display.float_format = '{:3}'.format
round(df.describe(), 1)
# Out:
#           이용시간(분)     이용거리(M)
# count 140876284.0 140876161.0
# mean         22.1      2505.9
# std          28.7      3201.6
# min         -15.0         0.0
# 25%           6.0       790.0
# 50%          12.0      1463.0
# 75%          28.0      2870.0
# max       20010.5    733682.0

# %% [markdown]
# ## 4. NULL값 있는 '반납대여소번호' 컬럼, '이용거리(M)' 컬럼 확인하기

# %% [markdown]
# - '반납대여소번호' null값 확인

# %%
df[df['반납대여소번호'].isnull()]
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)  이용거리(M)        대여일자
# 49064993   SPB-33395   02277    None     42.0      0.0  2022-07-01
# 49065002   SPB-53713   04600    None     54.0      0.0  2022-07-01
# 49065865   SPB-40778   03582    None     65.0      0.0  2022-07-01
# 49065940   SPB-53857   00236    None     55.0      0.0  2022-07-01
# 49066020   SPB-54473   01684    None     54.0      0.0  2022-07-01
# ...              ...     ...     ...      ...      ...         ...
# 140876279  SPB-52120   00334    None     60.0   4348.0  2024-06-30
# 140876280  SPB-57512   04217    None     60.0  32253.0  2024-06-30
# 140876281  SPB-50402   03569    None    870.0    848.0  2024-06-30
# 140876282  SPB-56869   02547    None    870.0   2119.0  2024-06-30
# 140876283  SPB-45157   02255    None    870.0      0.0  2024-06-30
#
# [382303 rows x 6 columns]

# %% [markdown]
# - 자전거번호 추출해서 저장하기

# %%
df['자전거번호_추출'] = df['자전거번호'].str[4:]
df
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)  이용거리(M)        대여일자 자전거번호_추출
# 0          SPB-53145   00003   00668     25.0      0.0  2021-01-02    53145
# 1          SPB-53074   00003   00668     14.0      0.0  2021-01-04    53074
# 2          SPB-50952   00003   00668     11.0  1853.99  2021-01-13    50952
# 3          SPB-52380   00003   00668     10.0      0.0  2021-01-14    52380
# 4          SPB-52380   00003   00540     13.0  2291.05  2021-01-18    52380
# ...              ...     ...     ...      ...      ...         ...      ...
# 140876279  SPB-52120   00334    None     60.0   4348.0  2024-06-30    52120
# 140876280  SPB-57512   04217    None     60.0  32253.0  2024-06-30    57512
# 140876281  SPB-50402   03569    None    870.0    848.0  2024-06-30    50402
# 140876282  SPB-56869   02547    None    870.0   2119.0  2024-06-30    56869
# 140876283  SPB-45157   02255    None    870.0      0.0  2024-06-30    45157
#
# [140876284 rows x 7 columns]

# %% [markdown]
# - 대여가 이루어진 자전거를 확인. 하지만, 자전거가 선택되었다는 것은 신형일 것이다. 따라서 대여횟수를 확인해야하기 때문에
#   null값을 제거하지 않는다.

# %%
df['대여_일자'] = pd.to_datetime(df['대여일자'])

# %%
df['대여_일자'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['자전거번호_추출'].unique()
# Out:
# array(['53145', '53074', '50952', ..., '70189', '64848', '68910'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140876284 entries, 0 to 140876283
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   자전거번호     object
#  1   대여대여소번호   object
#  2   반납대여소번호   object
#  3   이용시간(분)   float64
#  4   이용거리(M)   float64
#  5   대여일자      object
#  6   자전거번호_추출  object
#  7   대여_일자     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 8.4+ GB

# %% [markdown]
# - 각 자전거의 최초 대여일자 찾기

# %%
earliest_dates = df.groupby('자전거번호_추출')['대여일자'].min().reset_index()

# %%
earliest_dates
# Out:
#       자전거번호_추출        대여일자
# 0        00025  2021-04-06
# 1        00291  2021-01-01
# 2        00385  2021-01-01
# 3        00811  2021-01-11
# 4        00830  2021-01-14
# ...        ...         ...
# 47194    84996  2022-03-26
# 47195    84997  2022-03-31
# 47196    84998  2022-03-25
# 47197    84999  2022-03-25
# 47198    85000  2022-03-25
#
# [47199 rows x 2 columns]

# %%
earliest_dates = earliest_dates.rename(columns={'대여일자':'최초대여일자'})
earliest_dates
# Out:
#       자전거번호_추출      최초대여일자
# 0        00025  2021-04-06
# 1        00291  2021-01-01
# 2        00385  2021-01-01
# 3        00811  2021-01-11
# 4        00830  2021-01-14
# ...        ...         ...
# 47194    84996  2022-03-26
# 47195    84997  2022-03-31
# 47196    84998  2022-03-25
# 47197    84999  2022-03-25
# 47198    85000  2022-03-25
#
# [47199 rows x 2 columns]

# %%
earliest_dates.sort_values(by='자전거번호_추출')
# Out:
#       자전거번호_추출      최초대여일자
# 0        00025  2021-04-06
# 1        00291  2021-01-01
# 2        00385  2021-01-01
# 3        00811  2021-01-11
# 4        00830  2021-01-14
# ...        ...         ...
# 47194    84996  2022-03-26
# 47195    84997  2022-03-31
# 47196    84998  2022-03-25
# 47197    84999  2022-03-25
# 47198    85000  2022-03-25
#
# [47199 rows x 2 columns]

# %%
earliest_dates.sort_values(by='최초대여일자')
# Out:
#       자전거번호_추출      최초대여일자
# 23599    51724  2021-01-01
# 13374    41019  2021-01-01
# 13375    41020  2021-01-01
# 13379    41024  2021-01-01
# 13380    41025  2021-01-01
# ...        ...         ...
# 42032    70180  2024-04-21
# 42038    70187  2024-04-21
# 42039    70189  2024-04-22
# 36708    64848  2024-05-13
# 40767    68910  2024-06-03
#
# [47199 rows x 2 columns]

# %% [markdown]
# - 원본 데이터프레임에 최초대여일자 추가

# %%
df.merge(earliest_dates, on='자전거번호_추출', how='left')
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)  이용거리(M)        대여일자 자전거번호_추출  \
# 0          SPB-53145   00003   00668     25.0      0.0  2021-01-02    53145
# 1          SPB-53074   00003   00668     14.0      0.0  2021-01-04    53074
# 2          SPB-50952   00003   00668     11.0  1853.99  2021-01-13    50952
# 3          SPB-52380   00003   00668     10.0      0.0  2021-01-14    52380
# 4          SPB-52380   00003   00540     13.0  2291.05  2021-01-18    52380
# ...              ...     ...     ...      ...      ...         ...      ...
# 140876279  SPB-52120   00334    None     60.0   4348.0  2024-06-30    52120
# 140876280  SPB-57512   04217    None     60.0  32253.0  2024-06-30    57512
# 140876281  SPB-50402   03569    None    870.0    848.0  2024-06-30    50402
# 140876282  SPB-56869   02547    None    870.0   2119.0  2024-06-30    56869
# 140876283  SPB-45157   02255    None    870.0      0.0  2024-06-30    45157
#
#                대여_일자      최초대여일자
# 0         2021-01-02  2021-01-02
# 1         2021-01-04  2021-01-02
# 2         2021-01-13  2021-01-01
# 3         2021-01-14  2021-01-09
# 4         2021-01-18  2021-01-09
# ...              ...         ...
# 140876279 2024-06-30  2021-01-01
# 140876280 2024-06-30  2022-04-13
# 140876281 2024-06-30  2021-01-01
# 140876282 2024-06-30  2022-05-01
# 140876283 2024-06-30  2021-04-08
#
# [140876284 rows x 9 columns]

# %%
from datetime import datetime
df['기준일'] = pd.to_datetime(datetime.now().date())
df
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)  이용거리(M)        대여일자 자전거번호_추출  \
# 0          SPB-53145   00003   00668     25.0      0.0  2021-01-02    53145
# 1          SPB-53074   00003   00668     14.0      0.0  2021-01-04    53074
# 2          SPB-50952   00003   00668     11.0  1853.99  2021-01-13    50952
# 3          SPB-52380   00003   00668     10.0      0.0  2021-01-14    52380
# 4          SPB-52380   00003   00540     13.0  2291.05  2021-01-18    52380
# ...              ...     ...     ...      ...      ...         ...      ...
# 140876279  SPB-52120   00334    None     60.0   4348.0  2024-06-30    52120
# 140876280  SPB-57512   04217    None     60.0  32253.0  2024-06-30    57512
# 140876281  SPB-50402   03569    None    870.0    848.0  2024-06-30    50402
# 140876282  SPB-56869   02547    None    870.0   2119.0  2024-06-30    56869
# 140876283  SPB-45157   02255    None    870.0      0.0  2024-06-30    45157
#
#                대여_일자        기준일
# 0         2021-01-02 2024-10-29
# 1         2021-01-04 2024-10-29
# 2         2021-01-13 2024-10-29
# 3         2021-01-14 2024-10-29
# 4         2021-01-18 2024-10-29
# ...              ...        ...
# 140876279 2024-06-30 2024-10-29
# 140876280 2024-06-30 2024-10-29
# 140876281 2024-06-30 2024-10-29
# 140876282 2024-06-30 2024-10-29
# 140876283 2024-06-30 2024-10-29
#
# [140876284 rows x 9 columns]

# %%
df['사용일수'] = (df['기준일'] - df['대여_일자']).dt.days

# %%
df
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)  이용거리(M)        대여일자 자전거번호_추출  \
# 0          SPB-53145   00003   00668     25.0      0.0  2021-01-02    53145
# 1          SPB-53074   00003   00668     14.0      0.0  2021-01-04    53074
# 2          SPB-50952   00003   00668     11.0  1853.99  2021-01-13    50952
# 3          SPB-52380   00003   00668     10.0      0.0  2021-01-14    52380
# 4          SPB-52380   00003   00540     13.0  2291.05  2021-01-18    52380
# ...              ...     ...     ...      ...      ...         ...      ...
# 140876279  SPB-52120   00334    None     60.0   4348.0  2024-06-30    52120
# 140876280  SPB-57512   04217    None     60.0  32253.0  2024-06-30    57512
# 140876281  SPB-50402   03569    None    870.0    848.0  2024-06-30    50402
# 140876282  SPB-56869   02547    None    870.0   2119.0  2024-06-30    56869
# 140876283  SPB-45157   02255    None    870.0      0.0  2024-06-30    45157
#
#                대여_일자        기준일  사용일수
# 0         2021-01-02 2024-10-29  1396
# 1         2021-01-04 2024-10-29  1394
# 2         2021-01-13 2024-10-29  1385
# 3         2021-01-14 2024-10-29  1384
# 4         2021-01-18 2024-10-29  1380
# ...              ...        ...   ...
# 140876279 2024-06-30 2024-10-29   121
# 140876280 2024-06-30 2024-10-29   121
# 140876281 2024-06-30 2024-10-29   121
# 140876282 2024-06-30 2024-10-29   121
# 140876283 2024-06-30 2024-10-29   121
#
# [140876284 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140876284 entries, 0 to 140876283
# Data columns (total 10 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   자전거번호     object
#  1   대여대여소번호   object
#  2   반납대여소번호   object
#  3   이용시간(분)   float64
#  4   이용거리(M)   float64
#  5   대여일자      object
#  6   자전거번호_추출  object
#  7   대여_일자     datetime64[ns]
#  8   기준일       datetime64[ns]
#  9   사용일수      int64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(5)
# memory usage: 10.5+ GB

# %% [markdown]
# - 2024년 1월 1일부터 2024년 6월 30일까지의 데이터만 필터링

# %%
start_date = '2024-01-01'
end_date = '2024-06-30'
filtered_df = df[(df['대여일자'] >= start_date) & (df['대여일자'] <= end_date)]

# %%
filtered_df
# Out:
#                자전거번호 대여대여소번호 반납대여소번호  이용시간(분)  이용거리(M)        대여일자 자전거번호_추출  \
# 118768743  SPB-46712   04804   01416      1.0      0.0  2024-01-01    46712
# 118768744  SPB-35089   04169   00251      6.0  1147.58  2024-01-01    35089
# 118768745  SPB-36386   00540   03509      3.0   642.13  2024-01-01    36386
# 118768746  SPB-61278   01139   00701      4.0    830.0  2024-01-01    61278
# 118768747  SPB-36848   03416   00346      4.0   791.08  2024-01-01    36848
# ...              ...     ...     ...      ...      ...         ...      ...
# 140876279  SPB-52120   00334    None     60.0   4348.0  2024-06-30    52120
# 140876280  SPB-57512   04217    None     60.0  32253.0  2024-06-30    57512
# 140876281  SPB-50402   03569    None    870.0    848.0  2024-06-30    50402
# 140876282  SPB-56869   02547    None    870.0   2119.0  2024-06-30    56869
# 140876283  SPB-45157   02255    None    870.0      0.0  2024-06-30    45157
#
#                대여_일자        기준일  사용일수
# 118768743 2024-01-01 2024-10-29   302
# 118768744 2024-01-01 2024-10-29   302
# 118768745 2024-01-01 2024-10-29   302
# 118768746 2024-01-01 2024-10-29   302
# 118768747 2024-01-01 2024-10-29   302
# ...              ...        ...   ...
# 140876279 2024-06-30 2024-10-29   121
# 140876280 2024-06-30 2024-10-29   121
# 140876281 2024-06-30 2024-10-29   121
# 140876282 2024-06-30 2024-10-29   121
# 140876283 2024-06-30 2024-10-29   121
#
# [22107541 rows x 10 columns]

# %% [markdown]
# - 자전거 번호별 대여 횟수 계산

# %%
rental_counts = filtered_df['자전거번호_추출'].value_counts().reset_index()
rental_counts
# Out:
#       자전거번호_추출  count
# 0        60816   1640
# 1        69996   1614
# 2        47367   1605
# 3        43523   1534
# 4        44743   1517
# ...        ...    ...
# 41868    82656      1
# 41869    52380      1
# 41870    32572      1
# 41871    35028      1
# 41872    63680      1
#
# [41873 rows x 2 columns]

# %%
filtered_df = filtered_df.merge(rental_counts, on='자전거번호_추출', how='left')

# %%
filtered_df
# Out:
#               자전거번호 대여대여소번호 반납대여소번호  이용시간(분)  이용거리(M)        대여일자 자전거번호_추출  \
# 0         SPB-46712   04804   01416      1.0      0.0  2024-01-01    46712
# 1         SPB-35089   04169   00251      6.0  1147.58  2024-01-01    35089
# 2         SPB-36386   00540   03509      3.0   642.13  2024-01-01    36386
# 3         SPB-61278   01139   00701      4.0    830.0  2024-01-01    61278
# 4         SPB-36848   03416   00346      4.0   791.08  2024-01-01    36848
# ...             ...     ...     ...      ...      ...         ...      ...
# 22107536  SPB-52120   00334    None     60.0   4348.0  2024-06-30    52120
# 22107537  SPB-57512   04217    None     60.0  32253.0  2024-06-30    57512
# 22107538  SPB-50402   03569    None    870.0    848.0  2024-06-30    50402
# 22107539  SPB-56869   02547    None    870.0   2119.0  2024-06-30    56869
# 22107540  SPB-45157   02255    None    870.0      0.0  2024-06-30    45157
#
#               대여_일자        기준일  사용일수  대여횟수
# 0        2024-01-01 2024-10-29   302  1129
# 1        2024-01-01 2024-10-29   302  1124
# 2        2024-01-01 2024-10-29   302   435
# 3        2024-01-01 2024-10-29   302   603
# 4        2024-01-01 2024-10-29   302   612
# ...             ...        ...   ...   ...
# 22107536 2024-06-30 2024-10-29   121   670
# 22107537 2024-06-30 2024-10-29   121   682
# 22107538 2024-06-30 2024-10-29   121   561
# 22107539 2024-06-30 2024-10-29   121   678
# 22107540 2024-06-30 2024-10-29   121  1198
#
# [22107541 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프 스타일 설정
sns.set_theme()
plt.figure(figsize=(10,6))

# 산점도 그리기
sns.scatterplot(x='사용일수', y='대여횟수', data=filtered_df)

# 추세선 그리기
sns.regplot(x='사용일수', y='대여횟수', data=filtered_df, scatter=False, color='red')

# 그래프 제목과 축 레이블 설정
plt.title('자전거 사용일수와 대여획수의 상관관계', fontsize=16)
plt.xlabel('사용일수', fontsize=12)
plt.ylabel('대여횟수', fontsize=12)

# 그래프 표시
plt.tight_layout()
plt.show()

# 상관계수 계산
correlation = filtered_df['사용일수'].corr(filtered_df['대여횟수'])
print(f"사용일수와 대여횟수의 상관계수: {correlatrion:.2f}")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 50752 (\N{HANGUL SYLLABLE WA}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 54925 (\N{HANGUL SYLLABLE HOEG}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_9748\926870703.py:21: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50752 (\N{HANGUL SYLLABLE WA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54925 (\N{HANGUL SYLLABLE HOEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 26
#      24 # 상관계수 계산
#      25 correlation = filtered_df['사용일수'].corr(filtered_df['대여횟수'])
# ---> 26 print(f"사용일수와 대여횟수의 상관계수: {correlatrion:.2f}")
#
# NameError: name 'correlatrion' is not defined
