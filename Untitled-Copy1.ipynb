# %%
import time
import pandas as  pd

start_time = time.time()
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울시 공공자전거 대여소 정보\\'
filename = '공공자전거 대여소 정보_통합본'
df_2020 = pd.read_parquet(filepath + filename + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 0.9074656963348389

# %%
df_2024 = df_2020[df_2020["데이터 등록 월"] == '2024-06']

# %%
df_2024
# Out:
#       대여소 번호     보관소(대여소)명   자치구                             상세주소         위도  \
# 18090  00301   경복궁역 7번출구 앞   종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞  37.575794
# 18091  00302   경복궁역 4번출구 뒤   종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤  37.575947
# 18092  00303   광화문역 1번출구 앞   종로구       서울특별시 종로구 세종대로 지하189 세종로공원  37.571770
# 18093  00305        종로구청 옆   종로구               서울특별시 종로구 세종로 84-1  37.572559
# 18094  00307     서울역사박물관 앞   종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞  37.570000
# ...      ...           ...   ...                              ...        ...
# 20848  05872       서경팰리스 앞  영등포구                    영등포구 가마산로 468  37.505764
# 20849  06057   을지로5가(방산시장)    중구                       중구 동호로 369  37.567398
# 20850  06058   서울도시건축전시관 옆    중구                      중구 세종대로 101  37.566540
# 20851  06059         덕수중학교    중구                   중구 인현동2가 240-2  37.564392
# 20852  06173   서울자동차운전전문학원   강서구                    강서구 남부순환로 216  37.546135
#
#                경도       설치 시기   LCD    QR 운영 방식 데이터 등록 월
# 18090  126.971451  2015-10-07  20.0  20.0    QR  2024-06
# 18091  126.974060  2015-10-07  12.0  12.0    QR  2024-06
# 18092  126.974663  2015-10-07   8.0   8.0    QR  2024-06
# 18093  126.978332  2015-01-07  16.0  16.0    QR  2024-06
# 18094  126.971100  2015-10-07  11.0  11.0    QR  2024-06
# ...           ...         ...   ...   ...   ...      ...
# 20848  126.908661  2024-03-18   NaN   7.0    QR  2024-06
# 20849  127.002014  2024-04-11   NaN   6.0    QR  2024-06
# 20850  126.976845  2024-04-26   NaN  10.0    QR  2024-06
# 20851  126.997299  2024-06-03   NaN   8.0    QR  2024-06
# 20852  126.821060  2024-03-18   NaN  10.0    QR  2024-06
#
# [2763 rows x 11 columns]
