# %%
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")

# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
path_sub = '서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/'

# %%
em.Merge_File(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.02.csv , encoding :  utf-8
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.02.csv, 674297
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.04.csv , encoding :  utf-8
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.04.csv, 1659277
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.10.csv , encoding :  EUC-KR
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.10.csv, 2332765
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.01.csv , encoding :  utf-8
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.01.csv, 706335
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.09.csv , encoding :  EUC-KR
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.09.csv, 2202087
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.11.csv , encoding :  EUC-KR
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.11.csv, 1679827
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.12.csv , encoding :  EUC-KR
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.12.csv, 1066900
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.03.csv , encoding :  utf-8
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.03.csv, 1222521
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.08.csv , encoding :  EUC-KR
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.08.csv, 1445993
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.06.csv , encoding :  EUC-KR
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.06.csv, 2126547
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.05.csv , encoding :  utf-8
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.05.csv, 1855476
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
# read_file - file_path :  G:/내 드라이브/DataSet/서울특별시 공공자전거 대여소별 이용정보(시간대별)/2020/서울특별시 공공자전거 이용정보(시간대별)_20.07.csv , encoding :  EUC-KR
# ==============================================================
# .csv, 서울특별시 공공자전거 이용정보(시간대별)_20.07.csv, 2053999
# ['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리', '사용시간']
