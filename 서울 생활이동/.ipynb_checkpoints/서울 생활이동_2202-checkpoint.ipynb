# %%
import os
import pandas as pd

# %%
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
def extract_extension(file_path):
    _, file_extension = os.path.splitext(file_path)
    return file_extension

# %%
# extract_extension('G:/내 드라이브/DataSet/서울 생활이동/2023/생활이동_행정동_202302/생활이동_행정동_2023.02_00시.csv')
# Out:
# '.csv'

# %%
def extract_filename(file_path):
    file_name = os.path.basename(file_path)
    filename_without_extension, _ = os.path.splitext(file_name)
    return filename_without_extension

# %%
def read_file(file_path):
    extension = extract_extension(file_path)
    if ".xlsx" == extension:
        return pd.read_excel(file_path)
    if ".csv" == extension:
        try:
            return pd.read_csv(file_path, encoding='cp949')
        except:
            return pd.read_csv(file_path, encoding='utf-8')

# %%
def check_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    file_list.sort()
    print('path : ', path)
    
    for _, file in enumerate(file_lists):
        df = read_file(path + file)
    
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))
        print(list(df.iloc[1]))

# %%
def merge_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    file_list.sort()
    print('path : ', path)
    
    for i, file in enumerate(file_lists):
        df = read_file(path + file)
        
        if (i > 0):
            df = df.iloc[1:]

        # excel = excel.append(df , ignore_index=True) #파일 하나에 다른 파일 추가하기(파일 합치기)
        excel = pd.concat([excel, df], ignore_index=True)        
        
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))

    # excel.to_csv(path+'merge.csv',index=False,encoding='euc-kr')
    # excel.to_csv(path + '생활이동_행정동_2024.01.csv', index=False, encoding='cp949')
    excel.to_csv(path + '생활이동_행정동_2022.02.csv', index=False, encoding='utf-8')

# %%
path_sub = '서울 생활이동/2022/생활이동_행정동_202202/'
check_file(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울 생활이동/2022/생활이동_행정동_202202/
# ==============================================================
# .csv, 생활이동_행정동_2022.02_02시.csv, 556205
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 2, 1101053, 1101053, 'F', 20, 'EH', 10, '4.37']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_01시.csv, 871542
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 1, 1101053, 1101053, 'F', 25, 'HH', 50, '4.08']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_00시.csv, 1437613
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 0, 1101053, 1101053, 'F', 30, 'HE', 20, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_06시.csv, 1555744
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 6, 1101053, 1101053, 'F', 45, 'HE', 10, '3.29']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_05시.csv, 788640
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 5, 1101053, 1101053, 'F', 50, 'WW', 40, '3.12']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_03시.csv, 412626
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 3, 1101053, 1101053, 'F', 60, 'HW', 20, '3.79']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_04시.csv, 420519
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 4, 1101053, 1101053, 'F', 60, 'HE', 10, '3.79']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_08시.csv, 5035257
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 8, 1101053, 1101053, 'F', 30, 'EE', 10, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_07시.csv, 2869798
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 7, 1101053, 1101053, 'F', 25, 'HE', 180, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_10시.csv, 5382398
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 10, 1101053, 1101053, 'F', 15, 'EE', 10, '8.1']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_09시.csv, 5433750
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 9, 1101053, 1101053, 'F', 25, 'EH', 10, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_14시.csv, 6684721
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 14, 1101053, 1101053, 'F', 10, 'HE', 10, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_13시.csv, 6831990
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 13, 1101053, 1101053, 'F', 15, 'EE', 10, '23.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_12시.csv, 6531291
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 12, 1101053, 1101053, 'F', 10, 'EH', 10, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_11시.csv, 5866115
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 11, 1101053, 1101053, 'F', 10, 'HE', 10, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_15시.csv, 6663168
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 15, 1101053, 1101053, 'F', 10, 'EH', 20, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_19시.csv, 7347619
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 19, 1101053, 1101053, 'F', 20, 'EE', 10, '35.12']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_18시.csv, 7978877
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 18, 1101053, 1101053, 'F', 15, 'EE', 10, '8.18']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_17시.csv, 7364814
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 17, 1101053, 1101053, 'F', 15, 'HE', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_16시.csv, 6852348
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 16, 1101053, 1101053, 'F', 15, 'WH', 10, '4.02']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_23시.csv, 2781742
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 23, 1101053, 1101053, 'F', 15, 'EH', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_22시.csv, 4238149
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 22, 1101053, 1101053, 'F', 20, 'WW', 10, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_21시.csv, 5090701
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 21, 1101053, 1101053, 'F', 15, 'EE', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_20시.csv, 5589135
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202202, '토', 20, 1101053, 1101053, 'F', 15, 'EE', 10, '4.07']

# %%
merge_file(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울 생활이동/2022/생활이동_행정동_202202/
# ==============================================================
# .csv, 생활이동_행정동_2022.02_02시.csv, 556205
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_01시.csv, 871541
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_00시.csv, 1437612
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_06시.csv, 1555743
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_05시.csv, 788639
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_03시.csv, 412625
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_04시.csv, 420518
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_08시.csv, 5035256
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_07시.csv, 2869797
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_10시.csv, 5382397
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_09시.csv, 5433749
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_14시.csv, 6684720
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_13시.csv, 6831989
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_12시.csv, 6531290
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_11시.csv, 5866114
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_15시.csv, 6663167
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_19시.csv, 7347618
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_18시.csv, 7978876
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_17시.csv, 7364813
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_16시.csv, 6852347
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_23시.csv, 2781741
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_22시.csv, 4238148
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_21시.csv, 5090700
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.02_20시.csv, 5589134
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']

# %%
rf = read_file(path_dateset + path_sub + '생활이동_행정동_2022.02.csv')

# %%
rf.tail(5)

# %%
print(len(rf))
print(len(set(rf['도착시간'])))
