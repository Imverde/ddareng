# %%
import os
import pandas as pd

# %%
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
def extract_extension(file_path):
    _, file_extension = os.path.splitext(file_path)
    return file_extension

# %%
extract_extension('G:/내 드라이브/DataSet/서울 생활이동/2023/생활이동_행정동_202302/생활이동_행정동_2023.02_00시.csv')
# Out:
# '.csv'

# %%
def extract_filename(file_path):
    file_name = os.path.basename(file_path)
    filename_without_extension, _ = os.path.splitext(file_name)
    return filename_without_extension

# %%
def read_file(file_path):
    extension = extract_extension(file_path)
    if ".xlsx" == extension:
        return pd.read_excel(file_path)
    if ".csv" == extension:
        try:
            return pd.read_csv(file_path, encoding='cp949')
        except:
            return pd.read_csv(file_path, encoding='utf-8')

# %%
def check_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    file_list.sort()
    print('path : ', path)
    
    for _, file in enumerate(file_lists):
        df = read_file(path + file)
    
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))
        print(list(df.iloc[1]))

# %%
def merge_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    file_list.sort()
    print('path : ', path)
    
    for i, file in enumerate(file_lists):
        df = read_file(path + file)
        
        if (i > 0):
            df = df.iloc[1:]

        # excel = excel.append(df , ignore_index=True) #파일 하나에 다른 파일 추가하기(파일 합치기)
        excel = pd.concat([excel, df], ignore_index=True)        
        
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))

    # excel.to_csv(path+'merge.csv',index=False,encoding='euc-kr')
    excel.to_csv(path + '생활이동_행정동_2022.01.csv', index=False, encoding='cp949')
    # excel.to_csv(path + '생활이동_행정동_2022.01.csv', index=False, encoding='utf-8')

# %%
path_sub = '서울 생활이동/2022/생활이동_행정동_202201/'
check_file(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울 생활이동/2022/생활이동_행정동_202201/
# ==============================================================
# .csv, 생활이동_행정동_2022.01_00시.csv, 1647131
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 0, 1101053, 1101053, 'F', 15, 'WH', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_07시.csv, 2996196
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 7, 1101053, 1101053, 'F', 25, 'EH', 40, '4.08']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_03시.csv, 484716
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 3, 1101053, 1101053, 'F', 35, 'HH', 20, '3']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_06시.csv, 1696862
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 6, 1101053, 1101053, 'F', 35, 'HW', 10, '3']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_04시.csv, 495615
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 4, 1101053, 1101053, 'F', 35, 'EE', 10, '3.03']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_05시.csv, 887905
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 5, 1101053, 1101053, 'F', 50, 'HE', 10, '3.1']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_02시.csv, 656534
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 2, 1101053, 1101053, 'F', 30, 'HH', 50, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_01시.csv, 1042220
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 1, 1101053, 1101053, 'F', 15, 'WH', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_10시.csv, 5827160
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 10, 1101053, 1101053, 'F', 15, 'HE', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_09시.csv, 5768467
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 9, 1101053, 1101053, 'F', 10, 'EE', 10, '5.96']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_08시.csv, 5214946
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 8, 1101053, 1101053, 'F', 25, 'HW', 10, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_13시.csv, 7553182
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 13, 1101053, 1101053, 'F', 10, 'HE', 10, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_12시.csv, 7230410
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 12, 1101053, 1101053, 'F', 10, 'EE', 10, '12']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_11시.csv, 6476132
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 11, 1101053, 1101053, 'F', 10, 'HW', 10, '5.98']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_16시.csv, 7752327
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 16, 1101053, 1101053, 'F', 10, 'EE', 10, '30']

# %%
merge_file(path_dateset, path_sub)

# %%
rf = read_file(path_dateset + path_sub + '생활이동_행정동_2023.02.csv')

# %% [markdown]
# ### encoding='utf-8'

# %%
def merge_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    file_list.sort()
    print('path : ', path)
    
    for i, file in enumerate(file_lists):
        df = read_file(path + file)
        
        if (i > 0):
            df = df.iloc[1:]

        # excel = excel.append(df , ignore_index=True) #파일 하나에 다른 파일 추가하기(파일 합치기)
        excel = pd.concat([excel, df], ignore_index=True)        
        
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))

    # excel.to_csv(path+'merge.csv',index=False,encoding='euc-kr')
    # excel.to_csv(path + '생활이동_행정동_2022.01.csv', index=False, encoding='cp949')
    excel.to_csv(path + '생활이동_행정동_2022.01_2.csv', index=False, encoding='utf-8')

# %%
path_sub = '서울 생활이동/2022/생활이동_행정동_202201/'
check_file(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울 생활이동/2022/생활이동_행정동_202201/
# ==============================================================
# .csv, 생활이동_행정동_2022.01_00시.csv, 1647131
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 0, 1101053, 1101053, 'F', 15, 'WH', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_07시.csv, 2996196
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 7, 1101053, 1101053, 'F', 25, 'EH', 40, '4.08']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_03시.csv, 484716
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 3, 1101053, 1101053, 'F', 35, 'HH', 20, '3']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_06시.csv, 1696862
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 6, 1101053, 1101053, 'F', 35, 'HW', 10, '3']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_04시.csv, 495615
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 4, 1101053, 1101053, 'F', 35, 'EE', 10, '3.03']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_05시.csv, 887905
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 5, 1101053, 1101053, 'F', 50, 'HE', 10, '3.1']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_02시.csv, 656534
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 2, 1101053, 1101053, 'F', 30, 'HH', 50, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_01시.csv, 1042220
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 1, 1101053, 1101053, 'F', 15, 'WH', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_10시.csv, 5827160
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 10, 1101053, 1101053, 'F', 15, 'HE', 10, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_09시.csv, 5768467
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 9, 1101053, 1101053, 'F', 10, 'EE', 10, '5.96']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_08시.csv, 5214946
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 8, 1101053, 1101053, 'F', 25, 'HW', 10, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_13시.csv, 7553182
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 13, 1101053, 1101053, 'F', 10, 'HE', 10, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_12시.csv, 7230410
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 12, 1101053, 1101053, 'F', 10, 'EE', 10, '12']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_11시.csv, 6476132
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 11, 1101053, 1101053, 'F', 10, 'HW', 10, '5.98']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_16시.csv, 7752327
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 16, 1101053, 1101053, 'F', 10, 'EE', 10, '30']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_15시.csv, 7470007
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 15, 1101053, 1101053, 'F', 10, 'EE', 10, '5.96']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_14시.csv, 7424223
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 14, 1101053, 1101053, 'F', 10, 'EE', 10, '11.98']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_19시.csv, 8215856
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 19, 1101053, 1101053, 'F', 10, 'EE', 10, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_18시.csv, 8970434
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 18, 1101053, 1101053, 'F', 15, 'EE', 30, '8.18']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_17시.csv, 8340841
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 17, 1101053, 1101053, 'F', 10, 'WH', 40, '5.93']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_23시.csv, 2679820
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 23, 1101053, 1101053, 'F', 20, 'EH', 10, '*']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_22시.csv, 4790339
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 22, 1101053, 1101053, 'F', 15, 'HE', 20, '4.04']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_21시.csv, 6032508
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 21, 1101053, 1101053, 'F', 20, 'EH', 30, '4.37']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_20시.csv, 6266993
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# [202201, '일', 20, 1101053, 1101053, 'F', 15, 'HH', 10, '4.02']

# %%
merge_file(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울 생활이동/2022/생활이동_행정동_202201/
# ==============================================================
# .csv, 생활이동_행정동_2022.01_00시.csv, 1647131
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_07시.csv, 2996195
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_03시.csv, 484715
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_06시.csv, 1696861
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_04시.csv, 495614
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_05시.csv, 887904
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_02시.csv, 656533
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_01시.csv, 1042219
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_10시.csv, 5827159
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_09시.csv, 5768466
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_08시.csv, 5214945
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_13시.csv, 7553181
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_12시.csv, 7230409
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_11시.csv, 6476131
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_16시.csv, 7752326
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_15시.csv, 7470006
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_14시.csv, 7424222
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_19시.csv, 8215855
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_18시.csv, 8970433
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_17시.csv, 8340840
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_23시.csv, 2679819
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_22시.csv, 4790338
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_21시.csv, 6032507
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.01_20시.csv, 6266992
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']

# %%
rf = read_file(path_dateset + path_sub + '생활이동_행정동_2022.01_2.csv')

# %%
rf.tail(5)
# Out:
#              대상연월 요일  도착시간  출발 행정동 코드  도착 행정동 코드 성별  나이 이동유형  평균 이동 시간(분)  \
# 115920796  202201  토    20      39000    1125073  M  35   EH           70
# 115920797  202201  토    20      39000    1125073  M  55   EE           50
# 115920798  202201  토    20      39000    1125074  F  40   EH           60
# 115920799  202201  토    20      39000    1125074  F  55   EH           60
# 115920800  202201  토    20      39000    1125074  M  55   EH           80
#
#           이동인구(합)
# 115920796       *
# 115920797    3.27
# 115920798    3.42
# 115920799    3.24
# 115920800    3.27

# %%
print(len(rf))
print(len(set(rf['도착시간'])))
