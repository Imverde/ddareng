# %%
import os
import pandas as pd

# %%
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
def extract_extension(file_path):
    _, file_extension = os.path.splitext(file_path)
    return file_extension

# %%
# extract_extension('G:/내 드라이브/DataSet/서울 생활이동/2023/생활이동_행정동_202302/생활이동_행정동_2023.02_00시.csv')

# %%
def extract_filename(file_path):
    file_name = os.path.basename(file_path)
    filename_without_extension, _ = os.path.splitext(file_name)
    return filename_without_extension

# %%
def read_file(file_path):
    extension = extract_extension(file_path)
    if ".xlsx" == extension:
        return pd.read_excel(file_path)
    if ".csv" == extension:
        try:
            return pd.read_csv(file_path, encoding='cp949')
        except:
            return pd.read_csv(file_path, encoding='utf-8')

# %%
def check_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    file_list.sort()
    print('path : ', path)
    
    for _, file in enumerate(file_lists):
        df = read_file(path + file)
    
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))
        print(list(df.iloc[1]))

# %%
def merge_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    file_list.sort()
    print('path : ', path)
    
    for i, file in enumerate(file_lists):
        df = read_file(path + file)
        
        if (i > 0):
            df = df.iloc[1:]

        # excel = excel.append(df , ignore_index=True) #파일 하나에 다른 파일 추가하기(파일 합치기)
        excel = pd.concat([excel, df], ignore_index=True)        
        
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))

    # excel.to_csv(path+'merge.csv',index=False,encoding='euc-kr')
    # excel.to_csv(path + '생활이동_행정동_2024.01.csv', index=False, encoding='cp949')
    excel.to_csv(path + '생활이동_행정동_2022.03.csv', index=False, encoding='utf-8')

# %%
def merge2_file(path_dateset, path_sub, new_filename = 'merge', columns = ""):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()
    print('path : ', path)
    for i, file in enumerate(file_lists):
        df = read_file(path + file)
        if (i > 0):
            if columns == "":
                df = df.iloc[1:]
            else:
                df = df.iloc[1:][columns]
        else:
            if columns == "":
                df = df
            else:
                df = df[columns]
        # excel = excel.append(df , ignore_index=True) #파일 하나에 다른 파일 추가하기(파일 합치기)
        excel = pd.concat([excel, df], ignore_index=True)
        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))
    # excel.to_csv(path+'merge.csv',index=False,encoding='euc-kr')
    # excel.to_csv(path + new_filename + '.csv', index=False, encoding='cp949')
    excel.to_csv(path + new_filename + '.csv', index=False, encoding='utf-8')

# %%
# 생활이동 데이터 배치
year = '2022'   # '2021', '2022', '2023'
months = ['03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
for month in months:
    path_sub = '서울 생활이동/' + year + '/생활이동_행정동_' + year + month + '/'
    try:
        print(path_sub)
        print('서울 생활이동_' + year + '.' + month)
        merge2_file(path_dateset, path_sub, '서울 생활이동_' + year + month, '')
    except:
        print('Err : ', path_sub)
# Out:
# 서울 생활이동/2022/생활이동_행정동_202203/
# 서울 생활이동_2022.03
# path :  G:/내 드라이브/DataSet/서울 생활이동/2022/생활이동_행정동_202203/
# ==============================================================
# .csv, 생활이동_행정동_2022.03_07시.csv, 3274658
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_06시.csv, 1790867
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_01시.csv, 1084359
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_02시.csv, 675407
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_04시.csv, 500832
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_03시.csv, 494534
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_05시.csv, 894825
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_00시.csv, 1993311
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_10시.csv, 5709340
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_09시.csv, 5794875
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_08시.csv, 5502798
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_12시.csv, 6775288
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_11시.csv, 6134296
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_13시.csv, 7108948
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_15시.csv, 7058005
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_14시.csv, 6970682
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_16시.csv, 7373422
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_17시.csv, 8037801
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_19시.csv, 8132688
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_18시.csv, 8770289
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_21시.csv, 5164651
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_20시.csv, 6244517
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_23시.csv, 3263675
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 생활이동_행정동_2022.03_22시.csv, 4433053
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# ==============================================================
# .csv, 서울 생활이동_202203.csv, 113183120
# ['대상연월', '요일', '도착시간', '출발 행정동 코드', '도착 행정동 코드', '성별', '나이', '이동유형', '평균 이동 시간(분)', '이동인구(합)']
# 서울 생활이동/2022/생활이동_행정동_202204/
# 서울 생활이동_2022.04
# path :  G:/내 드라이브/DataSet/서울 생활이동/2022/생활이동_행정동_