# %% [markdown]
# ### 라이브러리 임포트

# %%
import os
import pandas as pd

# %% [markdown]
# ### 기본경로 설정

# %%
path_dateset = 'G:/내 드라이브/DataSet/'

# %% [markdown]
# ### 확장자 가져오기 (Ex) .csv, .xlsx

# %%
def extract_extension(file_path):
    _, file_extension = os.path.splitext(file_path)
    return file_extension

# %%
extract_extension('G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여/반납 승객수 정보/tpss_bcycl_od_statnhm_202407.csv')
# Out:
# '.csv'

# %% [markdown]
# ### 파일명 가져오기

# %%
def extract_filename(file_path):
    file_name = os.path.basename(file_path)
    filename_without_extension, _ = os.path.splitext(file_name)
    return filename_without_extension

# %%
extract_filename('G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여/반납 승객수 정보/tpss_bcycl_od_statnhm_202407.csv')
# Out:
# 'tpss_bcycl_od_statnhm_202407'

# %% [markdown]
# ### 파일 읽기

# %%
def read_file(file_path):
    extension = extract_extension(file_path)
    if ".xlsx" == extension:
        return pd.read_excel(file_path)
    if ".csv" == extension:
        return pd.read_csv(file_path, encoding='cp949')

# %% [markdown]
# ### 특정 폴더의 csx, xlsx 파일들 확인

# %%
def check_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()

    print('path : ', path)

    for _, file in enumerate(file_lists):
        df = read_file(path + file)

        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))
        print(list(df.iloc[1]))

# %% [markdown]
# ### 특정 폴더의 csx, xlsx 파일들 합치기

# %%
def merge_file(path_dateset, path_sub):
    path = path_dateset + path_sub
    #파일 경로명 변경
    file_list = os.listdir(path)
    file_lists = [file for file in file_list if file.endswith((".csv", ".xlsx"))]
    excel = pd.DataFrame()

    print('path : ', path)

    for i, file in enumerate(file_lists):
        df = read_file(path + file)

        if (i > 0):
            df = df.iloc[1:]

        # excel = excel.append(df , ignore_index=True) #파일 하나에 다른 파일 추가하기(파일 합치기)
        excel = pd.concat([excel, df], ignore_index=True)

        print('==============================================================')
        print(extract_extension(file) + ', ' + file + ', ' + str(len(df)))
        print(list(df.columns))

    # excel.to_csv(path+'merge.csv',index=False,encoding='euc-kr')
    excel.to_csv(path + 'merge.csv', index=False, encoding='cp949')

# %%
path_sub = '서울시 따릉이 대여소별 대여 반납 승객수 정보/tpss_bcycl_od_statnhm_202307/'
check_file(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/tpss_bcycl_od_statnhm_202307/
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230703.csv, 332008
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230703, '출발시간', 0, 'ST-1606', '종로5·6가동_007_1', 'ST-1606', '종로5·6가동_007_1', 1, 0, 0]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230702.csv, 247020
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230702, '출발시간', 0, 'ST-1286', '중계2·3동_050_1', 'ST-1286', '중계2·3동_050_1', 1, 0, 0]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230722.csv, 165148
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230722, '출발시간', 0, 'ST-1459', '길음1동_056_1', 'ST-1459', '길음1동_056_1', 1, 0, 30]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230729.csv, 225682
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230729, '출발시간', 0, 'ST-2133', '우이동_028_2', 'ST-2133', '우이동_028_2', 1, 0, 0]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230728.csv, 297051
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230728, '출발시간', 0, 'ST-1249', '등촌3동_042_1', 'ST-1249', '등촌3동_042_1', 1, 0, 0]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230730.csv, 155533
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230730, '출발시간', 0, 'ST-1254', '방화1동_017_1', 'ST-1254', '방화1동_017_1', 1, 0, 88]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230731.csv, 282239
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230731, '출발시간', 0, 'ST-1447', '전농2동_037_1', 'ST-1447', '전농2동_037_1', 1, 0, 0]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230726.csv, 286671
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230726, '출발시간', 0, 'ST-2025', '가양2동_010_1', 'ST-2025', '가양2동_010_1', 2, 0, 0]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230725.csv, 311197
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230725, '출발시간', 0, 'ST-1366', '논현2동_017_1', 'ST-1366', '논현2동_017_1', 1, 0, 0]
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230727.csv, 311196
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20230727, '출발시간', 0, 'ST-1425', '중계본동_007_1', 'ST-1425', '중계본동_007_1', 1, 0, 0]

# %%
merge_file(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/tpss_bcycl_od_statnhm_202307/
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230703.csv, 332008
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230702.csv, 247019
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230701.csv, 259613
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230706.csv, 359139
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230705.csv, 332763
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230704.csv, 156845
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230710.csv, 309199
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230709.csv, 153610
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230708.csv, 286807
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230707.csv, 364744
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230717.csv, 289968
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230716.csv, 178372
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230712.csv, 329309
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230715.csv, 134549
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230714.csv, 48467
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230711.csv, 53999
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230713.csv, 81440
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230721.csv, 312050
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230720.csv, 330966
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230719.csv, 338571
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230718.csv, 231660
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230724.csv, 315441
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230723.csv, 61465
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230722.csv, 165147
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230729.csv, 225681
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230728.csv, 297050
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230730.csv, 155532
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230731.csv, 282238
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230726.csv, 286670
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230725.csv, 311196
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, tpss_bcycl_od_statnhm_20230727.csv, 311195
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# ==============================================================
# .csv, merge.csv, 7542712
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']

# %%
rf = read_file('G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/tpss_bcycl_od_statnhm_202307/merge.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 rf = read_file('G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/tpss_bcycl_od_statnhm_202407.csv/merge.csv')
#
# Cell In[14], line 6, in read_file(file_path)
#       4     return pd.read_excel(file_path)
#       5 if ".csv" == extension:
# ----> 6     return pd.read_csv(file_path, encoding='cp949')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/tpss_bcycl_od_statnhm_202407.csv/merge.csv'

# %%
rf.tail(5)

# %%
len(rf)
# Out:
# 33824107
